# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import random

MIN_LIST_LEN = 3
MAX_LIST_LEN = 3
MAX_STEPS = 16
EPS_START = 0.9
EPS_END = 0.1
EPS_DECAY = 2000
GAMMA = 0.9
NUM_EPISODES = 100000

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    '0': 2,
    '1': 3,
    '2': 4,
    '3': 5,
    '4': 6,
    '5': 7,
    '6': 8,
    '7': 9,
    'less': 10,
    'equal': 11,
    'more': 12,
    'len1': 13,
    'len2': 14,
    'len3': 15,
    'len4': 16,
    'len5': 17,
    'len6': 18,
    'len7': 19,
    'len8': 20,
}
inv_vocab = {v: k for k, v in vocab.items()}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.list = [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        initial_token = 'len{}'.format(self.length)
        return vocab[initial_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_list_len(self):
        return len(self.list)

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 >= self.length or index2 >= self.length or index1 < 0 or index2 < 0:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = -0.01
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = -0.02
            else:
                response_token = vocab['more']
                reward = -0.01
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = 10.0
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = 0.1
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -0.1
            else:
                reward = -0.01
            self.indices = None
        else:
            reward = -1.0
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()

# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=256):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=128, nhead=8, num_layers=3):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])

def equalize_nonzero_entries(probs):
    # Move tensor to CPU if it's on CUDA for compatibility
    probs = probs.cpu() if probs.is_cuda else probs
    
    # Find the non-zero entries
    non_zero_mask = probs != 0
    
    # Count the number of non-zero entries
    non_zero_count = non_zero_mask.sum().item()
    
    if non_zero_count == 0:
        raise ValueError("Tensor has no non-zero entries to equalize.")
    
    # Set each non-zero entry to an equal value that sums to 1
    equal_value = 1.0 / non_zero_count
    probs[non_zero_mask] = equal_value
    
    # Return the modified tensor, moving it back to CUDA if needed
    return probs.to(device)


# Training Loop
def train(verbose=False):
    torch.autograd.set_detect_anomaly(True)  # Detect anomalies in autograd
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4) 

    for episode in range(NUM_EPISODES):
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, current_list = env.reset()
        input_tokens = [initial_token_id]
        log_probs = []
        rewards = []
        state = 'expect_action'
        done = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            output = model(input_seq)  # (seq_len, batch_size, vocab_size)
            # Get logits for the last token
            logits = output[-1, 0, :]  # (vocab_size)

            # Check for NaNs in logits
            if torch.isnan(logits).any():
                print(f"Episode {episode}, NaNs in logits before masking.")
                break

            # Get valid tokens based on state
            def get_valid_tokens(state):
                action_tokens = [vocab['Comparison'], vocab['Swap']]
                index_tokens = [vocab[str(i)] for i in range(env.length)]
                if state == 'expect_action':
                    return action_tokens
                elif state == 'expect_index1':
                    return index_tokens
                elif state == 'expect_index2':
                    return index_tokens
                else:
                    # Handle unexpected states by defaulting to expect_action
                    return action_tokens

            valid_token_ids = get_valid_tokens(state)

            # Ensure valid_token_ids are within the vocab range
            if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                break

            # Mask invalid tokens
            mask_value = -1e9  # Use a large negative value instead of -inf
            mask = torch.full_like(logits, mask_value).to(device)
            mask[valid_token_ids] = 0
            masked_logits = logits + mask

            # Check for NaNs in masked_logits
            if torch.isnan(masked_logits).any():
                print(f"Episode {episode}, NaNs in masked_logits after masking.")
                break

            # Compute probabilities
            probs = F.softmax(masked_logits, dim=0)

            # Check for NaNs in probs
            if torch.isnan(probs).any():
                print(f"Episode {episode}, NaNs in probs after softmax.")
                break

            # Sample action. Have some chance to randomly pick a valid action.
            eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
            if random.random() < eps_threshold:
                probs = equalize_nonzero_entries(probs)
            try:
                m = torch.distributions.Categorical(probs)
                action_token = m.sample()
                log_prob = m.log_prob(action_token)
            except ValueError as e:
                print(f"Episode {episode}, error in sampling action: {e}")
                break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        # Can't perform Swap without a previous Comparison
                        reward = -1.0
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    if verbose:
                        print("Reward:", reward)
                    rewards.append(reward)
                    state = 'expect_action'
                else:
                    # Invalid action, end the episode
                    reward = -1.0
                    rewards.append(reward)
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                response_token, reward, done, current_list = env.step(action_tokens)
                if verbose:
                    print("Reward:", reward)
                rewards.append(reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                # Invalid state, end the episode
                reward = -1.0
                rewards.append(reward)
                done = True

        print(decode(input_tokens, inv_vocab))
        print(env.get_list())
                
        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns
        returns = []
        R = 0
        gamma = GAMMA
        for r in rewards[::-1]:
            R = r + gamma * R
            returns.insert(0, R)
        returns = torch.tensor(returns)

        # Check for NaNs in returns
        if torch.isnan(returns).any():
            print(f"Episode {episode}, NaNs in returns.")
            continue

        if returns.std() != 0 and not torch.isnan(returns.std()):
            returns = (returns - returns.mean()) / (returns.std() + 1e-9)
        else:
            pass #returns = returns - returns.mean()

        # Check for NaNs in standardized returns
        if torch.isnan(returns).any():
            print(f"Episode {episode}, NaNs in standardized returns.")
            continue

        # Compute loss
        loss = 0
        for log_prob, R in zip(log_probs, returns):
            loss -= log_prob * R

        # Check for NaNs in loss
        if torch.isnan(loss):
            print(f"Episode {episode}, NaN in loss.")
            continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        if episode % 1 == 0:
            print(f"Episode {episode}, loss: {loss.item():.4f}, total reward: {sum(rewards):.4f}")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# Using device: cuda
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# len3 Comparison 2 2 equal Swap Comparison 0 2 more Swap
# [12, 89, 96]
# Episode 0, loss: -0.0312, total reward: 9.9600
# len3 Swap
# [88, 93, 4]
# Episode 1, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [88, 24, 28]
# Episode 2, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 more Swap Swap
# [4, 83, 2]
# Episode 3, loss: -0.4682, total reward: -1.1100
# len3 Comparison 0 0 equal Comparison 1 0 more Swap Comparison 1 1 equal Comparison 0
# [81, 76, 96]
# Episode 4, loss: -0.3639, total reward: -0.1500
# len3 Comparison 1 2 more Swap
# [22, 75, 79]
# Episode 5, loss: 0.2867, total reward: 9.9900
# len3 Swap
# [36, 33, 41]
# Episode 6, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [62, 39, 46]
# Episode 7, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [61, 54, 96]
# Episode 8, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [40, 66, 70]
# Episode 9, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 less Swap Swap
# [37, 33, 60]
# Episode 10, loss: -0.3280, total reward: -0.9100
# len3 Comparison 1 2 less Swap Comparison 0 0 equal Swap Comparison 0 1 more Swap
# [15, 93, 14]
# Episode 11, loss: 0.1664, total reward: -0.0500
# len3 Comparison 1 0 more Comparison 2 2 equal Swap
# [6, 20, 33]
# Episode 12, loss: 0.3974, total reward: 9.9700
# len3 Comparison 2 0 more Swap Comparison 2 1 less Swap Swap
# [83, 43, 49]
# Episode 13, loss: 0.1610, total reward: -1.0200
# len3 Swap
# [22, 91, 31]
# Episode 14, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [21, 44, 13]
# Episode 15, loss: -0.9247, total reward: -1.0000
# len3 Swap
# [85, 36, 23]
# Episode 16, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Swap Swap
# [89, 48, 10]
# Episode 17, loss: -0.7946, total reward: -1.0300
# len3 Swap
# [49, 82, 79]
# Episode 18, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 0 1 less Swap Comparison 1
# [26, 12, 20]
# Episode 19, loss: 0.1996, total reward: -0.1500
# len3 Comparison 2 2 equal Comparison 2 0 less Swap Swap
# [48, 62, 50]
# Episode 20, loss: 0.2107, total reward: -0.9300
# len3 Swap
# [65, 46, 33]
# Episode 21, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [31, 84, 76]
# Episode 22, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Swap Comparison 2 0 more Comparison 1 2 more Swap
# [4, 41, 97]
# Episode 23, loss: -1.1793, total reward: 10.0700
# len3 Comparison 0 0 equal Swap Swap
# [20, 8, 10]
# Episode 24, loss: -0.3886, total reward: -1.0300
# len3 Comparison 2 0 more Comparison 2 1 more Comparison 2 2 equal Comparison 0 2 less
# [74, 68, 86]
# Episode 25, loss: -0.1819, total reward: -0.0500
# len3 Comparison 0 1 more Comparison 0 2 more Comparison 1 1 equal Swap Swap
# [33, 30, 29]
# Episode 26, loss: -0.2619, total reward: -1.0500
# len3 Comparison 2 1 less Swap Comparison 2 2 equal Comparison 0 0 equal Swap Comparison
# [93, 37, 100]
# Episode 27, loss: 0.0534, total reward: 0.0400
# len3 Swap
# [77, 74, 43]
# Episode 28, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [6, 46, 97]
# Episode 29, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 more Comparison 2 2 equal Comparison 1 0 more Comparison 2 1 less
# [36, 92, 14]
# Episode 30, loss: -0.7999, total reward: -0.0500
# len3 Swap
# [7, 69, 88]
# Episode 31, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [61, 92, 17]
# Episode 32, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 0 more Comparison 1 1 equal Comparison 2 2 equal Comparison 2 0 more
# [15, 62, 79]
# Episode 33, loss: -1.0321, total reward: -0.0600
# len3 Comparison 1 0 less Comparison 1 1 equal Swap Comparison 0 2 more Comparison 0
# [83, 56, 4]
# Episode 34, loss: -0.0354, total reward: -0.0500
# len3 Comparison 0 0 equal Swap Swap
# [42, 88, 67]
# Episode 35, loss: -1.0513, total reward: -1.0300
# len3 Comparison 2 2 equal Comparison 0 2 more Swap Comparison 2 0 more Comparison 2
# [71, 2, 97]
# Episode 36, loss: -0.2410, total reward: 0.0600
# len3 Swap
# [67, 40, 33]
# Episode 37, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [19, 62, 90]
# Episode 38, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Comparison 2 0 less Swap
# [1, 59, 72]
# Episode 39, loss: 1.0791, total reward: 9.9700
# len3 Comparison 0 0 equal Comparison 1 0 less Swap Swap
# [22, 90, 39]
# Episode 40, loss: 0.2107, total reward: -0.9300
# len3 Comparison 0 2 less Swap Swap
# [99, 21, 48]
# Episode 41, loss: -0.4682, total reward: -1.1100
# len3 Comparison 2 2 equal Comparison 1 0 more Swap Comparison 2 0 less Comparison 1
# [81, 51, 4]
# Episode 42, loss: 0.0983, total reward: -0.1400
# len3 Comparison 1 2 more Swap Swap
# [41, 38, 71]
# Episode 43, loss: -0.8876, total reward: -0.9100
# len3 Comparison 1 2 more Comparison 2 0 more Swap Comparison 0 1 less Comparison 0
# [46, 52, 10]
# Episode 44, loss: -0.0783, total reward: -0.1300
# len3 Comparison 0 1 less Comparison 2 1 less Comparison 0 2 more Comparison 2 1 less
# [11, 18, 4]
# Episode 45, loss: -0.0330, total reward: -0.0400
# len3 Comparison 1 2 less Comparison 0 2 more Comparison 2 2 equal Swap Swap
# [71, 11, 43]
# Episode 46, loss: -1.1347, total reward: -1.0500
# len3 Comparison 2 1 more Comparison 2 2 equal Swap
# [34, 72, 82]
# Episode 47, loss: 0.4383, total reward: 9.9700
# len3 Swap
# [30, 29, 78]
# Episode 48, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 0 more Swap Swap
# [36, 17, 4]
# Episode 49, loss: -0.4682, total reward: -1.1100
# len3 Comparison 1 0 more Swap Comparison 0 2 less Comparison 2 2 equal Comparison 1
# [77, 17, 94]
# Episode 50, loss: -0.0369, total reward: -0.1400
# len3 Swap
# [73, 18, 60]
# Episode 51, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [25, 44, 74]
# Episode 52, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 more Comparison 2 1 less Comparison 0 0 equal Swap Swap
# [64, 80, 18]
# Episode 53, loss: -0.2928, total reward: -1.0500
# len3 Swap
# [78, 87, 12]
# Episode 54, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 0 more Comparison 1 1 equal Swap Swap
# [6, 97, 31]
# Episode 55, loss: -0.2476, total reward: -1.0600
# len3 Swap
# [48, 36, 78]
# Episode 56, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Swap Comparison 1 2 less Comparison 0 2 less Swap Swap
# [78, 17, 20]
# Episode 57, loss: -0.8719, total reward: -1.1500
# len3 Swap
# [84, 5, 66]
# Episode 58, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [98, 84, 92]
# Episode 59, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 less Swap Swap
# [79, 54, 65]
# Episode 60, loss: -0.4682, total reward: -1.1100
# len3 Swap
# [32, 87, 61]
# Episode 61, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [9, 95, 14]
# Episode 62, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Swap Swap
# [68, 100, 10]
# Episode 63, loss: -0.3886, total reward: -1.0300
# len3 Swap
# [58, 31, 87]
# Episode 64, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Swap Comparison 2 2 equal Comparison 1 1 equal Comparison 0
# [6, 2, 24]
# Episode 65, loss: -0.0057, total reward: 0.0500
# len3 Comparison 0 1 less Swap Comparison 0 1 more Swap Comparison 2 2 equal Swap
# [27, 47, 31]
# Episode 66, loss: 0.3673, total reward: -0.0500
# len3 Swap
# [98, 91, 33]
# Episode 67, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 0 1 less Comparison 2 2 equal Swap
# [50, 51, 63]
# Episode 68, loss: -0.0889, total reward: 9.9500
# len3 Comparison 2 2 equal Swap Swap
# [70, 3, 100]
# Episode 69, loss: 0.6009, total reward: -1.0300
# len3 Swap
# [64, 44, 34]
# Episode 70, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 less Swap Swap
# [25, 16, 50]
# Episode 71, loss: -0.8882, total reward: -0.9100
# len3 Comparison 0 0 equal Swap Comparison 0 1 less Comparison 0 0 equal Comparison 0
# [32, 88, 19]
# Episode 72, loss: 1.0500, total reward: -0.0600
# len3 Comparison 2 1 less Comparison 0 1 less Swap Comparison 0 2 more Comparison 1
# [86, 70, 35]
# Episode 73, loss: -1.4510, total reward: -0.1300
# len3 Swap
# [100, 18, 33]
# Episode 74, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 more Comparison 1 2 less Swap Swap
# [49, 53, 36]
# Episode 75, loss: -0.1996, total reward: -1.1200
# len3 Comparison 1 1 equal Comparison 0 2 less Comparison 0 1 less Swap Swap
# [84, 78, 96]
# Episode 76, loss: -0.1404, total reward: -1.1400
# len3 Comparison 1 1 equal Swap Comparison 1 0 less Comparison 1 0 less Comparison 2
# [76, 68, 7]
# Episode 77, loss: 0.1149, total reward: -0.0500
# len3 Swap
# [91, 90, 52]
# Episode 78, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [54, 94, 77]
# Episode 79, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [62, 28, 40]
# Episode 80, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [79, 42, 80]
# Episode 81, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 0 less Swap
# [10, 41, 96]
# Episode 82, loss: 0.2867, total reward: 9.9900
# len3 Comparison 0 0 equal Swap Swap
# [95, 73, 46]
# Episode 83, loss: -0.3886, total reward: -1.0300
# len3 Comparison 0 0 equal Comparison 1 2 less Comparison 1 2 less Comparison 0 0 equal
# [20, 48, 62]
# Episode 84, loss: -0.5772, total reward: -0.0600
# len3 Comparison 0 1 less Comparison 0 0 equal Comparison 1 1 equal Comparison 0 1 less
# [23, 83, 80]
# Episode 85, loss: -1.0399, total reward: -0.0600
# len3 Comparison 1 1 equal Swap Swap
# [54, 69, 42]
# Episode 86, loss: -0.3886, total reward: -1.0300
# len3 Comparison 2 1 less Swap Comparison 2 0 more Comparison 0 2 less Comparison 2
# [59, 20, 63]
# Episode 87, loss: 0.0365, total reward: 0.0700
# len3 Comparison 1 2 less Swap Swap
# [61, 52, 22]
# Episode 88, loss: -0.4682, total reward: -1.1100
# len3 Swap
# [28, 78, 17]
# Episode 89, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 less Comparison 2 2 equal Swap Swap
# [80, 54, 85]
# Episode 90, loss: 0.8712, total reward: -1.0400
# len3 Comparison 0 1 more Comparison 2 1 more Comparison 0 1 more Comparison 1 2 less
# [72, 29, 54]
# Episode 91, loss: -0.8654, total reward: -0.0400
# len3 Comparison 2 1 less Swap Comparison 2 0 more Swap Swap
# [100, 51, 53]
# Episode 92, loss: 0.2162, total reward: -1.0200
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 0 1 more Swap
# [3, 22, 64]
# Episode 93, loss: -0.8619, total reward: 9.9500
# len3 Swap
# [52, 40, 92]
# Episode 94, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Swap Swap
# [7, 3, 69]
# Episode 95, loss: -0.3280, total reward: -0.9100
# len3 Comparison 0 1 less Swap Swap
# [34, 4, 46]
# Episode 96, loss: -0.4682, total reward: -1.1100
# len3 Comparison 1 0 more Comparison 2 0 less Comparison 2 2 equal Swap Comparison 0
# [61, 62, 18]
# Episode 97, loss: -0.1819, total reward: -0.0500
# len3 Comparison 1 2 more Comparison 0 0 equal Comparison 2 0 less Swap
# [23, 88, 96]
# Episode 98, loss: -0.3056, total reward: 9.9600
# len3 Comparison 2 2 equal Comparison 1 1 equal Comparison 0 2 less Swap Comparison 0
# [94, 73, 88]
# Episode 99, loss: 0.4445, total reward: -0.1500
# len3 Comparison 1 2 less Comparison 2 0 less Swap Swap
# [77, 66, 84]
# Episode 100, loss: -0.4419, total reward: -0.9200
# len3 Comparison 2 2 equal Swap Swap
# [32, 19, 85]
# Episode 101, loss: -0.3886, total reward: -1.0300
# len3 Comparison 1 0 less Swap Comparison 1 1 equal Swap Comparison 1 0 more Comparison
# [1, 6, 3]
# Episode 102, loss: -0.5243, total reward: 0.0500
# len3 Swap
# [80, 33, 37]
# Episode 103, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [29, 33, 76]
# Episode 104, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Comparison 1 1 equal Swap Comparison 1 0 less Comparison 0
# [83, 76, 2]
# Episode 105, loss: 0.0765, total reward: -0.0600
# len3 Comparison 2 1 less Swap
# [19, 75, 92]
# Episode 106, loss: 0.2867, total reward: 9.9900
# len3 Swap
# [89, 10, 63]
# Episode 107, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 equal Comparison 1 1 equal Comparison 1 0 more Comparison 0 0 equal
# [28, 31, 31]
# Episode 108, loss: 0.0835, total reward: -0.0700
# len3 Comparison 2 0 more Swap Comparison 2 2 equal Comparison 2 0 less Comparison 2
# [51, 48, 30]
# Episode 109, loss: -0.0715, total reward: -0.1400
# len3 Comparison 1 1 equal Comparison 2 1 less Comparison 1 2 more Comparison 1 2 more
# [65, 90, 19]
# Episode 110, loss: 0.1149, total reward: -0.0500
# len3 Swap
# [82, 1, 2]
# Episode 111, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 less Swap Comparison 0 1 more Comparison 2 2 equal Comparison 1
# [59, 16, 77]
# Episode 112, loss: 0.0365, total reward: 0.0600
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Swap Comparison 1 0 less Comparison
# [45, 1, 6]
# Episode 113, loss: -0.0249, total reward: -0.0700
# len3 Swap
# [48, 27, 47]
# Episode 114, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [23, 14, 35]
# Episode 115, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Swap Comparison 0 2 less Comparison 0 2 less Swap Comparison
# [51, 61, 14]
# Episode 116, loss: 0.3627, total reward: -0.1500
# len3 Swap
# [58, 68, 41]
# Episode 117, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Swap
# [12, 16, 21]
# Episode 118, loss: 0.4303, total reward: 9.9600
# len3 Comparison 1 2 more Comparison 2 1 less Swap Comparison 2 0 less Comparison 0
# [94, 8, 77]
# Episode 119, loss: -0.3634, total reward: 0.0700
# len3 Comparison 0 0 equal Comparison 1 2 more Swap Swap
# [98, 49, 95]
# Episode 120, loss: 0.2107, total reward: -0.9300
# len3 Comparison 2 0 less Comparison 2 1 less Comparison 1 2 more Comparison 2 0 less
# [27, 68, 26]
# Episode 121, loss: 0.3895, total reward: -0.0400
# len3 Swap
# [81, 20, 34]
# Episode 122, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 less Swap Comparison 2 1 less Swap Swap
# [43, 15, 37]
# Episode 123, loss: 1.5203, total reward: -1.0200
# len3 Swap
# [38, 13, 5]
# Episode 124, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [58, 43, 71]
# Episode 125, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Swap Comparison 2 2 equal Swap Swap
# [62, 40, 13]
# Episode 126, loss: 1.2317, total reward: -1.0600
# len3 Comparison 1 0 more Swap Comparison 2 2 equal Swap Comparison 0 1 more Comparison
# [15, 13, 67]
# Episode 127, loss: -0.2576, total reward: -0.1500
# len3 Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal Swap Comparison 0
# [68, 40, 70]
# Episode 128, loss: -1.0397, total reward: -0.0600
# len3 Comparison 2 1 less Comparison 1 1 equal Comparison 2 1 less Swap Comparison 2
# [49, 18, 76]
# Episode 129, loss: 0.4973, total reward: 0.0600
# len3 Comparison 2 1 more Comparison 2 2 equal Swap Comparison 2 0 less Comparison 0
# [25, 6, 16]
# Episode 130, loss: -0.0354, total reward: -0.0500
# len3 Swap
# [85, 80, 37]
# Episode 131, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 more Comparison 2 2 equal Comparison 1 1 equal Comparison 0 2 less
# [31, 63, 85]
# Episode 132, loss: -0.1473, total reward: -0.0600
# len3 Swap
# [39, 6, 99]
# Episode 133, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 more Swap Swap
# [86, 1, 67]
# Episode 134, loss: -0.3280, total reward: -0.9100
# len3 Comparison 2 1 less Swap Swap
# [60, 7, 69]
# Episode 135, loss: -1.0954, total reward: -0.9100
# len3 Comparison 0 2 more Comparison 1 1 equal Swap Comparison 2 0 less Swap Comparison
# [65, 14, 67]
# Episode 136, loss: -0.2094, total reward: 0.0500
# len3 Comparison 0 0 equal Comparison 2 1 more Comparison 2 0 more Comparison 0 0 equal
# [37, 38, 41]
# Episode 137, loss: 0.1275, total reward: -0.0600
# len3 Swap
# [68, 97, 85]
# Episode 138, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [15, 9, 95]
# Episode 139, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Swap Comparison 1 2 more Comparison 0 0 equal Swap Swap
# [13, 95, 46]
# Episode 140, loss: 0.4217, total reward: -1.0700
# len3 Swap
# [84, 78, 30]
# Episode 141, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [27, 23, 53]
# Episode 142, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 less Comparison 2 1 more Swap Comparison 1 0 less Comparison 0
# [86, 85, 22]
# Episode 143, loss: -0.4124, total reward: -0.1300
# len3 Comparison 2 2 equal Swap Comparison 1 0 less Comparison 0 0 equal Comparison 2
# [79, 1, 11]
# Episode 144, loss: 0.2278, total reward: -0.0600
# len3 Swap
# [34, 98, 73]
# Episode 145, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 1 1 equal Swap Comparison 2 0 less Swap
# [43, 56, 80]
# Episode 146, loss: 0.3049, total reward: 9.9400
# len3 Comparison 2 0 less Swap Comparison 2 2 equal Swap Comparison 1 2 less Comparison
# [65, 18, 95]
# Episode 147, loss: -0.5242, total reward: 0.0500
# len3 Comparison 1 2 less Comparison 2 2 equal Swap Comparison 0 1 more Swap Comparison
# [44, 61, 51]
# Episode 148, loss: -0.2763, total reward: 0.0500
# len3 Swap
# [47, 82, 18]
# Episode 149, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Swap Swap
# [28, 98, 1]
# Episode 150, loss: -0.3886, total reward: -1.0300
# len3 Swap
# [91, 50, 18]
# Episode 151, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [10, 63, 74]
# Episode 152, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 1 2 more Comparison 2 0 less Swap
# [23, 52, 70]
# Episode 153, loss: -0.0112, total reward: 9.9600
# len3 Swap
# [80, 52, 8]
# Episode 154, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [86, 42, 77]
# Episode 155, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [46, 25, 68]
# Episode 156, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 1 1 equal Swap Swap
# [91, 61, 31]
# Episode 157, loss: -0.7048, total reward: -1.0500
# len3 Comparison 0 2 more Swap Comparison 0 1 less Swap Swap
# [49, 5, 26]
# Episode 158, loss: 1.0442, total reward: -1.0200
# len3 Comparison 2 1 more Comparison 0 0 equal Swap
# [14, 17, 71]
# Episode 159, loss: 1.0885, total reward: 9.9700
# len3 Comparison 1 2 more Swap Comparison 1 2 less Comparison 2 1 more Swap Swap
# [10, 58, 5]
# Episode 160, loss: -1.9926, total reward: -1.0300
# len3 Comparison 0 2 less Comparison 2 2 equal Swap
# [33, 44, 63]
# Episode 161, loss: 0.3974, total reward: 9.9700
# len3 Comparison 0 2 less Swap Swap
# [59, 98, 19]
# Episode 162, loss: -1.2679, total reward: -1.1100
# len3 Swap
# [85, 53, 54]
# Episode 163, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 2 0 less Swap
# [39, 52, 52]
# Episode 164, loss: 1.0804, total reward: 9.9700
# len3 Swap
# [22, 98, 23]
# Episode 165, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [96, 47, 34]
# Episode 166, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [37, 91, 33]
# Episode 167, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Swap Comparison 1 0 less Comparison 0 0 equal Swap Comparison
# [80, 64, 85]
# Episode 168, loss: -0.1888, total reward: -0.0700
# len3 Comparison 1 2 less Swap Comparison 0 1 less Comparison 0 1 less Comparison 0
# [32, 61, 17]
# Episode 169, loss: 0.1587, total reward: -0.1300
# len3 Swap
# [76, 42, 82]
# Episode 170, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Swap Swap
# [76, 18, 77]
# Episode 171, loss: -0.3280, total reward: -0.9100
# len3 Comparison 0 0 equal Comparison 0 0 equal Comparison 1 0 more Comparison 0 2 more
# [60, 65, 41]
# Episode 172, loss: -0.4667, total reward: -0.0600
# len3 Comparison 1 1 equal Comparison 0 1 less Comparison 2 0 more Swap Comparison 2
# [57, 55, 12]
# Episode 173, loss: 0.0592, total reward: -0.1400
# len3 Comparison 0 1 more Comparison 0 0 equal Comparison 1 1 equal Swap Swap
# [95, 85, 46]
# Episode 174, loss: -0.2669, total reward: -1.0600
# len3 Comparison 0 1 more Comparison 1 2 less Comparison 1 0 less Comparison 2 2 equal
# [83, 35, 43]
# Episode 175, loss: 0.7426, total reward: -0.0500
# len3 Comparison 2 0 more Comparison 0 1 less Comparison 2 0 more Comparison 2 0 more
# [61, 98, 87]
# Episode 176, loss: -0.3454, total reward: -0.0400
# len3 Swap
# [78, 58, 1]
# Episode 177, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [67, 25, 9]
# Episode 178, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 less Comparison 0 0 equal Comparison 0 1 less Swap Comparison 0
# [69, 38, 65]
# Episode 179, loss: -0.0369, total reward: -0.1400
# len3 Comparison 1 1 equal Comparison 1 1 equal Comparison 0 2 less Comparison 1 0 more
# [68, 70, 96]
# Episode 180, loss: -0.6358, total reward: -0.0600
# len3 Comparison 0 0 equal Swap Swap
# [21, 90, 25]
# Episode 181, loss: -1.0522, total reward: -1.0300
# len3 Comparison 0 1 less Comparison 1 1 equal Swap Comparison 0 2 less Swap Comparison
# [74, 86, 25]
# Episode 182, loss: 0.8887, total reward: -0.1500
# len3 Comparison 2 0 more Comparison 0 1 less Swap Swap
# [28, 21, 72]
# Episode 183, loss: -0.5393, total reward: -1.1200
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Comparison 0 1 less Comparison 1
# [14, 92, 2]
# Episode 184, loss: 0.0494, total reward: -0.0600
# len3 Swap
# [21, 69, 2]
# Episode 185, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 1 1 equal Swap Comparison 0 1 less Swap Swap
# [78, 11, 72]
# Episode 186, loss: -0.1636, total reward: -1.1600
# len3 Swap
# [21, 77, 95]
# Episode 187, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 1 more Comparison 2 0 less Comparison 2 0 less Comparison 1 0 less
# [100, 82, 48]
# Episode 188, loss: -0.8647, total reward: -0.0400
# len3 Comparison 2 2 equal Comparison 2 1 more Comparison 0 2 less Comparison 0 0 equal
# [26, 31, 73]
# Episode 189, loss: -0.5762, total reward: -0.0600
# len3 Comparison 2 0 less Comparison 1 0 equal Swap Swap
# [46, 46, 38]
# Episode 190, loss: 0.0325, total reward: -1.0400
# len3 Comparison 1 2 more Swap
# [10, 16, 61]
# Episode 191, loss: 0.2867, total reward: 9.9900
# len3 Comparison 0 0 equal Comparison 2 2 equal Swap Comparison 0 2 less Comparison 1
# [2, 93, 62]
# Episode 192, loss: 0.7107, total reward: -0.0600
# len3 Swap
# [52, 65, 92]
# Episode 193, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Swap
# [42, 69, 81]
# Episode 194, loss: 0.2867, total reward: 9.9800
# len3 Comparison 0 2 less Swap Comparison 0 0 equal Comparison 1 0 more Swap Comparison
# [96, 19, 18]
# Episode 195, loss: 1.7298, total reward: -0.2400
# len3 Comparison 1 0 more Swap Swap
# [68, 5, 15]
# Episode 196, loss: -0.1223, total reward: -1.1100
# len3 Comparison 1 0 less Swap
# [41, 44, 92]
# Episode 197, loss: 0.7758, total reward: 9.9900
# len3 Comparison 2 2 equal Comparison 1 1 equal Swap Comparison 0 1 more Swap Swap
# [13, 38, 31]
# Episode 198, loss: -0.4281, total reward: -0.9600
# len3 Comparison 0 0 equal Swap
# [34, 77, 80]
# Episode 199, loss: 0.2867, total reward: 9.9800
# len3 Swap
# [27, 45, 88]
# Episode 200, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [98, 62, 15]
# Episode 201, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 less Comparison 2 1 more Comparison 2 2 equal Swap Comparison 2
# [35, 29, 75]
# Episode 202, loss: -1.1367, total reward: -0.0500
# len3 Comparison 2 0 more Comparison 0 0 equal Swap Comparison 1 2 more Comparison 0
# [50, 83, 66]
# Episode 203, loss: 0.6789, total reward: -0.0500
# len3 Swap
# [30, 84, 45]
# Episode 204, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [52, 88, 45]
# Episode 205, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 less Swap Swap
# [1, 17, 16]
# Episode 206, loss: -0.4682, total reward: -1.1100
# len3 Comparison 2 1 more Comparison 1 1 equal Comparison 0 2 less Comparison 2 0 more
# [54, 12, 57]
# Episode 207, loss: -0.0354, total reward: -0.0500
# len3 Comparison 0 1 more Swap Swap
# [28, 77, 70]
# Episode 208, loss: -0.8877, total reward: -0.9100
# len3 Swap
# [99, 24, 78]
# Episode 209, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Swap
# [36, 58, 100]
# Episode 210, loss: 0.2867, total reward: 9.9800
# len3 Comparison 2 0 less Swap Comparison 1 2 more Comparison 0 0 equal Swap Swap
# [25, 86, 48]
# Episode 211, loss: 0.4495, total reward: -0.9500
# len3 Comparison 0 1 less Comparison 1 2 less Swap Comparison 0 2 less Swap Comparison
# [42, 61, 29]
# Episode 212, loss: 0.1492, total reward: -0.2300
# len3 Swap
# [52, 92, 27]
# Episode 213, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Swap Comparison 1 2 more Comparison 0 0 equal Swap Swap
# [25, 91, 61]
# Episode 214, loss: -1.0485, total reward: -0.9500
# len3 Swap
# [63, 57, 44]
# Episode 215, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 less Swap Comparison 2 2 equal Comparison 2 2 equal Swap Swap
# [9, 35, 8]
# Episode 216, loss: -4.0336, total reward: -1.1600
# len3 Comparison 0 0 equal Comparison 0 0 equal Swap Comparison 0 2 more Comparison 2
# [92, 70, 38]
# Episode 217, loss: 0.3099, total reward: -0.0600
# len3 Comparison 0 0 equal Swap Comparison 2 1 less Comparison 2 0 less Swap
# [37, 96, 98]
# Episode 218, loss: -1.2134, total reward: 9.9500
# len3 Comparison 0 0 equal Swap
# [7, 65, 95]
# Episode 219, loss: 0.0166, total reward: 9.9800
# len3 Comparison 1 1 equal Comparison 2 0 more Swap Comparison 2 0 less Swap Comparison
# [53, 94, 58]
# Episode 220, loss: -0.0355, total reward: -0.0400
# len3 Comparison 2 0 more Comparison 2 0 more Swap Swap
# [66, 75, 50]
# Episode 221, loss: 0.6534, total reward: -1.1200
# len3 Comparison 1 2 less Comparison 1 2 less Comparison 0 0 equal Swap Comparison 0
# [42, 35, 43]
# Episode 222, loss: -0.1819, total reward: -0.0500
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Comparison 0 2 less Comparison 2
# [8, 2, 51]
# Episode 223, loss: 0.8600, total reward: -0.0600
# len3 Comparison 1 2 more Swap Comparison 1 2 less Comparison 1 0 less Comparison 0
# [90, 10, 49]
# Episode 224, loss: 0.0365, total reward: 0.0700
# len3 Swap
# [84, 19, 96]
# Episode 225, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 1 more Comparison 2 1 more Comparison 2 0 less Comparison 0 0 equal
# [76, 48, 71]
# Episode 226, loss: 0.7415, total reward: -0.0500
# len3 Swap
# [97, 50, 27]
# Episode 227, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 less Comparison 1 2 less Swap Comparison 0 0 equal Comparison 1
# [34, 99, 92]
# Episode 228, loss: -0.0981, total reward: -0.1400
# len3 Comparison 2 0 less Comparison 2 0 less Comparison 0 1 less Comparison 1 1 equal
# [72, 90, 42]
# Episode 229, loss: -0.0897, total reward: -0.0500
# len3 Swap
# [54, 94, 27]
# Episode 230, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [75, 84, 71]
# Episode 231, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Swap Comparison 2 0 less Comparison 0 1 less Comparison 0
# [84, 93, 58]
# Episode 232, loss: 1.0257, total reward: -0.0500
# len3 Comparison 1 2 less Comparison 2 0 less Comparison 2 0 less Swap Comparison 2
# [94, 48, 95]
# Episode 233, loss: -0.8637, total reward: 0.0700
# len3 Comparison 0 2 more Comparison 1 0 less Swap Comparison 2 0 less Comparison 2
# [79, 86, 38]
# Episode 234, loss: 1.0229, total reward: 0.0700
# len3 Swap
# [60, 60, 25]
# Episode 235, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [48, 22, 26]
# Episode 236, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 less Comparison 1 0 more Comparison 1 2 more Swap
# [31, 61, 96]
# Episode 237, loss: -0.8645, total reward: 9.9700
# len3 Comparison 0 0 equal Comparison 1 2 less Swap Comparison 2 2 equal Comparison 0
# [99, 98, 75]
# Episode 238, loss: -0.3639, total reward: -0.1500
# len3 Swap
# [83, 2, 37]
# Episode 239, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 more Swap
# [10, 33, 85]
# Episode 240, loss: 0.2867, total reward: 9.9900
# len3 Swap
# [16, 23, 24]
# Episode 241, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [32, 68, 82]
# Episode 242, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 more Swap Comparison 2 1 more Comparison 0 2 more Comparison 2
# [57, 27, 48]
# Episode 243, loss: -0.8928, total reward: -0.1300
# len3 Comparison 2 2 equal Swap Swap
# [11, 6, 36]
# Episode 244, loss: -0.3886, total reward: -1.0300
# len3 Comparison 1 0 more Comparison 0 0 equal Comparison 0 2 more Comparison 2 1 less
# [20, 88, 9]
# Episode 245, loss: -0.0354, total reward: -0.0500
# len3 Swap
# [77, 57, 81]
# Episode 246, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 more Swap Comparison 1 2 more Swap Comparison 0 0 equal Swap
# [31, 6, 9]
# Episode 247, loss: -0.4801, total reward: -0.0500
# len3 Comparison 0 0 equal Comparison 2 2 equal Swap Comparison 0 0 equal Swap Swap
# [36, 23, 97]
# Episode 248, loss: -0.6862, total reward: -1.0800
# len3 Swap
# [95, 25, 81]
# Episode 249, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 0 1 less Swap Comparison 1 1 equal Comparison 1
# [13, 1, 34]
# Episode 250, loss: -0.3639, total reward: -0.1500
# len3 Comparison 1 2 less Swap Swap
# [69, 63, 61]
# Episode 251, loss: 0.0517, total reward: -1.1100
# len3 Comparison 2 0 less Swap
# [69, 77, 82]
# Episode 252, loss: 0.2867, total reward: 9.9900
# len3 Comparison 2 2 equal Swap
# [51, 69, 86]
# Episode 253, loss: 0.2867, total reward: 9.9800
# len3 Swap
# [9, 98, 98]
# Episode 254, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 0 less Swap Swap
# [50, 87, 28]
# Episode 255, loss: -0.3280, total reward: -0.9100
# len3 Comparison 2 0 less Comparison 2 2 equal Swap Comparison 0 1 less Swap Swap
# [93, 88, 39]
# Episode 256, loss: -0.4099, total reward: -1.1500
# len3 Comparison 2 0 less Comparison 1 2 more Swap Comparison 0 0 equal Comparison 2
# [20, 17, 62]
# Episode 257, loss: 1.5153, total reward: 0.0600
# len3 Comparison 0 1 more Comparison 2 0 less Swap Comparison 0 2 less Swap Comparison
# [80, 7, 20]
# Episode 258, loss: 0.9636, total reward: -0.0300
# len3 Comparison 0 1 more Comparison 1 2 less Swap Comparison 0 1 more Comparison 1
# [95, 20, 7]
# Episode 259, loss: 0.4643, total reward: -0.1300
# len3 Comparison 0 2 more Comparison 0 2 more Swap Comparison 2 1 more Comparison 0
# [85, 55, 96]
# Episode 260, loss: 0.5031, total reward: 0.0700
# len3 Comparison 1 2 more Comparison 2 0 less Swap
# [6, 39, 73]
# Episode 261, loss: 1.0590, total reward: 9.9800
# len3 Comparison 1 2 more Swap Swap
# [91, 10, 86]
# Episode 262, loss: -0.8724, total reward: -0.9100
# len3 Comparison 0 2 less Comparison 2 1 more Swap Comparison 2 1 less Swap
# [50, 75, 80]
# Episode 263, loss: 0.2307, total reward: 9.8700
# len3 Comparison 0 0 equal Comparison 0 0 equal Swap Swap
# [69, 80, 8]
# Episode 264, loss: 0.3839, total reward: -1.0500
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Swap Swap
# [66, 56, 34]
# Episode 265, loss: 0.2985, total reward: -1.0600
# len3 Comparison 0 2 less Swap Comparison 0 0 equal Swap Comparison 1 0 more Comparison
# [45, 54, 9]
# Episode 266, loss: -0.2576, total reward: -0.1500
# len3 Comparison 2 2 equal Comparison 2 0 more Comparison 0 0 equal Swap
# [49, 60, 65]
# Episode 267, loss: -0.1135, total reward: 9.9500
# len3 Comparison 0 2 equal Comparison 0 0 equal Swap Comparison 1 0 less Comparison 2
# [71, 12, 71]
# Episode 268, loss: 0.4871, total reward: -0.0600
# len3 Swap
# [59, 47, 97]
# Episode 269, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [40, 24, 59]
# Episode 270, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [95, 89, 65]
# Episode 271, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [63, 96, 4]
# Episode 272, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 less Comparison 1 0 more Swap Comparison 2 0 less Comparison 1
# [99, 16, 23]
# Episode 273, loss: -0.1521, total reward: -0.1300
# len3 Swap
# [3, 18, 32]
# Episode 274, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [35, 79, 50]
# Episode 275, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 more Comparison 1 1 equal Comparison 0 0 equal Comparison 0 1 less
# [13, 74, 76]
# Episode 276, loss: -0.1473, total reward: -0.0600
# len3 Comparison 1 0 more Comparison 1 2 less Comparison 0 1 less Swap Comparison 2
# [54, 46, 67]
# Episode 277, loss: -0.3584, total reward: -0.1300
# len3 Comparison 2 1 less Swap Comparison 2 1 more Swap Comparison 2 0 less Comparison
# [53, 35, 27]
# Episode 278, loss: -0.0898, total reward: -0.0300
# len3 Swap
# [39, 41, 35]
# Episode 279, loss: -0.4453, total reward: -1.0000
# len3 Swap
# [95, 76, 34]
# Episode 280, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Swap Comparison 0 1 less Swap
# [86, 23, 48]
# Episode 281, loss: 0.5352, total reward: -0.1700
# len3 Comparison 1 2 more Swap Comparison 0 0 equal Swap Comparison 0 0 equal Comparison
# [97, 15, 29]
# Episode 282, loss: 0.0017, total reward: 0.0400
# len3 Comparison 0 0 equal Comparison 2 0 less Comparison 1 0 less Comparison 1 0 less
# [93, 36, 69]
# Episode 283, loss: 0.1149, total reward: -0.0500
# len3 Comparison 0 2 more Comparison 1 2 more Swap Comparison 0 0 equal Comparison 1
# [89, 48, 49]
# Episode 284, loss: 1.0123, total reward: 0.0600
# len3 Swap
# [99, 95, 85]
# Episode 285, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [28, 69, 94]
# Episode 286, loss: -0.8104, total reward: -1.0000
# len3 Comparison 1 1 equal Swap
# [31, 35, 99]
# Episode 287, loss: 0.2867, total reward: 9.9800
# len3 Comparison 0 2 less Comparison 2 1 more Swap Comparison 0 0 equal Swap Comparison
# [65, 96, 29]
# Episode 288, loss: -0.0971, total reward: -0.1500
# len3 Swap
# [40, 62, 75]
# Episode 289, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Swap
# [12, 36, 41]
# Episode 290, loss: 0.6286, total reward: 9.9900
# len3 Comparison 0 0 equal Swap Swap
# [43, 20, 52]
# Episode 291, loss: 0.7485, total reward: -1.0300
# len3 Comparison 0 2 less Comparison 2 0 more Swap Swap
# [87, 87, 36]
# Episode 292, loss: -0.7299, total reward: -1.1200
# len3 Swap
# [18, 40, 14]
# Episode 293, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 less Comparison 0 2 more Comparison 0 0 equal Comparison 0 2 more
# [78, 7, 77]
# Episode 294, loss: -0.8156, total reward: -0.0500
# len3 Comparison 2 2 equal Swap Comparison 0 0 equal Swap Comparison 2 0 more Comparison
# [76, 30, 95]
# Episode 295, loss: -0.2714, total reward: -0.0700
# len3 Swap
# [39, 12, 4]
# Episode 296, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [96, 33, 21]
# Episode 297, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 0 1 more Comparison 2 2 equal Comparison 1 1 equal
# [76, 22, 63]
# Episode 298, loss: 0.0508, total reward: -0.0700
# len3 Swap
# [100, 94, 83]
# Episode 299, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [40, 53, 57]
# Episode 300, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Comparison 0 2 more Swap Swap
# [76, 4, 87]
# Episode 301, loss: -0.0237, total reward: -0.9200
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Comparison 2 0 less Swap
# [17, 25, 84]
# Episode 302, loss: -0.2949, total reward: 9.9400
# len3 Swap
# [59, 21, 2]
# Episode 303, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 less Comparison 0 2 more Swap Comparison 0 2 less Comparison 1
# [59, 24, 70]
# Episode 304, loss: 0.5464, total reward: 0.0700
# len3 Swap
# [14, 99, 94]
# Episode 305, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [80, 60, 31]
# Episode 306, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 more Swap Swap
# [23, 33, 15]
# Episode 307, loss: 0.1646, total reward: -1.1100
# len3 Swap
# [71, 17, 74]
# Episode 308, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [49, 59, 91]
# Episode 309, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [67, 94, 87]
# Episode 310, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 less Comparison 0 0 equal Comparison 0 1 less Swap Swap
# [61, 40, 15]
# Episode 311, loss: -1.0508, total reward: -1.1400
# len3 Comparison 0 1 less Comparison 0 0 equal Swap Comparison 1 0 more Comparison 1
# [20, 37, 34]
# Episode 312, loss: -0.7786, total reward: -0.0500
# len3 Comparison 2 0 more Comparison 2 0 more Swap Swap
# [85, 82, 68]
# Episode 313, loss: -0.1996, total reward: -1.1200
# len3 Comparison 1 1 equal Swap
# [3, 23, 31]
# Episode 314, loss: 0.2867, total reward: 9.9800
# len3 Comparison 0 2 less Comparison 1 2 less Comparison 2 0 more Comparison 0 1 more
# [71, 9, 74]
# Episode 315, loss: 0.3821, total reward: -0.0400
# len3 Comparison 2 0 more Swap Swap
# [94, 52, 87]
# Episode 316, loss: -0.4682, total reward: -1.1100
# len3 Comparison 1 0 more Swap Swap
# [51, 30, 97]
# Episode 317, loss: 0.1609, total reward: -1.1100
# len3 Comparison 0 1 more Swap Comparison 2 1 less Comparison 2 2 equal Swap Comparison
# [50, 74, 1]
# Episode 318, loss: -0.9701, total reward: 0.0500
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Swap Comparison 1 1 equal Comparison
# [45, 27, 23]
# Episode 319, loss: 0.8247, total reward: -0.0800
# len3 Comparison 0 0 equal Comparison 0 2 less Swap Swap
# [84, 34, 16]
# Episode 320, loss: -0.4956, total reward: -1.1300
# len3 Swap
# [13, 80, 84]
# Episode 321, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 less Comparison 2 0 more Comparison 0 1 less Comparison 0 1 less
# [9, 91, 69]
# Episode 322, loss: -0.3937, total reward: -0.0400
# len3 Comparison 0 1 less Comparison 0 0 equal Comparison 0 2 more Swap Comparison 1
# [10, 41, 35]
# Episode 323, loss: 1.2961, total reward: 0.0600
# len3 Comparison 0 0 equal Comparison 0 0 equal Comparison 0 1 less Comparison 2 0 more
# [1, 82, 70]
# Episode 324, loss: 0.7071, total reward: -0.0600
# len3 Swap
# [64, 18, 13]
# Episode 325, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [87, 21, 37]
# Episode 326, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [22, 32, 49]
# Episode 327, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [54, 23, 68]
# Episode 328, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 1 more Comparison 1 1 equal Swap Swap
# [74, 72, 96]
# Episode 329, loss: 0.8601, total reward: -1.0400
# len3 Swap
# [98, 28, 6]
# Episode 330, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 1 more Swap Comparison 2 0 less Comparison 1 1 equal Comparison 1
# [21, 32, 17]
# Episode 331, loss: 0.0365, total reward: 0.0600
# len3 Swap
# [90, 6, 93]
# Episode 332, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 1 0 less Swap
# [39, 45, 90]
# Episode 333, loss: 1.0762, total reward: 9.9700
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Swap Swap
# [23, 91, 68]
# Episode 334, loss: -0.5074, total reward: -1.0600
# len3 Swap
# [30, 55, 13]
# Episode 335, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [84, 84, 96]
# Episode 336, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 0 2 more Comparison 0 0 equal Swap Swap
# [68, 19, 2]
# Episode 337, loss: -0.2476, total reward: -1.0600
# len3 Swap
# [18, 89, 92]
# Episode 338, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [28, 10, 9]
# Episode 339, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [86, 77, 62]
# Episode 340, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [84, 68, 70]
# Episode 341, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [72, 3, 37]
# Episode 342, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 more Swap Comparison 0 1 more Comparison 0 0 equal Comparison 1
# [95, 6, 55]
# Episode 343, loss: -0.3281, total reward: -0.1400
# len3 Swap
# [91, 87, 31]
# Episode 344, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Comparison 2 2 equal Swap Comparison 1 2 more Swap
# [42, 73, 79]
# Episode 345, loss: 0.2451, total reward: 9.9400
# len3 Comparison 1 0 more Swap Swap
# [27, 1, 22]
# Episode 346, loss: 0.1605, total reward: -1.1100
# len3 Comparison 2 0 more Comparison 0 0 equal Swap Swap
# [4, 88, 69]
# Episode 347, loss: 0.4260, total reward: -1.0400
# len3 Swap
# [59, 28, 19]
# Episode 348, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 less Swap Comparison 2 0 less Comparison 0 0 equal Comparison 2
# [92, 97, 83]
# Episode 349, loss: -0.0369, total reward: -0.1400
# len3 Comparison 0 1 less Swap Swap
# [88, 27, 5]
# Episode 350, loss: -0.4682, total reward: -1.1100
# len3 Comparison 1 2 more Swap Swap
# [45, 23, 94]
# Episode 351, loss: -0.8828, total reward: -0.9100
# len3 Comparison 0 1 less Comparison 0 0 equal Swap
# [44, 70, 73]
# Episode 352, loss: 0.4397, total reward: 9.9700
# len3 Comparison 1 1 equal Comparison 0 2 less Swap Comparison 2 0 less Comparison 0
# [53, 77, 52]
# Episode 353, loss: -0.3577, total reward: -0.1400
# len3 Swap
# [96, 94, 10]
# Episode 354, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [34, 72, 24]
# Episode 355, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [83, 88, 68]
# Episode 356, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [23, 84, 75]
# Episode 357, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [29, 16, 1]
# Episode 358, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 2 less Swap Swap
# [45, 19, 11]
# Episode 359, loss: -0.4682, total reward: -1.1100
# len3 Swap
# [89, 5, 50]
# Episode 360, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 less Swap
# [34, 43, 58]
# Episode 361, loss: 0.2867, total reward: 9.9900
# len3 Comparison 1 2 more Swap
# [31, 42, 96]
# Episode 362, loss: 0.2867, total reward: 9.9900
# len3 Comparison 2 0 more Comparison 2 0 more Comparison 2 0 more Comparison 0 1 more
# [20, 13, 36]
# Episode 363, loss: -0.4108, total reward: -0.0400
# len3 Comparison 0 0 equal Comparison 0 0 equal Swap Comparison 2 1 less Swap
# [18, 44, 65]
# Episode 364, loss: 0.5582, total reward: 9.9400
# len3 Comparison 0 0 equal Comparison 1 1 equal Comparison 1 0 more Comparison 0 0 equal
# [2, 84, 25]
# Episode 365, loss: 0.0835, total reward: -0.0700
# len3 Swap
# [28, 5, 73]
# Episode 366, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 1 more Comparison 0 0 equal Swap Swap
# [91, 72, 4]
# Episode 367, loss: -0.3579, total reward: -1.0400
# len3 Comparison 2 0 more Comparison 2 1 less Comparison 1 0 more Comparison 1 2 more
# [2, 46, 5]
# Episode 368, loss: -0.0330, total reward: -0.0400
# len3 Swap
# [60, 27, 60]
# Episode 369, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [69, 22, 30]
# Episode 370, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 1 less Comparison 0 1 less Swap Comparison 1 0 less Comparison 2
# [63, 2, 64]
# Episode 371, loss: -0.0804, total reward: -0.1300
# len3 Swap
# [40, 100, 9]
# Episode 372, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Comparison 0 0 equal Comparison 2 0 more Swap Comparison 1
# [100, 41, 76]
# Episode 373, loss: 0.1996, total reward: -0.1500
# len3 Comparison 1 0 more Swap Comparison 0 2 less Swap Comparison 0 1 more Swap
# [29, 68, 64]
# Episode 374, loss: -1.3537, total reward: -0.1300
# len3 Comparison 0 2 more Comparison 0 0 equal Comparison 1 2 less Comparison 0 0 equal
# [97, 15, 36]
# Episode 375, loss: 1.3668, total reward: -0.0600
# len3 Comparison 1 2 less Comparison 0 0 equal Comparison 0 0 equal Comparison 0 0 equal
# [4, 22, 33]
# Episode 376, loss: -0.1547, total reward: -0.0700
# len3 Swap
# [26, 75, 4]
# Episode 377, loss: -5.1606, total reward: -1.0000
# len3 Comparison 1 2 more Comparison 0 0 equal Comparison 0 1 less Comparison 1 0 more
# [10, 96, 56]
# Episode 378, loss: -0.7830, total reward: -0.0500
# len3 Comparison 0 1 more Comparison 0 1 more Comparison 2 1 more Swap Comparison 1
# [99, 60, 24]
# Episode 379, loss: -0.1819, total reward: -0.1300
# len3 Swap
# [84, 86, 74]
# Episode 380, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 2 equal Swap
# [60, 72, 92]
# Episode 381, loss: 0.2867, total reward: 9.9800
# len3 Swap
# [64, 45, 78]
# Episode 382, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 1 less Comparison 2 0 less Comparison 1 2 more Comparison 1 0 less
# [45, 40, 27]
# Episode 383, loss: -0.0330, total reward: -0.0400
# len3 Comparison 1 0 less Comparison 2 1 more Swap Comparison 2 0 less Comparison 2
# [40, 56, 25]
# Episode 384, loss: -1.4478, total reward: -0.1300
# len3 Comparison 2 0 less Comparison 1 0 more Comparison 0 2 more Comparison 2 2 equal
# [47, 69, 11]
# Episode 385, loss: -0.8631, total reward: -0.0500
# len3 Comparison 1 2 more Comparison 0 2 less Swap Comparison 0 0 equal Swap Comparison
# [33, 62, 32]
# Episode 386, loss: -1.4686, total reward: -0.1500
# len3 Comparison 0 1 less Comparison 0 0 equal Swap Comparison 0 0 equal Comparison 1
# [13, 90, 84]
# Episode 387, loss: 1.3729, total reward: -0.0600
# len3 Comparison 0 0 equal Swap Comparison 2 2 equal Comparison 2 0 more Swap Swap
# [90, 15, 28]
# Episode 388, loss: 0.7620, total reward: -1.1600
# len3 Comparison 1 0 less Comparison 2 1 more Comparison 2 0 more Swap Swap
# [84, 10, 67]
# Episode 389, loss: -0.1588, total reward: -1.1300
# len3 Comparison 0 0 equal Comparison 2 0 more Comparison 2 0 more Comparison 0 0 equal
# [15, 68, 53]
# Episode 390, loss: 0.5832, total reward: -0.0600
# len3 Comparison 0 0 equal Swap Swap
# [92, 78, 35]
# Episode 391, loss: -0.3886, total reward: -1.0300
# len3 Comparison 1 1 equal Comparison 0 2 less Comparison 1 1 equal Swap Comparison 0
# [55, 32, 58]
# Episode 392, loss: 0.7790, total reward: -0.0600
# len3 Swap
# [58, 76, 63]
# Episode 393, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [23, 75, 65]
# Episode 394, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [48, 24, 33]
# Episode 395, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Swap Comparison 2 2 equal Comparison 0 0 equal Comparison 0
# [93, 6, 68]
# Episode 396, loss: 0.2166, total reward: -0.0700
# len3 Comparison 2 0 more Swap Swap
# [66, 68, 62]
# Episode 397, loss: 0.1614, total reward: -1.1100
# len3 Comparison 0 0 equal Comparison 1 2 more Comparison 1 0 more Comparison 2 0 more
# [42, 91, 90]
# Episode 398, loss: -0.6003, total reward: -0.0500
# len3 Comparison 1 1 equal Comparison 1 1 equal Swap Swap
# [49, 32, 23]
# Episode 399, loss: 0.9062, total reward: -1.0500
# len3 Comparison 0 0 equal Swap Swap
# [69, 86, 85]
# Episode 400, loss: 0.0831, total reward: -1.0300
# len3 Swap
# [37, 4, 7]
# Episode 401, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 0 0 equal Comparison 0 0 equal Comparison 0 1 less
# [37, 96, 97]
# Episode 402, loss: 0.3643, total reward: -0.0700
# len3 Comparison 2 1 more Comparison 1 0 less Comparison 2 0 more Swap Swap
# [88, 11, 44]
# Episode 403, loss: -0.1588, total reward: -1.1300
# len3 Swap
# [4, 35, 43]
# Episode 404, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [46, 78, 25]
# Episode 405, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 less Swap Swap
# [92, 51, 71]
# Episode 406, loss: -0.4682, total reward: -1.1100
# len3 Swap
# [2, 39, 13]
# Episode 407, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [86, 40, 32]
# Episode 408, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 0 equal Swap Comparison 2 1 more Swap Swap
# [98, 19, 6]
# Episode 409, loss: -1.3149, total reward: -1.1400
# len3 Comparison 0 0 equal Swap
# [45, 49, 74]
# Episode 410, loss: 0.2867, total reward: 9.9800
# len3 Comparison 0 0 equal Comparison 2 0 less Swap Comparison 2 0 more Swap Swap
# [47, 97, 12]
# Episode 411, loss: 0.8895, total reward: -1.0400
# len3 Swap
# [56, 49, 90]
# Episode 412, loss: -0.6931, total reward: -1.0000
# len3 Comparison 2 0 less Comparison 0 0 equal Comparison 2 2 equal Comparison 0 1 less
# [26, 56, 4]
# Episode 413, loss: -0.4469, total reward: -0.0600
# len3 Comparison 0 1 less Comparison 1 1 equal Swap Comparison 0 0 equal Comparison 0
# [44, 69, 5]
# Episode 414, loss: -0.0969, total reward: -0.0600
# len3 Swap
# [70, 11, 34]
# Episode 415, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [6, 76, 100]
# Episode 416, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 1 equal Comparison 0 1 less Comparison 0 0 equal Swap
# [11, 31, 91]
# Episode 417, loss: -0.0892, total reward: 9.9500
# len3 Comparison 1 0 more Comparison 0 2 more Comparison 1 0 more Comparison 1 0 more
# [56, 99, 36]
# Episode 418, loss: -0.4509, total reward: -0.0400
# len3 Comparison 1 2 less Comparison 1 2 less Comparison 2 0 less Comparison 0 0 equal
# [91, 57, 67]
# Episode 419, loss: -0.0330, total reward: -0.0500
# len3 Comparison 2 0 less Comparison 2 1 less Swap Swap
# [56, 16, 67]
# Episode 420, loss: 0.1923, total reward: -0.9200
# len3 Comparison 0 0 equal Comparison 0 0 equal Comparison 1 0 more Comparison 0 0 equal
# [6, 72, 61]
# Episode 421, loss: 0.2994, total reward: -0.0700
# len3 Comparison 0 1 less Comparison 2 1 less Comparison 0 2 less Comparison 0 2 less
# [79, 99, 98]
# Episode 422, loss: -0.0330, total reward: -0.0400
# len3 Swap
# [12, 26, 39]
# Episode 423, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 0 more Comparison 2 0 more Comparison 1 2 more Comparison 2 1 less
# [22, 83, 79]
# Episode 424, loss: -0.0330, total reward: -0.0400
# len3 Swap
# [82, 17, 39]
# Episode 425, loss: -0.6931, total reward: -1.0000
# len3 Comparison 1 0 more Comparison 2 0 more Comparison 0 1 less Swap Swap
# [69, 27, 53]
# Episode 426, loss: -1.0828, total reward: -1.1300
# len3 Comparison 0 0 equal Swap Comparison 0 0 equal Comparison 0 0 equal Comparison 1
# [47, 94, 11]
# Episode 427, loss: 1.0272, total reward: -0.0700
# len3 Comparison 0 2 less Comparison 1 1 equal Swap Comparison 0 0 equal Swap Comparison
# [25, 68, 53]
# Episode 428, loss: 1.8941, total reward: -0.0700
# len3 Comparison 0 0 equal Comparison 2 1 less Swap
# [3, 4, 50]
# Episode 429, loss: -0.6762, total reward: 9.9700
# len3 Swap
# [97, 62, 33]
# Episode 430, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [72, 87, 45]
# Episode 431, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [27, 46, 37]
# Episode 432, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 1 less Comparison 2 0 more Swap Swap
# [11, 65, 2]
# Episode 433, loss: -0.5284, total reward: -1.1200
# len3 Swap
# [72, 21, 23]
# Episode 434, loss: -0.6931, total reward: -1.0000
# ...
# [51, 100, 94]
# Episode 18425, loss: -0.8367, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 1 2 less Comparison 2 2 equal Swap Comparison 2
# [47, 12, 68]
# Episode 18426, loss: -0.7724, total reward: -0.0600
# len3 Swap
# [32, 46, 48]
# Episode 18427, loss: -0.7418, total reward: -1.0000
# len3 Comparison 1 2 more Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [63, 41, 17]
# Episode 18428, loss: -1.3381, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 1 2 more
# [17, 88, 62]
# Episode 18429, loss: -0.8204, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal
# [47, 60, 72]
# Episode 18430, loss: -0.8179, total reward: -0.0700
# len3 Swap
# [52, 28, 68]
# Episode 18431, loss: -0.7253, total reward: -1.0000
# len3 Swap
# [64, 92, 23]
# Episode 18432, loss: -0.7941, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal
# [33, 61, 63]
# Episode 18433, loss: -0.7689, total reward: -0.0700
# len3 Swap
# [52, 35, 70]
# Episode 18434, loss: -0.6888, total reward: -1.0000
# len3 Swap
# [27, 81, 37]
# Episode 18435, loss: -0.6096, total reward: -1.0000
# len3 Comparison 0 2 more Comparison 2 2 equal Comparison 1 2 more Comparison 2 2 equal
# [26, 79, 24]
# Episode 18436, loss: -1.3981, total reward: -0.0600
# len3 Comparison 2 2 equal Comparison 0 2 less Comparison 2 2 equal Comparison 2 2 equal
# [67, 25, 70]
# Episode 18437, loss: -0.8439, total reward: -0.0700
# len3 Swap
# [89, 87, 38]
# Episode 18438, loss: -0.7179, total reward: -1.0000
# len3 Swap
# [92, 35, 10]
# Episode 18439, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [58, 44, 27]
# Episode 18440, loss: -0.7213, total reward: -1.0000
# len3 Swap
# [75, 25, 85]
# Episode 18441, loss: -0.6958, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 0 2 less Swap Comparison 2
# [44, 87, 31]
# Episode 18442, loss: -0.9444, total reward: -0.1500
# len3 Swap
# [92, 63, 53]
# Episode 18443, loss: -0.7389, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 1 more Comparison 0 2 more
# [98, 83, 88]
# Episode 18444, loss: -0.8476, total reward: -0.0600
# len3 Swap
# [87, 40, 96]
# Episode 18445, loss: -0.7344, total reward: -1.0000
# len3 Swap
# [24, 99, 58]
# Episode 18446, loss: -0.7870, total reward: -1.0000
# len3 Swap
# [33, 76, 37]
# Episode 18447, loss: -0.6931, total reward: -1.0000
# len3 Comparison 0 2 more Comparison 2 2 equal Comparison 0 2 more Comparison 2 2 equal
# [80, 37, 37]
# Episode 18448, loss: -1.3338, total reward: -0.0600
# len3 Comparison 1 2 more Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [58, 99, 15]
# Episode 18449, loss: -1.9374, total reward: -0.0700
# len3 Comparison 0 2 more Comparison 2 2 equal Comparison 1 2 more Comparison 2 1 less
# [47, 96, 26]
# Episode 18450, loss: -2.5042, total reward: -0.0500
# len3 Swap
# [100, 78, 21]
# Episode 18451, loss: -0.7468, total reward: -1.0000
# len3 Swap
# [89, 15, 46]
# Episode 18452, loss: -0.8014, total reward: -1.0000
# len3 Swap
# [75, 82, 34]
# Episode 18453, loss: -0.8159, total reward: -1.0000
# len3 Swap
# [10, 39, 91]
# Episode 18454, loss: -0.6892, total reward: -1.0000
# len3 Swap
# [53, 59, 54]
# Episode 18455, loss: -0.8427, total reward: -1.0000
# len3 Swap
# [1, 14, 94]
# Episode 18456, loss: -0.7739, total reward: -1.0000
# len3 Comparison 2 2 equal Swap Comparison 2 2 equal Comparison 2 2 equal Comparison 2
# [95, 13, 32]
# Episode 18457, loss: 0.1235, total reward: -0.0700
# len3 Swap
# [7, 67, 60]
# Episode 18458, loss: -0.8161, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 0 2 less Comparison 2 2 equal Comparison 2 2 equal
# [29, 90, 63]
# Episode 18459, loss: -0.7613, total reward: -0.0700
# len3 Comparison 1 1 equal Comparison 2 1 less Comparison 2 2 equal Swap Comparison 2
# [76, 85, 68]
# Episode 18460, loss: -0.7763, total reward: -0.0600
# len3 Swap
# [83, 73, 99]
# Episode 18461, loss: -0.8459, total reward: -1.0000
# len3 Swap
# [59, 49, 65]
# Episode 18462, loss: -0.8033, total reward: -1.0000
# len3 Swap
# [64, 25, 39]
# Episode 18463, loss: -0.8049, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 0 more
# [27, 16, 30]
# Episode 18464, loss: -0.7290, total reward: -0.0700
# len3 Comparison 1 2 less Comparison 0 2 more Comparison 2 2 equal Comparison 1 2 less
# [87, 55, 65]
# Episode 18465, loss: -1.7145, total reward: -0.0500
# len3 Swap
# [3, 25, 3]
# Episode 18466, loss: -0.8395, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 1 1 equal Swap Comparison 0
# [58, 36, 64]
# Episode 18467, loss: -0.6714, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 1 2 less Comparison 2 2 equal Comparison 2 1 more
# [53, 69, 72]
# Episode 18468, loss: -0.7335, total reward: -0.0600
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 0 more Comparison 2 2 equal
# [94, 45, 99]
# Episode 18469, loss: -0.0885, total reward: -0.0700
# len3 Comparison 2 0 more Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [66, 76, 86]
# Episode 18470, loss: -0.2810, total reward: -0.0700
# len3 Swap
# [57, 71, 100]
# Episode 18471, loss: -0.7920, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 0 2 more Swap
# [3, 33, 57]
# Episode 18472, loss: -0.5748, total reward: 9.9700
# len3 Swap
# [8, 75, 98]
# Episode 18473, loss: -0.8425, total reward: -1.0000
# len3 Swap
# [25, 12, 22]
# Episode 18474, loss: -0.8401, total reward: -1.0000
# len3 Comparison 2 2 equal Swap Comparison 2 0 less Comparison 2 2 equal Comparison 0
# [47, 73, 2]
# Episode 18475, loss: -0.0947, total reward: -0.0600
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 0 2 less
# [46, 23, 48]
# Episode 18476, loss: -0.6530, total reward: -0.0700
# len3 Swap
# [24, 60, 75]
# Episode 18477, loss: -0.7901, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [5, 30, 51]
# Episode 18478, loss: -0.6947, total reward: -0.0800
# len3 Comparison 2 1 less Comparison 0 2 more Comparison 2 2 equal Comparison 0 2 more
# [99, 90, 67]
# Episode 18479, loss: -0.5243, total reward: -0.0500
# len3 Comparison 2 2 equal Comparison 0 2 more Comparison 2 2 equal Comparison 2 2 equal
# [54, 75, 19]
# Episode 18480, loss: -0.9807, total reward: -0.0700
# len3 Comparison 2 0 more Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [52, 24, 84]
# Episode 18481, loss: -0.2927, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal
# [40, 38, 100]
# Episode 18482, loss: 0.0151, total reward: -0.0700
# len3 Comparison 0 2 less Comparison 2 2 equal Comparison 2 2 equal Comparison 0 2 less
# [48, 12, 80]
# Episode 18483, loss: -1.5033, total reward: -0.0600
# len3 Comparison 2 2 equal Comparison 2 1 more Comparison 2 0 more Comparison 2 2 equal
# [10, 67, 82]
# Episode 18484, loss: -0.7851, total reward: -0.0600
# len3 Swap
# [47, 36, 41]
# Episode 18485, loss: -0.7769, total reward: -1.0000
# len3 Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [74, 40, 88]
# Episode 18486, loss: -1.3227, total reward: -0.0700
# len3 Swap
# [64, 19, 21]
# Episode 18487, loss: -0.7607, total reward: -1.0000
# len3 Comparison 0 0 equal Comparison 2 2 equal Swap
# [33, 71, 88]
# Episode 18488, loss: 0.4620, total reward: 9.9600
# len3 Swap
# [11, 39, 76]
# Episode 18489, loss: -0.6907, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal
# [76, 1, 70]
# Episode 18490, loss: -0.8164, total reward: -0.0700
# len3 Comparison 0 2 more Comparison 1 2 more Comparison 2 2 equal Comparison 2 2 equal
# [86, 78, 20]
# Episode 18491, loss: -1.0906, total reward: -0.0600
# len3 Swap
# [53, 74, 2]
# Episode 18492, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [30, 18, 8]
# Episode 18493, loss: -0.7208, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Swap Comparison 2 2 equal Comparison 2
# [53, 35, 17]
# Episode 18494, loss: -0.8797, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 0 2 less Comparison 0 2 less Comparison 2 2 equal
# [24, 36, 72]
# Episode 18495, loss: -0.8590, total reward: -0.0600
# len3 Swap
# [39, 4, 81]
# Episode 18496, loss: -0.7170, total reward: -1.0000
# len3 Swap
# [72, 71, 33]
# Episode 18497, loss: -0.7313, total reward: -1.0000
# len3 Swap
# [74, 11, 18]
# Episode 18498, loss: -0.6804, total reward: -1.0000
# len3 Comparison 2 2 equal Swap Comparison 2 2 equal Comparison 1 2 more Comparison 2
# [34, 66, 32]
# Episode 18499, loss: 0.0267, total reward: -0.0600
# len3 Comparison 2 0 less Comparison 0 0 equal Comparison 2 1 less Comparison 2 2 equal
# [36, 52, 2]
# Episode 18500, loss: -0.1972, total reward: -0.0600
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [12, 8, 51]
# Episode 18501, loss: -0.8282, total reward: -0.0800
# len3 Comparison 0 2 less Comparison 2 2 equal Comparison 2 2 equal Comparison 1 2 less
# [6, 48, 73]
# Episode 18502, loss: -2.3122, total reward: -0.0600
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 0 2 less Swap Comparison 0
# [93, 3, 44]
# Episode 18503, loss: -0.9012, total reward: -0.1500
# len3 Swap
# [24, 70, 5]
# Episode 18504, loss: -0.7301, total reward: -1.0000
# len3 Comparison 0 2 less Comparison 1 1 equal Comparison 2 2 equal Comparison 1 2 less
# [21, 54, 85]
# Episode 18505, loss: -2.4763, total reward: -0.0600
# len3 Swap
# [39, 67, 41]
# Episode 18506, loss: -0.6975, total reward: -1.0000
# len3 Comparison 2 0 less Comparison 2 2 equal Comparison 2 1 more Comparison 2 2 equal
# [82, 22, 67]
# Episode 18507, loss: -0.1851, total reward: -0.0600
# len3 Swap
# [1, 87, 39]
# Episode 18508, loss: -0.6812, total reward: -1.0000
# len3 Swap
# [99, 91, 33]
# Episode 18509, loss: -0.6744, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [15, 84, 73]
# Episode 18510, loss: -0.8296, total reward: -0.0800
# len3 Swap
# [13, 4, 84]
# Episode 18511, loss: -0.7141, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [34, 90, 61]
# Episode 18512, loss: -0.7840, total reward: -0.0800
# len3 Swap
# [5, 66, 62]
# Episode 18513, loss: -0.7088, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [60, 45, 100]
# Episode 18514, loss: -0.8191, total reward: -0.0800
# len3 Swap
# [32, 8, 73]
# Episode 18515, loss: -0.6587, total reward: -1.0000
# len3 Swap
# [32, 6, 42]
# Episode 18516, loss: -0.6873, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 0 more Comparison 2 2 equal Comparison 2 2 equal
# [66, 48, 72]
# Episode 18517, loss: -1.0333, total reward: -0.0700
# len3 Swap
# [78, 79, 88]
# Episode 18518, loss: -0.6914, total reward: -1.0000
# len3 Swap
# [13, 83, 61]
# Episode 18519, loss: -0.6721, total reward: -1.0000
# len3 Swap
# [19, 43, 58]
# Episode 18520, loss: -0.6886, total reward: -1.0000
# len3 Comparison 1 2 more Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [44, 64, 48]
# Episode 18521, loss: -1.0140, total reward: -0.0700
# len3 Swap
# [58, 19, 20]
# Episode 18522, loss: -0.6984, total reward: -1.0000
# len3 Swap
# [53, 9, 73]
# Episode 18523, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [16, 73, 9]
# Episode 18524, loss: -0.7318, total reward: -1.0000
# len3 Swap
# [36, 21, 19]
# Episode 18525, loss: -0.7688, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 0 2 more Comparison 2 2 equal Comparison 2 2 equal
# [59, 64, 31]
# Episode 18526, loss: -0.7494, total reward: -0.0700
# len3 Comparison 0 2 more Swap Comparison 0 2 less Comparison 2 2 equal Comparison 2
# [8, 64, 28]
# Episode 18527, loss: 1.0223, total reward: 0.0600
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 0 2 more
# [94, 42, 82]
# Episode 18528, loss: -0.7844, total reward: -0.0700
# len3 Swap
# [96, 28, 18]
# Episode 18529, loss: -0.7126, total reward: -1.0000
# len3 Comparison 1 2 less Comparison 2 0 more Swap Comparison 2 2 equal Comparison 2
# [60, 52, 7]
# Episode 18530, loss: -1.4245, total reward: -0.1400
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 1 2 less Swap Comparison 2
# [52, 88, 25]
# Episode 18531, loss: -0.8037, total reward: -0.1500
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [67, 91, 17]
# Episode 18532, loss: -0.7777, total reward: -0.0800
# len3 Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [66, 61, 72]
# Episode 18533, loss: -2.2218, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal
# [44, 2, 41]
# Episode 18534, loss: -0.8035, total reward: -0.0700
# len3 Swap
# [53, 97, 17]
# Episode 18535, loss: -0.8040, total reward: -1.0000
# len3 Swap
# [71, 38, 50]
# Episode 18536, loss: -0.7911, total reward: -1.0000
# len3 Swap
# [65, 48, 87]
# Episode 18537, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [82, 25, 60]
# Episode 18538, loss: -0.7374, total reward: -1.0000
# len3 Comparison 1 0 more Comparison 1 2 more Comparison 0 2 less Comparison 2 2 equal
# [12, 72, 70]
# Episode 18539, loss: -0.8022, total reward: -0.0500
# len3 Swap
# [100, 53, 95]
# Episode 18540, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [17, 63, 82]
# Episode 18541, loss: -0.7593, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [33, 1, 85]
# Episode 18542, loss: -0.7892, total reward: -0.0800
# len3 Comparison 1 2 less Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [3, 38, 82]
# Episode 18543, loss: -1.3986, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 1 2 more Comparison 2 2 equal Comparison 2 2 equal
# [84, 92, 68]
# Episode 18544, loss: -0.7642, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 1 2 more Comparison 2 2 equal
# [49, 53, 30]
# Episode 18545, loss: -0.7365, total reward: -0.0700
# len3 Swap
# [64, 12, 54]
# Episode 18546, loss: -0.7457, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 1 2 less
# [85, 18, 66]
# Episode 18547, loss: -0.7583, total reward: -0.0700
# len3 Swap
# [37, 31, 97]
# Episode 18548, loss: -0.7681, total reward: -1.0000
# len3 Comparison 2 2 equal Swap Comparison 2 2 equal Comparison 2 2 equal Comparison 2
# [53, 90, 43]
# Episode 18549, loss: 0.1025, total reward: -0.0700
# len3 Swap
# [95, 55, 79]
# Episode 18550, loss: -0.7482, total reward: -1.0000
# len3 Swap
# [91, 3, 24]
# Episode 18551, loss: -0.7808, total reward: -1.0000
# len3 Swap
# [4, 75, 93]
# Episode 18552, loss: -0.7669, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Swap Comparison 2 2 equal Comparison 2
# [73, 93, 92]
# Episode 18553, loss: -0.8434, total reward: -0.0700
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [15, 1, 98]
# Episode 18554, loss: -0.7398, total reward: -0.0800
# len3 Comparison 2 2 equal Comparison 2 1 less Comparison 2 2 equal Comparison 2 2 equal
# [60, 52, 46]
# Episode 18555, loss: -0.8431, total reward: -0.0700
# len3 Swap
# [10, 82, 1]
# Episode 18556, loss: -0.6931, total reward: -1.0000
# len3 Swap
# [56, 65, 73]
# Episode 18557, loss: -0.7602, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 1 2 more Comparison 2 2 equal
# [81, 79, 49]
# Episode 18558, loss: -0.8057, total reward: -0.0700
# len3 Swap
# [63, 90, 23]
# Episode 18559, loss: -0.7494, total reward: -1.0000
# len3 Swap
# [2, 47, 87]
# Episode 18560, loss: -0.7796, total reward: -1.0000
# len3 Swap
# [15, 43, 37]
# Episode 18561, loss: -0.7564, total reward: -1.0000
# len3 Comparison 2 2 equal Comparison 2 2 equal Comparison 0 2 less Comparison 2 2 equal
# [75, 25, 91]
# Episode 18562, loss: -0.8516, total reward: -0.0700
# len3 Swap
# [91, 14, 56]
# Episode 18563, loss: -0.8404, total reward: -1.0000
# len3 Swap
# [16, 20, 43]
# Episode 18564, loss: -0.7504, total reward: -1.0000
# len3 Swap
# [89, 29, 85]
# Episode 18565, loss: -0.7570, total reward: -1.0000
# len3 Comparison 1 2 more Comparison 2 2 equal Comparison 2 2 equal Comparison 2 2 equal
# [53, 68, 19]
# Episode 18566, loss: -2.3051, total reward: -0.0700

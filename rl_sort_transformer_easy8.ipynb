# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import random

MIN_LIST_LEN = 8
MAX_LIST_LEN = 8
MAX_STEPS = 210
SUCCESS_REWARD = 10.0
EPS_START = 0.5
EPS_END = 0.05
EPS_DECAY = 1000
GAMMA = 0.99
NUM_EPISODES = 100000
EPISODES_SAVE = 1000
OUTPUT_DIR = 'datasets/rl_sort_transformer_easy/list8_transformer3_128_gamma099_step210'

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    '0': 2,
    '1': 3,
    '2': 4,
    '3': 5,
    '4': 6,
    '5': 7,
    '6': 8,
    '7': 9,
    'less': 10,
    'equal': 11,
    'more': 12,
    'len1': 13,
    'len2': 14,
    'len3': 15,
    'len4': 16,
    'len5': 17,
    'len6': 18,
    'len7': 19,
    'len8': 20,
}
inv_vocab = {v: k for k, v in vocab.items()}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.list = [random.randint(1, 100) for _ in range(self.length)]
        while self.list == sorted(self.list):
            self.list = [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        initial_token = 'len{}'.format(self.length)
        return vocab[initial_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_list_len(self):
        return len(self.list)

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 >= self.length or index2 >= self.length or index1 < 0 or index2 < 0:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = -0.01
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = -0.02
            else:
                response_token = vocab['more']
                reward = -0.01
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = SUCCESS_REWARD
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = 0.1
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -0.1
            else:
                reward = -0.01
            self.indices = None
        else:
            reward = -1.0
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()
# Out:
# Using device: cuda

# %%
# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=256):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=128, nhead=8, num_layers=3):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])


def save_checkpoint(model, optimizer, episode, folder, filename):
    """
    Save the model and optimizer state to the designated filepath.

    Args:
        model (nn.Module): The model to save.
        optimizer (torch.optim.Optimizer): The optimizer whose state to save.
        episode (int): The current episode number.
        filepath (str): The path where to save the checkpoint.
    """
    filepath = os.path.join(folder, filename)
    # Ensure the directory exists
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    # Save the checkpoint
    torch.save({
        'episode': episode,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, filepath)
    print(f"Checkpoint saved at episode {episode} to {filepath}")

def load_checkpoint(filepath, model, optimizer):
    """
    Load the model and optimizer state from the designated filepath.

    Args:
        filepath (str): The path from where to load the checkpoint.
        model (nn.Module): The model into which to load the state_dict.
        optimizer (torch.optim.Optimizer): The optimizer into which to load the state.

    Returns:
        int: The episode number to resume from.
    """
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        episode = checkpoint['episode']
        print(f"Checkpoint loaded from {filepath}, resuming from episode {episode}")
        return episode
    else:
        print(f"No checkpoint found at {filepath}, starting from scratch.")
        return 0

# %%
# Training Loop
def train(verbose=False):
    torch.autograd.set_detect_anomaly(True)  # Detect anomalies in autograd
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Reduced learning rate
    #load_checkpoint("datasets/rl_sort_transformer_easy/list6_transformer3_128_gamma098/ckpt_7000_0.9286.pth", model, optimizer)

    episode_cnt = 0
    total_reward = 0.0
    for episode in range(NUM_EPISODES):
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, current_list = env.reset()
        input_tokens = [initial_token_id]
        log_probs = []
        rewards = []
        state = 'expect_action'
        done = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            output = model(input_seq)  # (seq_len, batch_size, vocab_size)
            # Get logits for the last token
            logits = output[-1, 0, :]  # (vocab_size)

            # Check for NaNs in logits
            if torch.isnan(logits).any():
                print(f"Episode {episode}, NaNs in logits before masking.")
                break

            # Get valid tokens based on state
            def get_valid_tokens(state):
                action_tokens = [vocab['Comparison'], vocab['Swap']]
                index_tokens = [vocab[str(i)] for i in range(env.length)]
                if state == 'expect_action':
                    return action_tokens
                elif state == 'expect_index1':
                    return index_tokens[:-1]
                elif state == 'expect_index2':
                    return [x for x in index_tokens if x > input_tokens[-1]]
                else:
                    # Handle unexpected states by defaulting to expect_action
                    return action_tokens

            valid_token_ids = get_valid_tokens(state)

            # Ensure valid_token_ids are within the vocab range
            if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                break

            # Mask invalid tokens
            mask_value = -1e9  # Use a large negative value instead of -inf
            mask = torch.full_like(logits, mask_value).to(device)
            mask[valid_token_ids] = 0
            masked_logits = logits + mask
            
            # Sample action. Have some chance to randomly pick a valid action.
            eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
            if random.random() < eps_threshold:
                masked_logits = masked_logits / 4

            # Check for NaNs in masked_logits
            if torch.isnan(masked_logits).any():
                print(f"Episode {episode}, NaNs in masked_logits after masking.")
                break

            # Compute probabilities
            probs = F.softmax(masked_logits, dim=0)

            # Check for NaNs in probs
            if torch.isnan(probs).any():
                print(f"Episode {episode}, NaNs in probs after softmax.")
                break

            try:
                m = torch.distributions.Categorical(probs)
                action_token = m.sample()
                log_prob = m.log_prob(action_token)
            except ValueError as e:
                print(f"Episode {episode}, error in sampling action: {e}")
                break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            reward = 0.0
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        # Can't perform Swap without a previous Comparison
                        reward = -1.0
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    if verbose:
                        print("Reward:", reward)
                    #rewards.append(reward)
                    state = 'expect_action'
                else:
                    # Invalid action, end the episode
                    reward = -1.0
                    #rewards.append(reward)
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                response_token, reward, done, current_list = env.step(action_tokens)
                if verbose:
                    print("Reward:", reward)
                #rewards.append(reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                # Invalid state, end the episode
                reward = -1.0
                #rewards.append(reward)
                done = True
            #
            rewards.append(reward)
        #
        # Save checkpoint
        if episode > 0 and episode % EPISODES_SAVE == 0:
            avg_reward = total_reward / (episode_cnt + 0.00001)
            episode_cnt = 0
            total_reward = 0.0
            save_checkpoint(model, optimizer, episode, OUTPUT_DIR, f"ckpt_{episode}_{avg_reward:.4f}.pth")
        #
        #print(decode(input_tokens, inv_vocab))
        #print(env.get_list())
        #print("rewards:", rewards)
        assert len(log_probs) == len(rewards), "log_probs and returns have different sizes!"
        
        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns
        returns = []
        R = 0
        gamma = GAMMA
        for r in rewards[::-1]:
            R = r + gamma * R
            returns.insert(0, R)
        returns = torch.tensor(returns)
        #print(returns)

        # Check for NaNs in returns
        if torch.isnan(returns).any():
            print(f"Episode {episode}, NaNs in returns.")
            continue

#         if returns.std() != 0 and not torch.isnan(returns.std()):
#             returns = (returns - returns.mean()) / (returns.std() + 1e-9)
#         else:
#             pass #returns = returns - returns.mean()

        # Check for NaNs in standardized returns
        if torch.isnan(returns).any():
            print(f"Episode {episode}, NaNs in standardized returns.")
            continue

        # Compute loss
        loss = 0
        #print("log_probs:", log_probs)
        #print("returns:", returns)
        assert len(log_probs) == len(returns), "log_probs and returns have different sizes!"
        for log_prob, R in zip(log_probs, returns):
            loss -= log_prob * R

        # Check for NaNs in loss
        if torch.isnan(loss):
            print(f"Episode {episode}, NaN in loss.")
            continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        episode_cnt += 1
        total_reward += sum(rewards)
        if episode % 1 == 0:
            print(f"Episode {episode}, loss: {loss.item():.4f}, total reward: {sum(rewards):.4f}")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Episode 0, loss: -23.7438, total reward: -0.9600
# Episode 1, loss: -8.2705, total reward: -0.9200
# Episode 2, loss: -49.2720, total reward: -0.8300
# Episode 3, loss: -6.1235, total reward: -0.9200
# Episode 4, loss: -25.5703, total reward: -1.0800
# Episode 5, loss: -1.5408, total reward: -1.0000
# Episode 6, loss: -12.4977, total reward: -0.9400
# Episode 7, loss: -12.0577, total reward: -0.9300
# Episode 8, loss: -25.3064, total reward: -1.2600
# Episode 9, loss: -90.4774, total reward: -1.4700
# Episode 10, loss: -0.9747, total reward: -1.0000
# Episode 11, loss: -92.2992, total reward: -1.2600
# Episode 12, loss: -1.2158, total reward: -1.0000
# Episode 13, loss: -87.7318, total reward: -1.3500
# Episode 14, loss: -85.9030, total reward: -1.3700
# Episode 15, loss: -1.3806, total reward: -1.0000
# Episode 16, loss: -40.0651, total reward: -0.8100
# Episode 17, loss: -16.6363, total reward: -0.2100
# Episode 18, loss: -36.2025, total reward: -0.6100
# Episode 19, loss: -13.0180, total reward: -0.3100
# Episode 20, loss: -26.4572, total reward: -0.5200
# Episode 21, loss: -31.1981, total reward: -0.6100
# Episode 22, loss: -31.0040, total reward: -0.9900
# Episode 23, loss: -25.3972, total reward: -0.5100
# Episode 24, loss: -85.2864, total reward: -1.1400
# Episode 25, loss: -120.2187, total reward: -1.6400
# Episode 26, loss: -84.5502, total reward: -1.5700
# Episode 27, loss: -42.3890, total reward: -0.7400
# Episode 28, loss: -32.7675, total reward: -0.6200
# Episode 29, loss: -29.8441, total reward: -0.5400
# Episode 30, loss: -34.0715, total reward: -0.5100
# Episode 31, loss: -57.4492, total reward: -1.2000
# Episode 32, loss: 2.1190, total reward: 0.0000
# Episode 33, loss: -24.0995, total reward: -0.4100
# Episode 34, loss: -22.3130, total reward: -0.5100
# Episode 35, loss: -33.5761, total reward: -0.5600
# Episode 36, loss: -40.1333, total reward: -0.7300
# Episode 37, loss: -48.2464, total reward: -1.0700
# Episode 38, loss: -39.2780, total reward: -0.6800
# Episode 39, loss: -12.5760, total reward: -0.3200
# Episode 40, loss: -1.9881, total reward: -1.0000
# Episode 41, loss: -66.6019, total reward: -1.2800
# Episode 42, loss: -19.4520, total reward: -0.4200
# Episode 43, loss: -33.6995, total reward: -0.6200
# Episode 44, loss: -51.6587, total reward: -1.0500
# Episode 45, loss: -22.1316, total reward: -0.4200
# Episode 46, loss: -15.0420, total reward: -0.4100
# Episode 47, loss: -20.2642, total reward: -0.4200
# Episode 48, loss: -27.2891, total reward: -0.6100
# Episode 49, loss: -15.7525, total reward: -0.3200
# Episode 50, loss: -32.9879, total reward: -0.6200
# Episode 51, loss: -65.4425, total reward: -1.1100
# Episode 52, loss: -1.9874, total reward: -1.0000
# Episode 53, loss: -35.6703, total reward: -0.7100
# Episode 54, loss: -31.3872, total reward: -0.7100
# Episode 55, loss: -119.2018, total reward: -1.7600
# Episode 56, loss: -49.8237, total reward: -0.9100
# Episode 57, loss: -2.2097, total reward: -1.0000
# Episode 58, loss: -37.1906, total reward: -0.6100
# Episode 59, loss: -85.7210, total reward: -1.1900
# Episode 60, loss: -115.2093, total reward: -1.7600
# Episode 61, loss: -29.5747, total reward: -0.5400
# Episode 62, loss: -40.0368, total reward: -0.6300
# Episode 63, loss: -38.2288, total reward: -0.6400
# Episode 64, loss: -13.3514, total reward: -0.9300
# Episode 65, loss: -40.8747, total reward: -0.7100
# Episode 66, loss: -25.0430, total reward: -0.5200
# Episode 67, loss: -34.4582, total reward: -0.6100
# Episode 68, loss: -66.8905, total reward: -1.2800
# Episode 69, loss: -33.9463, total reward: -0.6900
# Episode 70, loss: -3.2752, total reward: -0.1100
# Episode 71, loss: -30.1038, total reward: -0.7500
# Episode 72, loss: -31.2783, total reward: -0.7200
# Episode 73, loss: -33.3779, total reward: -0.6100
# Episode 74, loss: -28.8251, total reward: -0.7200
# Episode 75, loss: -23.0544, total reward: -0.4100
# Episode 76, loss: -112.6806, total reward: -1.6400
# Episode 77, loss: -2.2998, total reward: -1.0000
# Episode 78, loss: -19.0086, total reward: -0.4200
# Episode 79, loss: -2.3732, total reward: -1.0000
# Episode 80, loss: -45.1242, total reward: -1.1000
# Episode 81, loss: -30.9809, total reward: -0.5200
# Episode 82, loss: -25.2732, total reward: -0.5200
# Episode 83, loss: -23.9278, total reward: -0.5200
# Episode 84, loss: -24.7052, total reward: -0.6100
# Episode 85, loss: -27.2575, total reward: -0.5200
# Episode 86, loss: -20.7208, total reward: -0.4200
# Episode 87, loss: -24.6452, total reward: -0.6400
# Episode 88, loss: -23.9612, total reward: -0.5200
# Episode 89, loss: -31.1198, total reward: -0.8100
# Episode 90, loss: -14.1354, total reward: -0.5100
# Episode 91, loss: -40.0637, total reward: -1.0500
# Episode 92, loss: -92.5810, total reward: -1.4600
# Episode 93, loss: -25.7157, total reward: -0.6200
# Episode 94, loss: -13.6529, total reward: -0.3200
# Episode 95, loss: -21.8354, total reward: -0.5200
# Episode 96, loss: -59.1282, total reward: -1.2500
# Episode 97, loss: -25.1657, total reward: -0.6200
# Episode 98, loss: -20.5788, total reward: -1.1600
# Episode 99, loss: -50.5975, total reward: -1.2800
# Episode 100, loss: -13.0503, total reward: -1.1400
# Episode 101, loss: -29.1844, total reward: -0.6500
# Episode 102, loss: -21.4074, total reward: -0.4200
# Episode 103, loss: -39.5469, total reward: -0.7100
# Episode 104, loss: -20.5252, total reward: -0.4100
# Episode 105, loss: -15.1462, total reward: -0.3100
# Episode 106, loss: -31.3851, total reward: -0.6100
# Episode 107, loss: -82.4171, total reward: -1.3700
# Episode 108, loss: -20.5238, total reward: -0.5100
# Episode 109, loss: -27.7684, total reward: -0.5200
# Episode 110, loss: -19.0357, total reward: -0.5100
# Episode 111, loss: -21.1194, total reward: -0.5100
# Episode 112, loss: -4.9867, total reward: -0.2000
# Episode 113, loss: -39.6537, total reward: -0.8000
# Episode 114, loss: -61.5277, total reward: -1.3000
# Episode 115, loss: -42.0333, total reward: -1.1000
# Episode 116, loss: -24.7811, total reward: -0.6100
# Episode 117, loss: -23.9631, total reward: -0.4200
# Episode 118, loss: -91.6848, total reward: -1.3200
# Episode 119, loss: -25.3678, total reward: -0.5300
# Episode 120, loss: -21.0351, total reward: -0.4100
# Episode 121, loss: -31.3866, total reward: -0.8100
# Episode 122, loss: -22.7167, total reward: -0.6200
# Episode 123, loss: -2.1693, total reward: -1.0000
# Episode 124, loss: -15.4595, total reward: -0.3100
# Episode 125, loss: -24.1182, total reward: -0.6100
# Episode 126, loss: -2.0814, total reward: -1.0000
# Episode 127, loss: -16.0302, total reward: -0.4200
# Episode 128, loss: -12.6374, total reward: -0.3200
# Episode 129, loss: -20.5793, total reward: -0.4000
# Episode 130, loss: -8.2533, total reward: -0.1100
# Episode 131, loss: -11.7558, total reward: -0.3100
# Episode 132, loss: -26.1467, total reward: -0.4700
# Episode 133, loss: -62.4469, total reward: -1.4500
# Episode 134, loss: -41.5339, total reward: -1.1100
# Episode 135, loss: -40.1750, total reward: -1.1500
# Episode 136, loss: -2.0198, total reward: -1.0000
# Episode 137, loss: -23.3740, total reward: -1.0200
# Episode 138, loss: -36.7326, total reward: -1.1400
# Episode 139, loss: -23.4681, total reward: -0.6100
# Episode 140, loss: -61.9466, total reward: -1.5400
# Episode 141, loss: -15.9874, total reward: -0.5000
# Episode 142, loss: -27.9526, total reward: -0.8300
# Episode 143, loss: -9.4820, total reward: -0.4200
# Episode 144, loss: -73.8636, total reward: -1.5800
# Episode 145, loss: -11.0819, total reward: -0.4100
# Episode 146, loss: -10.3856, total reward: -0.4100
# Episode 147, loss: -13.7295, total reward: -0.3500
# Episode 148, loss: -21.5062, total reward: -0.6100
# Episode 149, loss: -2.5521, total reward: -1.0000
# Episode 150, loss: -46.9445, total reward: -0.9700
# Episode 151, loss: -5.4854, total reward: -0.9100
# Episode 152, loss: -71.5378, total reward: -1.3000
# Episode 153, loss: -18.6444, total reward: -0.5200
# Episode 154, loss: -20.2070, total reward: -0.5300
# Episode 155, loss: -8.2123, total reward: -0.2100
# Episode 156, loss: -6.5983, total reward: -0.2100
# Episode 157, loss: -18.9429, total reward: -0.6100
# Episode 158, loss: -67.2949, total reward: -1.3500
# Episode 159, loss: -23.9471, total reward: -0.5500
# Episode 160, loss: -23.8275, total reward: -0.5100
# Episode 161, loss: -28.1414, total reward: -1.2200
# Episode 162, loss: -2.6802, total reward: -1.0000
# Episode 163, loss: -24.7714, total reward: -0.6200
# Episode 164, loss: -19.2539, total reward: -0.4000
# Episode 165, loss: -19.6225, total reward: -0.4600
# Episode 166, loss: -13.1475, total reward: -0.4000
# Episode 167, loss: -6.5519, total reward: -0.2000
# Episode 168, loss: -19.2145, total reward: -0.4200
# Episode 169, loss: -61.9480, total reward: -1.4000
# Episode 170, loss: -9.8491, total reward: -0.2100
# Episode 171, loss: -2.7164, total reward: -1.0000
# Episode 172, loss: -19.5869, total reward: -0.5200
# Episode 173, loss: -16.3433, total reward: -0.3100
# Episode 174, loss: -56.6991, total reward: -1.1700
# Episode 175, loss: -11.8551, total reward: -0.3200
# Episode 176, loss: -18.9831, total reward: -0.3000
# Episode 177, loss: -30.8720, total reward: -0.6200
# Episode 178, loss: -24.7453, total reward: -0.6200
# Episode 179, loss: -17.1370, total reward: -0.4200
# Episode 180, loss: -11.8952, total reward: -0.3200
# Episode 181, loss: -17.2916, total reward: -0.3100
# Episode 182, loss: -51.0275, total reward: -1.0100
# Episode 183, loss: -29.2453, total reward: -0.6200
# Episode 184, loss: -20.8710, total reward: -0.4200
# Episode 185, loss: -15.3583, total reward: -0.4200
# Episode 186, loss: -17.2899, total reward: -0.3400
# Episode 187, loss: -33.6480, total reward: -0.6100
# Episode 188, loss: -12.8296, total reward: -0.4300
# Episode 189, loss: -18.3158, total reward: -0.4200
# Episode 190, loss: -19.6503, total reward: -0.5100
# Episode 191, loss: -17.6014, total reward: -0.4300
# Episode 192, loss: -30.2343, total reward: -0.6100
# Episode 193, loss: -17.5555, total reward: -0.4200
# Episode 194, loss: -7.6038, total reward: -0.2200
# Episode 195, loss: 4.7983, total reward: -0.0100
# Episode 196, loss: -61.0650, total reward: -1.1600
# Episode 197, loss: -68.1294, total reward: -1.1100
# Episode 198, loss: -7.0997, total reward: -0.1000
# Episode 199, loss: -19.9307, total reward: -0.5600
# Episode 200, loss: -11.5134, total reward: -0.3100
# Episode 201, loss: -29.2783, total reward: -1.3100
# Episode 202, loss: -49.2706, total reward: -1.2300
# Episode 203, loss: -40.4245, total reward: -1.2700
# Episode 204, loss: -54.3731, total reward: -1.1700
# Episode 205, loss: -49.0261, total reward: -1.0200
# Episode 206, loss: -17.6112, total reward: -0.5000
# Episode 207, loss: -5.1450, total reward: -0.0000
# Episode 208, loss: -38.8296, total reward: -1.0100
# Episode 209, loss: 13.5511, total reward: 0.4100
# Episode 210, loss: -61.7383, total reward: -1.0200
# Episode 211, loss: -47.4128, total reward: -1.1500
# Episode 212, loss: -54.3132, total reward: -1.0200
# Episode 213, loss: 1.0289, total reward: 0.2100
# Episode 214, loss: -18.1360, total reward: -0.9000
# Episode 215, loss: 4.9792, total reward: 0.3900
# Episode 216, loss: -30.3157, total reward: -0.8700
# Episode 217, loss: -35.6350, total reward: -0.8000
# Episode 218, loss: -2.8201, total reward: -1.0000
# Episode 219, loss: 0.1339, total reward: 0.3100
# Episode 220, loss: -32.4572, total reward: -1.0400
# Episode 221, loss: 6.8272, total reward: 0.1100
# Episode 222, loss: -46.3472, total reward: -0.9400
# Episode 223, loss: -33.7795, total reward: -0.9400
# Episode 224, loss: 6.5986, total reward: 0.2700
# Episode 225, loss: -25.9135, total reward: -0.7600
# Episode 226, loss: -2.7329, total reward: -1.0000
# Episode 227, loss: -34.4389, total reward: -0.6900
# Episode 228, loss: -18.3405, total reward: -0.6200
# Episode 229, loss: -14.1853, total reward: -0.7800
# Episode 230, loss: -26.1418, total reward: -0.8100
# Episode 231, loss: -20.5509, total reward: -0.8700
# Episode 232, loss: -4.5195, total reward: -0.2000
# Episode 233, loss: -47.1988, total reward: -0.9400
# Episode 234, loss: -6.4101, total reward: -0.1000
# Episode 235, loss: -15.6841, total reward: -0.9600
# Episode 236, loss: -11.0853, total reward: -0.9400
# Episode 237, loss: -14.4842, total reward: -0.2000
# Episode 238, loss: -2.9287, total reward: -0.0100
# Episode 239, loss: -3.3394, total reward: 0.0000
# Episode 240, loss: 2.7473, total reward: 0.0900
# Episode 241, loss: -8.5839, total reward: -0.8300
# Episode 242, loss: -5.8858, total reward: -0.0100
# Episode 243, loss: -10.3618, total reward: -0.3100
# Episode 244, loss: -6.4564, total reward: -0.0000
# Episode 245, loss: 3.4548, total reward: -0.0000
# Episode 246, loss: 30.0034, total reward: 0.5100
# Episode 247, loss: -12.0478, total reward: -0.2000
# Episode 248, loss: -0.9804, total reward: 0.2100
# Episode 249, loss: -2.0181, total reward: 0.1000
# Episode 250, loss: -2.6652, total reward: 0.0800
# Episode 251, loss: -61.5110, total reward: -1.0000
# Episode 252, loss: -52.3760, total reward: -0.6500
# Episode 253, loss: -9.1340, total reward: -0.0100
# Episode 254, loss: -7.2433, total reward: 0.0100
# Episode 255, loss: -15.5036, total reward: -0.8600
# Episode 256, loss: 0.7386, total reward: 0.1800
# Episode 257, loss: -13.3622, total reward: -0.0700
# Episode 258, loss: -12.7844, total reward: -0.2000
# Episode 259, loss: -17.9002, total reward: -0.2200
# Episode 260, loss: -18.1065, total reward: -0.2100
# Episode 261, loss: -50.7807, total reward: -0.5700
# Episode 262, loss: 681.1250, total reward: 10.4700
# Episode 263, loss: -48.9014, total reward: -0.4900
# Episode 264, loss: -11.1077, total reward: -0.1100
# Episode 265, loss: 701.5881, total reward: 9.7900
# Episode 266, loss: -3.9851, total reward: 0.3000
# Episode 267, loss: 2.5454, total reward: 0.2000
# Episode 268, loss: -11.3816, total reward: -0.1300
# Episode 269, loss: -7.4428, total reward: -0.2100
# Episode 270, loss: -51.6462, total reward: -0.4300
# Episode 271, loss: -4.8497, total reward: 0.3000
# Episode 272, loss: -11.5112, total reward: -0.1100
# Episode 273, loss: -2.9148, total reward: 0.1000
# Episode 274, loss: -7.2458, total reward: -0.9200
# Episode 275, loss: 5.0283, total reward: 0.4000
# Episode 276, loss: -55.5341, total reward: -0.6400
# Episode 277, loss: 16.1548, total reward: 0.3100
# Episode 278, loss: 7.7253, total reward: 0.5100
# Episode 279, loss: 16.2335, total reward: 0.4100
# Episode 280, loss: 5.5610, total reward: 0.4000
# Episode 281, loss: 700.9822, total reward: 10.2400
# Episode 282, loss: -26.5729, total reward: -0.3200
# Episode 283, loss: -7.8137, total reward: -0.1100
# Episode 284, loss: 11.5073, total reward: 0.4100
# Episode 285, loss: 554.0506, total reward: 10.0000
# Episode 286, loss: 8.4478, total reward: 0.4800
# Episode 287, loss: -11.1033, total reward: -0.2300
# Episode 288, loss: 7.3069, total reward: 0.3000
# Episode 289, loss: 33.7220, total reward: 0.9200
# Episode 290, loss: -2.2690, total reward: -0.0000
# Episode 291, loss: -6.0681, total reward: -0.0000
# Episode 292, loss: 9.4245, total reward: 0.3000
# Episode 293, loss: -10.7674, total reward: -0.0100
# Episode 294, loss: -38.2079, total reward: -0.7000
# Episode 295, loss: -12.0812, total reward: 0.0300
# Episode 296, loss: -2.7757, total reward: -1.0000
# Episode 297, loss: 12.2434, total reward: 0.3000
# Episode 298, loss: -7.2282, total reward: -0.0100
# Episode 299, loss: 1.6492, total reward: 0.1900
# Episode 300, loss: 2.5517, total reward: 0.1000
# Episode 301, loss: -78.0409, total reward: -1.0600
# Episode 302, loss: 5.4081, total reward: 0.3000
# Episode 303, loss: -12.0616, total reward: 0.0100
# Episode 304, loss: -11.7443, total reward: -0.1100
# Episode 305, loss: -42.0627, total reward: -0.6200
# Episode 306, loss: -37.7708, total reward: -0.8500
# Episode 307, loss: -9.5185, total reward: -0.7300
# Episode 308, loss: 6.1466, total reward: 0.1000
# Episode 309, loss: -0.7566, total reward: 0.2000
# Episode 310, loss: -8.7012, total reward: -0.0000
# Episode 311, loss: -7.6085, total reward: -0.1000
# Episode 312, loss: 24.7770, total reward: 0.4100
# Episode 313, loss: 6.2523, total reward: 0.5000
# Episode 314, loss: 5.4135, total reward: 0.5000
# Episode 315, loss: 38.5136, total reward: 0.9200
# Episode 316, loss: 20.3949, total reward: 0.7100
# Episode 317, loss: 7.2476, total reward: 0.2800
# Episode 318, loss: 3.9727, total reward: 0.0900
# Episode 319, loss: -2.9292, total reward: -1.0000
# Episode 320, loss: 14.8266, total reward: 0.6200
# Episode 321, loss: 768.1111, total reward: 9.9100
# Episode 322, loss: 0.8869, total reward: -0.0100
# Episode 323, loss: -5.2871, total reward: -0.0100
# Episode 324, loss: 730.9963, total reward: 10.1200
# Episode 325, loss: 12.5408, total reward: 0.5100
# Episode 326, loss: 13.0209, total reward: 0.4100
# Episode 327, loss: -38.7708, total reward: -0.7100
# Episode 328, loss: 749.3007, total reward: 10.3300
# Episode 329, loss: 7.5285, total reward: 0.2100
# Episode 330, loss: 13.4468, total reward: 0.3100
# Episode 331, loss: -66.4397, total reward: -0.4600
# Episode 332, loss: -21.0749, total reward: -0.9700
# Episode 333, loss: 9.1101, total reward: 0.4000
# Episode 334, loss: 9.0945, total reward: 0.5900
# Episode 335, loss: -33.0390, total reward: -0.8500
# Episode 336, loss: 12.2236, total reward: 0.2000
# Episode 337, loss: 709.4496, total reward: 10.4100
# Episode 338, loss: -10.5209, total reward: -0.9300
# Episode 339, loss: -5.1837, total reward: 0.2000
# Episode 340, loss: 4.9529, total reward: 0.4000
# Episode 341, loss: 3.8488, total reward: 0.3000
# Episode 342, loss: 14.7049, total reward: 0.4200
# Episode 343, loss: 15.5944, total reward: 0.6100
# Episode 344, loss: -30.0694, total reward: -0.7300
# Episode 345, loss: 25.1903, total reward: 0.4100
# Episode 346, loss: 15.9257, total reward: 0.6100
# Episode 347, loss: 1.4205, total reward: 0.4000
# Episode 348, loss: 16.1688, total reward: 0.4100
# Episode 349, loss: 6.9201, total reward: 0.5000
# Episode 350, loss: 663.2335, total reward: 10.0300
# Episode 351, loss: 12.3937, total reward: 0.2100
# Episode 352, loss: -3.0675, total reward: -1.0000
# Episode 353, loss: 6.6239, total reward: 0.2000
# Episode 354, loss: -2.8785, total reward: 0.2000
# Episode 355, loss: 11.1441, total reward: 0.4100
# Episode 356, loss: -52.4443, total reward: -0.5800
# Episode 357, loss: -28.8319, total reward: -0.3900
# Episode 358, loss: 0.6660, total reward: 0.2800
# Episode 359, loss: 778.5361, total reward: 10.2600
# Episode 360, loss: 13.5599, total reward: 0.6200
# Episode 361, loss: 11.2377, total reward: 0.5100
# Episode 362, loss: -16.5448, total reward: -0.6700
# Episode 363, loss: -0.1315, total reward: 0.3000
# Episode 364, loss: -74.3146, total reward: -0.8300
# Episode 365, loss: 764.7200, total reward: 10.4100
# Episode 366, loss: 23.6966, total reward: 0.7100
# Episode 367, loss: 21.0328, total reward: 0.6100
# Episode 368, loss: 19.1216, total reward: 0.6100
# Episode 369, loss: 10.9437, total reward: 0.3900
# Episode 370, loss: 16.3314, total reward: 0.6100
# Episode 371, loss: -6.5485, total reward: 0.2300
# Episode 372, loss: -30.7270, total reward: -0.3500
# Episode 373, loss: 20.9802, total reward: 0.6100
# Episode 374, loss: -43.1745, total reward: -0.7000
# Episode 375, loss: 8.3124, total reward: 0.2500
# Episode 376, loss: -3.1309, total reward: -1.0000
# Episode 377, loss: 7.2213, total reward: 0.3000
# Episode 378, loss: 497.2445, total reward: 10.3500
# Episode 379, loss: 700.1605, total reward: 10.4700
# Episode 380, loss: 698.7615, total reward: 10.3500
# Episode 381, loss: 4.6815, total reward: 0.3000
# Episode 382, loss: 12.3158, total reward: 0.4000
# Episode 383, loss: 8.1953, total reward: 0.4800
# Episode 384, loss: 6.2711, total reward: 0.3000
# Episode 385, loss: 706.4885, total reward: 10.3700
# Episode 386, loss: -11.1838, total reward: 0.0900
# Episode 387, loss: 600.9579, total reward: 10.1700
# Episode 388, loss: -6.4627, total reward: 0.2000
# Episode 389, loss: 2.7123, total reward: 0.5000
# Episode 390, loss: -17.4876, total reward: -0.6700
# Episode 391, loss: -37.3303, total reward: -0.4700
# Episode 392, loss: 465.4327, total reward: 10.3900
# Episode 393, loss: -0.0706, total reward: 0.4000
# Episode 394, loss: 1.1502, total reward: 0.2000
# Episode 395, loss: -9.0860, total reward: 0.0900
# Episode 396, loss: 6.1656, total reward: 0.3900
# Episode 397, loss: -80.0390, total reward: -1.0700
# Episode 398, loss: 22.3290, total reward: 0.7100
# Episode 399, loss: 11.6256, total reward: 0.5000
# Episode 400, loss: -43.5339, total reward: -1.0100
# Episode 401, loss: 11.2738, total reward: 0.6100
# Episode 402, loss: 450.0043, total reward: 10.1800
# Episode 403, loss: -16.1908, total reward: -0.2100
# Episode 404, loss: -13.5075, total reward: -0.0100
# Episode 405, loss: 13.2340, total reward: 0.5900
# Episode 406, loss: -0.8071, total reward: 0.6200
# Episode 407, loss: 385.0514, total reward: 10.4200
# Episode 408, loss: -5.3467, total reward: 0.0900
# Episode 409, loss: 26.9557, total reward: 0.6700
# Episode 410, loss: 602.6391, total reward: 10.3000
# Episode 411, loss: 22.6140, total reward: 0.9100
# Episode 412, loss: 20.1519, total reward: 0.4700
# Episode 413, loss: 725.0898, total reward: 10.9300
# Episode 414, loss: -14.9558, total reward: -0.1500
# Episode 415, loss: -2.8132, total reward: 0.3000
# Episode 416, loss: 660.9069, total reward: 10.4100
# Episode 417, loss: 28.6640, total reward: 1.1200
# Episode 418, loss: -5.5100, total reward: -0.0000
# Episode 419, loss: 9.7135, total reward: 0.5000
# Episode 420, loss: 16.9132, total reward: 0.5000
# Episode 421, loss: 20.4974, total reward: 0.6100
# Episode 422, loss: 23.3293, total reward: 0.8200
# Episode 423, loss: 694.8713, total reward: 10.1500
# Episode 424, loss: -3.9843, total reward: 0.1000
# Episode 425, loss: -2.8242, total reward: 0.2000
# Episode 426, loss: 11.4825, total reward: 0.3100
# Episode 427, loss: -0.7736, total reward: 0.1000
# Episode 428, loss: 1.0494, total reward: 0.2100
# Episode 429, loss: 639.1270, total reward: 10.5200
# Episode 430, loss: -1.2309, total reward: 0.5000
# Episode 431, loss: -1.7694, total reward: 0.0100
# Episode 432, loss: -4.2102, total reward: 0.1000
# Episode 433, loss: 24.0003, total reward: 0.6100
# Episode 434, loss: 17.7080, total reward: 0.6100
# Episode 435, loss: -3.7957, total reward: -0.2400
# Episode 436, loss: -11.2054, total reward: 0.0900
# Episode 437, loss: 18.4771, total reward: 0.6100
# Episode 438, loss: 1.5858, total reward: 0.3400
# Episode 439, loss: 9.2852, total reward: 0.5000
# Episode 440, loss: 7.7599, total reward: 0.6100
# Episode 441, loss: 626.5945, total reward: 10.4400
# Episode 442, loss: 2.4445, total reward: 0.2100
# Episode 443, loss: 374.9858, total reward: 10.0400
# Episode 444, loss: -0.0262, total reward: 0.0900
# Episode 445, loss: -20.9228, total reward: -0.4100
# Episode 446, loss: 25.8782, total reward: 0.6200
# Episode 447, loss: -35.1741, total reward: -0.5700
# Episode 448, loss: 17.9450, total reward: 0.7100
# Episode 449, loss: 20.7258, total reward: 0.8200
# Episode 450, loss: 2.6029, total reward: 0.2000
# Episode 451, loss: 24.6152, total reward: 0.8200
# Episode 452, loss: 523.5637, total reward: 10.6200
# Episode 453, loss: 12.3508, total reward: 0.5100
# Episode 454, loss: -2.0237, total reward: 0.0500
# Episode 455, loss: 698.7482, total reward: 10.4000
# Episode 456, loss: -26.4228, total reward: -0.4400
# Episode 457, loss: -10.7866, total reward: 0.0200
# Episode 458, loss: 4.4975, total reward: 0.3000
# Episode 459, loss: 697.8374, total reward: 10.7100
# Episode 460, loss: 14.4685, total reward: 0.6100
# Episode 461, loss: 12.9931, total reward: 0.5000
# Episode 462, loss: -6.9530, total reward: 0.1900
# Episode 463, loss: 6.8198, total reward: 0.6100
# Episode 464, loss: -0.8155, total reward: 0.1700
# Episode 465, loss: 19.8264, total reward: 0.5100
# Episode 466, loss: -3.0442, total reward: 0.3000
# Episode 467, loss: 26.2662, total reward: 0.8100
# Episode 468, loss: 12.1049, total reward: 0.3900
# Episode 469, loss: 14.7287, total reward: 0.7100
# Episode 470, loss: 3.0242, total reward: 0.2000
# Episode 471, loss: 604.0105, total reward: 10.6900
# Episode 472, loss: -20.0982, total reward: -0.5900
# Episode 473, loss: 12.6183, total reward: 0.5600
# Episode 474, loss: 617.9513, total reward: 10.0300
# Episode 475, loss: 5.8921, total reward: 0.4100
# Episode 476, loss: 12.4575, total reward: 0.6100
# Episode 477, loss: 9.7819, total reward: 0.6100
# Episode 478, loss: 12.1612, total reward: 0.2000
# Episode 479, loss: 6.9145, total reward: 0.4100
# Episode 480, loss: 4.7298, total reward: 0.6600
# Episode 481, loss: -27.2527, total reward: -0.7000
# Episode 482, loss: 8.1571, total reward: 0.4100
# Episode 483, loss: 20.8188, total reward: 0.8200
# Episode 484, loss: 11.4814, total reward: 0.3100
# Episode 485, loss: -12.4383, total reward: -0.0600
# Episode 486, loss: -18.4360, total reward: 0.0500
# Episode 487, loss: 1.4167, total reward: 0.4000
# Episode 488, loss: 11.0891, total reward: 0.6100
# Episode 489, loss: 15.6578, total reward: 0.5100
# Episode 490, loss: 19.3314, total reward: 0.8100
# Episode 491, loss: 19.7791, total reward: 0.5100
# Episode 492, loss: 0.5343, total reward: 0.1200
# Episode 493, loss: 5.6700, total reward: 0.2000
# Episode 494, loss: 576.0110, total reward: 10.3300
# Episode 495, loss: 4.5627, total reward: 0.3000
# Episode 496, loss: 3.2746, total reward: 0.1500
# Episode 497, loss: -39.6313, total reward: -0.3800
# Episode 498, loss: -5.3008, total reward: 0.5100
# Episode 499, loss: -4.2608, total reward: -0.1000
# Episode 500, loss: -21.9715, total reward: -0.6000
# Episode 501, loss: 686.6964, total reward: 10.3000
# Episode 502, loss: 678.8643, total reward: 11.0800
# Episode 503, loss: -16.9917, total reward: -0.8500
# Episode 504, loss: 23.0591, total reward: 1.0300
# Episode 505, loss: -2.7500, total reward: 0.2000
# Episode 506, loss: 2.3261, total reward: 0.2100
# Episode 507, loss: 2.3443, total reward: 0.4100
# Episode 508, loss: 2.6717, total reward: 0.2000
# Episode 509, loss: 17.6787, total reward: 0.5000
# Episode 510, loss: 3.4408, total reward: 0.4000
# Episode 511, loss: -0.0421, total reward: 0.3000
# Episode 512, loss: -11.3312, total reward: 0.0800
# Episode 513, loss: 6.7249, total reward: 0.5000
# Episode 514, loss: 614.9433, total reward: 10.0400
# Episode 515, loss: 28.0310, total reward: 0.6100
# Episode 516, loss: -9.5534, total reward: 0.2000
# Episode 517, loss: 634.7313, total reward: 10.6100
# Episode 518, loss: 617.8198, total reward: 10.7000
# Episode 519, loss: 0.4886, total reward: 0.3000
# Episode 520, loss: 14.2140, total reward: 0.4100
# Episode 521, loss: 30.8613, total reward: 0.5100
# Episode 522, loss: -4.9576, total reward: -0.0100
# Episode 523, loss: 407.8712, total reward: 10.3800
# Episode 524, loss: -4.3862, total reward: -0.9100
# Episode 525, loss: 26.5015, total reward: 0.6900
# Episode 526, loss: 23.7083, total reward: 0.8100
# Episode 527, loss: 20.7648, total reward: 0.5100
# Episode 528, loss: 11.7888, total reward: 0.3000
# Episode 529, loss: -40.0786, total reward: -0.9500
# Episode 530, loss: -2.8595, total reward: 0.1400
# Episode 531, loss: 7.8275, total reward: 0.3000
# Episode 532, loss: 15.0622, total reward: 0.6000
# Episode 533, loss: 17.6848, total reward: 0.7000
# Episode 534, loss: 14.1502, total reward: 0.4100
# Episode 535, loss: -0.8720, total reward: 0.2900
# Episode 536, loss: 0.5909, total reward: 0.4000
# Episode 537, loss: -2.2735, total reward: 0.0900
# Episode 538, loss: -3.1834, total reward: -1.0000
# Episode 539, loss: 5.4359, total reward: 0.5100
# Episode 540, loss: -10.4445, total reward: -0.2100
# Episode 541, loss: 2.6046, total reward: 0.4100
# Episode 542, loss: -16.9498, total reward: -0.1100
# Episode 543, loss: 4.5719, total reward: 0.2000
# Episode 544, loss: 12.4375, total reward: 0.5000
# Episode 545, loss: -3.1596, total reward: -1.0000
# Episode 546, loss: 0.9146, total reward: 0.2000
# Episode 547, loss: -17.4615, total reward: -0.2100
# Episode 548, loss: -3.2024, total reward: 0.0900
# Episode 549, loss: 21.4878, total reward: 0.8100
# Episode 550, loss: 3.9958, total reward: 0.2000
# Episode 551, loss: -29.4927, total reward: -0.6100
# Episode 552, loss: -10.4651, total reward: -0.9500
# Episode 553, loss: -15.0065, total reward: -0.3200
# Episode 554, loss: 560.6927, total reward: 10.3000
# Episode 555, loss: 15.8763, total reward: 0.4100
# Episode 556, loss: 1.2066, total reward: 0.1000
# Episode 557, loss: 2.1243, total reward: 0.4000
# Episode 558, loss: 602.6797, total reward: 10.5000
# Episode 559, loss: -15.2328, total reward: -0.2100
# Episode 560, loss: 0.8334, total reward: 0.5000
# Episode 561, loss: -6.5814, total reward: -0.0100
# Episode 562, loss: 588.0825, total reward: 10.4900
# Episode 563, loss: -14.6905, total reward: -0.3900
# Episode 564, loss: -41.9660, total reward: -0.4300
# Episode 565, loss: 9.6384, total reward: 0.5100
# Episode 566, loss: 429.3694, total reward: 10.5700
# Episode 567, loss: 499.5842, total reward: 10.5500
# Episode 568, loss: 629.2713, total reward: 10.5500
# Episode 569, loss: 0.7604, total reward: 0.3200
# Episode 570, loss: -2.3788, total reward: 0.2000
# Episode 571, loss: 6.7393, total reward: 0.5100
# Episode 572, loss: 6.1771, total reward: 0.3100
# Episode 573, loss: -0.3067, total reward: 0.0900
# Episode 574, loss: 19.8692, total reward: 0.5000
# Episode 575, loss: 522.6432, total reward: 10.5300
# Episode 576, loss: 519.8032, total reward: 10.2700
# Episode 577, loss: -3.6302, total reward: 0.4000
# Episode 578, loss: -0.2426, total reward: 0.3900
# Episode 579, loss: -27.0441, total reward: -0.3800
# Episode 580, loss: 16.5659, total reward: 0.7100
# Episode 581, loss: 12.9314, total reward: 0.5000
# Episode 582, loss: 18.6795, total reward: 0.8100
# Episode 583, loss: 10.8085, total reward: 0.5000
# Episode 584, loss: -2.2481, total reward: 0.1800
# Episode 585, loss: -5.6964, total reward: 0.2000
# Episode 586, loss: 3.3099, total reward: 0.6100
# Episode 587, loss: -6.9414, total reward: -0.0700
# Episode 588, loss: 3.7698, total reward: 0.3000
# Episode 589, loss: 1.2543, total reward: 0.0900
# Episode 590, loss: -0.8203, total reward: 0.1000
# Episode 591, loss: 5.2341, total reward: 0.4000
# Episode 592, loss: 10.6825, total reward: 0.3000
# Episode 593, loss: 525.4218, total reward: 10.4600
# Episode 594, loss: 39.0537, total reward: 1.0200
# Episode 595, loss: 31.6515, total reward: 1.0200
# Episode 596, loss: -5.7875, total reward: 0.2000
# Episode 597, loss: 9.8346, total reward: 0.6100
# Episode 598, loss: 24.0882, total reward: 0.8200
# Episode 599, loss: -0.2787, total reward: 0.2000
# Episode 600, loss: -4.1142, total reward: 0.2000
# Episode 601, loss: 586.5179, total reward: 10.4600
# Episode 602, loss: 584.3307, total reward: 10.5100
# Episode 603, loss: 17.3191, total reward: 0.6100
# Episode 604, loss: -9.6739, total reward: -0.7500
# Episode 605, loss: -18.0518, total reward: -0.4400
# Episode 606, loss: 497.8399, total reward: 10.0000
# Episode 607, loss: -6.5293, total reward: -0.0200
# Episode 608, loss: -12.9880, total reward: -0.0200
# Episode 609, loss: 14.6923, total reward: 0.4100
# Episode 610, loss: 685.7457, total reward: 11.0500
# Episode 611, loss: 15.1988, total reward: 0.6100
# Episode 612, loss: 602.9728, total reward: 10.8400
# Episode 613, loss: 13.9638, total reward: 0.5000
# Episode 614, loss: -22.1349, total reward: -0.1300
# Episode 615, loss: -27.2749, total reward: -0.5500
# Episode 616, loss: 10.0433, total reward: 0.3000
# Episode 617, loss: -2.7049, total reward: 0.1900
# Episode 618, loss: 1.8613, total reward: 0.0900
# Episode 619, loss: 13.5954, total reward: 0.7100
# Episode 620, loss: 23.4188, total reward: 0.8200
# Episode 621, loss: -24.8527, total reward: -0.6900
# Episode 622, loss: 10.0027, total reward: 0.3700
# Episode 623, loss: 13.2253, total reward: 0.8100
# Episode 624, loss: 12.6258, total reward: 0.6100
# Episode 625, loss: -8.3694, total reward: -0.0500
# Episode 626, loss: 13.5430, total reward: 0.6100
# Episode 627, loss: -2.0410, total reward: 0.3000
# Episode 628, loss: 6.3494, total reward: 0.5000
# Episode 629, loss: -36.7146, total reward: -0.7300
# Episode 630, loss: 18.9538, total reward: 0.8000
# Episode 631, loss: 20.4282, total reward: 0.5100
# Episode 632, loss: 10.3078, total reward: 0.4100
# Episode 633, loss: -3.4797, total reward: 0.2000
# Episode 634, loss: 1.8881, total reward: 0.3000
# Episode 635, loss: -4.4874, total reward: 0.0900
# Episode 636, loss: 25.8838, total reward: 0.8100
# Episode 637, loss: -8.2546, total reward: -0.0100
# Episode 638, loss: 21.3120, total reward: 0.7100
# Episode 639, loss: -0.7656, total reward: 0.2200
# Episode 640, loss: -1.0779, total reward: 0.4000
# Episode 641, loss: -5.7941, total reward: 0.3000
# Episode 642, loss: 13.0529, total reward: 0.3800
# Episode 643, loss: 15.2705, total reward: 0.5000
# Episode 644, loss: 500.6330, total reward: 10.2100
# Episode 645, loss: 14.7087, total reward: 0.7100
# Episode 646, loss: 435.7312, total reward: 10.4700
# Episode 647, loss: 10.3943, total reward: 0.4100
# Episode 648, loss: 9.9625, total reward: 0.6100
# Episode 649, loss: 6.2788, total reward: 0.6100
# Episode 650, loss: 19.6831, total reward: 0.7100
# Episode 651, loss: -3.6410, total reward: 0.1300
# Episode 652, loss: 30.8830, total reward: 1.0200
# Episode 653, loss: 4.4980, total reward: 0.3000
# Episode 654, loss: 500.9890, total reward: 10.3700
# Episode 655, loss: 3.4399, total reward: 0.3000
# Episode 656, loss: 22.9233, total reward: 0.6200
# Episode 657, loss: 498.0953, total reward: 10.3100
# Episode 658, loss: -0.3287, total reward: 0.2000
# Episode 659, loss: 15.3702, total reward: 0.8100
# Episode 660, loss: -0.9675, total reward: 0.2900
# Episode 661, loss: 22.2861, total reward: 0.7100
# Episode 662, loss: 11.4331, total reward: 0.3000
# Episode 663, loss: -11.5247, total reward: -0.1100
# Episode 664, loss: 29.5327, total reward: 0.7100
# Episode 665, loss: 14.3145, total reward: 0.5000
# Episode 666, loss: 567.9266, total reward: 10.7400
# Episode 667, loss: 2.1936, total reward: 0.2000
# Episode 668, loss: -3.6626, total reward: 0.0900
# Episode 669, loss: 3.8538, total reward: 0.2000
# Episode 670, loss: 4.1095, total reward: 0.2000
# Episode 671, loss: 2.0981, total reward: 0.1300
# Episode 672, loss: -0.4290, total reward: 0.1000
# Episode 673, loss: 484.8794, total reward: 10.3000
# Episode 674, loss: 17.4731, total reward: 0.4000
# Episode 675, loss: -5.6419, total reward: 0.2000
# Episode 676, loss: 4.0221, total reward: 0.5000
# Episode 677, loss: 439.4657, total reward: 10.2800
# Episode 678, loss: 3.9963, total reward: 0.4000
# Episode 679, loss: 17.0796, total reward: 0.4900
# Episode 680, loss: 19.2218, total reward: 0.8100
# Episode 681, loss: 12.0154, total reward: 0.6100
# Episode 682, loss: -8.4856, total reward: -0.0100
# Episode 683, loss: 15.6155, total reward: 0.7100
# Episode 684, loss: 13.5857, total reward: 0.6100
# Episode 685, loss: 15.1864, total reward: 0.6100
# Episode 686, loss: 13.4272, total reward: 0.6100
# Episode 687, loss: -16.4691, total reward: -0.3400
# Episode 688, loss: 37.6755, total reward: 0.9100
# Episode 689, loss: 1.6275, total reward: 0.2000
# Episode 690, loss: 416.7241, total reward: 9.9300
# Episode 691, loss: -0.1471, total reward: -0.0300
# Episode 692, loss: 6.2380, total reward: 0.5100
# Episode 693, loss: 9.3356, total reward: 0.4800
# Episode 694, loss: 19.5520, total reward: 0.5100
# Episode 695, loss: 3.2912, total reward: 0.2100
# Episode 696, loss: 17.7269, total reward: 1.0200
# Episode 697, loss: -0.8800, total reward: 0.3000
# Episode 698, loss: 16.0890, total reward: 0.3100
# Episode 699, loss: 0.3733, total reward: 0.0900
# Episode 700, loss: 239.6582, total reward: 10.2700
# Episode 701, loss: 4.7413, total reward: 0.5000
# Episode 702, loss: 12.8119, total reward: 0.6100
# Episode 703, loss: 565.4261, total reward: 10.2900
# Episode 704, loss: -0.6177, total reward: 0.0900
# Episode 705, loss: -12.5453, total reward: -0.1100
# Episode 706, loss: 597.1196, total reward: 10.7800
# Episode 707, loss: -6.2841, total reward: 0.0900
# Episode 708, loss: -14.2309, total reward: -0.0700
# Episode 709, loss: 19.4428, total reward: 0.7100
# Episode 710, loss: 450.4264, total reward: 10.3400
# Episode 711, loss: 10.0344, total reward: 0.6100
# Episode 712, loss: 14.9852, total reward: 0.2100
# Episode 713, loss: 14.0581, total reward: 0.5000
# Episode 714, loss: 614.5762, total reward: 10.0200
# Episode 715, loss: 13.5040, total reward: 0.6100
# Episode 716, loss: 692.9922, total reward: 10.4500
# Episode 717, loss: 20.8074, total reward: 0.6100
# Episode 718, loss: -1.7261, total reward: 0.3800
# Episode 719, loss: -14.8480, total reward: -0.2100
# Episode 720, loss: 2.6504, total reward: 0.5000
# Episode 721, loss: 5.3493, total reward: 0.3000
# Episode 722, loss: -5.7668, total reward: 0.1000
# Episode 723, loss: 34.0279, total reward: 1.0200
# Episode 724, loss: -6.0317, total reward: -0.9100
# Episode 725, loss: -82.1347, total reward: -0.9700
# Episode 726, loss: -28.9317, total reward: -0.5900
# Episode 727, loss: -6.9351, total reward: 0.0000
# Episode 728, loss: 9.7685, total reward: 0.5000
# Episode 729, loss: 799.6528, total reward: 10.5100
# Episode 730, loss: 4.6012, total reward: 0.4000
# Episode 731, loss: 0.5046, total reward: 0.3000
# Episode 732, loss: 19.5756, total reward: 0.7100
# Episode 733, loss: -6.8349, total reward: 0.1900
# Episode 734, loss: -9.7995, total reward: 0.3000
# Episode 735, loss: 1.4098, total reward: 0.2000
# Episode 736, loss: 10.7882, total reward: 0.5000
# Episode 737, loss: 31.0374, total reward: 0.7100
# Episode 738, loss: 703.4823, total reward: 10.2600
# Episode 739, loss: 24.9839, total reward: 0.7100
# Episode 740, loss: 5.2389, total reward: 0.4000
# Episode 741, loss: 22.6934, total reward: 0.4900
# Episode 742, loss: 18.5194, total reward: 0.7100
# Episode 743, loss: 22.5007, total reward: 0.9200
# Episode 744, loss: -12.9367, total reward: 0.0400
# Episode 745, loss: 26.7934, total reward: 0.7200
# Episode 746, loss: 6.9114, total reward: 0.4000
# Episode 747, loss: 22.6987, total reward: 0.6100
# Episode 748, loss: -7.2020, total reward: 0.0600
# Episode 749, loss: 11.6080, total reward: 0.4000
# Episode 750, loss: 21.9299, total reward: 0.7100
# Episode 751, loss: 45.7698, total reward: 1.1200
# Episode 752, loss: 426.0068, total reward: 10.3100
# Episode 753, loss: 2.9389, total reward: 0.3000
# Episode 754, loss: 13.5186, total reward: 0.3000
# Episode 755, loss: -6.2739, total reward: 0.3000
# Episode 756, loss: 4.2716, total reward: 0.5800
# Episode 757, loss: -8.9028, total reward: -0.1100
# Episode 758, loss: 21.2044, total reward: 0.9100
# Episode 759, loss: -2.5892, total reward: 0.4000
# Episode 760, loss: 45.6008, total reward: 1.1200
# Episode 761, loss: 17.2150, total reward: 0.4900
# Episode 762, loss: 750.2852, total reward: 10.0000
# Episode 763, loss: 457.5123, total reward: 10.3200
# Episode 764, loss: -3.2609, total reward: 0.1900
# Episode 765, loss: 8.7487, total reward: 0.4900
# Episode 766, loss: 796.7204, total reward: 10.4800
# Episode 767, loss: 700.5529, total reward: 10.0200
# Episode 768, loss: 23.6286, total reward: 0.7100
# Episode 769, loss: -9.5503, total reward: -0.0000
# Episode 770, loss: -2.1831, total reward: 0.2000
# Episode 771, loss: 293.4996, total reward: 10.3800
# Episode 772, loss: 10.7938, total reward: 0.7100
# Episode 773, loss: 14.8185, total reward: 0.4900
# Episode 774, loss: 26.6573, total reward: 0.8100
# Episode 775, loss: 264.2576, total reward: 10.2800
# Episode 776, loss: 725.2220, total reward: 10.6600
# Episode 777, loss: -4.4668, total reward: 0.2000
# Episode 778, loss: -8.9126, total reward: -0.0100
# Episode 779, loss: -17.2621, total reward: 0.2100
# Episode 780, loss: 22.9007, total reward: 1.1200
# Episode 781, loss: 8.8629, total reward: 0.4000
# Episode 782, loss: 47.5815, total reward: 1.4300
# Episode 783, loss: 26.5804, total reward: 0.7100
# Episode 784, loss: 7.1697, total reward: 0.3000
# Episode 785, loss: 516.5104, total reward: 10.4200
# Episode 786, loss: 36.4999, total reward: 1.1000
# Episode 787, loss: 701.9973, total reward: 10.7200
# Episode 788, loss: 7.9660, total reward: 0.4000
# Episode 789, loss: 10.1422, total reward: 0.5000
# Episode 790, loss: 3.6497, total reward: -0.0100
# Episode 791, loss: -1.0081, total reward: 0.4000
# Episode 792, loss: 29.0836, total reward: 0.7000
# Episode 793, loss: 32.2893, total reward: 1.2200
# Episode 794, loss: 670.3096, total reward: 10.0800
# Episode 795, loss: 24.5226, total reward: 0.5000
# Episode 796, loss: 20.8660, total reward: 0.8200
# Episode 797, loss: 476.4549, total reward: 10.6700
# Episode 798, loss: 718.2036, total reward: 10.5900
# Episode 799, loss: 586.0346, total reward: 10.6300
# Episode 800, loss: 5.6146, total reward: 0.3000
# Episode 801, loss: 702.4907, total reward: 10.3100
# Episode 802, loss: 443.6030, total reward: 10.2700
# Episode 803, loss: 19.0935, total reward: 0.7000
# Episode 804, loss: 13.9546, total reward: 0.4100
# Episode 805, loss: 634.3289, total reward: 10.4700
# Episode 806, loss: 28.8119, total reward: 0.9200
# Episode 807, loss: -18.6807, total reward: -0.4100
# Episode 808, loss: -13.5034, total reward: -0.1600
# Episode 809, loss: -10.9650, total reward: 0.0400
# Episode 810, loss: 2.1983, total reward: 0.3000
# Episode 811, loss: 27.2695, total reward: 0.7100
# Episode 812, loss: 12.8221, total reward: 0.4000
# Episode 813, loss: 20.3154, total reward: 0.5000
# Episode 814, loss: 30.4578, total reward: 0.8100
# Episode 815, loss: 414.1169, total reward: 10.3100
# Episode 816, loss: -14.4684, total reward: -0.0600
# Episode 817, loss: 11.5538, total reward: 0.4000
# Episode 818, loss: -22.6306, total reward: -0.0400
# Episode 819, loss: 17.7047, total reward: 0.6100
# Episode 820, loss: 718.2961, total reward: 10.2400
# Episode 821, loss: -20.0231, total reward: -0.0000
# Episode 822, loss: 19.6621, total reward: 0.5100
# Episode 823, loss: 460.8579, total reward: 10.4600
# Episode 824, loss: 11.3234, total reward: 0.6100
# Episode 825, loss: 616.4352, total reward: 10.9200
# Episode 826, loss: 22.4030, total reward: 0.9100
# Episode 827, loss: 591.6357, total reward: 10.5200
# Episode 828, loss: 11.0363, total reward: 0.4100
# Episode 829, loss: 11.9017, total reward: 0.2800
# Episode 830, loss: -8.3114, total reward: -0.9200
# Episode 831, loss: 22.4256, total reward: 0.5900
# Episode 832, loss: 13.3925, total reward: 0.9100
# Episode 833, loss: -14.8083, total reward: -0.1200
# Episode 834, loss: 10.0258, total reward: 0.5000
# Episode 835, loss: 22.3269, total reward: 0.9100
# Episode 836, loss: 745.4657, total reward: 10.7300
# Episode 837, loss: 22.4372, total reward: 0.7200
# Episode 838, loss: -2.4415, total reward: 0.1800
# Episode 839, loss: 674.2295, total reward: 10.6300
# Episode 840, loss: -7.4627, total reward: -0.8200
# Episode 841, loss: -27.0972, total reward: -0.2900
# Episode 842, loss: 623.9779, total reward: 10.6100
# Episode 843, loss: 20.2902, total reward: 0.8100
# Episode 844, loss: -2.9496, total reward: 0.0900
# Episode 845, loss: 6.1813, total reward: 0.2000
# Episode 846, loss: 588.2121, total reward: 10.3100
# Episode 847, loss: 589.2656, total reward: 10.7000
# Episode 848, loss: 456.6944, total reward: 10.1700
# Episode 849, loss: 18.2383, total reward: 0.5100
# Episode 850, loss: 13.5198, total reward: 0.5000
# Episode 851, loss: -32.1034, total reward: 0.2100
# Episode 852, loss: 22.9105, total reward: 0.6900
# Episode 853, loss: 12.6255, total reward: 0.4000
# Episode 854, loss: -6.5755, total reward: -0.0600
# Episode 855, loss: 12.2922, total reward: 0.2000
# Episode 856, loss: 607.8786, total reward: 10.6700
# Episode 857, loss: 320.0934, total reward: 10.7400
# Episode 858, loss: 649.0616, total reward: 11.0400
# Episode 859, loss: -1.0397, total reward: 0.4100
# Episode 860, loss: -11.4521, total reward: 0.3000
# Episode 861, loss: 46.3104, total reward: 1.1200
# Episode 862, loss: 664.5953, total reward: 10.5000
# Episode 863, loss: -5.8480, total reward: 0.1800
# Episode 864, loss: 22.0271, total reward: 0.6100
# Episode 865, loss: 4.5281, total reward: 0.3000
# Episode 866, loss: -3.5553, total reward: -1.0000
# Episode 867, loss: 13.6056, total reward: 0.6100
# Episode 868, loss: 11.4866, total reward: 0.4000
# Episode 869, loss: 2.5804, total reward: 0.5000
# Episode 870, loss: -19.0662, total reward: -0.1100
# Episode 871, loss: 0.3391, total reward: 0.4000
# Episode 872, loss: -30.3027, total reward: -0.6500
# Episode 873, loss: 477.8603, total reward: 10.5400
# Episode 874, loss: 665.8527, total reward: 10.9600
# Episode 875, loss: 2.5539, total reward: 0.4000
# Episode 876, loss: 625.4738, total reward: 10.6000
# Episode 877, loss: 643.5901, total reward: 11.0900
# Episode 878, loss: 25.0857, total reward: 0.8000
# Episode 879, loss: 23.2598, total reward: 0.8200
# Episode 880, loss: 598.9635, total reward: 10.4700
# Episode 881, loss: 9.3003, total reward: 0.2700
# Episode 882, loss: 16.4153, total reward: 0.4800
# Episode 883, loss: 523.3918, total reward: 10.4100
# Episode 884, loss: 26.9585, total reward: 0.8100
# Episode 885, loss: 17.0918, total reward: 0.5100
# Episode 886, loss: 538.5727, total reward: 10.6400
# Episode 887, loss: -2.7989, total reward: 0.0900
# Episode 888, loss: -0.8038, total reward: 0.0600
# Episode 889, loss: 566.0207, total reward: 10.4500
# Episode 890, loss: 4.1941, total reward: 0.4300
# Episode 891, loss: 5.9674, total reward: 0.6500
# Episode 892, loss: 557.4832, total reward: 10.2500
# Episode 893, loss: -14.8489, total reward: -0.9500
# Episode 894, loss: 2.1884, total reward: 0.3000
# Episode 895, loss: 704.8921, total reward: 10.2400
# Episode 896, loss: 678.7064, total reward: 9.9900
# Episode 897, loss: 11.2459, total reward: 0.4000
# Episode 898, loss: 620.9595, total reward: 10.9400
# Episode 899, loss: -14.5953, total reward: -0.7500
# Episode 900, loss: 38.7310, total reward: 1.1200
# Episode 901, loss: 552.4949, total reward: 10.3700
# Episode 902, loss: 8.1596, total reward: 0.4000
# Episode 903, loss: 12.9082, total reward: 0.3000
# Episode 904, loss: 408.2156, total reward: 10.8100
# Episode 905, loss: 22.6602, total reward: 0.8200
# Episode 906, loss: -5.0709, total reward: 0.4000
# Episode 907, loss: -27.5276, total reward: 0.1100
# Episode 908, loss: 366.5857, total reward: 10.6900
# Episode 909, loss: 25.6663, total reward: 0.6100
# Episode 910, loss: 26.9953, total reward: 0.7100
# Episode 911, loss: 25.4511, total reward: 1.0600
# Episode 912, loss: 529.2408, total reward: 11.0500
# Episode 913, loss: 28.3675, total reward: 0.9100
# Episode 914, loss: 642.9658, total reward: 10.7900
# Episode 915, loss: 34.7602, total reward: 0.9100
# Episode 916, loss: 44.0330, total reward: 1.1200
# Episode 917, loss: -4.4284, total reward: 0.3500
# Episode 918, loss: 567.6296, total reward: 10.3500
# Episode 919, loss: 26.2699, total reward: 0.9100
# Episode 920, loss: 681.5072, total reward: 10.9400
# Episode 921, loss: 13.9250, total reward: 0.6300
# Episode 922, loss: 731.7302, total reward: 10.4300
# Episode 923, loss: 23.3642, total reward: 0.3700
# Episode 924, loss: 701.7480, total reward: 10.5500
# Episode 925, loss: 2.0280, total reward: 0.2500
# Episode 926, loss: 16.9212, total reward: 0.7100
# Episode 927, loss: 667.4340, total reward: 10.4300
# Episode 928, loss: 7.6480, total reward: 0.4000
# Episode 929, loss: 699.3858, total reward: 11.0500
# Episode 930, loss: 3.4141, total reward: 0.2700
# Episode 931, loss: 6.0489, total reward: 0.3000
# Episode 932, loss: 22.4318, total reward: 0.7100
# Episode 933, loss: 30.7041, total reward: 0.7100
# Episode 934, loss: 588.7864, total reward: 10.3200
# Episode 935, loss: 493.3168, total reward: 11.0900
# Episode 936, loss: 37.0685, total reward: 1.3200
# Episode 937, loss: 514.3699, total reward: 10.7200
# Episode 938, loss: 629.5375, total reward: 11.0800
# Episode 939, loss: 707.4247, total reward: 10.5600
# Episode 940, loss: 614.0610, total reward: 10.1500
# Episode 941, loss: 484.8007, total reward: 10.7100
# Episode 942, loss: 637.2456, total reward: 10.3800
# Episode 943, loss: 21.7025, total reward: 0.8100
# Episode 944, loss: 15.5995, total reward: 0.7100
# Episode 945, loss: 31.8162, total reward: 0.8100
# Episode 946, loss: -8.2448, total reward: 0.2700
# Episode 947, loss: -32.0168, total reward: -0.5100
# Episode 948, loss: 6.0524, total reward: 0.5100
# Episode 949, loss: 611.4062, total reward: 10.3500
# Episode 950, loss: 440.6197, total reward: 10.3600
# Episode 951, loss: 709.1572, total reward: 10.3500
# Episode 952, loss: 14.1038, total reward: 0.2000
# Episode 953, loss: 22.8432, total reward: 0.8100
# Episode 954, loss: -3.6940, total reward: 0.2000
# Episode 955, loss: 31.2356, total reward: 0.8200
# Episode 956, loss: 485.8670, total reward: 10.9300
# ...
# Episode 9686, loss: 317.8664, total reward: 10.6000
# Episode 9687, loss: 18.1010, total reward: 1.0200
# Episode 9688, loss: 340.5593, total reward: 10.1500
# Episode 9689, loss: 17.5186, total reward: 0.6100
# Episode 9690, loss: 14.5856, total reward: 0.5800
# Episode 9691, loss: -5.0261, total reward: -0.0200
# Episode 9692, loss: 18.2720, total reward: 0.8100
# Episode 9693, loss: 6.9546, total reward: 0.4000
# Episode 9694, loss: 349.5874, total reward: 10.2200
# Episode 9695, loss: 294.1256, total reward: 10.3100
# Episode 9696, loss: 330.5168, total reward: 10.4900
# Episode 9697, loss: 240.4796, total reward: 10.6200
# Episode 9698, loss: 2.4048, total reward: 0.2000
# Episode 9699, loss: 7.0991, total reward: 0.6100
# Episode 9700, loss: 332.1652, total reward: 10.6700
# Episode 9701, loss: 3.8496, total reward: 0.6100
# Episode 9702, loss: 16.4056, total reward: 0.6100
# Episode 9703, loss: 7.9542, total reward: 0.8100
# Episode 9704, loss: 17.2246, total reward: 0.9100
# Episode 9705, loss: 16.3499, total reward: 0.8100
# Episode 9706, loss: 7.0029, total reward: 0.3000
# Episode 9707, loss: 9.2331, total reward: 0.8100
# Episode 9708, loss: 378.3146, total reward: 10.2200
# Episode 9709, loss: 369.4692, total reward: 11.0200
# Episode 9710, loss: 10.0984, total reward: 0.8100
# Episode 9711, loss: 8.5148, total reward: 0.5000
# Episode 9712, loss: 402.9870, total reward: 10.7200
# Episode 9713, loss: 16.9880, total reward: 0.6100
# Episode 9714, loss: 13.5650, total reward: 1.0200
# Episode 9715, loss: 5.2860, total reward: 0.3000
# Episode 9716, loss: 29.9335, total reward: 1.4300
# Episode 9717, loss: 17.4229, total reward: 0.8600
# Episode 9718, loss: 2.8269, total reward: 0.3000
# Episode 9719, loss: 18.5900, total reward: 1.2200
# Episode 9720, loss: 22.6511, total reward: 1.0200
# Episode 9721, loss: 8.0977, total reward: 0.3900
# Episode 9722, loss: 10.9588, total reward: 0.5000
# Episode 9723, loss: 5.4169, total reward: 0.5000
# Episode 9724, loss: -0.7543, total reward: 0.4000
# Episode 9725, loss: 8.8469, total reward: 0.5000
# Episode 9726, loss: 17.1181, total reward: 1.0200
# Episode 9727, loss: 336.3842, total reward: 10.4100
# Episode 9728, loss: 4.2438, total reward: 0.3000
# Episode 9729, loss: 257.1294, total reward: 10.2300
# Episode 9730, loss: 4.3151, total reward: 0.4000
# Episode 9731, loss: 10.0310, total reward: 0.7100
# Episode 9732, loss: 296.5060, total reward: 10.4500
# Episode 9733, loss: -8.5563, total reward: 0.0700
# Episode 9734, loss: 14.3800, total reward: 0.7000
# Episode 9735, loss: -3.2598, total reward: 0.4000
# Episode 9736, loss: -1.4032, total reward: 0.3000
# Episode 9737, loss: 7.5099, total reward: 0.5000
# Episode 9738, loss: 391.6208, total reward: 10.7300
# Episode 9739, loss: 419.0998, total reward: 10.9600
# Episode 9740, loss: 297.7206, total reward: 10.6800
# Episode 9741, loss: 21.4754, total reward: 1.0100
# Episode 9742, loss: 288.3954, total reward: 10.5100
# Episode 9743, loss: 2.9044, total reward: 0.4000
# Episode 9744, loss: 28.8934, total reward: 1.2200
# Episode 9745, loss: 8.4399, total reward: 0.8100
# Episode 9746, loss: 0.8482, total reward: 0.0900
# Episode 9747, loss: 12.3558, total reward: 0.7100
# Episode 9748, loss: 14.6904, total reward: 0.8100
# Episode 9749, loss: 280.3533, total reward: 10.4100
# Episode 9750, loss: -5.9677, total reward: -0.0300
# Episode 9751, loss: 3.3839, total reward: 0.3000
# Episode 9752, loss: 22.5928, total reward: 1.0800
# Episode 9753, loss: 378.2153, total reward: 10.4100
# Episode 9754, loss: 352.2977, total reward: 10.7800
# Episode 9755, loss: 7.1783, total reward: 0.5100
# Episode 9756, loss: -2.5286, total reward: 0.1900
# Episode 9757, loss: 9.4667, total reward: 0.5000
# Episode 9758, loss: -1.5392, total reward: 0.2000
# Episode 9759, loss: 12.0045, total reward: 0.8100
# Episode 9760, loss: 26.8067, total reward: 1.4300
# Episode 9761, loss: 308.6562, total reward: 10.7400
# Episode 9762, loss: 7.4732, total reward: 0.5000
# Episode 9763, loss: 200.0555, total reward: 10.2500
# Episode 9764, loss: 318.6919, total reward: 10.9100
# Episode 9765, loss: 1.0583, total reward: 0.2000
# Episode 9766, loss: 364.1019, total reward: 10.7500
# Episode 9767, loss: 8.5549, total reward: 0.6100
# Episode 9768, loss: 14.6665, total reward: 1.0200
# Episode 9769, loss: 404.8785, total reward: 10.9000
# Episode 9770, loss: 6.7977, total reward: 0.5000
# Episode 9771, loss: 369.6718, total reward: 10.6100
# Episode 9772, loss: 299.9996, total reward: 10.3600
# Episode 9773, loss: 12.0503, total reward: 0.6100
# Episode 9774, loss: 394.9892, total reward: 10.6300
# Episode 9775, loss: 25.8274, total reward: 1.2200
# Episode 9776, loss: 0.4556, total reward: 0.4000
# Episode 9777, loss: 311.9799, total reward: 10.8500
# Episode 9778, loss: 170.4812, total reward: 10.2500
# Episode 9779, loss: 385.8197, total reward: 10.5000
# Episode 9780, loss: 210.6477, total reward: 10.5500
# Episode 9781, loss: 371.3691, total reward: 10.6000
# Episode 9782, loss: 388.6052, total reward: 10.7200
# Episode 9783, loss: 20.5773, total reward: 1.0200
# Episode 9784, loss: 9.7430, total reward: 0.6100
# Episode 9785, loss: 438.4749, total reward: 10.5200
# Episode 9786, loss: 6.8189, total reward: 0.8100
# Episode 9787, loss: 14.3809, total reward: 0.7900
# Episode 9788, loss: 8.8147, total reward: 0.6000
# Episode 9789, loss: -7.7493, total reward: 0.0800
# Episode 9790, loss: 4.8183, total reward: 0.5000
# Episode 9791, loss: 367.8438, total reward: 10.8200
# Episode 9792, loss: 13.2362, total reward: 0.7100
# Episode 9793, loss: 16.8503, total reward: 0.9100
# Episode 9794, loss: 425.4678, total reward: 10.8500
# Episode 9795, loss: 4.4210, total reward: 0.2000
# Episode 9796, loss: 412.5829, total reward: 10.5800
# Episode 9797, loss: 280.3573, total reward: 10.5500
# Episode 9798, loss: 308.3485, total reward: 10.5000
# Episode 9799, loss: 402.4801, total reward: 10.9300
# Episode 9800, loss: 337.5526, total reward: 10.7800
# Episode 9801, loss: 425.1587, total reward: 10.3600
# Episode 9802, loss: 387.4529, total reward: 10.7200
# Episode 9803, loss: 332.7432, total reward: 11.1200
# Episode 9804, loss: 335.3717, total reward: 10.7000
# Episode 9805, loss: 394.0211, total reward: 10.9800
# Episode 9806, loss: 457.2654, total reward: 10.6100
# Episode 9807, loss: 3.3889, total reward: 0.4000
# Episode 9808, loss: 359.9715, total reward: 10.6000
# Episode 9809, loss: 21.8383, total reward: 1.0200
# Episode 9810, loss: 378.8708, total reward: 10.2700
# Episode 9811, loss: 338.0433, total reward: 10.7000
# Episode 9812, loss: -3.4998, total reward: 0.0900
# Episode 9813, loss: 11.9306, total reward: 0.7800
# Episode 9814, loss: 441.6177, total reward: 10.3100
# Episode 9815, loss: 287.4345, total reward: 10.4700
# Episode 9816, loss: 431.0774, total reward: 11.1300
# Episode 9817, loss: -2.5047, total reward: 0.4000
# Episode 9818, loss: 23.2630, total reward: 1.2200
# Episode 9819, loss: 351.4850, total reward: 10.5200
# Episode 9820, loss: 21.0340, total reward: 0.8100
# Episode 9821, loss: 2.1328, total reward: 0.5900
# Episode 9822, loss: 1.3197, total reward: 0.2000
# Episode 9823, loss: 9.3674, total reward: 0.5000
# Episode 9824, loss: 10.5373, total reward: 0.6800
# Episode 9825, loss: 3.8225, total reward: 0.3000
# Episode 9826, loss: 15.1361, total reward: 0.7100
# Episode 9827, loss: 9.8275, total reward: 0.6100
# Episode 9828, loss: 9.2627, total reward: 0.7900
# Episode 9829, loss: 392.0342, total reward: 10.6200
# Episode 9830, loss: 22.8084, total reward: 1.1200
# Episode 9831, loss: 26.1434, total reward: 1.3200
# Episode 9832, loss: 325.7437, total reward: 10.7700
# Episode 9833, loss: 409.1721, total reward: 10.5000
# Episode 9834, loss: 181.5323, total reward: 10.3900
# Episode 9835, loss: 4.7724, total reward: 0.5000
# Episode 9836, loss: -3.8730, total reward: -0.0300
# Episode 9837, loss: 19.8827, total reward: 1.1200
# Episode 9838, loss: 405.5851, total reward: 10.7200
# Episode 9839, loss: 325.0206, total reward: 10.8900
# Episode 9840, loss: 16.0455, total reward: 0.8100
# Episode 9841, loss: 375.2688, total reward: 11.0300
# Episode 9842, loss: 223.1391, total reward: 10.5200
# Episode 9843, loss: 0.0831, total reward: 0.3000
# Episode 9844, loss: 276.3168, total reward: 10.2600
# Episode 9845, loss: 260.7166, total reward: 10.7700
# Episode 9846, loss: 6.6101, total reward: 0.2900
# Episode 9847, loss: 426.2072, total reward: 10.3100
# Episode 9848, loss: 17.8164, total reward: 0.8100
# Episode 9849, loss: 291.7076, total reward: 10.4500
# Episode 9850, loss: 16.3191, total reward: 0.7100
# Episode 9851, loss: 262.9571, total reward: 10.4700
# Episode 9852, loss: 24.7062, total reward: 1.4300
# Episode 9853, loss: 469.5755, total reward: 10.8200
# Episode 9854, loss: 372.5267, total reward: 11.3700
# Episode 9855, loss: 9.4246, total reward: 0.6100
# Episode 9856, loss: 19.8470, total reward: 1.3200
# Episode 9857, loss: 16.4588, total reward: 0.9100
# Episode 9858, loss: 461.5792, total reward: 10.8400
# Episode 9859, loss: 23.1485, total reward: 0.9800
# Episode 9860, loss: 18.5179, total reward: 1.0200
# Episode 9861, loss: 0.6867, total reward: 0.0800
# Episode 9862, loss: 376.2253, total reward: 10.3600
# Episode 9863, loss: 474.2744, total reward: 10.3400
# Episode 9864, loss: 295.2508, total reward: 10.6300
# Episode 9865, loss: 28.6879, total reward: 1.2200
# Episode 9866, loss: -22.4053, total reward: -0.2000
# Episode 9867, loss: 382.3717, total reward: 10.7700
# Episode 9868, loss: 281.3753, total reward: 10.6800
# Episode 9869, loss: 7.0414, total reward: 0.7800
# Episode 9870, loss: 268.0507, total reward: 10.4100
# Episode 9871, loss: 314.7904, total reward: 10.7800
# Episode 9872, loss: 14.3445, total reward: 0.7100
# Episode 9873, loss: 396.0598, total reward: 11.1700
# Episode 9874, loss: 382.6166, total reward: 11.1200
# Episode 9875, loss: 29.4143, total reward: 1.1900
# Episode 9876, loss: 436.1693, total reward: 10.6100
# Episode 9877, loss: 25.4435, total reward: 1.2100
# Episode 9878, loss: 22.0198, total reward: 0.7100
# Episode 9879, loss: 407.3806, total reward: 11.0500
# Episode 9880, loss: 6.8977, total reward: 0.4000
# Episode 9881, loss: 431.4663, total reward: 10.5300
# Episode 9882, loss: 383.7544, total reward: 11.1900
# Episode 9883, loss: 235.7198, total reward: 10.4500
# Episode 9884, loss: 355.1176, total reward: 10.3300
# Episode 9885, loss: 32.4777, total reward: 1.5300
# Episode 9886, loss: 267.0856, total reward: 10.8900
# Episode 9887, loss: 26.6955, total reward: 1.3200
# Episode 9888, loss: 354.3734, total reward: 10.8800
# Episode 9889, loss: 448.0148, total reward: 10.2200
# Episode 9890, loss: 25.2745, total reward: 1.3200
# Episode 9891, loss: 9.5372, total reward: 0.8100
# Episode 9892, loss: -1.4373, total reward: 0.4000
# Episode 9893, loss: 386.9004, total reward: 10.6000
# Episode 9894, loss: -5.5371, total reward: 0.0900
# Episode 9895, loss: 334.3120, total reward: 10.2400
# Episode 9896, loss: 4.2691, total reward: 0.0700
# Episode 9897, loss: 396.9235, total reward: 11.0300
# Episode 9898, loss: 388.7778, total reward: 10.3100
# Episode 9899, loss: 2.8822, total reward: 0.4000
# Episode 9900, loss: 6.7354, total reward: 0.4000
# Episode 9901, loss: 14.0420, total reward: 1.1200
# Episode 9902, loss: 16.5277, total reward: 0.9100
# Episode 9903, loss: 5.2984, total reward: 0.5000
# Episode 9904, loss: 22.1081, total reward: 1.1200
# Episode 9905, loss: 9.8264, total reward: 0.6100
# Episode 9906, loss: 432.0928, total reward: 11.1000
# Episode 9907, loss: 1.8379, total reward: 0.3000
# Episode 9908, loss: 267.5060, total reward: 10.2800
# Episode 9909, loss: 5.0294, total reward: 0.4900
# Episode 9910, loss: 12.8839, total reward: 0.7100
# Episode 9911, loss: 13.0628, total reward: 0.8700
# Episode 9912, loss: -1.5055, total reward: 0.4000
# Episode 9913, loss: 344.6174, total reward: 10.3900
# Episode 9914, loss: 400.6361, total reward: 10.3100
# Episode 9915, loss: 11.0339, total reward: 0.7000
# Episode 9916, loss: 308.0763, total reward: 10.5300
# Episode 9917, loss: 12.8004, total reward: 1.0200
# Episode 9918, loss: -4.1756, total reward: 0.0500
# Episode 9919, loss: 22.3823, total reward: 0.7100
# Episode 9920, loss: 16.6274, total reward: 0.7000
# Episode 9921, loss: 19.4093, total reward: 0.8100
# Episode 9922, loss: 5.4545, total reward: 0.5700
# Episode 9923, loss: 5.0765, total reward: 0.5000
# Episode 9924, loss: 280.9732, total reward: 10.1700
# Episode 9925, loss: 1.8295, total reward: 0.3000
# Episode 9926, loss: 7.6901, total reward: 0.6100
# Episode 9927, loss: 1.3966, total reward: 0.2000
# Episode 9928, loss: 8.3811, total reward: 0.2800
# Episode 9929, loss: 2.8998, total reward: 0.5000
# Episode 9930, loss: -4.8299, total reward: -0.0400
# Episode 9931, loss: 16.7640, total reward: 1.2200
# Episode 9932, loss: 11.4483, total reward: 0.6100
# Episode 9933, loss: 8.3425, total reward: 0.3000
# Episode 9934, loss: 6.3312, total reward: 0.4000
# Episode 9935, loss: 6.1770, total reward: 0.3900
# Episode 9936, loss: 26.7130, total reward: 1.3200
# Episode 9937, loss: 10.8392, total reward: 0.6100
# Episode 9938, loss: 3.2203, total reward: 0.4000
# Episode 9939, loss: 2.7890, total reward: 0.5000
# Episode 9940, loss: 373.3806, total reward: 10.1000
# Episode 9941, loss: 10.0658, total reward: 0.6700
# Episode 9942, loss: 5.8641, total reward: 0.6100
# Episode 9943, loss: 11.5201, total reward: 0.4000
# Episode 9944, loss: 289.2319, total reward: 10.7800
# Episode 9945, loss: 15.9151, total reward: 0.9100
# Episode 9946, loss: 3.0585, total reward: 0.3000
# Episode 9947, loss: 9.7566, total reward: 0.6100
# Episode 9948, loss: 261.2023, total reward: 10.4200
# Episode 9949, loss: 7.5445, total reward: 0.3900
# Episode 9950, loss: 13.0296, total reward: 0.7100
# Episode 9951, loss: 4.2716, total reward: 0.2000
# Episode 9952, loss: 14.7214, total reward: 0.7100
# Episode 9953, loss: 4.9918, total reward: 0.5000
# Episode 9954, loss: 12.3728, total reward: 0.7100
# Episode 9955, loss: 6.1870, total reward: 0.4000
# Episode 9956, loss: 210.4325, total reward: 10.5500
# Episode 9957, loss: 14.5100, total reward: 0.8100
# Episode 9958, loss: 17.6200, total reward: 0.8100
# Episode 9959, loss: 366.3072, total reward: 10.5500
# Episode 9960, loss: 0.6705, total reward: 0.4500
# Episode 9961, loss: -2.3461, total reward: 0.0900
# Episode 9962, loss: 378.3188, total reward: 10.2500
# Episode 9963, loss: -5.2171, total reward: -0.2100
# Episode 9964, loss: -6.5247, total reward: 0.0700
# Episode 9965, loss: 17.2278, total reward: 0.7100
# Episode 9966, loss: 8.5165, total reward: 0.3000
# Episode 9967, loss: 12.8020, total reward: 0.9100
# Episode 9968, loss: 389.1557, total reward: 10.1000
# Episode 9969, loss: -3.2818, total reward: 0.1800
# Episode 9970, loss: 4.6145, total reward: 0.5000
# Episode 9971, loss: -7.1397, total reward: 0.0900
# Episode 9972, loss: 430.0968, total reward: 10.7600
# Episode 9973, loss: 16.5246, total reward: 0.9100
# Episode 9974, loss: 12.5206, total reward: 0.9100
# Episode 9975, loss: 7.3909, total reward: 0.5000
# Episode 9976, loss: 8.7634, total reward: 0.4000
# Episode 9977, loss: 8.7540, total reward: 0.4700
# Episode 9978, loss: 12.4725, total reward: 0.7100
# Episode 9979, loss: 15.6016, total reward: 0.7100
# Episode 9980, loss: 3.1758, total reward: 0.5000
# Episode 9981, loss: 6.6862, total reward: 0.4000
# Episode 9982, loss: 19.5512, total reward: 1.0200
# Episode 9983, loss: 296.3365, total reward: 10.3200
# Episode 9984, loss: -8.3086, total reward: -0.3200
# Episode 9985, loss: 17.8362, total reward: 0.8100
# Episode 9986, loss: -0.4479, total reward: 0.3000
# Episode 9987, loss: 261.6385, total reward: 10.7800
# Episode 9988, loss: 6.9442, total reward: 0.0800
# Episode 9989, loss: 1.7714, total reward: 0.4000
# Episode 9990, loss: 11.7744, total reward: 0.8100
# Episode 9991, loss: 2.3008, total reward: 0.0900
# Episode 9992, loss: 16.4091, total reward: 0.9100
# Episode 9993, loss: 3.1277, total reward: 0.4000
# Episode 9994, loss: 309.0478, total reward: 10.6100
# Episode 9995, loss: -2.3140, total reward: 0.0900
# Episode 9996, loss: 14.2532, total reward: 0.9100
# Episode 9997, loss: -1.2014, total reward: 0.2000
# Episode 9998, loss: 10.2454, total reward: 0.5000
# Episode 9999, loss: 426.0506, total reward: 10.6700
# Checkpoint saved at episode 10000 to datasets/rl_sort_transformer_easy/list8_transformer3_128_gamma099_step210/ckpt_10000_4.4066.pth

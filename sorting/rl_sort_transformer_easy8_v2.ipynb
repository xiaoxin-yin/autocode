# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import random

MIN_LIST_LEN = 8
MAX_LIST_LEN = 8
MAX_STEPS = 210

SUCCESS_REWARD = 2.0
STEP_REWARD = -0.2
COMPARISON_ENTROPY_MULTIPLIER = -0.05
SWAP_REWARD = 1.0
INVALID_ACTION_REWARD = -10.0

EPS_START = 0.5
EPS_END = 0.05
EPS_DECAY = 1000
GAMMA = 0.9
NUM_EPISODES = 100000
EPISODES_SAVE = 1000
OUTPUT_DIR = 'datasets/rl_sort_transformer_easy/list8_transformer4_192_gamma09_step210_v2'

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    'less': 2,
    'equal': 3,
    'more': 4,
    '0': 5,
    '1': 6,
    '2': 7,
    '3': 8,
    '4': 9,
    '5': 10,
    '6': 11,
    '7': 12,
    '8': 13,
    '9': 14,
    '10': 15,
    '11': 16,
    '12': 17,
    '13': 18,
    '14': 19,
    '15': 20,
    'len1': 21,
    'len2': 22,
    'len3': 23,
    'len4': 24,
    'len5': 25,
    'len6': 26,
    'len7': 27,
    'len8': 28,
    'len9': 29,
    'len10': 30,
    'len11': 31,
    'len12': 32,
    'len13': 33,
    'len14': 34,
    'len15': 35,
    'len16': 36,
}
inv_vocab = {v: k for k, v in vocab.items()}

def compute_entropy(N, alpha=1):
    K = 2**N
    values = np.arange(K)
    unnormalized_probs = np.exp(-alpha * values)
    Z = unnormalized_probs.sum()
    probs = unnormalized_probs / Z
    return values, -np.log2(probs)

_, int_entropy = compute_entropy(4)

def get_entropy_of_integer(x):
    x = min(15, abs(x))
    return int_entropy[x]

def compute_min_delta_entropy(comparisons):
    # Initialize the result list to store minDelta values
    min_delta = None

    # Iterate through each pair in the comparisons list
    i = len(comparisons) - 1
    xi, yi = comparisons[i]
    if i == 0:
        # For i = 0, use the first case directly
        min_delta = (xi, min(yi, yi - xi), 0)
    else:
        # For i > 0, compute all possible options and select the minimal one
        options = []

        # Simple Entropy
        simple_entropy = (xi, min(yi, yi - xi), 0)
        options.append(simple_entropy)

        # First Delta Entropy
        xi_prev, yi_prev = comparisons[i - 1]
        first_delta_entropy = (xi - xi_prev, yi - yi_prev, 0)
        options.append(first_delta_entropy)

        # Second Delta Entropy (only valid for i > 1)
        if i > 1:
            xi_prev2, yi_prev2 = comparisons[i - 2]
            second_delta_entropy = (
                (xi - xi_prev) - (xi_prev - xi_prev2),
                (yi - yi_prev) - (yi_prev - yi_prev2),
                0,
            )
            options.append(second_delta_entropy)

        # Arbitrary Position Entropy (only valid for i > 1)
        for j in range(i):
            xj, yj = comparisons[j]
            arbitrary_position_entropy = (
                xi - xj,
                yi - yj,
                min(j, i - j),
            )
            options.append(arbitrary_position_entropy)

        # Find the option with the minimal sum
        min_delta = min(options, key=lambda t: sum([get_entropy_of_integer(x) for x in t]))

    return sum([get_entropy_of_integer(x) for x in min_delta])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.list = [random.randint(1, 100) for _ in range(self.length)]
        while self.list == sorted(self.list):
            self.list = [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        initial_token = 'len{}'.format(self.length)
        return vocab[initial_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_list_len(self):
        return len(self.list)

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 >= self.length or index2 >= self.length or index1 < 0 or index2 < 0:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = STEP_REWARD
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = STEP_REWARD * 2
            else:
                response_token = vocab['more']
                reward = STEP_REWARD
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = SUCCESS_REWARD
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = SWAP_REWARD
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -SWAP_REWARD
            else:
                reward = STEP_REWARD
            self.indices = None
        else:
            reward = INVALID_ACTION_REWARD
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()
# Out:
# Using device: cuda

# %%
# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=512):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=192, nhead=8, num_layers=4):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])


def save_checkpoint(model, optimizer, episode, folder, filename):
    """
    Save the model and optimizer state to the designated filepath.

    Args:
        model (nn.Module): The model to save.
        optimizer (torch.optim.Optimizer): The optimizer whose state to save.
        episode (int): The current episode number.
        filepath (str): The path where to save the checkpoint.
    """
    filepath = os.path.join(folder, filename)
    # Ensure the directory exists
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    # Save the checkpoint
    torch.save({
        'episode': episode,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, filepath)
    print(f"Checkpoint saved at episode {episode} to {filepath}")

def load_checkpoint(filepath, model, optimizer):
    """
    Load the model and optimizer state from the designated filepath.

    Args:
        filepath (str): The path from where to load the checkpoint.
        model (nn.Module): The model into which to load the state_dict.
        optimizer (torch.optim.Optimizer): The optimizer into which to load the state.

    Returns:
        int: The episode number to resume from.
    """
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        episode = checkpoint['episode']
        print(f"Checkpoint loaded from {filepath}, resuming from episode {episode}")
        return episode
    else:
        print(f"No checkpoint found at {filepath}, starting from scratch.")
        return 0

# %%
# Training Loop
def train(verbose=False):
    # Removed torch.autograd.set_detect_anomaly(True)
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Reduced learning rate
    # Optionally, load a checkpoint
    checkpoint_path = os.path.join(OUTPUT_DIR, "ckpt_52000_0.6910_169.16.pth")
    load_checkpoint(checkpoint_path, model, optimizer)

    episode_cnt = 0
    total_reward = 0.0
    num_successes = 0
    total_steps = 0
    
    for episode in range(NUM_EPISODES):
        t1 = time.time()
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, current_list = env.reset()
        input_tokens = [initial_token_id]
        log_probs = []
        rewards = []
        comparisons = []
        
        state = 'expect_action'
        done = False
        success = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
                print(comparisons)
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
                output = model(input_seq)  # (seq_len, batch_size, vocab_size)
                # Get logits for the last token
                logits = output[-1, 0, :]  # (vocab_size)

                # Check for NaNs in logits
                if torch.isnan(logits).any():
                    print(f"Episode {episode}, NaNs in logits before masking.")
                    break

                # Get valid tokens based on state
                def get_valid_tokens(state):
                    action_tokens = [vocab['Comparison'], vocab['Swap']]
                    index_tokens = [vocab[str(i)] for i in range(env.length)]
                    if state == 'expect_action':
                        return action_tokens
                    elif state == 'expect_index1':
                        return index_tokens[:-1]
                    elif state == 'expect_index2':
                        return [x for x in index_tokens if x > input_tokens[-1]]
                    else:
                        # Handle unexpected states by defaulting to expect_action
                        return action_tokens

                valid_token_ids = get_valid_tokens(state)

                # Ensure valid_token_ids are within the vocab range
                if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                    print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                    break

                # Mask invalid tokens
                mask_value = -1e9  # Use a large negative value instead of -inf
                mask = torch.full_like(logits, mask_value).to(device)
                mask[valid_token_ids] = 0
                masked_logits = logits + mask

                # Sample action. Have some chance to randomly pick a valid action.
                eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
                if random.random() < eps_threshold:
                    masked_logits = masked_logits / 4

                # Check for NaNs in masked_logits
                if torch.isnan(masked_logits).any():
                    print(f"Episode {episode}, NaNs in masked_logits after masking.")
                    break

                # Compute probabilities
                probs = F.softmax(masked_logits, dim=0)

                # Check for NaNs in probs
                if torch.isnan(probs).any():
                    print(f"Episode {episode}, NaNs in probs after softmax.")
                    break

                try:
                    m = torch.distributions.Categorical(probs)
                    action_token = m.sample()
                    log_prob = m.log_prob(action_token)
                except ValueError as e:
                    print(f"Episode {episode}, error in sampling action: {e}")
                    break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            reward = 0.0
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        reward = INVALID_ACTION_REWARD
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    if done and reward == SUCCESS_REWARD:
                        success = True
                        #print(decode(input_tokens, inv_vocab))
                    if verbose:
                        print("Reward:", reward)
                    state = 'expect_action'
                else:
                    reward = INVALID_ACTION_REWARD
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                comparisons.append((int(inv_vocab[index1_token.item()]), 
                                    int(inv_vocab[index2_token.item()])))
                response_token, reward, done, current_list = env.step(action_tokens)
                if done and reward == SUCCESS_REWARD:
                    success = True
                    #print(decode(input_tokens, inv_vocab))
                else:
                    reward += COMPARISON_ENTROPY_MULTIPLIER * compute_min_delta_entropy(comparisons)
                if verbose:
                    print("Reward:", reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                reward = INVALID_ACTION_REWARD
                done = True

            rewards.append(reward)
        #
        if success: 
            num_successes += 1
        # Save checkpoint
        if episode > 0 and episode % EPISODES_SAVE == 0:
            avg_reward = total_reward / episode_cnt
            success_rate = num_successes / episode_cnt
            avg_steps = total_steps / episode_cnt
            episode_cnt = 0
            total_reward = 0.0
            num_successes = 0
            total_steps = 0
            save_checkpoint(model, optimizer, episode, OUTPUT_DIR, f"ckpt_{episode}_{success_rate:.4f}_{avg_steps:.2f}.pth")
        #
        assert len(log_probs) == len(rewards), "log_probs and returns have different sizes!"

        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns and loss within autocast
        with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
            # Compute returns
            returns = []
            R = 0
            gamma = GAMMA
            for r in rewards[::-1]:
                R = r + gamma * R
                returns.insert(0, R)
            returns = torch.tensor(returns).to(device)

            # Check for NaNs in returns
            if torch.isnan(returns).any():
                print(f"Episode {episode}, NaNs in returns.")
                continue

            # Compute loss
            loss = 0
            for log_prob, R in zip(log_probs, returns):
                loss -= log_prob * R

            # Check for NaNs in loss
            if torch.isnan(loss):
                print(f"Episode {episode}, NaN in loss.")
                continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        episode_cnt += 1
        total_reward += sum(rewards)
        total_steps += len(rewards)
        t2 = time.time()
        if episode % 1 == 0:
            print(f"Episode {episode}, loss:{loss.item():.4f}, {'succeed' if success else 'fail'}, steps:{len(rewards)}, total reward:{sum(rewards):.4f}, {t2-t1} sec")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# No checkpoint found at datasets/rl_sort_transformer_easy/list8_transformer4_192_gamma09_step210_v2/ckpt_52000_0.6910_169.16.pth, starting from scratch.
# Episode 0, loss:-68.0615, fail, steps:12, total reward:-11.6913, 0.361278772354126 sec
# Episode 1, loss:-14.7772, fail, steps:1, total reward:-10.0000, 0.0053904056549072266 sec
# Episode 2, loss:-72.0592, fail, steps:8, total reward:-12.2477, 0.020350933074951172 sec
# Episode 3, loss:-181.0044, fail, steps:159, total reward:-20.3830, 0.4952394962310791 sec
# Episode 4, loss:-156.1559, fail, steps:158, total reward:-21.3937, 0.4323863983154297 sec
# Episode 5, loss:-121.6667, fail, steps:158, total reward:-18.3224, 0.4314444065093994 sec
# Episode 6, loss:-157.3369, fail, steps:158, total reward:-23.2601, 0.4921417236328125 sec
# Episode 7, loss:-106.3106, fail, steps:158, total reward:-19.3838, 0.4371950626373291 sec
# Episode 8, loss:-122.1537, fail, steps:78, total reward:-20.0783, 0.2270948886871338 sec
# Episode 9, loss:-84.5488, fail, steps:158, total reward:-20.6624, 0.42089319229125977 sec
# Episode 10, loss:-108.7664, fail, steps:158, total reward:-21.0854, 0.4330761432647705 sec
# Episode 11, loss:-128.5492, fail, steps:157, total reward:-21.5388, 0.44107508659362793 sec
# Episode 12, loss:-18.0474, fail, steps:1, total reward:-10.0000, 0.019242048263549805 sec
# Episode 13, loss:-156.6217, fail, steps:158, total reward:-21.6929, 0.3945655822753906 sec
# Episode 14, loss:-141.5409, fail, steps:158, total reward:-21.8788, 0.42029571533203125 sec
# Episode 15, loss:-104.2667, fail, steps:157, total reward:-19.3781, 0.42833971977233887 sec
# Episode 16, loss:-143.6052, fail, steps:158, total reward:-21.2601, 0.43381524085998535 sec
# Episode 17, loss:-138.4935, fail, steps:157, total reward:-21.9815, 0.43877577781677246 sec
# Episode 18, loss:-145.2658, fail, steps:158, total reward:-22.9346, 0.43888020515441895 sec
# Episode 19, loss:-95.2203, fail, steps:157, total reward:-18.8174, 0.436535120010376 sec
# Episode 20, loss:-169.1088, fail, steps:158, total reward:-23.4757, 0.4419515132904053 sec
# Episode 21, loss:-196.9179, fail, steps:158, total reward:-23.1159, 0.44374632835388184 sec
# Episode 22, loss:-123.7959, fail, steps:158, total reward:-20.0536, 0.44571828842163086 sec
# Episode 23, loss:-117.4057, fail, steps:158, total reward:-19.3838, 0.4427506923675537 sec
# Episode 24, loss:-125.3688, fail, steps:158, total reward:-19.8166, 0.44206976890563965 sec
# Episode 25, loss:-132.6210, fail, steps:158, total reward:-21.8372, 0.441342830657959 sec
# Episode 26, loss:-101.6910, fail, steps:157, total reward:-20.4568, 0.44195032119750977 sec
# Episode 27, loss:-74.0886, fail, steps:158, total reward:-17.6732, 0.4416999816894531 sec
# Episode 28, loss:-138.5350, fail, steps:52, total reward:-17.8801, 0.15642261505126953 sec
# Episode 29, loss:-103.7452, fail, steps:158, total reward:-24.6919, 0.41465020179748535 sec
# Episode 30, loss:-69.1977, fail, steps:158, total reward:-18.5190, 0.43085432052612305 sec
# Episode 31, loss:-78.1019, fail, steps:159, total reward:-18.9247, 0.44197726249694824 sec
# Episode 32, loss:-137.3496, fail, steps:125, total reward:-25.9378, 0.35556864738464355 sec
# Episode 33, loss:-157.5401, fail, steps:149, total reward:-27.5375, 0.4079608917236328 sec
# Episode 34, loss:-78.1450, fail, steps:158, total reward:-17.5804, 0.489609956741333 sec
# Episode 35, loss:-84.3297, fail, steps:158, total reward:-19.1518, 0.4393486976623535 sec
# Episode 36, loss:-103.6129, fail, steps:158, total reward:-20.3945, 0.4413139820098877 sec
# Episode 37, loss:-67.0444, fail, steps:158, total reward:-18.2296, 0.4453158378601074 sec
# Episode 38, loss:-93.0412, fail, steps:54, total reward:-14.6744, 0.16226458549499512 sec
# Episode 39, loss:-78.6434, fail, steps:158, total reward:-19.4568, 0.41360044479370117 sec
# Episode 40, loss:-55.2839, fail, steps:158, total reward:-17.1476, 0.43259429931640625 sec
# Episode 41, loss:-71.9432, fail, steps:157, total reward:-19.0698, 0.435546875 sec
# Episode 42, loss:-65.4124, fail, steps:158, total reward:-19.0854, 0.4440484046936035 sec
# Episode 43, loss:-56.9581, fail, steps:158, total reward:-18.0854, 0.43776583671569824 sec
# Episode 44, loss:-87.1453, fail, steps:157, total reward:-18.3846, 0.4388744831085205 sec
# Episode 45, loss:-49.2343, fail, steps:157, total reward:-17.4469, 0.4381847381591797 sec
# Episode 46, loss:-65.9386, fail, steps:158, total reward:-16.1575, 0.4413115978240967 sec
# Episode 47, loss:-87.7307, fail, steps:158, total reward:-19.1682, 0.44731950759887695 sec
# Episode 48, loss:-41.3760, fail, steps:158, total reward:-15.8698, 0.44141268730163574 sec
# Episode 49, loss:-48.0994, fail, steps:158, total reward:-17.5813, 0.44183945655822754 sec
# Episode 50, loss:-68.8368, fail, steps:55, total reward:-13.6744, 0.16472554206848145 sec
# Episode 51, loss:-81.2086, fail, steps:158, total reward:-19.9411, 0.41594815254211426 sec
# Episode 52, loss:-102.5674, fail, steps:95, total reward:-20.5647, 0.26767492294311523 sec
# Episode 53, loss:-46.9785, fail, steps:158, total reward:-17.3541, 0.4275364875793457 sec
# Episode 54, loss:-82.5436, fail, steps:158, total reward:-17.8690, 0.4350132942199707 sec
# Episode 55, loss:-66.0799, fail, steps:39, total reward:-14.6010, 0.11988997459411621 sec
# Episode 56, loss:-59.7059, fail, steps:23, total reward:-11.8883, 0.0629434585571289 sec
# Episode 57, loss:-63.0126, fail, steps:39, total reward:-12.7453, 0.09910798072814941 sec
# Episode 58, loss:-53.1474, fail, steps:161, total reward:-13.6105, 0.40901637077331543 sec
# Episode 59, loss:-51.7896, fail, steps:22, total reward:-11.3005, 0.06969165802001953 sec
# Episode 60, loss:-50.7243, fail, steps:78, total reward:-14.6142, 0.19652962684631348 sec
# Episode 61, loss:-54.8296, fail, steps:36, total reward:-13.0746, 0.09569549560546875 sec
# Episode 62, loss:-12.4004, fail, steps:1, total reward:-10.0000, 0.006575822830200195 sec
# Episode 63, loss:-43.8978, fail, steps:29, total reward:-12.4868, 0.06984949111938477 sec
# Episode 64, loss:-29.2881, fail, steps:5, total reward:-9.8042, 0.014573097229003906 sec
# Episode 65, loss:-65.9986, fail, steps:159, total reward:-17.4460, 0.4001302719116211 sec
# Episode 66, loss:-43.3528, fail, steps:159, total reward:-13.2812, 0.4220447540283203 sec
# Episode 67, loss:-33.5226, fail, steps:158, total reward:-14.9312, 0.4305894374847412 sec
# Episode 68, loss:-15.5392, fail, steps:1, total reward:-10.0000, 0.018174409866333008 sec
# Episode 69, loss:-41.6328, fail, steps:160, total reward:-11.9655, 0.4505040645599365 sec
# Episode 70, loss:-17.6573, fail, steps:1, total reward:-10.0000, 0.013807535171508789 sec
# Episode 71, loss:-19.5365, fail, steps:1, total reward:-10.0000, 0.003923654556274414 sec
# Episode 72, loss:-76.7651, fail, steps:30, total reward:-10.9089, 0.07196307182312012 sec
# Episode 73, loss:-41.8025, fail, steps:158, total reward:-13.8690, 0.3963766098022461 sec
# Episode 74, loss:-66.3452, fail, steps:159, total reward:-15.2090, 0.42845916748046875 sec
# Episode 75, loss:-43.4573, fail, steps:159, total reward:-13.1575, 0.43224382400512695 sec
# Episode 76, loss:-50.4541, fail, steps:159, total reward:-15.3018, 0.4373137950897217 sec
# Episode 77, loss:-45.8975, fail, steps:159, total reward:-11.7140, 0.44051551818847656 sec
# Episode 78, loss:-57.6679, fail, steps:160, total reward:-14.8582, 0.44460463523864746 sec
# Episode 79, loss:-75.9041, fail, steps:160, total reward:-14.6212, 0.44791436195373535 sec
# Episode 80, loss:-66.8576, fail, steps:159, total reward:-13.6517, 0.44440221786499023 sec
# Episode 81, loss:-93.9588, fail, steps:160, total reward:-13.9394, 0.44785475730895996 sec
# Episode 82, loss:-76.5374, fail, steps:160, total reward:-9.7952, 0.44843244552612305 sec
# Episode 83, loss:-84.5316, fail, steps:159, total reward:-11.0845, 0.4505324363708496 sec
# Episode 84, loss:-117.6700, fail, steps:160, total reward:-12.5165, 0.44959115982055664 sec
# Episode 85, loss:-205.8606, fail, steps:119, total reward:-20.4007, 0.33728623390197754 sec
# Episode 86, loss:-56.2993, fail, steps:160, total reward:-10.1558, 0.4378623962402344 sec
# Episode 87, loss:-75.7160, fail, steps:18, total reward:-10.3619, 0.06651091575622559 sec
# Episode 88, loss:-123.6913, fail, steps:159, total reward:-16.3009, 0.40558791160583496 sec
# Episode 89, loss:-70.4431, fail, steps:160, total reward:-10.3001, 0.4361541271209717 sec
# Episode 90, loss:-116.6133, fail, steps:158, total reward:-18.1674, 0.4342975616455078 sec
# Episode 91, loss:-131.2911, fail, steps:158, total reward:-17.8822, 0.43535399436950684 sec
# Episode 92, loss:-103.5456, fail, steps:159, total reward:-14.7445, 0.44062185287475586 sec
# Episode 93, loss:-119.9216, fail, steps:159, total reward:-13.5895, 0.4430429935455322 sec
# Episode 94, loss:-97.5164, fail, steps:158, total reward:-15.3117, 0.44444799423217773 sec
# Episode 95, loss:-97.9567, fail, steps:159, total reward:-14.6723, 0.44460630416870117 sec
# Episode 96, loss:-146.0208, fail, steps:158, total reward:-19.1150, 0.5019218921661377 sec
# Episode 97, loss:-110.6428, fail, steps:158, total reward:-15.9609, 0.44249820709228516 sec
# Episode 98, loss:-91.6464, fail, steps:159, total reward:-13.0845, 0.4474372863769531 sec
# Episode 99, loss:-119.9190, fail, steps:158, total reward:-18.5773, 0.4437685012817383 sec
# Episode 100, loss:-88.1169, fail, steps:14, total reward:-11.4233, 0.056621551513671875 sec
# Episode 101, loss:-105.2423, fail, steps:159, total reward:-12.6715, 0.40365147590637207 sec
# Episode 102, loss:-79.0399, fail, steps:159, total reward:-14.1468, 0.4277834892272949 sec
# Episode 103, loss:-82.1877, fail, steps:159, total reward:-13.6624, 0.43520355224609375 sec
# Episode 104, loss:-72.7728, fail, steps:160, total reward:-10.7230, 0.44681215286254883 sec
# Episode 105, loss:-30.8583, fail, steps:1, total reward:-10.0000, 0.019111156463623047 sec
# Episode 106, loss:-127.2724, fail, steps:158, total reward:-18.8166, 0.3932774066925049 sec
# Episode 107, loss:-63.3735, fail, steps:160, total reward:-10.1459, 0.42578577995300293 sec
# Episode 108, loss:-89.9714, fail, steps:159, total reward:-12.9403, 0.43288397789001465 sec
# Episode 109, loss:-104.1324, fail, steps:158, total reward:-16.6002, 0.43341517448425293 sec
# Episode 110, loss:-77.4335, fail, steps:160, total reward:-10.7173, 0.44648170471191406 sec
# Episode 111, loss:-86.8355, fail, steps:159, total reward:-13.0854, 0.4423837661743164 sec
# Episode 112, loss:-84.0100, fail, steps:159, total reward:-13.7861, 0.44400572776794434 sec
# Episode 113, loss:-104.3802, fail, steps:124, total reward:-14.6072, 0.3517272472381592 sec
# Episode 114, loss:-72.3399, fail, steps:161, total reward:-8.7754, 0.44179272651672363 sec
# Episode 115, loss:-71.2499, fail, steps:159, total reward:-13.6746, 0.44642019271850586 sec
# Episode 116, loss:-47.0495, fail, steps:160, total reward:-9.8376, 0.44698143005371094 sec
# Episode 117, loss:-111.6880, fail, steps:98, total reward:-14.5025, 0.28272080421447754 sec
# Episode 118, loss:-117.9741, fail, steps:75, total reward:-16.7477, 0.2088761329650879 sec
# Episode 119, loss:-66.7205, fail, steps:27, total reward:-11.3318, 0.0780787467956543 sec
# Episode 120, loss:-64.0805, fail, steps:160, total reward:-11.0746, 0.41036510467529297 sec
# Episode 121, loss:-73.7725, fail, steps:160, total reward:-12.7731, 0.43439626693725586 sec
# Episode 122, loss:-73.5358, fail, steps:8, total reward:-10.1756, 0.0468592643737793 sec
# Episode 123, loss:-89.3893, fail, steps:158, total reward:-17.0239, 0.39864397048950195 sec
# Episode 124, loss:-79.4947, fail, steps:159, total reward:-13.8780, 0.48142004013061523 sec
# Episode 125, loss:-115.4448, fail, steps:36, total reward:-9.6517, 0.10799479484558105 sec
# Episode 126, loss:-82.6713, fail, steps:160, total reward:-10.2738, 0.41154932975769043 sec
# Episode 127, loss:-109.2210, fail, steps:159, total reward:-13.5403, 0.43032002449035645 sec
# Episode 128, loss:-72.6938, fail, steps:160, total reward:-9.2082, 0.4452664852142334 sec
# Episode 129, loss:-17.7000, succeed, steps:106, total reward:-1.3174, 0.2997288703918457 sec
# Episode 130, loss:-119.4639, fail, steps:159, total reward:-16.0429, 0.4310457706451416 sec
# Episode 131, loss:-119.2740, fail, steps:159, total reward:-12.7960, 0.4387242794036865 sec
# Episode 132, loss:-135.2343, fail, steps:158, total reward:-17.8887, 0.4381263256072998 sec
# Episode 133, loss:-73.6758, fail, steps:161, total reward:-6.0631, 0.45210933685302734 sec
# Episode 134, loss:-152.7560, fail, steps:67, total reward:-16.0092, 0.19802427291870117 sec
# Episode 135, loss:-31.5064, succeed, steps:108, total reward:-3.9151, 0.2873969078063965 sec
# Episode 136, loss:-100.2878, fail, steps:160, total reward:-14.1567, 0.42644381523132324 sec
# Episode 137, loss:-113.1789, fail, steps:92, total reward:-11.6146, 0.2615165710449219 sec
# Episode 138, loss:-74.9584, fail, steps:160, total reward:-9.0738, 0.42765259742736816 sec
# Episode 139, loss:-108.3892, fail, steps:159, total reward:-14.0944, 0.44081878662109375 sec
# Episode 140, loss:-122.9174, fail, steps:158, total reward:-17.4559, 0.4380464553833008 sec
# Episode 141, loss:-111.8251, fail, steps:46, total reward:-10.2708, 0.1393744945526123 sec
# Episode 142, loss:-74.9182, fail, steps:159, total reward:-12.2288, 0.4143819808959961 sec
# Episode 143, loss:-128.6915, fail, steps:158, total reward:-19.1543, 0.4305398464202881 sec
# Episode 144, loss:-93.4429, fail, steps:161, total reward:-10.2181, 0.4469146728515625 sec
# Episode 145, loss:-119.8194, fail, steps:158, total reward:-15.8887, 0.441056489944458 sec
# Episode 146, loss:-63.0860, fail, steps:160, total reward:-7.4147, 0.44545984268188477 sec
# Episode 147, loss:-49.6566, fail, steps:162, total reward:-3.9910, 0.45258116722106934 sec
# Episode 148, loss:-80.2943, fail, steps:160, total reward:-9.5066, 0.44825196266174316 sec
# Episode 149, loss:-40.5188, succeed, steps:107, total reward:-2.3208, 0.30638837814331055 sec
# Episode 150, loss:-135.8427, fail, steps:158, total reward:-17.2593, 0.4323694705963135 sec
# Episode 151, loss:-32.1864, succeed, steps:112, total reward:-2.9980, 0.3164701461791992 sec
# Episode 152, loss:-79.0222, fail, steps:159, total reward:-11.5796, 0.4312877655029297 sec
# Episode 153, loss:-128.4103, fail, steps:158, total reward:-16.4559, 0.49248647689819336 sec
# Episode 154, loss:-102.3476, fail, steps:160, total reward:-11.3666, 0.4442787170410156 sec
# Episode 155, loss:-64.3533, succeed, steps:139, total reward:-8.4970, 0.39405083656311035 sec
# Episode 156, loss:-119.5041, fail, steps:159, total reward:-14.7445, 0.438474178314209 sec
# Episode 157, loss:-48.2280, fail, steps:161, total reward:-3.9287, 0.4481940269470215 sec
# Episode 158, loss:-116.1223, fail, steps:159, total reward:-12.2387, 0.4445981979370117 sec
# Episode 159, loss:-56.5205, fail, steps:161, total reward:-5.2467, 0.45338940620422363 sec
# Episode 160, loss:-156.6436, fail, steps:158, total reward:-18.1872, 0.4431331157684326 sec
# Episode 161, loss:-152.3717, fail, steps:158, total reward:-17.0429, 0.443528413772583 sec
# Episode 162, loss:-105.6960, fail, steps:160, total reward:-11.1788, 0.4480447769165039 sec
# Episode 163, loss:-115.2220, fail, steps:160, total reward:-12.0936, 0.4491589069366455 sec
# Episode 164, loss:-164.0228, fail, steps:35, total reward:-11.8353, 0.1123192310333252 sec
# Episode 165, loss:-78.5322, succeed, steps:111, total reward:-7.0800, 0.2919013500213623 sec
# Episode 166, loss:-42.7435, succeed, steps:63, total reward:-5.2312, 0.17571163177490234 sec
# Episode 167, loss:-141.5004, fail, steps:159, total reward:-16.1863, 0.4133431911468506 sec
# Episode 168, loss:-126.3242, fail, steps:160, total reward:-11.6936, 0.43509936332702637 sec
# Episode 169, loss:-136.2983, fail, steps:159, total reward:-14.5994, 0.43776988983154297 sec
# Episode 170, loss:-82.6970, fail, steps:160, total reward:-8.7853, 0.4422729015350342 sec
# Episode 171, loss:-122.3159, fail, steps:160, total reward:-11.7493, 0.44806408882141113 sec
# Episode 172, loss:-145.8072, fail, steps:160, total reward:-13.8772, 0.44516706466674805 sec
# Episode 173, loss:-181.7130, fail, steps:158, total reward:-21.3314, 0.4433572292327881 sec
# Episode 174, loss:-96.0545, fail, steps:160, total reward:-10.7337, 0.44913482666015625 sec
# Episode 175, loss:-35.5251, fail, steps:1, total reward:-10.0000, 0.01974630355834961 sec
# Episode 176, loss:-130.8971, fail, steps:159, total reward:-15.9215, 0.40291762351989746 sec
# Episode 177, loss:-114.5709, fail, steps:160, total reward:-12.6092, 0.42676353454589844 sec
# Episode 178, loss:-135.9429, fail, steps:159, total reward:-14.5272, 0.48516082763671875 sec
# Episode 179, loss:-122.2065, fail, steps:160, total reward:-12.9699, 0.4394955635070801 sec
# Episode 180, loss:-137.0694, fail, steps:159, total reward:-15.1666, 0.43956851959228516 sec
# Episode 181, loss:-108.7911, fail, steps:160, total reward:-11.3459, 0.44884777069091797 sec
# Episode 182, loss:-60.2971, fail, steps:160, total reward:-7.2181, 0.4455752372741699 sec
# Episode 183, loss:-68.8557, fail, steps:160, total reward:-9.1459, 0.4458889961242676 sec
# Episode 184, loss:-57.0074, fail, steps:160, total reward:-6.7131, 0.44843339920043945 sec
# Episode 185, loss:-112.2681, fail, steps:159, total reward:-15.0330, 0.44401097297668457 sec
# Episode 186, loss:-96.9544, fail, steps:160, total reward:-10.7952, 0.4511110782623291 sec
# Episode 187, loss:-68.9890, fail, steps:160, total reward:-9.4246, 0.45188260078430176 sec
# Episode 188, loss:-65.5376, fail, steps:161, total reward:-6.4860, 0.45093369483947754 sec
# Episode 189, loss:-148.4350, fail, steps:155, total reward:-18.5483, 0.43459606170654297 sec
# Episode 190, loss:-96.5743, fail, steps:159, total reward:-13.2387, 0.4482424259185791 sec
# Episode 191, loss:-93.9943, fail, steps:160, total reward:-10.9295, 0.44850993156433105 sec
# Episode 192, loss:-103.9092, fail, steps:159, total reward:-13.5903, 0.44585323333740234 sec
# Episode 193, loss:-21.5464, succeed, steps:92, total reward:-2.8417, 0.2662084102630615 sec
# Episode 194, loss:-79.7001, fail, steps:160, total reward:-10.5066, 0.43180203437805176 sec
# Episode 195, loss:-101.5071, fail, steps:160, total reward:-12.0936, 0.4430258274078369 sec
# Episode 196, loss:-92.1355, fail, steps:159, total reward:-12.3009, 0.44016337394714355 sec
# Episode 197, loss:-44.6838, succeed, steps:153, total reward:-5.6818, 0.427032470703125 sec
# Episode 198, loss:-80.8671, fail, steps:160, total reward:-11.7032, 0.4453861713409424 sec
# Episode 199, loss:-78.3024, fail, steps:161, total reward:-10.1910, 0.4505791664123535 sec
# Episode 200, loss:-97.1634, fail, steps:160, total reward:-13.4551, 0.4522700309753418 sec
# Episode 201, loss:-131.5134, fail, steps:159, total reward:-14.9501, 0.4984121322631836 sec
# Episode 202, loss:-133.9770, fail, steps:86, total reward:-14.3153, 0.24938392639160156 sec
# Episode 203, loss:-74.3622, fail, steps:160, total reward:-8.7853, 0.4286000728607178 sec
# Episode 204, loss:-92.9085, fail, steps:159, total reward:-11.8780, 0.43776369094848633 sec
# Episode 205, loss:-103.6853, fail, steps:160, total reward:-11.8879, 0.4487192630767822 sec
# Episode 206, loss:-37.8043, succeed, steps:98, total reward:-3.9288, 0.28174400329589844 sec
# Episode 207, loss:-103.0066, fail, steps:160, total reward:-11.9403, 0.4308481216430664 sec
# Episode 208, loss:-178.7297, fail, steps:159, total reward:-19.0486, 0.43910837173461914 sec
# Episode 209, loss:-75.2812, succeed, steps:139, total reward:-6.9897, 0.3886692523956299 sec
# Episode 210, loss:-82.5280, succeed, steps:119, total reward:-11.1229, 0.3330955505371094 sec
# Episode 211, loss:-202.6386, fail, steps:114, total reward:-22.8457, 0.3204317092895508 sec
# Episode 212, loss:-112.3907, fail, steps:159, total reward:-13.4551, 0.43112707138061523 sec
# Episode 213, loss:-85.5248, fail, steps:161, total reward:-8.0017, 0.4434962272644043 sec
# Episode 214, loss:-93.6490, fail, steps:159, total reward:-12.5895, 0.44388318061828613 sec
# Episode 215, loss:-102.2375, fail, steps:160, total reward:-10.8780, 0.4455890655517578 sec
# Episode 216, loss:-55.0472, succeed, steps:117, total reward:-6.2556, 0.33710384368896484 sec
# Episode 217, loss:-101.5204, fail, steps:63, total reward:-9.9114, 0.1781911849975586 sec
# Episode 218, loss:-27.6518, succeed, steps:90, total reward:-2.1917, 0.23981881141662598 sec
# Episode 219, loss:-79.8420, succeed, steps:96, total reward:-7.9115, 0.2567145824432373 sec
# Episode 220, loss:-119.4443, fail, steps:159, total reward:-13.5436, 0.4226412773132324 sec
# Episode 221, loss:-151.8507, fail, steps:158, total reward:-17.8364, 0.43301892280578613 sec
# Episode 222, loss:-69.2398, fail, steps:161, total reward:-8.0008, 0.4502861499786377 sec
# Episode 223, loss:-111.6131, fail, steps:159, total reward:-14.1666, 0.44350218772888184 sec
# Episode 224, loss:-76.6874, fail, steps:160, total reward:-7.3623, 0.44672489166259766 sec
# Episode 225, loss:-54.3096, fail, steps:160, total reward:-7.9295, 0.4467356204986572 sec
# Episode 226, loss:-35.8288, fail, steps:1, total reward:-10.0000, 0.019542455673217773 sec
# Episode 227, loss:-102.6008, fail, steps:158, total reward:-15.5838, 0.4503650665283203 sec
# Episode 228, loss:-67.0078, succeed, steps:136, total reward:-6.9626, 0.3678717613220215 sec
# Episode 229, loss:-55.9203, fail, steps:161, total reward:-7.4246, 0.43175220489501953 sec
# Episode 230, loss:-53.1517, succeed, steps:114, total reward:-5.5956, 0.3177666664123535 sec
# Episode 231, loss:-96.8876, fail, steps:25, total reward:-11.3604, 0.07685732841491699 sec
# Episode 232, loss:-126.4332, fail, steps:159, total reward:-15.6101, 0.40665173530578613 sec
# Episode 233, loss:-81.1583, fail, steps:160, total reward:-10.6410, 0.4306302070617676 sec
# Episode 234, loss:-77.3271, fail, steps:160, total reward:-7.7230, 0.4426555633544922 sec
# Episode 235, loss:-80.8042, fail, steps:160, total reward:-11.3830, 0.44172000885009766 sec
# Episode 236, loss:-54.2354, fail, steps:162, total reward:-3.6294, 0.4492034912109375 sec
# Episode 237, loss:-38.9377, succeed, steps:147, total reward:-3.9481, 0.41033124923706055 sec
# Episode 238, loss:-68.1425, fail, steps:160, total reward:-8.0116, 0.4437854290008545 sec
# Episode 239, loss:-87.0819, fail, steps:160, total reward:-10.7886, 0.44977617263793945 sec
# Episode 240, loss:-54.8600, fail, steps:161, total reward:-6.0008, 0.44930434226989746 sec
# Episode 241, loss:-80.3568, fail, steps:160, total reward:-8.9295, 0.44750356674194336 sec
# Episode 242, loss:-104.0714, fail, steps:159, total reward:-13.2288, 0.44510626792907715 sec
# Episode 243, loss:-106.1791, fail, steps:160, total reward:-12.6814, 0.4517643451690674 sec
# Episode 244, loss:-103.7373, fail, steps:161, total reward:-9.0008, 0.4572939872741699 sec
# Episode 245, loss:-75.9206, fail, steps:161, total reward:-8.6772, 0.4532167911529541 sec
# Episode 246, loss:-42.6235, fail, steps:161, total reward:-4.6402, 0.45278120040893555 sec
# Episode 247, loss:-117.4603, succeed, steps:158, total reward:-13.4650, 0.44580793380737305 sec
# Episode 248, loss:-11.3035, succeed, steps:57, total reward:-0.8285, 0.1704423427581787 sec
# Episode 249, loss:-76.5860, fail, steps:160, total reward:-7.6509, 0.4224414825439453 sec
# Episode 250, loss:-125.1822, fail, steps:160, total reward:-13.5066, 0.4389309883117676 sec
# Episode 251, loss:-84.6996, fail, steps:161, total reward:-7.9295, 0.44707727432250977 sec
# Episode 252, loss:-113.8907, fail, steps:160, total reward:-10.8444, 0.4980032444000244 sec
# Episode 253, loss:-108.9148, fail, steps:159, total reward:-13.4551, 0.45053553581237793 sec
# Episode 254, loss:-37.5311, succeed, steps:90, total reward:-5.0581, 0.26097893714904785 sec
# Episode 255, loss:-113.6285, fail, steps:159, total reward:-13.0223, 0.427213191986084 sec
# Episode 256, loss:-113.4801, fail, steps:161, total reward:-9.6599, 0.4438343048095703 sec
# Episode 257, loss:-91.1489, succeed, steps:128, total reward:-10.1149, 0.36266183853149414 sec
# Episode 258, loss:6.0418, succeed, steps:21, total reward:1.1224, 0.0702509880065918 sec
# Episode 259, loss:-45.4417, succeed, steps:151, total reward:-3.1752, 0.38641357421875 sec
# Episode 260, loss:-155.2936, fail, steps:158, total reward:-18.0429, 0.42647480964660645 sec
# Episode 261, loss:-94.4351, fail, steps:160, total reward:-9.7952, 0.4367070198059082 sec
# Episode 262, loss:-76.6042, fail, steps:160, total reward:-8.7230, 0.4409012794494629 sec
# Episode 263, loss:-112.5848, fail, steps:159, total reward:-12.3108, 0.4422140121459961 sec
# Episode 264, loss:-43.7005, succeed, steps:160, total reward:-4.5680, 0.4517652988433838 sec
# Episode 265, loss:-98.9332, fail, steps:161, total reward:-10.5066, 0.45046544075012207 sec
# Episode 266, loss:-37.0226, succeed, steps:131, total reward:-2.6583, 0.3689615726470947 sec
# Episode 267, loss:14.6337, succeed, steps:46, total reward:2.0177, 0.13623833656311035 sec
# Episode 268, loss:-100.9222, fail, steps:64, total reward:-9.2721, 0.16833090782165527 sec
# Episode 269, loss:-146.7460, fail, steps:159, total reward:-14.7895, 0.4132668972015381 sec
# Episode 270, loss:-118.5549, succeed, steps:148, total reward:-12.3081, 0.4026782512664795 sec
# Episode 271, loss:-97.2145, fail, steps:160, total reward:-8.9394, 0.44368672370910645 sec
# Episode 272, loss:-133.9763, fail, steps:160, total reward:-13.0214, 0.4430713653564453 sec
# Episode 273, loss:-120.4008, fail, steps:159, total reward:-12.7436, 0.44463396072387695 sec
# Episode 274, loss:-109.5324, fail, steps:160, total reward:-10.3886, 0.4472992420196533 sec
# Episode 275, loss:-135.4952, fail, steps:29, total reward:-12.8475, 0.09536147117614746 sec
# Episode 276, loss:-116.6146, fail, steps:160, total reward:-11.5886, 0.41971874237060547 sec
# Episode 277, loss:-64.0904, fail, steps:161, total reward:-6.1459, 0.43619275093078613 sec
# Episode 278, loss:-90.0499, fail, steps:161, total reward:-8.5058, 0.44405484199523926 sec
# Episode 279, loss:-129.2678, fail, steps:45, total reward:-10.6937, 0.19273614883422852 sec
# Episode 280, loss:-90.8159, fail, steps:14, total reward:-10.7020, 0.04245185852050781 sec
# Episode 281, loss:-98.8418, fail, steps:161, total reward:-9.5516, 0.40674686431884766 sec
# Episode 282, loss:-133.8496, fail, steps:159, total reward:-14.6715, 0.4289872646331787 sec
# Episode 283, loss:-140.3263, fail, steps:159, total reward:-16.4551, 0.4368579387664795 sec
# Episode 284, loss:-126.7696, fail, steps:159, total reward:-15.8986, 0.43934059143066406 sec
# Episode 285, loss:-72.2334, fail, steps:160, total reward:-8.4181, 0.44550657272338867 sec
# Episode 286, loss:-176.4605, fail, steps:158, total reward:-18.8429, 0.4439847469329834 sec
# Episode 287, loss:-29.6023, succeed, steps:127, total reward:-2.8213, 0.36270785331726074 sec
# Episode 288, loss:-115.1572, fail, steps:159, total reward:-13.3207, 0.4414708614349365 sec
# Episode 289, loss:-65.5917, fail, steps:161, total reward:-8.2894, 0.45082902908325195 sec
# Episode 290, loss:-50.6915, succeed, steps:127, total reward:-5.7927, 0.3599720001220703 sec
# Episode 291, loss:-100.7125, fail, steps:160, total reward:-11.8715, 0.44114184379577637 sec
# Episode 292, loss:-62.2189, succeed, steps:116, total reward:-6.6785, 0.3304610252380371 sec
# Episode 293, loss:-91.9224, fail, steps:160, total reward:-10.2902, 0.4374699592590332 sec
# Episode 294, loss:-141.2549, fail, steps:159, total reward:-14.7470, 0.4419693946838379 sec
# Episode 295, loss:-123.0407, fail, steps:159, total reward:-13.9764, 0.44686293601989746 sec
# Episode 296, loss:-128.6623, fail, steps:159, total reward:-14.3108, 0.44692134857177734 sec
# Episode 297, loss:-117.4948, fail, steps:159, total reward:-12.6715, 0.4503498077392578 sec
# Episode 298, loss:-158.9427, fail, steps:68, total reward:-15.0977, 0.19995617866516113 sec
# Episode 299, loss:-115.9374, fail, steps:160, total reward:-12.3928, 0.42574167251586914 sec
# Episode 300, loss:-131.7108, fail, steps:160, total reward:-10.8772, 0.4383368492126465 sec
# Episode 301, loss:-50.1638, succeed, steps:138, total reward:-5.0511, 0.3871450424194336 sec
# Episode 302, loss:-160.6154, fail, steps:158, total reward:-16.5379, 0.436037540435791 sec
# Episode 303, loss:-91.5179, succeed, steps:127, total reward:-9.2362, 0.36147141456604004 sec
# Episode 304, loss:-14.4340, succeed, steps:105, total reward:-0.6773, 0.2936973571777344 sec
# Episode 305, loss:-106.0815, fail, steps:160, total reward:-11.6509, 0.4915916919708252 sec
# Episode 306, loss:-119.3148, fail, steps:159, total reward:-13.1436, 0.43863487243652344 sec
# Episode 307, loss:-116.4353, fail, steps:159, total reward:-12.8780, 0.4428129196166992 sec
# Episode 308, loss:-111.1144, fail, steps:161, total reward:-9.8772, 0.452481746673584 sec
# Episode 309, loss:-110.4103, fail, steps:160, total reward:-11.4551, 0.4471769332885742 sec
# Episode 310, loss:-24.0448, succeed, steps:89, total reward:-2.7589, 0.25673961639404297 sec
# Episode 311, loss:-114.0327, fail, steps:159, total reward:-12.4551, 0.4286620616912842 sec
# Episode 312, loss:-34.4464, succeed, steps:111, total reward:-1.4922, 0.31221938133239746 sec
# Episode 313, loss:-96.7940, fail, steps:160, total reward:-9.5788, 0.4398062229156494 sec
# Episode 314, loss:-90.3068, succeed, steps:146, total reward:-8.7325, 0.4057741165161133 sec
# Episode 315, loss:-86.2481, fail, steps:160, total reward:-8.3525, 0.44336557388305664 sec
# Episode 316, loss:-36.9293, succeed, steps:122, total reward:-3.4007, 0.34596967697143555 sec
# Episode 317, loss:-127.8748, fail, steps:160, total reward:-11.3830, 0.43897056579589844 sec
# Episode 318, loss:-77.5499, fail, steps:160, total reward:-8.4181, 0.4487025737762451 sec
# Episode 319, loss:-92.7411, fail, steps:159, total reward:-12.3108, 0.4433410167694092 sec
# Episode 320, loss:-122.0292, fail, steps:160, total reward:-12.2322, 0.4475727081298828 sec
# Episode 321, loss:-97.8008, fail, steps:160, total reward:-11.3108, 0.44850659370422363 sec
# Episode 322, loss:-157.6884, fail, steps:158, total reward:-17.5379, 0.4413321018218994 sec
# Episode 323, loss:-99.8961, fail, steps:159, total reward:-11.6452, 0.4481196403503418 sec
# Episode 324, loss:-80.8160, fail, steps:160, total reward:-9.2181, 0.44801759719848633 sec
# Episode 325, loss:-99.0189, fail, steps:159, total reward:-12.0124, 0.44757676124572754 sec
# Episode 326, loss:-127.3589, fail, steps:160, total reward:-12.8059, 0.4500460624694824 sec
# Episode 327, loss:-75.4601, fail, steps:159, total reward:-10.7697, 0.44686412811279297 sec
# Episode 328, loss:-138.4743, fail, steps:159, total reward:-15.4452, 0.45170044898986816 sec
# Episode 329, loss:-118.0265, fail, steps:159, total reward:-11.4452, 0.44674134254455566 sec
# Episode 330, loss:-115.6915, fail, steps:159, total reward:-13.1666, 0.4464282989501953 sec
# Episode 331, loss:-112.1528, fail, steps:159, total reward:-11.0845, 0.5011982917785645 sec
# Episode 332, loss:-154.7748, fail, steps:31, total reward:-11.1360, 0.1005096435546875 sec
# Episode 333, loss:-42.7865, fail, steps:161, total reward:-4.4238, 0.42133522033691406 sec
# Episode 334, loss:-93.1485, fail, steps:160, total reward:-11.0017, 0.43473196029663086 sec
# Episode 335, loss:-55.4719, fail, steps:161, total reward:-5.3525, 0.4424872398376465 sec
# Episode 336, loss:-120.5132, fail, steps:159, total reward:-12.8715, 0.441025972366333 sec
# Episode 337, loss:-54.8218, succeed, steps:159, total reward:-5.7745, 0.442669153213501 sec
# Episode 338, loss:-96.9846, fail, steps:159, total reward:-11.7960, 0.4502522945404053 sec
# Episode 339, loss:-87.6425, fail, steps:160, total reward:-9.1295, 0.4472682476043701 sec
# Episode 340, loss:-32.0282, succeed, steps:67, total reward:-3.8813, 0.19683098793029785 sec
# Episode 341, loss:-55.2846, fail, steps:5, total reward:-9.6599, 0.02291250228881836 sec
# Episode 342, loss:-80.2995, fail, steps:159, total reward:-10.5075, 0.39832472801208496 sec
# Episode 343, loss:-71.6349, fail, steps:160, total reward:-8.3525, 0.42740797996520996 sec
# Episode 344, loss:-159.2457, fail, steps:158, total reward:-18.6265, 0.43602514266967773 sec
# Episode 345, loss:-50.6761, succeed, steps:111, total reward:-5.0078, 0.31107497215270996 sec
# Episode 346, loss:-96.1965, fail, steps:161, total reward:-8.6501, 0.4366486072540283 sec
# Episode 347, loss:-125.0018, fail, steps:158, total reward:-16.4624, 0.4356963634490967 sec
# Episode 348, loss:-100.9693, fail, steps:160, total reward:-11.4967, 0.44566965103149414 sec
# Episode 349, loss:-29.2310, fail, steps:162, total reward:-3.0532, 0.45423197746276855 sec
# Episode 350, loss:-67.4262, succeed, steps:159, total reward:-8.4246, 0.44439697265625 sec
# Episode 351, loss:-99.0881, fail, steps:160, total reward:-10.1459, 0.4476053714752197 sec
# Episode 352, loss:-120.3057, fail, steps:158, total reward:-15.7445, 0.4435079097747803 sec
# Episode 353, loss:-103.4731, fail, steps:159, total reward:-13.2387, 0.44530272483825684 sec
# Episode 354, loss:-70.8939, fail, steps:160, total reward:-9.9394, 0.45198702812194824 sec
# Episode 355, loss:-95.0082, fail, steps:159, total reward:-14.0952, 0.4456334114074707 sec
# Episode 356, loss:-38.5729, fail, steps:1, total reward:-10.0000, 0.019829511642456055 sec
# Episode 357, loss:-25.9899, fail, steps:161, total reward:-3.0532, 0.4016153812408447 sec
# Episode 358, loss:-51.6427, fail, steps:160, total reward:-6.2704, 0.4811716079711914 sec
# Episode 359, loss:-66.8747, fail, steps:159, total reward:-10.9239, 0.4339718818664551 sec
# Episode 360, loss:-40.6301, succeed, steps:116, total reward:-6.5342, 0.32627320289611816 sec
# Episode 361, loss:-63.7337, fail, steps:160, total reward:-9.5075, 0.43323397636413574 sec
# Episode 362, loss:-123.8121, fail, steps:159, total reward:-18.6101, 0.43907761573791504 sec
# Episode 363, loss:-55.0605, succeed, steps:113, total reward:-6.3529, 0.3208746910095215 sec
# Episode 364, loss:-98.7922, fail, steps:159, total reward:-12.5272, 0.4329383373260498 sec
# Episode 365, loss:-112.5334, fail, steps:159, total reward:-15.5173, 0.4450092315673828 sec
# Episode 366, loss:-40.4675, succeed, steps:111, total reward:-4.5029, 0.31476783752441406 sec
# Episode 367, loss:-79.8624, fail, steps:160, total reward:-10.4082, 0.4344441890716553 sec
# Episode 368, loss:-74.8429, fail, steps:160, total reward:-10.0124, 0.4420487880706787 sec
# Episode 369, loss:-101.7374, fail, steps:159, total reward:-13.6616, 0.44271039962768555 sec
# Episode 370, loss:-57.6924, fail, steps:160, total reward:-6.7131, 0.44913530349731445 sec
# Episode 371, loss:-128.5997, fail, steps:159, total reward:-15.5379, 0.44413328170776367 sec
# Episode 372, loss:-78.8686, fail, steps:160, total reward:-8.5886, 0.44692492485046387 sec
# Episode 373, loss:-25.3604, succeed, steps:128, total reward:-1.8541, 0.3653128147125244 sec
# Episode 374, loss:-47.8290, succeed, steps:134, total reward:-5.3912, 0.37273383140563965 sec
# Episode 375, loss:-135.4831, fail, steps:159, total reward:-16.2944, 0.442155122756958 sec
# Episode 376, loss:-101.3073, fail, steps:159, total reward:-12.6715, 0.4428834915161133 sec
# Episode 377, loss:-58.4458, fail, steps:161, total reward:-6.3623, 0.4491300582885742 sec
# Episode 378, loss:-58.3179, fail, steps:161, total reward:-5.7024, 0.4521903991699219 sec
# Episode 379, loss:-113.5233, fail, steps:160, total reward:-14.2486, 0.44864964485168457 sec
# Episode 380, loss:-74.6771, fail, steps:8, total reward:-10.1035, 0.041280508041381836 sec
# Episode 381, loss:-98.3551, fail, steps:160, total reward:-10.7230, 0.40918827056884766 sec
# Episode 382, loss:-112.4071, fail, steps:159, total reward:-14.1666, 0.4263172149658203 sec
# Episode 383, loss:-73.2623, fail, steps:161, total reward:-7.8050, 0.4392528533935547 sec
# Episode 384, loss:-108.2864, fail, steps:160, total reward:-12.6608, 0.49939608573913574 sec
# Episode 385, loss:-107.7990, fail, steps:160, total reward:-12.6814, 0.45025634765625 sec
# Episode 386, loss:-107.7323, fail, steps:159, total reward:-13.7830, 0.4442012310028076 sec
# Episode 387, loss:-158.2059, fail, steps:158, total reward:-18.6101, 0.44043850898742676 sec
# Episode 388, loss:-39.9514, fail, steps:1, total reward:-10.0000, 0.019211769104003906 sec
# Episode 389, loss:-48.4207, succeed, steps:92, total reward:-6.7574, 0.22756028175354004 sec
# Episode 390, loss:-22.8822, succeed, steps:134, total reward:-1.8755, 0.3462519645690918 sec
# Episode 391, loss:-78.6046, fail, steps:160, total reward:-8.9394, 0.4260692596435547 sec
# Episode 392, loss:-88.9588, fail, steps:160, total reward:-10.6616, 0.44012999534606934 sec
# Episode 393, loss:-121.0423, fail, steps:159, total reward:-14.1666, 0.4372437000274658 sec
# Episode 394, loss:-79.6805, fail, steps:159, total reward:-11.7239, 0.44176483154296875 sec
# Episode 395, loss:-41.2837, fail, steps:161, total reward:-4.8467, 0.44711875915527344 sec
# Episode 396, loss:-22.6094, succeed, steps:132, total reward:-2.8656, 0.3736302852630615 sec
# Episode 397, loss:-131.9394, fail, steps:159, total reward:-17.2845, 0.4398467540740967 sec
# Episode 398, loss:-62.8381, succeed, steps:141, total reward:-7.7119, 0.39507079124450684 sec
# Episode 399, loss:-73.9043, fail, steps:160, total reward:-8.3722, 0.4422590732574463 sec
# Episode 400, loss:-80.1986, fail, steps:160, total reward:-8.9394, 0.4470233917236328 sec
# Episode 401, loss:-75.3124, fail, steps:161, total reward:-7.2280, 0.45462894439697266 sec
# Episode 402, loss:-94.1110, fail, steps:160, total reward:-12.6616, 0.4489023685455322 sec
# Episode 403, loss:-99.6493, fail, steps:160, total reward:-11.5796, 0.44939589500427246 sec
# Episode 404, loss:-49.8901, fail, steps:160, total reward:-9.9426, 0.44827842712402344 sec
# Episode 405, loss:-57.4954, fail, steps:160, total reward:-9.5066, 0.45067906379699707 sec
# Episode 406, loss:-95.5685, fail, steps:158, total reward:-14.8788, 0.4478645324707031 sec
# Episode 407, loss:-92.6959, fail, steps:159, total reward:-14.7445, 0.44434452056884766 sec
# Episode 408, loss:-69.9068, fail, steps:160, total reward:-9.7960, 0.44802141189575195 sec
# Episode 409, loss:-94.1030, fail, steps:159, total reward:-14.0223, 0.49947595596313477 sec
# Episode 410, loss:-63.0996, fail, steps:161, total reward:-6.4017, 0.4532012939453125 sec
# Episode 411, loss:-83.6226, fail, steps:160, total reward:-10.6616, 0.4487760066986084 sec
# Episode 412, loss:-60.9049, fail, steps:159, total reward:-10.4976, 0.44656968116760254 sec
# Episode 413, loss:-117.2228, fail, steps:159, total reward:-16.0231, 0.44740772247314453 sec
# Episode 414, loss:-69.2589, succeed, steps:131, total reward:-7.4755, 0.3693249225616455 sec
# Episode 415, loss:-74.1839, fail, steps:159, total reward:-11.4353, 0.442471981048584 sec
# Episode 416, loss:-50.6330, fail, steps:160, total reward:-7.0738, 0.4458615779876709 sec
# Episode 417, loss:-68.0848, fail, steps:160, total reward:-10.1239, 0.4489917755126953 sec
# Episode 418, loss:-88.0703, fail, steps:159, total reward:-11.9304, 0.4445047378540039 sec
# Episode 419, loss:-107.3736, fail, steps:160, total reward:-13.1337, 0.4480264186859131 sec
# Episode 420, loss:-68.4763, fail, steps:160, total reward:-9.0116, 0.45347166061401367 sec
# Episode 421, loss:-34.5369, succeed, steps:137, total reward:-2.6076, 0.3872222900390625 sec
# Episode 422, loss:-12.6234, succeed, steps:69, total reward:-1.7370, 0.1986374855041504 sec
# Episode 423, loss:-97.6550, fail, steps:160, total reward:-10.2902, 0.4242551326751709 sec
# Episode 424, loss:-79.8375, fail, steps:160, total reward:-8.2280, 0.43717241287231445 sec
# Episode 425, loss:-116.1918, fail, steps:159, total reward:-12.5895, 0.4436988830566406 sec
# Episode 426, loss:-130.9154, fail, steps:35, total reward:-11.1238, 0.11159420013427734 sec
# Episode 427, loss:-113.3025, fail, steps:160, total reward:-11.5994, 0.412980318069458 sec
# Episode 428, loss:-130.0038, fail, steps:159, total reward:-15.8978, 0.4306907653808594 sec
# Episode 429, loss:-40.0770, succeed, steps:118, total reward:-4.1014, 0.32920217514038086 sec
# Episode 430, loss:-57.1157, succeed, steps:126, total reward:-6.7927, 0.3432753086090088 sec
# Episode 431, loss:-2.4909, succeed, steps:89, total reward:0.8289, 0.24746394157409668 sec
# Episode 432, loss:-67.3598, succeed, steps:153, total reward:-6.6917, 0.4662292003631592 sec
# Episode 433, loss:-165.5133, fail, steps:52, total reward:-14.4571, 0.15353965759277344 sec
# Episode 434, loss:-128.1322, fail, steps:158, total reward:-17.1051, 0.4141960144042969 sec
# Episode 435, loss:-93.2270, fail, steps:28, total reward:-10.4761, 0.08813929557800293 sec
# Episode 436, loss:-70.6563, succeed, steps:135, total reward:-8.6741, 0.3456306457519531 sec
# Episode 437, loss:-101.7802, fail, steps:160, total reward:-12.3009, 0.4272727966308594 sec
# Episode 438, loss:-95.1638, succeed, steps:153, total reward:-8.8589, 0.42166900634765625 sec
# Episode 439, loss:-89.6257, fail, steps:161, total reward:-8.9188, 0.444474458694458 sec
# Episode 440, loss:-80.3053, fail, steps:160, total reward:-10.1567, 0.44383740425109863 sec
# Episode 441, loss:-109.7698, fail, steps:160, total reward:-11.1558, 0.44515371322631836 sec
# Episode 442, loss:-54.9727, fail, steps:161, total reward:-5.7024, 0.44936537742614746 sec
# Episode 443, loss:-150.8320, fail, steps:77, total reward:-14.9126, 0.22529888153076172 sec
# Episode 444, loss:-23.9876, fail, steps:161, total reward:-4.0532, 0.43265819549560547 sec
# Episode 445, loss:-136.0064, fail, steps:159, total reward:-14.8879, 0.43604326248168945 sec
# Episode 446, loss:-65.4677, fail, steps:160, total reward:-10.0845, 0.4435994625091553 sec
# Episode 447, loss:-37.0607, succeed, steps:119, total reward:-3.8228, 0.3377690315246582 sec
# Episode 448, loss:-83.0914, fail, steps:161, total reward:-8.8017, 0.438967227935791 sec
# Episode 449, loss:-96.5222, fail, steps:159, total reward:-13.1666, 0.44763779640197754 sec
# Episode 450, loss:-96.2822, fail, steps:160, total reward:-11.9600, 0.44559550285339355 sec
# Episode 451, loss:-104.8001, fail, steps:159, total reward:-12.2387, 0.44540858268737793 sec
# Episode 452, loss:-105.5455, fail, steps:159, total reward:-12.2288, 0.445110559463501 sec
# Episode 453, loss:-84.5813, fail, steps:160, total reward:-9.3100, 0.45308780670166016 sec
# Episode 454, loss:-46.2061, fail, steps:162, total reward:-3.3417, 0.45220279693603516 sec
# Episode 455, loss:-60.8410, fail, steps:161, total reward:-6.5788, 0.45216894149780273 sec
# Episode 456, loss:-84.3363, fail, steps:160, total reward:-10.2379, 0.4479086399078369 sec
# Episode 457, loss:-61.2102, fail, steps:160, total reward:-8.3623, 0.5066168308258057 sec
# Episode 458, loss:3.7854, succeed, steps:72, total reward:1.4072, 0.21843600273132324 sec
# Episode 459, loss:-94.2429, fail, steps:159, total reward:-12.8059, 0.42293787002563477 sec
# Episode 460, loss:-20.5469, fail, steps:162, total reward:-1.4860, 0.4455122947692871 sec
# Episode 461, loss:-65.5725, fail, steps:159, total reward:-10.0025, 0.4405381679534912 sec
# Episode 462, loss:-40.1172, fail, steps:161, total reward:-2.6303, 0.448061466217041 sec
# Episode 463, loss:-84.9533, fail, steps:159, total reward:-11.8780, 0.450408935546875 sec
# Episode 464, loss:-88.3298, fail, steps:158, total reward:-14.7346, 0.44291114807128906 sec
# Episode 465, loss:-69.4037, fail, steps:161, total reward:-8.6074, 0.4501056671142578 sec
# Episode 466, loss:-81.2070, fail, steps:160, total reward:-11.4944, 0.44873547554016113 sec
# Episode 467, loss:-167.8903, fail, steps:119, total reward:-13.8022, 0.3382904529571533 sec
# Episode 468, loss:-87.8872, fail, steps:160, total reward:-12.2124, 0.4434041976928711 sec
# Episode 469, loss:-35.3024, succeed, steps:77, total reward:-4.7168, 0.22325563430786133 sec
# Episode 470, loss:-16.7612, succeed, steps:143, total reward:-1.9798, 0.3804910182952881 sec
# Episode 471, loss:-83.2759, fail, steps:160, total reward:-10.1459, 0.43598389625549316 sec
# Episode 472, loss:-136.3774, fail, steps:158, total reward:-17.6101, 0.437880277633667 sec
# Episode 473, loss:-29.4699, succeed, steps:112, total reward:-3.7193, 0.3176441192626953 sec
# Episode 474, loss:-78.7576, fail, steps:161, total reward:-7.3615, 0.44253063201904297 sec
# Episode 475, loss:-40.4269, succeed, steps:158, total reward:-4.7024, 0.4395577907562256 sec
# Episode 476, loss:-74.9394, fail, steps:160, total reward:-9.5788, 0.4450571537017822 sec
# Episode 477, loss:-97.7768, fail, steps:159, total reward:-12.0124, 0.5059525966644287 sec
# Episode 478, loss:-97.9911, fail, steps:159, total reward:-13.7436, 0.4521517753601074 sec
# Episode 479, loss:-109.6215, fail, steps:159, total reward:-15.3830, 0.4455099105834961 sec
# Episode 480, loss:-61.7983, succeed, steps:159, total reward:-7.6902, 0.44529247283935547 sec
# Episode 481, loss:-66.2123, fail, steps:160, total reward:-7.9394, 0.4500577449798584 sec
# Episode 482, loss:-119.2440, fail, steps:161, total reward:-10.7230, 0.452178955078125 sec
# Episode 483, loss:-89.3062, fail, steps:160, total reward:-8.1361, 0.453920841217041 sec
# Episode 484, loss:-35.2581, fail, steps:161, total reward:-2.1975, 0.4532492160797119 sec
# Episode 485, loss:-65.4142, fail, steps:161, total reward:-6.8509, 0.45525097846984863 sec
# Episode 486, loss:-107.6524, fail, steps:159, total reward:-13.8879, 0.44724369049072266 sec
# Episode 487, loss:-86.9153, fail, steps:160, total reward:-10.5173, 0.45781683921813965 sec
# Episode 488, loss:-36.4108, succeed, steps:155, total reward:-4.8360, 0.4396965503692627 sec
# Episode 489, loss:-51.7846, fail, steps:161, total reward:-6.7230, 0.4540853500366211 sec
# Episode 490, loss:-90.3006, fail, steps:160, total reward:-11.1558, 0.4490792751312256 sec
# Episode 491, loss:-59.3129, fail, steps:160, total reward:-6.8574, 0.4502551555633545 sec
# Episode 492, loss:-39.1543, succeed, steps:139, total reward:-2.5552, 0.3985555171966553 sec
# Episode 493, loss:-87.2595, fail, steps:159, total reward:-11.0845, 0.44295835494995117 sec
# Episode 494, loss:-64.9649, fail, steps:160, total reward:-9.3001, 0.44711947441101074 sec
# Episode 495, loss:-69.6408, succeed, steps:126, total reward:-9.2985, 0.3561129570007324 sec
# Episode 496, loss:-65.9284, fail, steps:160, total reward:-7.7230, 0.44074368476867676 sec
# Episode 497, loss:-72.7755, fail, steps:160, total reward:-9.7960, 0.4512481689453125 sec
# Episode 498, loss:13.3251, succeed, steps:134, total reward:4.7230, 0.37857604026794434 sec
# Episode 499, loss:-31.5635, succeed, steps:117, total reward:-3.2186, 0.3272421360015869 sec
# Episode 500, loss:-80.0760, fail, steps:160, total reward:-8.0837, 0.4351770877838135 sec
# Episode 501, loss:-55.7326, fail, steps:161, total reward:-5.6238, 0.5009045600891113 sec
# Episode 502, loss:-71.8250, succeed, steps:156, total reward:-7.4238, 0.44216489791870117 sec
# Episode 503, loss:-134.2699, fail, steps:159, total reward:-16.8887, 0.4441812038421631 sec
# Episode 504, loss:-79.5394, fail, steps:160, total reward:-9.7230, 0.4467761516571045 sec
# Episode 505, loss:-98.5881, fail, steps:159, total reward:-13.2387, 0.44737792015075684 sec
# Episode 506, loss:-72.7745, fail, steps:160, total reward:-10.7337, 0.449434757232666 sec
# Episode 507, loss:-53.9787, succeed, steps:113, total reward:-4.0571, 0.3431570529937744 sec
# Episode 508, loss:-16.5257, succeed, steps:116, total reward:-2.3693, 0.3214247226715088 sec
# Episode 509, loss:-7.3512, succeed, steps:88, total reward:0.3339, 0.24547123908996582 sec
# Episode 510, loss:-87.7908, fail, steps:159, total reward:-11.8681, 0.42670583724975586 sec
# Episode 511, loss:-89.0463, fail, steps:160, total reward:-11.3108, 0.4396786689758301 sec
# Episode 512, loss:-86.9142, fail, steps:160, total reward:-9.0902, 0.4444749355316162 sec
# Episode 513, loss:-75.9890, fail, steps:159, total reward:-10.6517, 0.4470393657684326 sec
# Episode 514, loss:-75.9200, fail, steps:160, total reward:-9.8681, 0.44692230224609375 sec
# Episode 515, loss:-53.2097, fail, steps:161, total reward:-5.2074, 0.4503014087677002 sec
# Episode 516, loss:-97.5538, fail, steps:151, total reward:-9.7504, 0.4238016605377197 sec
# Episode 517, loss:-86.9500, fail, steps:160, total reward:-10.9066, 0.4523448944091797 sec
# ...
# Episode 19403, loss:3.6010, succeed, steps:80, total reward:6.0523, 0.22637391090393066 sec
# Episode 19404, loss:0.4044, succeed, steps:77, total reward:-0.8077, 0.20764875411987305 sec
# Episode 19405, loss:0.9081, succeed, steps:88, total reward:3.1053, 0.23372435569763184 sec
# Episode 19406, loss:-1.2226, succeed, steps:58, total reward:0.6764, 0.1570131778717041 sec
# Episode 19407, loss:0.5968, succeed, steps:118, total reward:6.7341, 0.3063664436340332 sec
# Episode 19408, loss:-8.3026, succeed, steps:108, total reward:-3.0495, 0.2908902168273926 sec
# Episode 19409, loss:-6.6163, succeed, steps:97, total reward:2.2304, 0.26343464851379395 sec
# Episode 19410, loss:-1.3411, succeed, steps:71, total reward:0.2630, 0.19220876693725586 sec
# Episode 19411, loss:-5.5396, fail, steps:161, total reward:-3.1253, 0.425487756729126 sec
# Episode 19412, loss:-6.4050, fail, steps:161, total reward:-1.6925, 0.43757081031799316 sec
# Episode 19413, loss:-7.5228, fail, steps:160, total reward:-9.0181, 0.44145917892456055 sec
# Episode 19414, loss:-2.5345, succeed, steps:123, total reward:1.5478, 0.3455941677093506 sec
# Episode 19415, loss:-5.2537, succeed, steps:81, total reward:-3.5833, 0.22782206535339355 sec
# Episode 19416, loss:-2.5110, succeed, steps:126, total reward:-5.6385, 0.33696413040161133 sec
# Episode 19417, loss:-1.6951, succeed, steps:114, total reward:-0.4045, 0.31332826614379883 sec
# Episode 19418, loss:-11.1475, fail, steps:160, total reward:-6.4967, 0.43166375160217285 sec
# Episode 19419, loss:-3.3010, succeed, steps:136, total reward:-5.2478, 0.3758556842803955 sec
# Episode 19420, loss:-1.5719, succeed, steps:151, total reward:-1.6669, 0.415905237197876 sec
# Episode 19421, loss:1.1281, succeed, steps:129, total reward:4.9699, 0.3596353530883789 sec
# Episode 19422, loss:0.2983, succeed, steps:92, total reward:-1.6712, 0.2623288631439209 sec
# Episode 19423, loss:-3.0204, succeed, steps:115, total reward:0.7234, 0.3101074695587158 sec
# Episode 19424, loss:-0.5445, succeed, steps:124, total reward:-0.6072, 0.3375554084777832 sec
# Episode 19425, loss:-4.3284, fail, steps:161, total reward:-3.2597, 0.43365931510925293 sec
# Episode 19426, loss:2.9202, succeed, steps:57, total reward:3.2249, 0.16546845436096191 sec
# Episode 19427, loss:-4.7651, succeed, steps:96, total reward:-1.2032, 0.2530696392059326 sec
# Episode 19428, loss:4.3615, succeed, steps:115, total reward:3.9505, 0.3053455352783203 sec
# Episode 19429, loss:0.3672, succeed, steps:154, total reward:-0.8055, 0.46921634674072266 sec
# Episode 19430, loss:-11.6211, fail, steps:160, total reward:-8.4967, 0.4455990791320801 sec
# Episode 19431, loss:-9.1494, succeed, steps:101, total reward:-0.3681, 0.2842562198638916 sec
# Episode 19432, loss:0.6457, succeed, steps:108, total reward:3.4048, 0.2950553894042969 sec
# Episode 19433, loss:-0.0037, succeed, steps:95, total reward:0.8796, 0.26020336151123047 sec
# Episode 19434, loss:-12.0453, fail, steps:161, total reward:-3.1975, 0.4300522804260254 sec
# Episode 19435, loss:3.5287, succeed, steps:54, total reward:3.7077, 0.16109967231750488 sec
# Episode 19436, loss:-15.9140, fail, steps:160, total reward:-6.2803, 0.4201176166534424 sec
# Episode 19437, loss:-1.9808, fail, steps:160, total reward:-6.1361, 0.4350132942199707 sec
# Episode 19438, loss:-20.1985, fail, steps:159, total reward:-10.3632, 0.43934082984924316 sec
# Episode 19439, loss:-0.6698, succeed, steps:78, total reward:0.8087, 0.22289061546325684 sec
# Episode 19440, loss:-0.0595, succeed, steps:97, total reward:6.3231, 0.26177072525024414 sec
# Episode 19441, loss:-6.2504, succeed, steps:153, total reward:-2.0219, 0.4121558666229248 sec
# Episode 19442, loss:-8.7103, fail, steps:159, total reward:-10.1468, 0.43251609802246094 sec
# Episode 19443, loss:-5.9686, fail, steps:162, total reward:-1.8925, 0.446209192276001 sec
# Episode 19444, loss:-3.5575, fail, steps:161, total reward:-2.4761, 0.4466562271118164 sec
# Episode 19445, loss:-2.1343, succeed, steps:90, total reward:-1.5654, 0.2601511478424072 sec
# Episode 19446, loss:-8.9944, succeed, steps:136, total reward:-8.9077, 0.3669745922088623 sec
# Episode 19447, loss:-1.2759, succeed, steps:65, total reward:1.0779, 0.18625855445861816 sec
# Episode 19448, loss:-5.8646, fail, steps:160, total reward:-5.6311, 0.41993045806884766 sec
# Episode 19449, loss:0.0671, succeed, steps:154, total reward:-3.9605, 0.4203345775604248 sec
# Episode 19450, loss:-1.4773, fail, steps:161, total reward:-1.2597, 0.4429183006286621 sec
# Episode 19451, loss:-1.5270, fail, steps:161, total reward:-3.5876, 0.44513702392578125 sec
# Episode 19452, loss:-0.2338, succeed, steps:65, total reward:1.2943, 0.19454169273376465 sec
# Episode 19453, loss:-4.2349, fail, steps:159, total reward:-11.8746, 0.42429542541503906 sec
# Episode 19454, loss:2.0702, fail, steps:163, total reward:5.4109, 0.4449641704559326 sec
# Episode 19455, loss:-4.0371, succeed, steps:78, total reward:-2.7069, 0.22691106796264648 sec
# Episode 19456, loss:-2.2959, fail, steps:161, total reward:-4.1262, 0.48272132873535156 sec
# Episode 19457, loss:1.0287, succeed, steps:81, total reward:3.5923, 0.23179292678833008 sec
# Episode 19458, loss:-6.4880, fail, steps:160, total reward:-10.3632, 0.45101332664489746 sec
# Episode 19459, loss:-1.4635, fail, steps:161, total reward:-4.9918, 0.4397563934326172 sec
# Episode 19460, loss:-8.2262, fail, steps:159, total reward:-11.2910, 0.44072532653808594 sec
# Episode 19461, loss:-6.0084, fail, steps:160, total reward:-10.2353, 0.4437987804412842 sec
# Episode 19462, loss:-0.0592, fail, steps:161, total reward:-0.8269, 0.44729113578796387 sec
# Episode 19463, loss:1.3597, succeed, steps:89, total reward:2.1995, 0.2616844177246094 sec
# Episode 19464, loss:-3.1702, fail, steps:160, total reward:-7.9205, 0.42877697944641113 sec
# Episode 19465, loss:-3.4197, fail, steps:161, total reward:-2.3319, 0.4442577362060547 sec
# Episode 19466, loss:-12.7416, fail, steps:160, total reward:-7.8147, 0.4463200569152832 sec
# Episode 19467, loss:-1.7679, fail, steps:160, total reward:-6.5590, 0.4488992691040039 sec
# Episode 19468, loss:0.8526, succeed, steps:83, total reward:2.0045, 0.24657416343688965 sec
# Episode 19469, loss:-5.7124, fail, steps:161, total reward:-4.8475, 0.43078017234802246 sec
# Episode 19470, loss:-9.2960, fail, steps:159, total reward:-10.3697, 0.4382517337799072 sec
# Episode 19471, loss:-1.5402, fail, steps:161, total reward:-4.7754, 0.44731783866882324 sec
# Episode 19472, loss:-1.1350, succeed, steps:111, total reward:-3.2438, 0.3178975582122803 sec
# Episode 19473, loss:-4.4306, fail, steps:160, total reward:-6.5590, 0.43874692916870117 sec
# Episode 19474, loss:-6.5916, fail, steps:161, total reward:-2.5876, 0.4468355178833008 sec
# Episode 19475, loss:-3.6850, succeed, steps:97, total reward:-0.2032, 0.2801206111907959 sec
# Episode 19476, loss:-6.0957, fail, steps:161, total reward:-3.9819, 0.4413301944732666 sec
# Episode 19477, loss:-4.1236, succeed, steps:88, total reward:0.5503, 0.253340482711792 sec
# Episode 19478, loss:-1.6855, succeed, steps:105, total reward:-2.1731, 0.2848961353302002 sec
# Episode 19479, loss:-1.7699, fail, steps:161, total reward:-5.7131, 0.43649911880493164 sec
# Episode 19480, loss:-19.6251, fail, steps:160, total reward:-7.7754, 0.4421062469482422 sec
# Episode 19481, loss:0.6455, succeed, steps:77, total reward:2.8916, 0.22222018241882324 sec
# Episode 19482, loss:-4.9898, succeed, steps:120, total reward:-2.1243, 0.37304139137268066 sec
# Episode 19483, loss:-4.1965, fail, steps:161, total reward:-4.1983, 0.4326760768890381 sec
# Episode 19484, loss:-1.9953, fail, steps:160, total reward:-7.3426, 0.44123363494873047 sec
# Episode 19485, loss:5.2039, succeed, steps:89, total reward:1.6224, 0.2585318088531494 sec
# Episode 19486, loss:-11.8867, fail, steps:159, total reward:-11.7960, 0.4263434410095215 sec
# Episode 19487, loss:-4.7396, fail, steps:161, total reward:-4.6311, 0.4438624382019043 sec
# Episode 19488, loss:1.2835, succeed, steps:91, total reward:3.7667, 0.2592940330505371 sec
# Episode 19489, loss:-0.2442, fail, steps:161, total reward:-3.2696, 0.4324049949645996 sec
# Episode 19490, loss:2.6687, succeed, steps:80, total reward:6.1080, 0.22929716110229492 sec
# Episode 19491, loss:2.3398, succeed, steps:115, total reward:0.5070, 0.31351613998413086 sec
# Episode 19492, loss:1.7822, succeed, steps:82, total reward:4.8809, 0.2259228229522705 sec
# Episode 19493, loss:-12.5202, fail, steps:159, total reward:-13.5173, 0.42287230491638184 sec
# Episode 19494, loss:3.3567, succeed, steps:56, total reward:5.9963, 0.1620020866394043 sec
# Episode 19495, loss:1.2912, succeed, steps:20, total reward:3.9266, 0.0582425594329834 sec
# Episode 19496, loss:1.5449, succeed, steps:91, total reward:3.8716, 0.22966790199279785 sec
# Episode 19497, loss:-4.7904, succeed, steps:138, total reward:-4.1855, 0.35869336128234863 sec
# Episode 19498, loss:-1.8898, succeed, steps:91, total reward:3.9109, 0.24976444244384766 sec
# Episode 19499, loss:-2.6321, succeed, steps:123, total reward:-2.2564, 0.3346214294433594 sec
# Episode 19500, loss:5.7998, succeed, steps:144, total reward:4.7531, 0.38716721534729004 sec
# Episode 19501, loss:0.1728, succeed, steps:112, total reward:0.9505, 0.31067967414855957 sec
# Episode 19502, loss:-7.7005, fail, steps:160, total reward:-7.9197, 0.43335771560668945 sec
# Episode 19503, loss:-15.2100, fail, steps:161, total reward:-2.9089, 0.44518184661865234 sec
# Episode 19504, loss:0.2403, succeed, steps:107, total reward:2.4769, 0.30255579948425293 sec
# Episode 19505, loss:-5.4000, succeed, steps:155, total reward:-0.5268, 0.42623066902160645 sec
# Episode 19506, loss:-13.2506, succeed, steps:153, total reward:-6.2589, 0.4209632873535156 sec
# Episode 19507, loss:-0.7348, succeed, steps:74, total reward:0.1080, 0.21306800842285156 sec
# Episode 19508, loss:0.5481, succeed, steps:105, total reward:0.6933, 0.28257298469543457 sec
# Episode 19509, loss:-5.6542, fail, steps:161, total reward:-2.0433, 0.43490099906921387 sec
# Episode 19510, loss:-2.5296, succeed, steps:79, total reward:-1.9233, 0.2248399257659912 sec
# Episode 19511, loss:-8.4232, succeed, steps:89, total reward:-2.6146, 0.24573993682861328 sec
# Episode 19512, loss:0.8206, succeed, steps:120, total reward:1.9192, 0.31907153129577637 sec
# Episode 19513, loss:-10.0212, fail, steps:160, total reward:-6.4967, 0.48235273361206055 sec
# Episode 19514, loss:-0.9214, succeed, steps:79, total reward:1.9530, 0.22501659393310547 sec
# Episode 19515, loss:-4.9171, fail, steps:161, total reward:-5.3525, 0.43036532402038574 sec
# Episode 19516, loss:0.4652, succeed, steps:71, total reward:3.7950, 0.20448064804077148 sec
# Episode 19517, loss:-2.2274, fail, steps:162, total reward:2.2461, 0.43659162521362305 sec
# Episode 19518, loss:-3.3198, succeed, steps:72, total reward:0.4466, 0.20604896545410156 sec
# Episode 19519, loss:2.4771, succeed, steps:105, total reward:3.7040, 0.2804534435272217 sec
# Episode 19520, loss:1.0932, succeed, steps:86, total reward:1.6331, 0.2344059944152832 sec
# Episode 19521, loss:1.5031, succeed, steps:66, total reward:5.3772, 0.17875170707702637 sec
# Episode 19522, loss:0.2957, succeed, steps:49, total reward:1.7185, 0.13227367401123047 sec
# Episode 19523, loss:5.5514, succeed, steps:123, total reward:4.8241, 0.318467378616333 sec
# Episode 19524, loss:4.0120, succeed, steps:71, total reward:3.4344, 0.1951279640197754 sec
# Episode 19525, loss:4.5609, succeed, steps:112, total reward:7.6212, 0.2966601848602295 sec
# Episode 19526, loss:-7.6152, fail, steps:160, total reward:-8.3525, 0.4306368827819824 sec
# Episode 19527, loss:4.1753, succeed, steps:83, total reward:9.1080, 0.23456621170043945 sec
# Episode 19528, loss:-6.6018, succeed, steps:109, total reward:-2.4102, 0.293212890625 sec
# Episode 19529, loss:1.5045, succeed, steps:65, total reward:4.3772, 0.1789848804473877 sec
# Episode 19530, loss:-10.2560, fail, steps:160, total reward:-8.3918, 0.41893768310546875 sec
# Episode 19531, loss:-2.9020, fail, steps:161, total reward:-6.5066, 0.4367053508758545 sec
# Episode 19532, loss:-2.8147, succeed, steps:92, total reward:-9.1517, 0.26673126220703125 sec
# Episode 19533, loss:-0.1714, fail, steps:160, total reward:-6.2803, 0.42899417877197266 sec
# Episode 19534, loss:0.6572, succeed, steps:76, total reward:2.0359, 0.21744179725646973 sec
# Episode 19535, loss:-14.7311, fail, steps:159, total reward:-12.8681, 0.42141222953796387 sec
# Episode 19536, loss:-7.7221, fail, steps:160, total reward:-10.3197, 0.43866562843322754 sec
# Episode 19537, loss:-6.4654, fail, steps:160, total reward:-10.4452, 0.44188976287841797 sec
# Episode 19538, loss:-18.7436, fail, steps:159, total reward:-11.4353, 0.45067310333251953 sec
# Episode 19539, loss:-8.4306, fail, steps:160, total reward:-10.5895, 0.44702959060668945 sec
# Episode 19540, loss:1.7448, succeed, steps:73, total reward:2.2630, 0.2144780158996582 sec
# Episode 19541, loss:-4.3321, fail, steps:161, total reward:-3.9811, 0.4281620979309082 sec
# Episode 19542, loss:-8.1661, fail, steps:159, total reward:-11.6616, 0.4372878074645996 sec
# Episode 19543, loss:0.4317, succeed, steps:106, total reward:1.9097, 0.3035552501678467 sec
# Episode 19544, loss:0.9623, succeed, steps:49, total reward:1.8070, 0.13893508911132812 sec
# Episode 19545, loss:5.5081, succeed, steps:98, total reward:6.8903, 0.255321741104126 sec
# Episode 19546, loss:-9.9398, fail, steps:161, total reward:-5.4246, 0.48016810417175293 sec
# Episode 19547, loss:0.5689, fail, steps:161, total reward:-4.6311, 0.4375951290130615 sec
# Episode 19548, loss:0.8210, succeed, steps:102, total reward:4.1476, 0.28929972648620605 sec
# Episode 19549, loss:-9.7333, fail, steps:161, total reward:-2.6826, 0.43776965141296387 sec
# Episode 19550, loss:-17.0065, fail, steps:159, total reward:-16.0624, 0.43877172470092773 sec
# Episode 19551, loss:-4.3721, succeed, steps:141, total reward:-4.8585, 0.3923325538635254 sec
# Episode 19552, loss:-2.9765, fail, steps:161, total reward:-5.2082, 0.4454944133758545 sec
# Episode 19553, loss:1.2966, succeed, steps:84, total reward:3.3652, 0.25342416763305664 sec
# Episode 19554, loss:-4.3233, fail, steps:160, total reward:-7.7918, 0.4457113742828369 sec
# Episode 19555, loss:3.1095, succeed, steps:79, total reward:1.8087, 0.2323446273803711 sec
# Episode 19556, loss:1.2936, succeed, steps:97, total reward:3.1682, 0.2613565921783447 sec
# Episode 19557, loss:-0.6438, succeed, steps:87, total reward:2.9217, 0.23770856857299805 sec
# Episode 19558, loss:3.4203, succeed, steps:86, total reward:1.7938, 0.2311863899230957 sec
# Episode 19559, loss:-6.1725, fail, steps:160, total reward:-7.2704, 0.4220139980316162 sec
# Episode 19560, loss:2.3343, succeed, steps:92, total reward:0.1297, 0.25785231590270996 sec
# Episode 19561, loss:2.3265, succeed, steps:110, total reward:2.1055, 0.29753732681274414 sec
# Episode 19562, loss:-6.4233, fail, steps:160, total reward:-8.8582, 0.43320345878601074 sec
# Episode 19563, loss:0.3104, succeed, steps:44, total reward:-2.8487, 0.13127398490905762 sec
# Episode 19564, loss:-0.1877, succeed, steps:151, total reward:-0.5062, 0.3912053108215332 sec
# Episode 19565, loss:-14.8853, fail, steps:161, total reward:-3.7647, 0.4349079132080078 sec
# Episode 19566, loss:-8.7960, fail, steps:161, total reward:-4.9197, 0.4432978630065918 sec
# Episode 19567, loss:-0.4041, succeed, steps:98, total reward:-0.5082, 0.2801549434661865 sec
# Episode 19568, loss:2.4191, succeed, steps:78, total reward:3.9801, 0.21915912628173828 sec
# Episode 19569, loss:-25.9312, fail, steps:159, total reward:-13.2517, 0.42063331604003906 sec
# Episode 19570, loss:-0.7992, succeed, steps:143, total reward:0.8866, 0.3922703266143799 sec
# Episode 19571, loss:-0.2570, succeed, steps:136, total reward:0.7901, 0.42976808547973633 sec
# Episode 19572, loss:0.4859, succeed, steps:133, total reward:-1.7935, 0.3678133487701416 sec
# Episode 19573, loss:-5.4517, fail, steps:160, total reward:-6.8639, 0.4393949508666992 sec
# Episode 19574, loss:5.4648, succeed, steps:105, total reward:4.0647, 0.2981564998626709 sec
# Episode 19575, loss:-0.4277, succeed, steps:85, total reward:4.1652, 0.23481273651123047 sec

# %%
# Testing code

# %%
import numpy as np
import matplotlib.pyplot as plt

def compute_entropy(N, alpha=1):
    K = 2**N
    values = np.arange(K)
    unnormalized_probs = np.exp(-alpha * values)
    Z = unnormalized_probs.sum()
    probs = unnormalized_probs / Z
    return values, -np.log2(probs)

# Parameters
N = 4  # Number of bits
alpha = 1  # Decay rate

# Compute probabilities
values, probs = compute_entropy(N, alpha)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(values, probs, width=0.8, alpha=0.7, edgecolor="black")
plt.title(f"Exponential Decay Probabilities (N={N}, alpha={alpha})")
plt.xlabel("Integer Value")
plt.ylabel("Probability")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
def compute_min_delta(comparisons):
    # Initialize the result list to store minDelta values
    min_delta = []

    # Iterate through each pair in the comparisons list
    for i, (xi, yi) in enumerate(comparisons):
        if i == 0:
            # For i = 0, use the first case directly
            min_delta.append((xi, min(yi, yi - xi), 0))
        else:
            # For i > 0, compute all possible options and select the minimal one
            options = []

            # Simple Entropy
            simple_entropy = (xi, min(yi, yi - xi), 0)
            options.append(simple_entropy)

            # First Delta Entropy
            xi_prev, yi_prev = comparisons[i - 1]
            first_delta_entropy = (xi - xi_prev, yi - yi_prev, 0)
            options.append(first_delta_entropy)

            # Second Delta Entropy (only valid for i > 1)
            if i > 1:
                xi_prev2, yi_prev2 = comparisons[i - 2]
                second_delta_entropy = (
                    (xi - xi_prev) - (xi_prev - xi_prev2),
                    (yi - yi_prev) - (yi_prev - yi_prev2),
                    0,
                )
                options.append(second_delta_entropy)

            # Arbitrary Position Entropy (only valid for i > 1)
            for j in range(i):
                xj, yj = comparisons[j]
                arbitrary_position_entropy = (
                    xi - xj,
                    yi - yj,
                    min(j, i - j),
                )
                options.append(arbitrary_position_entropy)

            # Find the option with the minimal sum
            min_delta.append(min(options, key=lambda t: sum([abs(x) for x in t])))

    return min_delta


# Example Usage
comparisons = [(1, 5), (2, 7), (4, 10), (8, 15)]
result = compute_min_delta(comparisons)

# Output the results
for i, delta in enumerate(result):
    print(f"minDelta for comparison {i}: {delta}")

def compute_min_delta_entropy(comparisons):
    # Initialize the result list to store minDelta values
    min_delta = None

    # Iterate through each pair in the comparisons list
    i = len(comparisons) - 1
    xi, yi = comparisons[i]
    if i == 0:
        # For i = 0, use the first case directly
        min_delta = (xi, min(yi, yi - xi), 0)
    else:
        # For i > 0, compute all possible options and select the minimal one
        options = []

        # Simple Entropy
        simple_entropy = (xi, min(yi, yi - xi), 0)
        options.append(simple_entropy)

        # First Delta Entropy
        xi_prev, yi_prev = comparisons[i - 1]
        first_delta_entropy = (xi - xi_prev, yi - yi_prev, 0)
        options.append(first_delta_entropy)

        # Second Delta Entropy (only valid for i > 1)
        if i > 1:
            xi_prev2, yi_prev2 = comparisons[i - 2]
            second_delta_entropy = (
                (xi - xi_prev) - (xi_prev - xi_prev2),
                (yi - yi_prev) - (yi_prev - yi_prev2),
                0,
            )
            options.append(second_delta_entropy)

        # Arbitrary Position Entropy (only valid for i > 1)
        for j in range(i):
            xj, yj = comparisons[j]
            arbitrary_position_entropy = (
                xi - xj,
                yi - yj,
                min(j, i - j),
            )
            options.append(arbitrary_position_entropy)

        # Find the option with the minimal sum
        min_delta = min(options, key=lambda t: sum([get_entropy_of_integer(x) for x in t]))

    return sum([get_entropy_of_integer(x) for x in min_delta])

compute_min_delta_entropy(comparisons)

# %%
def test_case_1():
    # Test with a single comparison
    comparisons = [(3, 8)]
    expected_result = [(3, 5, 0)]
    assert compute_min_delta(comparisons) == expected_result

def test_case_2():
    # Test with multiple comparisons
    comparisons = [(1, 5), (2, 7), (4, 10), (8, 15)]
    expected_result = [
        (1, 4, 0),  # Simple Entropy for the first pair
        (1, 2, 0),  # Minimal sum using First Delta Entropy
        (1, 1, 0),  # Minimal sum using First Delta Entropy
        (2, 2, 0),  # Minimal sum using First Delta Entropy
    ]
    assert compute_min_delta(comparisons) == expected_result

def test_case_3():
    # Test with comparisons where the minimal sum comes from Arbitrary Position Entropy
    comparisons = [(1, 10), (3, 12), (5, 14), (1, 11)]
    expected_result = [
        (1, 9, 0),  # Simple Entropy for the first pair
        (2, 2, 0),  # Minimal sum using First Delta Entropy
        (0, 0, 0),  # Minimal sum using First Delta Entropy
        (0, 1, 0),  # Minimal sum using Arbitrary Position Entropy
    ]
    assert compute_min_delta(comparisons) == expected_result

test_case_1()
test_case_2()
test_case_3()
print("All cases succeeded.")

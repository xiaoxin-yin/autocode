# %%
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import random

MIN_LIST_LEN = 6
MAX_LIST_LEN = 6
MAX_STEPS = 120

SUCCESS_REWARD = 2.0
STEP_REWARD = -0.1
SWAP_REWARD = 1.0
INVALID_ACTION_REWARD = -10.0

EPS_START = 0.5
EPS_END = 0.05
EPS_DECAY = 1000
GAMMA = 0.8
NUM_EPISODES = 100000
EPISODES_SAVE = 1000
OUTPUT_DIR = 'datasets/rl_sort_transformer_easy/list6_transformer3_128_gamma098_step120_v1'

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    '0': 2,
    '1': 3,
    '2': 4,
    '3': 5,
    '4': 6,
    '5': 7,
    '6': 8,
    '7': 9,
    'less': 10,
    'equal': 11,
    'more': 12,
    'len1': 13,
    'len2': 14,
    'len3': 15,
    'len4': 16,
    'len5': 17,
    'len6': 18,
    'len7': 19,
    'len8': 20,
}
inv_vocab = {v: k for k, v in vocab.items()}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.list = [random.randint(1, 100) for _ in range(self.length)]
        while self.list == sorted(self.list):
            self.list = [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        initial_token = 'len{}'.format(self.length)
        return vocab[initial_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_list_len(self):
        return len(self.list)

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 >= self.length or index2 >= self.length or index1 < 0 or index2 < 0:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = STEP_REWARD
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = STEP_REWARD * 2
            else:
                response_token = vocab['more']
                reward = STEP_REWARD
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = SUCCESS_REWARD
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = SWAP_REWARD
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -SWAP_REWARD
            else:
                reward = STEP_REWARD
            self.indices = None
        else:
            reward = INVALID_ACTION_REWARD
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()
# Out:
# Using device: cuda

# %%
# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=256):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=128, nhead=8, num_layers=3):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])


def save_checkpoint(model, optimizer, episode, folder, filename):
    """
    Save the model and optimizer state to the designated filepath.

    Args:
        model (nn.Module): The model to save.
        optimizer (torch.optim.Optimizer): The optimizer whose state to save.
        episode (int): The current episode number.
        filepath (str): The path where to save the checkpoint.
    """
    filepath = os.path.join(folder, filename)
    # Ensure the directory exists
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    # Save the checkpoint
    torch.save({
        'episode': episode,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, filepath)
    print(f"Checkpoint saved at episode {episode} to {filepath}")

def load_checkpoint(filepath, model, optimizer):
    """
    Load the model and optimizer state from the designated filepath.

    Args:
        filepath (str): The path from where to load the checkpoint.
        model (nn.Module): The model into which to load the state_dict.
        optimizer (torch.optim.Optimizer): The optimizer into which to load the state.

    Returns:
        int: The episode number to resume from.
    """
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        episode = checkpoint['episode']
        print(f"Checkpoint loaded from {filepath}, resuming from episode {episode}")
        return episode
    else:
        print(f"No checkpoint found at {filepath}, starting from scratch.")
        return 0

# %%
# Training Loop
def train(verbose=False):
    # Removed torch.autograd.set_detect_anomaly(True)
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Reduced learning rate
    # Optionally, load a checkpoint
    # load_checkpoint("path_to_checkpoint", model, optimizer)

    episode_cnt = 0
    total_reward = 0.0
    num_successes = 0
    total_stesp = 0
    
    for episode in range(NUM_EPISODES):
        t1 = time.time()
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, current_list = env.reset()
        input_tokens = [initial_token_id]
        log_probs = []
        rewards = []
        
        state = 'expect_action'
        done = False
        success = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
                output = model(input_seq)  # (seq_len, batch_size, vocab_size)
                # Get logits for the last token
                logits = output[-1, 0, :]  # (vocab_size)

                # Check for NaNs in logits
                if torch.isnan(logits).any():
                    print(f"Episode {episode}, NaNs in logits before masking.")
                    break

                # Get valid tokens based on state
                def get_valid_tokens(state):
                    action_tokens = [vocab['Comparison'], vocab['Swap']]
                    index_tokens = [vocab[str(i)] for i in range(env.length)]
                    if state == 'expect_action':
                        return action_tokens
                    elif state == 'expect_index1':
                        return index_tokens[:-1]
                    elif state == 'expect_index2':
                        return [x for x in index_tokens if x > input_tokens[-1]]
                    else:
                        # Handle unexpected states by defaulting to expect_action
                        return action_tokens

                valid_token_ids = get_valid_tokens(state)

                # Ensure valid_token_ids are within the vocab range
                if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                    print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                    break

                # Mask invalid tokens
                mask_value = -1e9  # Use a large negative value instead of -inf
                mask = torch.full_like(logits, mask_value).to(device)
                mask[valid_token_ids] = 0
                masked_logits = logits + mask

                # Sample action. Have some chance to randomly pick a valid action.
                eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
                if random.random() < eps_threshold:
                    masked_logits = masked_logits / 4

                # Check for NaNs in masked_logits
                if torch.isnan(masked_logits).any():
                    print(f"Episode {episode}, NaNs in masked_logits after masking.")
                    break

                # Compute probabilities
                probs = F.softmax(masked_logits, dim=0)

                # Check for NaNs in probs
                if torch.isnan(probs).any():
                    print(f"Episode {episode}, NaNs in probs after softmax.")
                    break

                try:
                    m = torch.distributions.Categorical(probs)
                    action_token = m.sample()
                    log_prob = m.log_prob(action_token)
                except ValueError as e:
                    print(f"Episode {episode}, error in sampling action: {e}")
                    break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            reward = 0.0
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        reward = INVALID_ACTION_REWARD
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    if done and reward == SUCCESS_REWARD:
                        success = True
                    if verbose:
                        print("Reward:", reward)
                    state = 'expect_action'
                else:
                    reward = INVALID_ACTION_REWARD
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                response_token, reward, done, current_list = env.step(action_tokens)
                if done and reward == SUCCESS_REWARD:
                    success = True
                if verbose:
                    print("Reward:", reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                reward = INVALID_ACTION_REWARD
                done = True

            rewards.append(reward)
        #
        if success: 
            num_successes += 1
        # Save checkpoint
        if episode > 0 and episode % EPISODES_SAVE == 0:
            avg_reward = total_reward / episode_cnt
            success_rate = num_successes / episode_cnt
            avg_steps = total_steps / episode_cnt
            episode_cnt = 0
            total_reward = 0.0
            num_successes = 0
            total_steps = 0
            save_checkpoint(model, optimizer, episode, OUTPUT_DIR, f"ckpt_{episode}_{success_rate:.4f}_{avg_steps:.2f}.pth")
        #
        assert len(log_probs) == len(rewards), "log_probs and returns have different sizes!"

        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns and loss within autocast
        with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
            # Compute returns
            returns = []
            R = 0
            gamma = GAMMA
            for r in rewards[::-1]:
                R = r + gamma * R
                returns.insert(0, R)
            returns = torch.tensor(returns).to(device)

            # Check for NaNs in returns
            if torch.isnan(returns).any():
                print(f"Episode {episode}, NaNs in returns.")
                continue

            # Compute loss
            loss = 0
            for log_prob, R in zip(log_probs, returns):
                loss -= log_prob * R

            # Check for NaNs in loss
            if torch.isnan(loss):
                print(f"Episode {episode}, NaN in loss.")
                continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        episode_cnt += 1
        total_reward += sum(rewards)
        total_steps += len(rewards)
        t2 = time.time()
        if episode % 1 == 0:
            print(f"Episode {episode}, loss:{loss.item():.4f}, {'succeed' if success else 'fail'}, steps:{len(rewards)}, total reward:{sum(rewards):.4f}, {t2-t1} sec")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Episode 0, loss:-56.5354, fail, steps:26, total reward:-11.8000, 0.4371922016143799 sec
# Episode 1, loss:-7.0741, fail, steps:1, total reward:-10.0000, 0.005114078521728516 sec
# Episode 2, loss:-59.6471, fail, steps:26, total reward:-12.7000, 0.05188727378845215 sec
# Episode 3, loss:-47.3797, fail, steps:9, total reward:-10.2000, 0.018344640731811523 sec
# Episode 4, loss:-49.1862, fail, steps:34, total reward:-10.0000, 0.06811308860778809 sec
# Episode 5, loss:-8.9220, fail, steps:1, total reward:-10.0000, 0.003808259963989258 sec
# Episode 6, loss:-49.8247, fail, steps:17, total reward:-11.5000, 0.03262758255004883 sec
# Episode 7, loss:-8.7725, fail, steps:91, total reward:-1.8000, 0.20496225357055664 sec
# Episode 8, loss:-19.1759, fail, steps:90, total reward:-3.9000, 0.18864917755126953 sec
# Episode 9, loss:-13.5208, fail, steps:1, total reward:-10.0000, 0.007322072982788086 sec
# Episode 10, loss:-12.0954, fail, steps:90, total reward:-2.9000, 0.17507171630859375 sec
# Episode 11, loss:-11.3962, fail, steps:90, total reward:-2.9000, 0.18426990509033203 sec
# Episode 12, loss:-12.8847, fail, steps:90, total reward:-2.9000, 0.1859288215637207 sec
# Episode 13, loss:-12.4656, fail, steps:90, total reward:-2.9000, 0.18608784675598145 sec
# Episode 14, loss:-11.9312, fail, steps:90, total reward:-3.0000, 0.1887226104736328 sec
# Episode 15, loss:-19.6305, fail, steps:90, total reward:-3.9000, 0.18734049797058105 sec
# Episode 16, loss:-17.3990, fail, steps:1, total reward:-10.0000, 0.007852792739868164 sec
# Episode 17, loss:-18.3458, fail, steps:90, total reward:-3.9000, 0.18042492866516113 sec
# Episode 18, loss:-12.0610, fail, steps:90, total reward:-2.9000, 0.18332648277282715 sec
# Episode 19, loss:-14.5309, fail, steps:90, total reward:-2.9000, 0.18562602996826172 sec
# Episode 20, loss:-12.7710, fail, steps:90, total reward:-2.9000, 0.1864182949066162 sec
# Episode 21, loss:-7.2072, fail, steps:90, total reward:-2.2000, 0.18743062019348145 sec
# Episode 22, loss:-8.5054, fail, steps:90, total reward:-1.9000, 0.18757915496826172 sec
# Episode 23, loss:-17.2620, fail, steps:90, total reward:-3.9000, 0.18871474266052246 sec
# Episode 24, loss:-55.3790, fail, steps:23, total reward:-9.7000, 0.052031517028808594 sec
# Episode 25, loss:-1.1456, fail, steps:90, total reward:-1.9000, 0.1799466609954834 sec
# Episode 26, loss:-5.2657, fail, steps:90, total reward:-1.9000, 0.18530583381652832 sec
# Episode 27, loss:-11.4505, fail, steps:90, total reward:-2.9000, 0.18683385848999023 sec
# Episode 28, loss:-56.1127, fail, steps:38, total reward:-10.2000, 0.08151936531066895 sec
# Episode 29, loss:-2.8606, fail, steps:91, total reward:-1.0000, 0.1871013641357422 sec
# Episode 30, loss:-20.4483, fail, steps:1, total reward:-10.0000, 0.007704019546508789 sec
# Episode 31, loss:-8.0533, fail, steps:90, total reward:-1.9000, 0.17832279205322266 sec
# Episode 32, loss:-12.4783, fail, steps:90, total reward:-2.9000, 0.1869337558746338 sec
# Episode 33, loss:-7.8737, fail, steps:91, total reward:-2.4000, 0.19084739685058594 sec
# Episode 34, loss:-4.6961, fail, steps:90, total reward:-1.9000, 0.18706464767456055 sec
# Episode 35, loss:-10.3780, fail, steps:90, total reward:-2.9000, 0.18692278861999512 sec
# Episode 36, loss:-6.2077, fail, steps:90, total reward:-1.9000, 0.18854761123657227 sec
# Episode 37, loss:-53.7960, fail, steps:34, total reward:-10.0000, 0.07384443283081055 sec
# Episode 38, loss:-19.6470, fail, steps:90, total reward:-4.9000, 0.18082118034362793 sec
# Episode 39, loss:-7.3960, fail, steps:90, total reward:-1.9000, 0.18623685836791992 sec
# Episode 40, loss:-15.0188, fail, steps:90, total reward:-3.9000, 0.1872556209564209 sec
# Episode 41, loss:-11.5974, fail, steps:91, total reward:-2.9000, 0.18917536735534668 sec
# Episode 42, loss:-51.6911, fail, steps:32, total reward:-12.0000, 0.07016301155090332 sec
# Episode 43, loss:-1.0063, fail, steps:90, total reward:0.1000, 0.18364191055297852 sec
# Episode 44, loss:-2.0632, fail, steps:90, total reward:-0.9000, 0.18645071983337402 sec
# Episode 45, loss:-11.6572, fail, steps:90, total reward:-3.0000, 0.18738102912902832 sec
# Episode 46, loss:-15.7730, fail, steps:90, total reward:-3.9000, 0.18775534629821777 sec
# Episode 47, loss:-7.8230, fail, steps:90, total reward:-1.9000, 0.18783092498779297 sec
# Episode 48, loss:-60.1489, fail, steps:86, total reward:-13.8000, 0.1796872615814209 sec
# Episode 49, loss:-78.1994, fail, steps:47, total reward:-12.5000, 0.09986066818237305 sec
# Episode 50, loss:-49.2083, fail, steps:56, total reward:-9.7000, 0.11475896835327148 sec
# Episode 51, loss:-12.4221, fail, steps:91, total reward:-2.8000, 0.1841268539428711 sec
# Episode 52, loss:-10.5940, fail, steps:90, total reward:-2.9000, 0.1873023509979248 sec
# Episode 53, loss:-20.8918, fail, steps:1, total reward:-10.0000, 0.007828712463378906 sec
# Episode 54, loss:-21.1511, fail, steps:90, total reward:-4.9000, 0.17386841773986816 sec
# Episode 55, loss:-49.1190, fail, steps:23, total reward:-9.7000, 0.049889326095581055 sec
# Episode 56, loss:-22.2736, fail, steps:1, total reward:-10.0000, 0.003957509994506836 sec
# Episode 57, loss:-11.2767, fail, steps:90, total reward:-2.9000, 0.17421793937683105 sec
# Episode 58, loss:-3.0265, fail, steps:91, total reward:-0.9000, 0.18837308883666992 sec
# Episode 59, loss:-16.0383, fail, steps:90, total reward:-4.2000, 0.18654751777648926 sec
# Episode 60, loss:-8.7280, fail, steps:90, total reward:-1.9000, 0.1859445571899414 sec
# Episode 61, loss:-0.8405, fail, steps:91, total reward:-0.8000, 0.18872547149658203 sec
# Episode 62, loss:-51.3133, fail, steps:32, total reward:-10.0000, 0.07034468650817871 sec
# Episode 63, loss:-13.3404, fail, steps:90, total reward:-1.9000, 0.17990779876708984 sec
# Episode 64, loss:-8.7735, fail, steps:91, total reward:-0.8000, 0.18811798095703125 sec
# Episode 65, loss:-9.5371, fail, steps:90, total reward:-1.9000, 0.18693304061889648 sec
# Episode 66, loss:-3.4447, fail, steps:90, total reward:-0.9000, 0.18795371055603027 sec
# Episode 67, loss:-90.6109, fail, steps:18, total reward:-10.5000, 0.04222726821899414 sec
# Episode 68, loss:-61.9001, fail, steps:44, total reward:-9.3000, 0.08649873733520508 sec
# Episode 69, loss:9.8699, succeed, steps:58, total reward:3.2000, 0.11597537994384766 sec
# Episode 70, loss:15.0533, succeed, steps:73, total reward:5.8000, 0.14664268493652344 sec
# Episode 71, loss:-43.7915, fail, steps:73, total reward:-8.2000, 0.1521892547607422 sec
# Episode 72, loss:11.6401, succeed, steps:65, total reward:5.1000, 0.13535118103027344 sec
# Episode 73, loss:-39.5888, fail, steps:8, total reward:-9.2000, 0.020233869552612305 sec
# Episode 74, loss:-7.4109, fail, steps:91, total reward:0.2000, 0.1785902976989746 sec
# Episode 75, loss:4.8515, fail, steps:91, total reward:2.2000, 0.23830604553222656 sec
# Episode 76, loss:6.5512, fail, steps:91, total reward:3.2000, 0.18886661529541016 sec
# Episode 77, loss:-40.2077, fail, steps:32, total reward:-8.9000, 0.07071876525878906 sec
# Episode 78, loss:14.0710, fail, steps:91, total reward:4.2000, 0.18190717697143555 sec
# Episode 79, loss:7.4524, succeed, steps:88, total reward:2.2000, 0.18158435821533203 sec
# Episode 80, loss:-1.9917, fail, steps:92, total reward:1.2000, 0.1912684440612793 sec
# Episode 81, loss:-56.5082, fail, steps:56, total reward:-9.7000, 0.11866259574890137 sec
# Episode 82, loss:21.3764, succeed, steps:90, total reward:7.3000, 0.18298840522766113 sec
# Episode 83, loss:-42.3576, fail, steps:69, total reward:-7.1000, 0.14413762092590332 sec
# Episode 84, loss:-8.4052, fail, steps:92, total reward:-0.8000, 0.18943262100219727 sec
# Episode 85, loss:8.2714, succeed, steps:36, total reward:2.9000, 0.08104777336120605 sec
# Episode 86, loss:5.5930, fail, steps:91, total reward:2.2000, 0.18441414833068848 sec
# Episode 87, loss:-47.3517, fail, steps:21, total reward:-8.6000, 0.04784727096557617 sec
# Episode 88, loss:-43.2126, fail, steps:19, total reward:-7.5000, 0.03890681266784668 sec
# Episode 89, loss:-44.5121, fail, steps:24, total reward:-8.7000, 0.047142982482910156 sec
# Episode 90, loss:5.9000, fail, steps:91, total reward:1.9000, 0.17906737327575684 sec
# Episode 91, loss:-3.4359, fail, steps:91, total reward:1.2000, 0.18641042709350586 sec
# Episode 92, loss:1.8245, fail, steps:91, total reward:0.9000, 0.1888258457183838 sec
# Episode 93, loss:-48.0357, fail, steps:75, total reward:-5.1000, 0.15602684020996094 sec
# Episode 94, loss:-55.0067, fail, steps:60, total reward:-5.7000, 0.125762939453125 sec
# Episode 95, loss:-23.8561, fail, steps:1, total reward:-10.0000, 0.006243705749511719 sec
# Episode 96, loss:6.9020, succeed, steps:82, total reward:3.5000, 0.1584022045135498 sec
# Episode 97, loss:-2.7751, fail, steps:92, total reward:1.2000, 0.18661880493164062 sec
# Episode 98, loss:10.4001, fail, steps:92, total reward:3.2000, 0.1897110939025879 sec
# Episode 99, loss:-81.3177, fail, steps:43, total reward:-10.3000, 0.09238481521606445 sec
# Episode 100, loss:3.8695, fail, steps:91, total reward:3.2000, 0.18343639373779297 sec
# Episode 101, loss:-41.9504, fail, steps:48, total reward:-6.4000, 0.10259199142456055 sec
# Episode 102, loss:3.3006, fail, steps:91, total reward:2.2000, 0.18774700164794922 sec
# Episode 103, loss:0.0317, fail, steps:92, total reward:2.3000, 0.190887451171875 sec
# Episode 104, loss:10.0640, succeed, steps:72, total reward:4.7000, 0.15116429328918457 sec
# Episode 105, loss:0.7365, fail, steps:91, total reward:1.1000, 0.1885976791381836 sec
# Episode 106, loss:-2.5509, fail, steps:91, total reward:1.1000, 0.18918585777282715 sec
# Episode 107, loss:8.6684, succeed, steps:8, total reward:2.8000, 0.023218631744384766 sec
# Episode 108, loss:15.3895, succeed, steps:91, total reward:7.0000, 0.17937874794006348 sec
# Episode 109, loss:9.4894, fail, steps:91, total reward:4.2000, 0.1873173713684082 sec
# Episode 110, loss:13.5989, succeed, steps:75, total reward:4.7000, 0.15625357627868652 sec
# Episode 111, loss:-5.3998, succeed, steps:78, total reward:0.6000, 0.1620957851409912 sec
# Episode 112, loss:1.0461, fail, steps:91, total reward:1.1000, 0.18801283836364746 sec
# Episode 113, loss:-33.0901, fail, steps:5, total reward:-9.1000, 0.016468524932861328 sec
# Episode 114, loss:-13.5156, fail, steps:91, total reward:-1.8000, 0.1784043312072754 sec
# Episode 115, loss:-33.1645, fail, steps:5, total reward:-9.1000, 0.014812231063842773 sec
# Episode 116, loss:6.6706, fail, steps:92, total reward:3.2000, 0.18543052673339844 sec
# Episode 117, loss:-1.5995, fail, steps:90, total reward:0.1000, 0.18353581428527832 sec
# Episode 118, loss:-33.9283, fail, steps:5, total reward:-9.1000, 0.015795469284057617 sec
# Episode 119, loss:2.7220, succeed, steps:71, total reward:1.8000, 0.13867807388305664 sec
# Episode 120, loss:7.5656, fail, steps:91, total reward:3.2000, 0.1834096908569336 sec
# Episode 121, loss:14.8572, fail, steps:92, total reward:5.3000, 0.18967151641845703 sec
# Episode 122, loss:-2.6048, fail, steps:90, total reward:0.1000, 0.18727660179138184 sec
# Episode 123, loss:2.7832, fail, steps:91, total reward:2.2000, 0.19039678573608398 sec
# Episode 124, loss:2.8392, fail, steps:92, total reward:3.2000, 0.19164013862609863 sec
# Episode 125, loss:13.2410, succeed, steps:78, total reward:5.7000, 0.1643681526184082 sec
# Episode 126, loss:-0.7576, fail, steps:91, total reward:1.2000, 0.1888883113861084 sec
# Episode 127, loss:-35.9913, fail, steps:5, total reward:-9.1000, 0.016777992248535156 sec
# Episode 128, loss:10.6432, succeed, steps:58, total reward:3.2000, 0.11298251152038574 sec
# Episode 129, loss:11.7879, succeed, steps:59, total reward:4.2000, 0.1187746524810791 sec
# Episode 130, loss:1.9520, fail, steps:91, total reward:2.2000, 0.1876387596130371 sec
# Episode 131, loss:3.2571, fail, steps:91, total reward:2.2000, 0.18823790550231934 sec
# Episode 132, loss:2.7625, fail, steps:91, total reward:2.2000, 0.1893155574798584 sec
# Episode 133, loss:6.4817, fail, steps:91, total reward:3.2000, 0.19015741348266602 sec
# Episode 134, loss:17.8154, fail, steps:92, total reward:7.3000, 0.1916971206665039 sec
# Episode 135, loss:-42.6972, fail, steps:20, total reward:-6.5000, 0.04788327217102051 sec
# Episode 136, loss:-46.1429, fail, steps:14, total reward:-9.4000, 0.02943897247314453 sec
# Episode 137, loss:7.3662, fail, steps:92, total reward:4.3000, 0.18111157417297363 sec
# Episode 138, loss:17.4343, succeed, steps:67, total reward:6.0000, 0.13756322860717773 sec
# Episode 139, loss:-48.6246, fail, steps:28, total reward:-7.8000, 0.05900430679321289 sec
# Episode 140, loss:1.5702, fail, steps:91, total reward:2.2000, 0.1812734603881836 sec
# Episode 141, loss:2.4479, fail, steps:93, total reward:3.3000, 0.1920931339263916 sec
# Episode 142, loss:13.9599, succeed, steps:34, total reward:4.0000, 0.07413959503173828 sec
# Episode 143, loss:13.5321, fail, steps:92, total reward:6.3000, 0.1850893497467041 sec
# Episode 144, loss:6.8295, fail, steps:91, total reward:3.2000, 0.1911172866821289 sec
# Episode 145, loss:4.1435, fail, steps:91, total reward:2.2000, 0.18928909301757812 sec
# Episode 146, loss:4.3962, fail, steps:91, total reward:2.2000, 0.19051074981689453 sec
# Episode 147, loss:6.0552, fail, steps:92, total reward:3.2000, 0.19220280647277832 sec
# Episode 148, loss:12.2201, succeed, steps:69, total reward:4.7000, 0.14580845832824707 sec
# Episode 149, loss:1.5565, fail, steps:91, total reward:1.1000, 0.18820405006408691 sec
# Episode 150, loss:16.2222, succeed, steps:49, total reward:6.6000, 0.10478782653808594 sec
# Episode 151, loss:-44.2518, fail, steps:46, total reward:-5.3000, 0.0935828685760498 sec
# Episode 152, loss:14.8670, succeed, steps:64, total reward:6.1000, 0.12920856475830078 sec
# Episode 153, loss:3.8837, fail, steps:91, total reward:2.2000, 0.1840369701385498 sec
# Episode 154, loss:4.9372, fail, steps:91, total reward:3.2000, 0.18995380401611328 sec
# Episode 155, loss:8.4515, succeed, steps:27, total reward:3.2000, 0.059961557388305664 sec
# Episode 156, loss:10.3285, succeed, steps:81, total reward:4.5000, 0.16136765480041504 sec
# Episode 157, loss:5.6079, succeed, steps:35, total reward:1.9000, 0.0736081600189209 sec
# Episode 158, loss:9.1882, succeed, steps:68, total reward:3.9000, 0.13953852653503418 sec
# Episode 159, loss:-11.3270, fail, steps:91, total reward:-0.8000, 0.18698883056640625 sec
# Episode 160, loss:12.2050, fail, steps:92, total reward:6.3000, 0.1909196376800537 sec
# Episode 161, loss:15.2630, succeed, steps:39, total reward:5.9000, 0.08352208137512207 sec
# Episode 162, loss:-6.4440, fail, steps:91, total reward:-0.9000, 0.18393445014953613 sec
# Episode 163, loss:-57.0230, fail, steps:19, total reward:-7.5000, 0.04361391067504883 sec
# Episode 164, loss:-70.6408, fail, steps:12, total reward:-10.3000, 0.025104045867919922 sec
# Episode 165, loss:16.1895, succeed, steps:74, total reward:6.8000, 0.1449587345123291 sec
# Episode 166, loss:-26.7310, fail, steps:1, total reward:-10.0000, 0.005940437316894531 sec
# Episode 167, loss:4.2845, fail, steps:92, total reward:3.2000, 0.1787722110748291 sec
# Episode 168, loss:-49.4963, fail, steps:16, total reward:-7.4000, 0.03671121597290039 sec
# Episode 169, loss:-36.8892, fail, steps:5, total reward:-9.1000, 0.011312007904052734 sec
# Episode 170, loss:8.9536, fail, steps:91, total reward:3.2000, 0.17717313766479492 sec
# Episode 171, loss:-4.6049, fail, steps:91, total reward:0.2000, 0.18600082397460938 sec
# Episode 172, loss:14.8732, succeed, steps:58, total reward:6.2000, 0.12116837501525879 sec
# Episode 173, loss:14.3242, succeed, steps:68, total reward:7.0000, 0.1390058994293213 sec
# Episode 174, loss:8.8493, fail, steps:91, total reward:3.2000, 0.185499906539917 sec
# Episode 175, loss:3.6970, fail, steps:91, total reward:2.2000, 0.19083881378173828 sec
# Episode 176, loss:13.8853, succeed, steps:78, total reward:4.6000, 0.1643836498260498 sec
# Episode 177, loss:13.0089, succeed, steps:33, total reward:6.1000, 0.07121944427490234 sec
# Episode 178, loss:22.0746, succeed, steps:91, total reward:8.3000, 0.18183159828186035 sec
# Episode 179, loss:6.0417, succeed, steps:4, total reward:1.9000, 0.013691902160644531 sec
# Episode 180, loss:9.2466, fail, steps:92, total reward:5.3000, 0.17900609970092773 sec
# Episode 181, loss:-33.3551, fail, steps:50, total reward:-4.4000, 0.10322856903076172 sec
# Episode 182, loss:20.0186, fail, steps:92, total reward:7.3000, 0.18530750274658203 sec
# Episode 183, loss:16.0551, succeed, steps:32, total reward:5.1000, 0.06807637214660645 sec
# Episode 184, loss:2.7495, fail, steps:91, total reward:1.2000, 0.1820516586303711 sec
# Episode 185, loss:10.4691, succeed, steps:15, total reward:3.6000, 0.03491330146789551 sec
# Episode 186, loss:-29.0771, fail, steps:1, total reward:-10.0000, 0.0036268234252929688 sec
# Episode 187, loss:-5.5013, fail, steps:90, total reward:0.1000, 0.22359466552734375 sec
# Episode 188, loss:13.3439, succeed, steps:84, total reward:5.5000, 0.17084598541259766 sec
# Episode 189, loss:24.2125, succeed, steps:73, total reward:8.9000, 0.15061402320861816 sec
# Episode 190, loss:18.1315, succeed, steps:86, total reward:6.4000, 0.17567920684814453 sec
# Episode 191, loss:8.0054, succeed, steps:55, total reward:3.3000, 0.11604475975036621 sec
# Episode 192, loss:6.5158, succeed, steps:54, total reward:2.3000, 0.11428213119506836 sec
# Episode 193, loss:5.7710, succeed, steps:30, total reward:3.1000, 0.062325477600097656 sec
# Episode 194, loss:11.3322, succeed, steps:56, total reward:4.3000, 0.11161494255065918 sec
# Episode 195, loss:-47.7976, fail, steps:5, total reward:-9.1000, 0.013273477554321289 sec
# Episode 196, loss:12.6555, succeed, steps:33, total reward:6.1000, 0.06359076499938965 sec
# Episode 197, loss:12.2167, fail, steps:92, total reward:5.3000, 0.1831493377685547 sec
# Episode 198, loss:7.6890, succeed, steps:17, total reward:2.5000, 0.03877615928649902 sec
# Episode 199, loss:12.7714, succeed, steps:51, total reward:5.5000, 0.09974074363708496 sec
# Episode 200, loss:-10.4185, fail, steps:92, total reward:-0.8000, 0.18456625938415527 sec
# Episode 201, loss:-42.7772, fail, steps:13, total reward:-7.3000, 0.031293630599975586 sec
# Episode 202, loss:-0.4622, succeed, steps:31, total reward:0.8000, 0.060712337493896484 sec
# Episode 203, loss:13.4515, succeed, steps:71, total reward:6.9000, 0.14008879661560059 sec
# Episode 204, loss:-52.4437, fail, steps:19, total reward:-7.5000, 0.041326045989990234 sec
# Episode 205, loss:4.6722, fail, steps:91, total reward:2.2000, 0.1796112060546875 sec
# Episode 206, loss:10.5528, succeed, steps:47, total reward:4.6000, 0.09746003150939941 sec
# Episode 207, loss:18.4229, succeed, steps:61, total reward:6.2000, 0.12324976921081543 sec
# Episode 208, loss:-46.2865, fail, steps:21, total reward:-8.6000, 0.04508090019226074 sec
# Episode 209, loss:-43.5662, fail, steps:19, total reward:-7.5000, 0.038263797760009766 sec
# Episode 210, loss:24.3953, succeed, steps:90, total reward:11.5000, 0.1777188777923584 sec
# Episode 211, loss:6.6000, fail, steps:91, total reward:3.2000, 0.1863701343536377 sec
# Episode 212, loss:1.2165, fail, steps:91, total reward:2.2000, 0.19344806671142578 sec
# Episode 213, loss:7.1268, succeed, steps:86, total reward:4.4000, 0.17920684814453125 sec
# Episode 214, loss:16.3712, succeed, steps:80, total reward:6.6000, 0.16752982139587402 sec
# Episode 215, loss:1.0624, fail, steps:92, total reward:2.3000, 0.19032645225524902 sec
# Episode 216, loss:14.3187, succeed, steps:79, total reward:5.6000, 0.16609525680541992 sec
# Episode 217, loss:15.3638, succeed, steps:86, total reward:7.5000, 0.17810702323913574 sec
# Episode 218, loss:13.6716, succeed, steps:67, total reward:6.0000, 0.1408085823059082 sec
# Episode 219, loss:1.3873, fail, steps:91, total reward:0.8000, 0.1871175765991211 sec
# Episode 220, loss:2.0877, succeed, steps:71, total reward:0.7000, 0.14958882331848145 sec
# Episode 221, loss:9.0460, succeed, steps:34, total reward:4.0000, 0.07234811782836914 sec
# Episode 222, loss:17.9466, succeed, steps:62, total reward:7.2000, 0.12418484687805176 sec
# Episode 223, loss:14.6444, succeed, steps:88, total reward:6.2000, 0.1775493621826172 sec
# Episode 224, loss:18.8236, succeed, steps:63, total reward:8.2000, 0.13142132759094238 sec
# Episode 225, loss:6.0886, fail, steps:92, total reward:3.2000, 0.19136500358581543 sec
# Episode 226, loss:13.3091, succeed, steps:54, total reward:5.4000, 0.11538147926330566 sec
# Episode 227, loss:5.5882, succeed, steps:73, total reward:2.7000, 0.1498112678527832 sec
# Episode 228, loss:-50.7148, fail, steps:30, total reward:-8.9000, 0.06389188766479492 sec
# Episode 229, loss:-7.6144, fail, steps:90, total reward:-1.9000, 0.18027687072753906 sec
# Episode 230, loss:6.9472, succeed, steps:39, total reward:2.8000, 0.08181452751159668 sec
# Episode 231, loss:4.6374, succeed, steps:44, total reward:1.6000, 0.0884099006652832 sec
# Episode 232, loss:6.3305, succeed, steps:20, total reward:2.4000, 0.04193472862243652 sec
# Episode 233, loss:14.5353, succeed, steps:35, total reward:5.0000, 0.06875753402709961 sec
# Episode 234, loss:15.5618, succeed, steps:46, total reward:6.7000, 0.09064507484436035 sec
# Episode 235, loss:13.0206, succeed, steps:50, total reward:4.5000, 0.10048103332519531 sec
# Episode 236, loss:14.9912, fail, steps:92, total reward:5.2000, 0.18448281288146973 sec
# Episode 237, loss:4.4233, fail, steps:92, total reward:2.9000, 0.18978190422058105 sec
# Episode 238, loss:12.2231, succeed, steps:62, total reward:5.2000, 0.1299300193786621 sec
# Episode 239, loss:11.3790, succeed, steps:43, total reward:4.8000, 0.08956360816955566 sec
# Episode 240, loss:8.3738, succeed, steps:82, total reward:4.6000, 0.1648416519165039 sec
# Episode 241, loss:10.0604, succeed, steps:71, total reward:3.8000, 0.147416353225708 sec
# Episode 242, loss:16.8780, succeed, steps:55, total reward:6.4000, 0.11362314224243164 sec
# Episode 243, loss:18.5531, fail, steps:92, total reward:7.8000, 0.19059228897094727 sec
# Episode 244, loss:20.8741, succeed, steps:66, total reward:8.1000, 0.1378474235534668 sec
# Episode 245, loss:22.4470, succeed, steps:69, total reward:8.0000, 0.14298295974731445 sec
# Episode 246, loss:11.6783, succeed, steps:59, total reward:4.2000, 0.12144637107849121 sec
# Episode 247, loss:9.3589, succeed, steps:65, total reward:4.0000, 0.13303017616271973 sec
# Episode 248, loss:5.4087, succeed, steps:19, total reward:1.4000, 0.04206347465515137 sec
# Episode 249, loss:7.1328, succeed, steps:29, total reward:3.2000, 0.057459354400634766 sec
# Episode 250, loss:8.2725, succeed, steps:67, total reward:4.0000, 0.13239002227783203 sec
# Episode 251, loss:-50.9201, fail, steps:25, total reward:-7.7000, 0.05264115333557129 sec
# Episode 252, loss:11.2763, succeed, steps:72, total reward:4.8000, 0.1417226791381836 sec
# Episode 253, loss:10.5385, succeed, steps:78, total reward:4.6000, 0.15861821174621582 sec
# Episode 254, loss:5.9114, succeed, steps:54, total reward:2.3000, 0.11202335357666016 sec
# Episode 255, loss:3.8917, fail, steps:91, total reward:2.2000, 0.18448805809020996 sec
# Episode 256, loss:7.7110, fail, steps:91, total reward:4.2000, 0.18849802017211914 sec
# Episode 257, loss:16.1663, fail, steps:92, total reward:7.3000, 0.19222497940063477 sec
# Episode 258, loss:16.4593, succeed, steps:55, total reward:6.4000, 0.11661124229431152 sec
# Episode 259, loss:-40.6577, fail, steps:54, total reward:-5.5000, 0.1152029037475586 sec
# Episode 260, loss:8.0806, succeed, steps:25, total reward:4.3000, 0.05304908752441406 sec
# Episode 261, loss:7.6278, fail, steps:91, total reward:4.2000, 0.18167376518249512 sec
# Episode 262, loss:5.8814, fail, steps:91, total reward:3.2000, 0.1870427131652832 sec
# Episode 263, loss:-60.7808, fail, steps:35, total reward:-7.0000, 0.07597136497497559 sec
# Episode 264, loss:11.6892, fail, steps:92, total reward:4.8000, 0.18407011032104492 sec
# Episode 265, loss:10.7520, succeed, steps:50, total reward:4.5000, 0.10521936416625977 sec
# Episode 266, loss:16.6875, succeed, steps:41, total reward:5.9000, 0.0838623046875 sec
# Episode 267, loss:6.4010, succeed, steps:46, total reward:3.6000, 0.09240317344665527 sec
# Episode 268, loss:10.7690, succeed, steps:27, total reward:3.2000, 0.05553793907165527 sec
# Episode 269, loss:7.0193, fail, steps:91, total reward:3.2000, 0.18061375617980957 sec
# Episode 270, loss:4.5503, succeed, steps:20, total reward:2.2000, 0.04508614540100098 sec
# Episode 271, loss:-2.7350, fail, steps:90, total reward:0.1000, 0.17773890495300293 sec
# Episode 272, loss:18.5085, succeed, steps:56, total reward:7.4000, 0.11647510528564453 sec
# Episode 273, loss:7.3051, succeed, steps:67, total reward:2.6000, 0.13631439208984375 sec
# Episode 274, loss:10.4930, succeed, steps:28, total reward:4.2000, 0.05905318260192871 sec
# Episode 275, loss:10.8495, succeed, steps:67, total reward:2.9000, 0.13309788703918457 sec
# Episode 276, loss:19.2595, fail, steps:92, total reward:7.3000, 0.1902477741241455 sec
# Episode 277, loss:-1.0152, succeed, steps:61, total reward:-0.0000, 0.12882494926452637 sec
# Episode 278, loss:6.8598, succeed, steps:51, total reward:2.4000, 0.10515880584716797 sec
# Episode 279, loss:-1.6763, fail, steps:91, total reward:1.2000, 0.18364310264587402 sec
# Episode 280, loss:16.6226, succeed, steps:60, total reward:6.3000, 0.12438821792602539 sec
# Episode 281, loss:-49.7493, fail, steps:22, total reward:-7.6000, 0.047635555267333984 sec
# Episode 282, loss:-0.4283, fail, steps:91, total reward:1.2000, 0.18080615997314453 sec
# Episode 283, loss:8.4619, fail, steps:92, total reward:4.3000, 0.18828845024108887 sec
# Episode 284, loss:4.2992, succeed, steps:11, total reward:2.7000, 0.028060436248779297 sec
# Episode 285, loss:12.7682, succeed, steps:76, total reward:5.7000, 0.14895033836364746 sec
# Episode 286, loss:5.1742, fail, steps:91, total reward:2.2000, 0.18470191955566406 sec
# Episode 287, loss:5.8176, succeed, steps:42, total reward:2.7000, 0.08843111991882324 sec
# Episode 288, loss:10.4529, fail, steps:91, total reward:4.2000, 0.1829066276550293 sec
# Episode 289, loss:-39.9328, fail, steps:5, total reward:-9.1000, 0.015851259231567383 sec
# Episode 290, loss:16.2430, succeed, steps:57, total reward:6.4000, 0.11015558242797852 sec
# Episode 291, loss:6.4918, succeed, steps:47, total reward:2.6000, 0.09418296813964844 sec
# Episode 292, loss:18.6376, succeed, steps:41, total reward:7.9000, 0.08215761184692383 sec
# Episode 293, loss:-63.4138, fail, steps:90, total reward:-11.3000, 0.18245458602905273 sec
# Episode 294, loss:1.6525, fail, steps:91, total reward:1.1000, 0.18723797798156738 sec
# Episode 295, loss:6.9411, fail, steps:91, total reward:4.2000, 0.18842601776123047 sec
# Episode 296, loss:11.2683, fail, steps:92, total reward:5.2000, 0.19144964218139648 sec
# Episode 297, loss:-31.3808, fail, steps:1, total reward:-10.0000, 0.007960319519042969 sec
# Episode 298, loss:15.2830, succeed, steps:39, total reward:5.9000, 0.07545804977416992 sec
# Episode 299, loss:11.0617, succeed, steps:66, total reward:5.0000, 0.12932395935058594 sec
# Episode 300, loss:7.6494, succeed, steps:58, total reward:4.2000, 0.11710405349731445 sec
# Episode 301, loss:-11.7424, fail, steps:91, total reward:-0.9000, 0.18288326263427734 sec
# Episode 302, loss:-45.8949, fail, steps:28, total reward:-7.8000, 0.06110358238220215 sec
# Episode 303, loss:-0.5971, fail, steps:92, total reward:2.9000, 0.1825859546661377 sec
# Episode 304, loss:10.8853, succeed, steps:66, total reward:5.0000, 0.13740324974060059 sec
# Episode 305, loss:7.2080, succeed, steps:65, total reward:5.1000, 0.1328742504119873 sec
# Episode 306, loss:22.8656, succeed, steps:69, total reward:8.0000, 0.14113903045654297 sec
# Episode 307, loss:-42.6134, fail, steps:74, total reward:-2.1000, 0.1511538028717041 sec
# Episode 308, loss:8.0242, succeed, steps:80, total reward:3.5000, 0.16597509384155273 sec
# Episode 309, loss:13.2739, succeed, steps:76, total reward:5.6000, 0.16614103317260742 sec
# Episode 310, loss:10.5710, succeed, steps:60, total reward:6.3000, 0.12455916404724121 sec
# Episode 311, loss:1.2513, fail, steps:91, total reward:1.1000, 0.18507790565490723 sec
# Episode 312, loss:-2.3378, succeed, steps:71, total reward:1.8000, 0.14824438095092773 sec
# Episode 313, loss:4.8245, succeed, steps:14, total reward:2.6000, 0.03257560729980469 sec
# Episode 314, loss:19.2711, succeed, steps:83, total reward:6.5000, 0.16364502906799316 sec
# Episode 315, loss:-6.0795, fail, steps:91, total reward:0.2000, 0.1848909854888916 sec
# Episode 316, loss:1.4347, fail, steps:91, total reward:2.2000, 0.18722248077392578 sec
# Episode 317, loss:3.6114, succeed, steps:45, total reward:2.6000, 0.09693217277526855 sec
# Episode 318, loss:12.2206, succeed, steps:48, total reward:5.5000, 0.09734606742858887 sec
# Episode 319, loss:10.9823, succeed, steps:45, total reward:5.7000, 0.09045886993408203 sec
# Episode 320, loss:14.1261, fail, steps:93, total reward:5.3000, 0.1861250400543213 sec
# Episode 321, loss:4.6364, fail, steps:92, total reward:3.2000, 0.18971490859985352 sec
# Episode 322, loss:3.5353, fail, steps:91, total reward:2.2000, 0.19014763832092285 sec
# Episode 323, loss:5.1198, succeed, steps:39, total reward:2.8000, 0.0867915153503418 sec
# Episode 324, loss:8.0025, fail, steps:91, total reward:4.1000, 0.18779420852661133 sec
# Episode 325, loss:11.5654, fail, steps:92, total reward:5.2000, 0.18996977806091309 sec
# Episode 326, loss:-4.7078, fail, steps:91, total reward:0.2000, 0.189422607421875 sec
# Episode 327, loss:13.8268, succeed, steps:39, total reward:5.9000, 0.08387398719787598 sec
# Episode 328, loss:-7.4679, fail, steps:91, total reward:-0.8000, 0.18369269371032715 sec
# Episode 329, loss:13.3301, succeed, steps:75, total reward:5.8000, 0.15583014488220215 sec
# Episode 330, loss:10.6104, succeed, steps:57, total reward:5.3000, 0.11977171897888184 sec
# Episode 331, loss:6.4309, succeed, steps:76, total reward:3.7000, 0.15423989295959473 sec
# Episode 332, loss:8.9348, succeed, steps:68, total reward:3.9000, 0.14097046852111816 sec
# Episode 333, loss:6.5222, succeed, steps:86, total reward:3.3000, 0.17589545249938965 sec
# Episode 334, loss:-0.4756, succeed, steps:68, total reward:1.9000, 0.14223504066467285 sec
# Episode 335, loss:10.5308, fail, steps:91, total reward:4.2000, 0.18611884117126465 sec
# Episode 336, loss:18.8614, fail, steps:92, total reward:8.3000, 0.1961371898651123 sec
# Episode 337, loss:-0.8951, fail, steps:91, total reward:1.1000, 0.18950891494750977 sec
# Episode 338, loss:16.1960, succeed, steps:65, total reward:7.1000, 0.1371910572052002 sec
# Episode 339, loss:11.2867, succeed, steps:66, total reward:5.0000, 0.13595914840698242 sec
# Episode 340, loss:12.8848, succeed, steps:45, total reward:5.7000, 0.09372353553771973 sec
# Episode 341, loss:-3.4541, fail, steps:91, total reward:1.2000, 0.18348336219787598 sec
# Episode 342, loss:15.0340, succeed, steps:68, total reward:7.0000, 0.14183735847473145 sec
# Episode 343, loss:-31.5304, fail, steps:1, total reward:-10.0000, 0.006453752517700195 sec
# Episode 344, loss:7.8894, succeed, steps:71, total reward:3.8000, 0.13780760765075684 sec
# Episode 345, loss:8.7443, succeed, steps:23, total reward:2.3000, 0.04806828498840332 sec
# Episode 346, loss:-67.6742, fail, steps:8, total reward:-9.2000, 0.017129182815551758 sec
# Episode 347, loss:-7.8618, fail, steps:91, total reward:-0.9000, 0.17726469039916992 sec
# Episode 348, loss:-1.6969, fail, steps:91, total reward:2.2000, 0.18675518035888672 sec
# Episode 349, loss:13.8500, fail, steps:92, total reward:6.1000, 0.19025635719299316 sec
# Episode 350, loss:-50.9352, fail, steps:43, total reward:-7.4000, 0.09257292747497559 sec
# Episode 351, loss:6.0740, fail, steps:92, total reward:4.3000, 0.18464088439941406 sec
# Episode 352, loss:5.5339, succeed, steps:17, total reward:2.5000, 0.04060649871826172 sec
# Episode 353, loss:8.1516, fail, steps:93, total reward:7.3000, 0.23241901397705078 sec
# Episode 354, loss:13.9352, fail, steps:93, total reward:7.3000, 0.19103479385375977 sec
# Episode 355, loss:1.6065, fail, steps:91, total reward:2.2000, 0.1903390884399414 sec
# Episode 356, loss:-30.6488, fail, steps:52, total reward:-2.4000, 0.11036086082458496 sec
# Episode 357, loss:-59.0670, fail, steps:12, total reward:-8.3000, 0.027862548828125 sec
# Episode 358, loss:-6.9246, fail, steps:91, total reward:0.2000, 0.1800394058227539 sec
# Episode 359, loss:7.2253, fail, steps:91, total reward:4.2000, 0.18631529808044434 sec
# Episode 360, loss:11.5155, fail, steps:91, total reward:4.2000, 0.18839597702026367 sec
# Episode 361, loss:-41.8622, fail, steps:27, total reward:-5.7000, 0.05959773063659668 sec
# Episode 362, loss:1.2185, succeed, steps:72, total reward:1.3000, 0.14335346221923828 sec
# Episode 363, loss:13.3406, succeed, steps:86, total reward:6.2000, 0.1750345230102539 sec
# Episode 364, loss:-33.0309, fail, steps:1, total reward:-10.0000, 0.007012128829956055 sec
# Episode 365, loss:-0.0297, fail, steps:91, total reward:2.2000, 0.1777966022491455 sec
# Episode 366, loss:4.2761, fail, steps:92, total reward:4.3000, 0.18712449073791504 sec
# Episode 367, loss:20.0654, succeed, steps:48, total reward:8.7000, 0.10371851921081543 sec
# Episode 368, loss:8.2272, fail, steps:91, total reward:4.2000, 0.18517613410949707 sec
# Episode 369, loss:13.4357, succeed, steps:58, total reward:6.3000, 0.12243032455444336 sec
# Episode 370, loss:-5.6289, fail, steps:91, total reward:0.2000, 0.1845409870147705 sec
# Episode 371, loss:-55.3964, fail, steps:32, total reward:-8.9000, 0.0705251693725586 sec
# Episode 372, loss:6.4455, fail, steps:91, total reward:3.2000, 0.1826639175415039 sec
# Episode 373, loss:-78.1991, fail, steps:61, total reward:-11.1000, 0.12791967391967773 sec
# Episode 374, loss:14.2620, succeed, steps:82, total reward:6.6000, 0.16784262657165527 sec
# Episode 375, loss:-3.9329, fail, steps:91, total reward:0.9000, 0.18787813186645508 sec
# Episode 376, loss:-2.8870, fail, steps:91, total reward:2.2000, 0.18933367729187012 sec
# Episode 377, loss:-2.1560, fail, steps:90, total reward:0.1000, 0.18835687637329102 sec
# Episode 378, loss:10.8516, succeed, steps:45, total reward:5.7000, 0.09647130966186523 sec
# Episode 379, loss:13.1225, succeed, steps:59, total reward:7.3000, 0.12085628509521484 sec
# Episode 380, loss:11.2962, succeed, steps:79, total reward:5.6000, 0.16044163703918457 sec
# Episode 381, loss:13.9154, fail, steps:92, total reward:6.3000, 0.1935107707977295 sec
# Episode 382, loss:11.4208, succeed, steps:48, total reward:5.6000, 0.10189962387084961 sec
# Episode 383, loss:8.5760, fail, steps:91, total reward:4.2000, 0.1847236156463623 sec
# Episode 384, loss:12.2542, succeed, steps:51, total reward:5.5000, 0.1071920394897461 sec
# Episode 385, loss:8.5850, succeed, steps:62, total reward:4.1000, 0.12685132026672363 sec
# Episode 386, loss:-7.1352, fail, steps:91, total reward:0.2000, 0.1844651699066162 sec
# Episode 387, loss:16.5611, succeed, steps:50, total reward:7.6000, 0.10550642013549805 sec
# Episode 388, loss:3.5612, fail, steps:91, total reward:3.2000, 0.18459701538085938 sec
# Episode 389, loss:17.9414, succeed, steps:60, total reward:8.3000, 0.12595748901367188 sec
# Episode 390, loss:12.8805, succeed, steps:45, total reward:5.7000, 0.09302353858947754 sec
# Episode 391, loss:15.6716, succeed, steps:84, total reward:7.5000, 0.1698131561279297 sec
# Episode 392, loss:12.3734, succeed, steps:67, total reward:6.0000, 0.1385340690612793 sec
# Episode 393, loss:13.6851, succeed, steps:80, total reward:6.6000, 0.16503214836120605 sec
# Episode 394, loss:9.4045, succeed, steps:84, total reward:5.5000, 0.17301058769226074 sec
# Episode 395, loss:10.9979, fail, steps:92, total reward:5.2000, 0.19622015953063965 sec
# Episode 396, loss:25.1278, succeed, steps:80, total reward:9.7000, 0.16781949996948242 sec
# Episode 397, loss:11.0365, fail, steps:92, total reward:5.2000, 0.19117522239685059 sec
# Episode 398, loss:1.1011, fail, steps:91, total reward:1.5000, 0.19037485122680664 sec
# Episode 399, loss:19.0275, fail, steps:92, total reward:8.3000, 0.19221186637878418 sec
# Episode 400, loss:5.2408, fail, steps:91, total reward:3.2000, 0.19005274772644043 sec
# Episode 401, loss:9.6694, fail, steps:91, total reward:4.2000, 0.19084620475769043 sec
# Episode 402, loss:2.2795, fail, steps:92, total reward:3.2000, 0.19283556938171387 sec
# Episode 403, loss:15.0004, fail, steps:92, total reward:7.3000, 0.1924452781677246 sec
# Episode 404, loss:3.7249, fail, steps:92, total reward:3.2000, 0.19271183013916016 sec
# Episode 405, loss:10.2450, fail, steps:91, total reward:4.2000, 0.19107985496520996 sec
# Episode 406, loss:8.6924, succeed, steps:53, total reward:4.3000, 0.11462783813476562 sec
# Episode 407, loss:9.9156, succeed, steps:32, total reward:5.1000, 0.06908345222473145 sec
# Episode 408, loss:9.5584, succeed, steps:71, total reward:3.8000, 0.14243650436401367 sec
# Episode 409, loss:-52.9176, fail, steps:26, total reward:-9.8000, 0.05538463592529297 sec
# Episode 410, loss:7.0616, succeed, steps:46, total reward:3.6000, 0.09111738204956055 sec
# Episode 411, loss:9.7144, succeed, steps:45, total reward:5.7000, 0.08983922004699707 sec
# Episode 412, loss:6.4033, fail, steps:91, total reward:4.2000, 0.1819303035736084 sec
# Episode 413, loss:13.2754, succeed, steps:86, total reward:6.4000, 0.17753267288208008 sec
# Episode 414, loss:18.1623, succeed, steps:69, total reward:7.9000, 0.14373493194580078 sec
# Episode 415, loss:3.3400, fail, steps:92, total reward:3.2000, 0.18940091133117676 sec
# Episode 416, loss:10.4518, succeed, steps:25, total reward:4.3000, 0.05576801300048828 sec
# Episode 417, loss:7.9375, fail, steps:91, total reward:4.2000, 0.18195581436157227 sec
# Episode 418, loss:13.8028, succeed, steps:52, total reward:6.5000, 0.10814690589904785 sec
# Episode 419, loss:14.8619, succeed, steps:43, total reward:6.8000, 0.08788537979125977 sec
# Episode 420, loss:10.2289, succeed, steps:91, total reward:5.2000, 0.18284296989440918 sec
# Episode 421, loss:-0.2577, fail, steps:91, total reward:2.2000, 0.1878647804260254 sec
# Episode 422, loss:11.9065, succeed, steps:32, total reward:5.1000, 0.07048940658569336 sec
# Episode 423, loss:-4.1447, fail, steps:91, total reward:0.2000, 0.18778514862060547 sec
# Episode 424, loss:13.5009, fail, steps:92, total reward:5.2000, 0.19021105766296387 sec
# Episode 425, loss:13.2267, succeed, steps:83, total reward:6.5000, 0.17378759384155273 sec
# Episode 426, loss:19.9684, succeed, steps:67, total reward:9.1000, 0.14061760902404785 sec
# Episode 427, loss:0.7879, fail, steps:91, total reward:1.1000, 0.18600678443908691 sec
# Episode 428, loss:14.5074, succeed, steps:71, total reward:6.9000, 0.14899253845214844 sec
# Episode 429, loss:14.8052, succeed, steps:83, total reward:6.5000, 0.1713876724243164 sec
# Episode 430, loss:7.7638, succeed, steps:30, total reward:3.1000, 0.06619572639465332 sec
# Episode 431, loss:12.5177, succeed, steps:67, total reward:6.0000, 0.13400602340698242 sec
# Episode 432, loss:3.4750, fail, steps:91, total reward:2.2000, 0.1861433982849121 sec
# Episode 433, loss:6.9653, succeed, steps:90, total reward:4.2000, 0.18597650527954102 sec
# Episode 434, loss:9.6198, succeed, steps:42, total reward:5.8000, 0.09032988548278809 sec
# Episode 435, loss:11.5665, succeed, steps:36, total reward:6.0000, 0.07352900505065918 sec
# Episode 436, loss:10.6581, succeed, steps:70, total reward:5.9000, 0.13982200622558594 sec
# Episode 437, loss:17.7212, succeed, steps:89, total reward:6.3000, 0.18517494201660156 sec
# Episode 438, loss:1.3425, fail, steps:91, total reward:1.8000, 0.18916702270507812 sec
# Episode 439, loss:12.6494, succeed, steps:87, total reward:5.4000, 0.18126749992370605 sec
# Episode 440, loss:7.1416, succeed, steps:37, total reward:3.9000, 0.0801701545715332 sec
# Episode 441, loss:11.1616, succeed, steps:38, total reward:4.9000, 0.0769815444946289 sec
# Episode 442, loss:9.4857, succeed, steps:84, total reward:4.4000, 0.16822385787963867 sec
# Episode 443, loss:5.1597, fail, steps:91, total reward:3.2000, 0.18652081489562988 sec
# Episode 444, loss:10.7788, succeed, steps:35, total reward:5.0000, 0.0758218765258789 sec
# Episode 445, loss:16.4059, succeed, steps:70, total reward:5.9000, 0.14021754264831543 sec
# Episode 446, loss:16.0433, succeed, steps:81, total reward:7.6000, 0.16617465019226074 sec
# Episode 447, loss:14.5281, succeed, steps:47, total reward:7.7000, 0.09809350967407227 sec
# Episode 448, loss:22.6437, succeed, steps:86, total reward:9.5000, 0.17416763305664062 sec
# Episode 449, loss:20.2532, succeed, steps:65, total reward:10.2000, 0.1351172924041748 sec
# Episode 450, loss:11.9098, succeed, steps:59, total reward:4.2000, 0.12201285362243652 sec
# Episode 451, loss:8.2424, succeed, steps:78, total reward:4.6000, 0.1587533950805664 sec
# Episode 452, loss:3.3530, fail, steps:91, total reward:2.2000, 0.1906418800354004 sec
# Episode 453, loss:9.9159, succeed, steps:63, total reward:5.1000, 0.13187956809997559 sec
# Episode 454, loss:3.3698, fail, steps:91, total reward:2.7000, 0.18737244606018066 sec
# Episode 455, loss:8.7440, succeed, steps:43, total reward:3.7000, 0.09121036529541016 sec
# Episode 456, loss:11.7438, succeed, steps:70, total reward:5.9000, 0.14230084419250488 sec
# Episode 457, loss:11.1927, succeed, steps:29, total reward:5.2000, 0.06144905090332031 sec
# Episode 458, loss:9.8548, succeed, steps:63, total reward:5.1000, 0.12549948692321777 sec
# Episode 459, loss:11.5624, succeed, steps:73, total reward:5.8000, 0.14822006225585938 sec
# Episode 460, loss:11.6006, succeed, steps:80, total reward:6.6000, 0.16368842124938965 sec
# Episode 461, loss:0.1932, fail, steps:91, total reward:2.2000, 0.18783211708068848 sec
# Episode 462, loss:11.9426, succeed, steps:77, total reward:6.7000, 0.16076207160949707 sec
# Episode 463, loss:16.2397, succeed, steps:69, total reward:8.0000, 0.14427781105041504 sec
# Episode 464, loss:10.0741, succeed, steps:54, total reward:5.3000, 0.11172723770141602 sec
# Episode 465, loss:7.0152, fail, steps:92, total reward:5.2000, 0.18773293495178223 sec
# Episode 466, loss:14.5695, succeed, steps:62, total reward:7.2000, 0.13334870338439941 sec
# Episode 467, loss:14.2974, fail, steps:92, total reward:7.3000, 0.189042329788208 sec
# Episode 468, loss:13.9167, fail, steps:93, total reward:7.3000, 0.19345426559448242 sec
# Episode 469, loss:11.3093, succeed, steps:64, total reward:6.1000, 0.13612151145935059 sec
# Episode 470, loss:8.2356, succeed, steps:74, total reward:3.7000, 0.15274810791015625 sec
# Episode 471, loss:6.9624, fail, steps:91, total reward:4.2000, 0.18796420097351074 sec
# Episode 472, loss:6.1582, succeed, steps:78, total reward:4.6000, 0.1632084846496582 sec
# Episode 473, loss:6.1647, succeed, steps:78, total reward:4.6000, 0.1630570888519287 sec
# Episode 474, loss:5.5304, fail, steps:91, total reward:4.2000, 0.18833589553833008 sec
# Episode 475, loss:10.3812, succeed, steps:66, total reward:5.0000, 0.13921427726745605 sec
# Episode 476, loss:15.9953, succeed, steps:66, total reward:8.1000, 0.13631677627563477 sec
# Episode 477, loss:7.6229, fail, steps:92, total reward:5.2000, 0.19018101692199707 sec
# Episode 478, loss:4.7031, succeed, steps:30, total reward:3.1000, 0.06598424911499023 sec
# Episode 479, loss:16.1678, succeed, steps:57, total reward:8.4000, 0.11520242691040039 sec
# Episode 480, loss:4.3652, succeed, steps:59, total reward:4.1000, 0.12247109413146973 sec
# Episode 481, loss:11.0433, fail, steps:92, total reward:6.3000, 0.18646788597106934 sec
# Episode 482, loss:1.8524, succeed, steps:69, total reward:2.9000, 0.14466381072998047 sec
# Episode 483, loss:11.4179, succeed, steps:54, total reward:5.2000, 0.15833687782287598 sec
# Episode 484, loss:7.6474, succeed, steps:17, total reward:2.5000, 0.037261962890625 sec
# Episode 485, loss:7.1667, fail, steps:92, total reward:5.3000, 0.1819016933441162 sec
# Episode 486, loss:14.6615, succeed, steps:65, total reward:7.1000, 0.13453102111816406 sec
# Episode 487, loss:-39.0567, fail, steps:53, total reward:-4.5000, 0.10957932472229004 sec
# Episode 488, loss:10.6751, fail, steps:92, total reward:6.3000, 0.18642139434814453 sec
# Episode 489, loss:18.0378, succeed, steps:47, total reward:7.7000, 0.09978628158569336 sec
# Episode 490, loss:1.5426, succeed, steps:69, total reward:1.8000, 0.14006972312927246 sec
# Episode 491, loss:-4.1990, fail, steps:91, total reward:0.2000, 0.18598175048828125 sec
# Episode 492, loss:12.4000, succeed, steps:67, total reward:6.0000, 0.13951468467712402 sec
# Episode 493, loss:11.7690, succeed, steps:61, total reward:6.2000, 0.12686514854431152 sec
# Episode 494, loss:13.4508, succeed, steps:87, total reward:7.4000, 0.18016672134399414 sec
# Episode 495, loss:14.1351, succeed, steps:55, total reward:6.4000, 0.11668133735656738 sec
# Episode 496, loss:7.6819, fail, steps:92, total reward:5.2000, 0.1871323585510254 sec
# Episode 497, loss:6.0029, succeed, steps:52, total reward:4.5000, 0.1100606918334961 sec
# Episode 498, loss:12.2128, succeed, steps:65, total reward:7.1000, 0.13277268409729004 sec
# Episode 499, loss:10.4818, succeed, steps:79, total reward:5.6000, 0.1619710922241211 sec
# Episode 500, loss:8.3332, fail, steps:91, total reward:4.2000, 0.18726634979248047 sec
# Episode 501, loss:12.7788, succeed, steps:74, total reward:6.8000, 0.15521955490112305 sec
# Episode 502, loss:6.1011, succeed, steps:49, total reward:3.5000, 0.10215592384338379 sec
# Episode 503, loss:9.7275, succeed, steps:54, total reward:5.4000, 0.11060523986816406 sec
# Episode 504, loss:17.5325, fail, steps:92, total reward:7.3000, 0.1862030029296875 sec
# Episode 505, loss:18.2161, succeed, steps:71, total reward:10.0000, 0.14822697639465332 sec
# Episode 506, loss:15.1712, succeed, steps:68, total reward:7.0000, 0.14024925231933594 sec
# Episode 507, loss:11.7516, succeed, steps:49, total reward:6.6000, 0.10196423530578613 sec
# Episode 508, loss:3.6468, fail, steps:91, total reward:2.2000, 0.18407130241394043 sec
# Episode 509, loss:9.6624, succeed, steps:25, total reward:4.1000, 0.05745053291320801 sec
# Episode 510, loss:-1.8397, fail, steps:90, total reward:0.1000, 0.18112659454345703 sec
# Episode 511, loss:12.7495, succeed, steps:67, total reward:6.0000, 0.13926935195922852 sec
# Episode 512, loss:18.7232, fail, steps:92, total reward:8.3000, 0.18823766708374023 sec
# Episode 513, loss:-11.2754, fail, steps:91, total reward:-1.3000, 0.18979716300964355 sec
# Episode 514, loss:3.2942, fail, steps:91, total reward:3.2000, 0.1893291473388672 sec
# Episode 515, loss:8.6214, fail, steps:92, total reward:5.2000, 0.19281625747680664 sec
# Episode 516, loss:8.8024, succeed, steps:84, total reward:4.4000, 0.17525959014892578 sec
# Episode 517, loss:6.0789, succeed, steps:30, total reward:3.1000, 0.0666649341583252 sec
# Episode 518, loss:16.6619, succeed, steps:92, total reward:9.3000, 0.18425345420837402 sec
# Episode 519, loss:3.5959, fail, steps:91, total reward:3.2000, 0.18759846687316895 sec
# Episode 520, loss:4.3042, fail, steps:91, total reward:3.2000, 0.18910503387451172 sec
# Episode 521, loss:11.8607, fail, steps:92, total reward:6.3000, 0.19506072998046875 sec
# Episode 522, loss:17.3656, succeed, steps:64, total reward:9.2000, 0.1362016201019287 sec
# Episode 523, loss:3.7109, succeed, steps:39, total reward:2.8000, 0.0825190544128418 sec
# Episode 524, loss:1.8325, succeed, steps:88, total reward:2.2000, 0.17728161811828613 sec
# Episode 525, loss:13.1270, fail, steps:92, total reward:6.3000, 0.18971610069274902 sec
# Episode 526, loss:4.5191, fail, steps:91, total reward:3.2000, 0.1898808479309082 sec
# Episode 527, loss:5.1121, succeed, steps:76, total reward:2.6000, 0.1600782871246338 sec
# Episode 528, loss:-0.4165, fail, steps:91, total reward:1.1000, 0.18793129920959473 sec
# Episode 529, loss:13.7945, succeed, steps:77, total reward:6.7000, 0.16150665283203125 sec
# Episode 530, loss:13.4272, succeed, steps:58, total reward:6.3000, 0.12153983116149902 sec
# Episode 531, loss:8.2477, fail, steps:92, total reward:6.3000, 0.18893718719482422 sec
# Episode 532, loss:5.0057, succeed, steps:45, total reward:2.6000, 0.0957801342010498 sec
# Episode 533, loss:2.4487, fail, steps:91, total reward:2.2000, 0.18497061729431152 sec
# ...
# Episode 3920, loss:-0.0040, succeed, steps:39, total reward:5.9000, 0.07705235481262207 sec
# Episode 3921, loss:0.1402, succeed, steps:37, total reward:6.9000, 0.0735480785369873 sec
# Episode 3922, loss:0.1815, succeed, steps:56, total reward:4.3000, 0.11031150817871094 sec
# Episode 3923, loss:0.0033, succeed, steps:27, total reward:3.2000, 0.055277109146118164 sec
# Episode 3924, loss:0.0158, succeed, steps:39, total reward:9.0000, 0.07746076583862305 sec
# Episode 3925, loss:1.8630, succeed, steps:40, total reward:6.9000, 0.07889890670776367 sec
# Episode 3926, loss:0.2135, succeed, steps:58, total reward:12.5000, 0.11412453651428223 sec
# Episode 3927, loss:2.1089, succeed, steps:71, total reward:6.9000, 0.14256787300109863 sec
# Episode 3928, loss:0.0023, succeed, steps:39, total reward:5.9000, 0.08023571968078613 sec
# Episode 3929, loss:0.7824, succeed, steps:37, total reward:7.0000, 0.07429170608520508 sec
# Episode 3930, loss:2.7278, succeed, steps:34, total reward:7.1000, 0.0682976245880127 sec
# Episode 3931, loss:2.2665, succeed, steps:65, total reward:10.0000, 0.12818145751953125 sec
# Episode 3932, loss:1.7236, succeed, steps:32, total reward:8.2000, 0.06561684608459473 sec
# Episode 3933, loss:2.6725, succeed, steps:43, total reward:9.9000, 0.08564066886901855 sec
# Episode 3934, loss:0.3394, succeed, steps:34, total reward:7.1000, 0.06782007217407227 sec
# Episode 3935, loss:0.8427, succeed, steps:51, total reward:8.6000, 0.10135316848754883 sec
# Episode 3936, loss:0.0241, succeed, steps:68, total reward:10.1000, 0.13616371154785156 sec
# Episode 3937, loss:0.1866, succeed, steps:58, total reward:9.4000, 0.11836957931518555 sec
# Episode 3938, loss:-0.4128, fail, steps:92, total reward:6.3000, 0.18900227546691895 sec
# Episode 3939, loss:1.5894, succeed, steps:49, total reward:6.6000, 0.10245966911315918 sec
# Episode 3940, loss:0.2776, succeed, steps:36, total reward:6.0000, 0.07370996475219727 sec
# Episode 3941, loss:0.0005, succeed, steps:25, total reward:4.3000, 0.05123472213745117 sec
# Episode 3942, loss:0.5756, succeed, steps:48, total reward:5.6000, 0.09389925003051758 sec
# Episode 3943, loss:1.1257, succeed, steps:50, total reward:7.6000, 0.09915733337402344 sec
# Episode 3944, loss:0.1620, succeed, steps:59, total reward:10.4000, 0.11864113807678223 sec
# Episode 3945, loss:1.7131, succeed, steps:58, total reward:9.4000, 0.11703801155090332 sec
# Episode 3946, loss:0.0161, succeed, steps:53, total reward:7.5000, 0.10792708396911621 sec
# Episode 3947, loss:0.2633, succeed, steps:34, total reward:7.1000, 0.07008552551269531 sec
# Episode 3948, loss:0.0025, succeed, steps:21, total reward:3.4000, 0.0446019172668457 sec
# Episode 3949, loss:0.4214, succeed, steps:63, total reward:8.2000, 0.1242971420288086 sec
# Episode 3950, loss:0.0070, succeed, steps:38, total reward:8.0000, 0.07695937156677246 sec
# Episode 3951, loss:0.0058, succeed, steps:45, total reward:8.8000, 0.08925724029541016 sec
# Episode 3952, loss:1.1308, succeed, steps:85, total reward:11.2000, 0.1694941520690918 sec
# Episode 3953, loss:0.0010, succeed, steps:75, total reward:4.7000, 0.15420174598693848 sec
# Episode 3954, loss:-0.1368, fail, steps:91, total reward:3.2000, 0.18852996826171875 sec
# Episode 3955, loss:1.2644, succeed, steps:51, total reward:8.6000, 0.1066286563873291 sec
# Episode 3956, loss:-0.0333, succeed, steps:69, total reward:4.8000, 0.1432936191558838 sec
# Episode 3957, loss:1.6413, fail, steps:92, total reward:6.3000, 0.1902623176574707 sec
# Episode 3958, loss:1.1028, succeed, steps:61, total reward:9.3000, 0.12848997116088867 sec
# Episode 3959, loss:0.6044, succeed, steps:44, total reward:7.8000, 0.0925588607788086 sec
# Episode 3960, loss:-0.0014, succeed, steps:86, total reward:3.3000, 0.1742253303527832 sec
# Episode 3961, loss:0.9283, succeed, steps:61, total reward:9.3000, 0.12766265869140625 sec
# Episode 3962, loss:0.0008, succeed, steps:25, total reward:4.2000, 0.05293440818786621 sec
# Episode 3963, loss:2.0894, succeed, steps:62, total reward:7.2000, 0.12470173835754395 sec
# Episode 3964, loss:1.2470, succeed, steps:53, total reward:10.6000, 0.10680437088012695 sec
# Episode 3965, loss:0.9301, succeed, steps:62, total reward:10.3000, 0.12502789497375488 sec
# Episode 3966, loss:2.3128, succeed, steps:18, total reward:3.5000, 0.03919172286987305 sec
# Episode 3967, loss:0.0012, succeed, steps:26, total reward:5.3000, 0.05124044418334961 sec
# Episode 3968, loss:0.1524, succeed, steps:36, total reward:6.0000, 0.06979632377624512 sec
# Episode 3969, loss:-0.0012, succeed, steps:59, total reward:4.1000, 0.11627531051635742 sec
# Episode 3970, loss:0.4252, succeed, steps:47, total reward:7.7000, 0.09405279159545898 sec
# Episode 3971, loss:0.1876, succeed, steps:44, total reward:7.8000, 0.08786177635192871 sec
# Episode 3972, loss:0.0008, succeed, steps:24, total reward:6.4000, 0.04949164390563965 sec
# Episode 3973, loss:0.1313, succeed, steps:45, total reward:8.8000, 0.08791923522949219 sec
# Episode 3974, loss:0.0455, succeed, steps:32, total reward:5.1000, 0.06360459327697754 sec
# Episode 3975, loss:0.0018, succeed, steps:34, total reward:7.1000, 0.06719326972961426 sec
# Episode 3976, loss:0.0106, succeed, steps:44, total reward:7.8000, 0.08646416664123535 sec
# Episode 3977, loss:0.2397, succeed, steps:30, total reward:6.2000, 0.05994558334350586 sec
# Episode 3978, loss:0.4373, succeed, steps:52, total reward:9.6000, 0.1058812141418457 sec
# Episode 3979, loss:0.7662, succeed, steps:55, total reward:9.5000, 0.11057639122009277 sec
# Episode 3980, loss:0.0304, succeed, steps:39, total reward:9.0000, 0.07857561111450195 sec
# Episode 3981, loss:0.0121, succeed, steps:38, total reward:8.0000, 0.07639336585998535 sec
# Episode 3982, loss:0.3595, succeed, steps:70, total reward:2.8000, 0.13828468322753906 sec
# Episode 3983, loss:2.2767, succeed, steps:53, total reward:7.4000, 0.1080327033996582 sec
# Episode 3984, loss:0.4914, succeed, steps:45, total reward:5.7000, 0.09080815315246582 sec
# Episode 3985, loss:0.0573, succeed, steps:30, total reward:6.2000, 0.06062197685241699 sec
# Episode 3986, loss:1.2393, succeed, steps:60, total reward:8.2000, 0.11888670921325684 sec
# Episode 3987, loss:-0.1562, fail, steps:92, total reward:6.3000, 0.18494963645935059 sec
# Episode 3988, loss:0.0922, succeed, steps:33, total reward:6.1000, 0.07094526290893555 sec
# Episode 3989, loss:0.0402, succeed, steps:33, total reward:6.1000, 0.06625890731811523 sec
# Episode 3990, loss:0.0255, succeed, steps:33, total reward:6.1000, 0.0652000904083252 sec
# Episode 3991, loss:1.3600, succeed, steps:66, total reward:8.1000, 0.13039922714233398 sec
# Episode 3992, loss:0.4880, succeed, steps:83, total reward:12.7000, 0.16652131080627441 sec
# Episode 3993, loss:0.4872, succeed, steps:82, total reward:11.7000, 0.16910958290100098 sec
# Episode 3994, loss:0.4533, succeed, steps:45, total reward:8.8000, 0.093902587890625 sec
# Episode 3995, loss:0.3469, succeed, steps:47, total reward:7.7000, 0.09452247619628906 sec
# Episode 3996, loss:0.0013, succeed, steps:77, total reward:9.8000, 0.1539769172668457 sec
# Episode 3997, loss:0.0648, succeed, steps:49, total reward:6.6000, 0.1036989688873291 sec
# Episode 3998, loss:0.9345, succeed, steps:76, total reward:8.8000, 0.1540234088897705 sec
# Episode 3999, loss:0.2169, succeed, steps:45, total reward:8.8000, 0.09300112724304199 sec
# Checkpoint saved at episode 4000 to datasets/rl_sort_transformer_easy/list6_transformer3_128_gamma098_step120_v1/ckpt_4000_0.9310.pth
# Episode 4000, loss:-57.9996, fail, steps:19, total reward:-7.5000, 0.05695486068725586 sec
# Episode 4001, loss:0.1408, succeed, steps:26, total reward:5.3000, 0.05190443992614746 sec
# Episode 4002, loss:0.0015, succeed, steps:40, total reward:6.9000, 0.07844829559326172 sec
# Episode 4003, loss:0.1376, fail, steps:92, total reward:4.6000, 0.18282270431518555 sec
# Episode 4004, loss:2.8977, succeed, steps:43, total reward:6.8000, 0.08949398994445801 sec
# Episode 4005, loss:0.0428, succeed, steps:35, total reward:4.9000, 0.0705571174621582 sec
# Episode 4006, loss:1.2472, succeed, steps:61, total reward:9.3000, 0.12146306037902832 sec
# Episode 4007, loss:0.0081, succeed, steps:25, total reward:4.3000, 0.05201292037963867 sec
# Episode 4008, loss:5.3396, succeed, steps:92, total reward:9.3000, 0.1820659637451172 sec
# Episode 4009, loss:0.0004, succeed, steps:20, total reward:2.4000, 0.04455852508544922 sec
# Episode 4010, loss:0.5813, succeed, steps:60, total reward:8.2000, 0.11751890182495117 sec
# Episode 4011, loss:0.0063, succeed, steps:42, total reward:5.8000, 0.0852806568145752 sec
# Episode 4012, loss:0.0807, succeed, steps:65, total reward:7.1000, 0.12911152839660645 sec
# Episode 4013, loss:0.0430, succeed, steps:51, total reward:8.6000, 0.10393571853637695 sec
# Episode 4014, loss:0.2197, succeed, steps:45, total reward:8.8000, 0.09067606925964355 sec
# Episode 4015, loss:0.6017, succeed, steps:68, total reward:10.1000, 0.13594818115234375 sec
# Episode 4016, loss:0.0391, succeed, steps:42, total reward:5.8000, 0.0863192081451416 sec
# Episode 4017, loss:0.0009, succeed, steps:37, total reward:6.9000, 0.07431936264038086 sec
# Episode 4018, loss:0.0006, succeed, steps:38, total reward:8.0000, 0.07816743850708008 sec
# Episode 4019, loss:1.9226, succeed, steps:70, total reward:9.0000, 0.14007258415222168 sec
# Episode 4020, loss:0.3346, succeed, steps:33, total reward:6.1000, 0.06836056709289551 sec
# Episode 4021, loss:1.9506, succeed, steps:42, total reward:5.8000, 0.0835115909576416 sec
# Episode 4022, loss:0.0583, succeed, steps:47, total reward:7.5000, 0.09302330017089844 sec
# Episode 4023, loss:2.3345, succeed, steps:33, total reward:6.1000, 0.06711149215698242 sec
# Episode 4024, loss:0.6603, succeed, steps:47, total reward:7.7000, 0.09277772903442383 sec
# Episode 4025, loss:1.0810, succeed, steps:35, total reward:5.0000, 0.0694890022277832 sec
# Episode 4026, loss:6.4336, succeed, steps:59, total reward:10.4000, 0.11696767807006836 sec
# Episode 4027, loss:0.0072, succeed, steps:37, total reward:7.0000, 0.07503700256347656 sec
# Episode 4028, loss:0.0178, succeed, steps:29, total reward:5.2000, 0.05805087089538574 sec
# Episode 4029, loss:0.0135, succeed, steps:30, total reward:6.2000, 0.05909371376037598 sec
# Episode 4030, loss:2.1780, succeed, steps:76, total reward:8.8000, 0.14961981773376465 sec
# Episode 4031, loss:0.1297, succeed, steps:70, total reward:5.9000, 0.1421661376953125 sec
# Episode 4032, loss:0.4891, succeed, steps:41, total reward:7.9000, 0.08524298667907715 sec
# Episode 4033, loss:0.0754, succeed, steps:29, total reward:5.2000, 0.059305667877197266 sec
# Episode 4034, loss:0.4392, succeed, steps:47, total reward:7.7000, 0.0921170711517334 sec
# Episode 4035, loss:0.0061, succeed, steps:59, total reward:7.3000, 0.11759090423583984 sec
# Episode 4036, loss:0.1583, succeed, steps:29, total reward:5.2000, 0.059366464614868164 sec
# Episode 4037, loss:0.4060, succeed, steps:61, total reward:9.3000, 0.11983323097229004 sec
# Episode 4038, loss:0.3766, succeed, steps:45, total reward:8.8000, 0.09118866920471191 sec
# Episode 4039, loss:0.1938, succeed, steps:27, total reward:6.3000, 0.05521416664123535 sec
# Episode 4040, loss:0.7657, fail, steps:92, total reward:7.3000, 0.18338608741760254 sec
# Episode 4041, loss:-0.1741, fail, steps:92, total reward:5.1000, 0.18985772132873535 sec
# Episode 4042, loss:0.3681, succeed, steps:85, total reward:11.6000, 0.1768476963043213 sec
# Episode 4043, loss:0.0372, succeed, steps:33, total reward:6.1000, 0.07088184356689453 sec
# Episode 4044, loss:0.0943, succeed, steps:38, total reward:8.0000, 0.07725119590759277 sec
# Episode 4045, loss:0.5152, succeed, steps:50, total reward:7.6000, 0.09942913055419922 sec
# Episode 4046, loss:3.8997, succeed, steps:64, total reward:6.1000, 0.12707924842834473 sec
# Episode 4047, loss:0.0067, succeed, steps:15, total reward:3.6000, 0.033327579498291016 sec
# Episode 4048, loss:0.0004, succeed, steps:26, total reward:5.3000, 0.051354169845581055 sec
# Episode 4049, loss:0.0296, succeed, steps:38, total reward:8.0000, 0.07392644882202148 sec
# Episode 4050, loss:0.0490, succeed, steps:42, total reward:5.8000, 0.08231210708618164 sec
# Episode 4051, loss:0.1942, succeed, steps:28, total reward:4.2000, 0.05644965171813965 sec
# Episode 4052, loss:2.4492, succeed, steps:36, total reward:6.0000, 0.07084441184997559 sec
# Episode 4053, loss:0.2735, succeed, steps:32, total reward:5.1000, 0.06294584274291992 sec
# Episode 4054, loss:0.0017, succeed, steps:37, total reward:7.0000, 0.07337069511413574 sec
# Episode 4055, loss:0.2272, succeed, steps:36, total reward:6.0000, 0.07126545906066895 sec
# Episode 4056, loss:0.2110, succeed, steps:33, total reward:6.1000, 0.06498908996582031 sec
# Episode 4057, loss:0.0111, succeed, steps:33, total reward:6.1000, 0.06504559516906738 sec
# Episode 4058, loss:0.1893, succeed, steps:36, total reward:5.9000, 0.07168459892272949 sec
# Episode 4059, loss:0.0486, succeed, steps:68, total reward:6.8000, 0.13441252708435059 sec
# Episode 4060, loss:0.0050, succeed, steps:10, total reward:1.7000, 0.023770570755004883 sec
# Episode 4061, loss:0.4247, succeed, steps:75, total reward:10.9000, 0.14538192749023438 sec
# Episode 4062, loss:0.6708, succeed, steps:83, total reward:9.4000, 0.167893648147583 sec
# Episode 4063, loss:0.4358, succeed, steps:77, total reward:9.8000, 0.16233325004577637 sec
# Episode 4064, loss:0.1471, succeed, steps:38, total reward:8.0000, 0.07965373992919922 sec
# Episode 4065, loss:0.1632, succeed, steps:25, total reward:4.3000, 0.05166339874267578 sec
# Episode 4066, loss:1.0758, succeed, steps:71, total reward:10.0000, 0.13925528526306152 sec
# Episode 4067, loss:0.0378, succeed, steps:43, total reward:9.9000, 0.08779740333557129 sec
# Episode 4068, loss:0.1146, succeed, steps:14, total reward:2.6000, 0.030337095260620117 sec
# Episode 4069, loss:0.1397, succeed, steps:55, total reward:6.4000, 0.10678458213806152 sec
# Episode 4070, loss:0.0995, succeed, steps:66, total reward:8.1000, 0.1318035125732422 sec
# Episode 4071, loss:0.0020, succeed, steps:45, total reward:5.7000, 0.09146547317504883 sec
# Episode 4072, loss:0.2361, succeed, steps:38, total reward:8.0000, 0.07583189010620117 sec
# Episode 4073, loss:1.1593, succeed, steps:37, total reward:7.0000, 0.07399988174438477 sec
# Episode 4074, loss:1.1068, succeed, steps:51, total reward:8.6000, 0.1004948616027832 sec
# Episode 4075, loss:0.6431, succeed, steps:54, total reward:8.5000, 0.1079108715057373 sec
# Episode 4076, loss:0.2469, succeed, steps:41, total reward:7.8000, 0.08283615112304688 sec
# Episode 4077, loss:0.1033, succeed, steps:51, total reward:5.4000, 0.10078287124633789 sec
# Episode 4078, loss:0.6339, succeed, steps:70, total reward:9.0000, 0.13979840278625488 sec
# Episode 4079, loss:0.1667, succeed, steps:42, total reward:5.8000, 0.08603811264038086 sec
# Episode 4080, loss:0.3493, succeed, steps:37, total reward:7.0000, 0.07417154312133789 sec
# Episode 4081, loss:3.7139, succeed, steps:72, total reward:7.9000, 0.14357924461364746 sec
# Episode 4082, loss:0.3062, succeed, steps:46, total reward:6.7000, 0.09361004829406738 sec
# Episode 4083, loss:0.1453, succeed, steps:51, total reward:8.6000, 0.10184264183044434 sec
# Episode 4084, loss:0.2814, succeed, steps:41, total reward:7.9000, 0.08307528495788574 sec
# Episode 4085, loss:0.2504, succeed, steps:52, total reward:6.5000, 0.10729551315307617 sec
# Episode 4086, loss:0.0141, succeed, steps:42, total reward:8.9000, 0.08434128761291504 sec
# Episode 4087, loss:0.0009, succeed, steps:36, total reward:6.0000, 0.07260894775390625 sec
# Episode 4088, loss:0.3832, succeed, steps:33, total reward:6.0000, 0.0655982494354248 sec
# Episode 4089, loss:0.1065, succeed, steps:40, total reward:6.9000, 0.0783698558807373 sec
# Episode 4090, loss:0.0059, succeed, steps:32, total reward:5.1000, 0.06383776664733887 sec
# Episode 4091, loss:0.0006, succeed, steps:37, total reward:7.0000, 0.07275652885437012 sec
# Episode 4092, loss:0.0006, succeed, steps:36, total reward:6.0000, 0.07069802284240723 sec
# Episode 4093, loss:1.4958, succeed, steps:27, total reward:3.2000, 0.0538020133972168 sec

# %%
import gym
from gym import spaces
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque, namedtuple
from torch.optim.lr_scheduler import ExponentialLR


# Hyperparameters
MAX_VALUE = 32
MAX_LIST_LENGTH = 16
LIST_LENGTH = 7
MAX_STEPS = 80  #LIST_LENGTH * LIST_LENGTH * LIST_LENGTH / 4
HIDDEN_SIZE = 128
BATCH_SIZE = 64
GAMMA = 0.99
EPS_START = 0.2
EPS_END = 0.05
EPS_DECAY = 2000
TARGET_UPDATE = 10
LR = 1e-3
LR_DECAY = 0.9995
NUM_EPISODES = 40000
NUM_STEPS_IN_EPISODE = 10000

SUCCESS_REWARD = 10.0
SWAP_REWARD = 0.1
STEP_PENALTY = 0.01


# Define the custom environment
class SortingEnv(gym.Env):
    def __init__(self, list_length=LIST_LENGTH, max_list_length=MAX_LIST_LENGTH):
        super(SortingEnv, self).__init__()
        self.list_length = list_length
        self.max_list_length = max_list_length
        self.action_space = spaces.Discrete(4)  # 0: Move Left, 1: Move Right, 2: Compare, 3: Swap
        # Observation space: the list and cursor position
        # Values are normalized between 0 and 1
        self.observation_space = spaces.Box(
            low=0.0, high=1.0, shape=(self.max_list_length + 1,), dtype=np.float32
        )
        self.reset()

    def reset(self):
        self.list = np.random.randint(0, MAX_VALUE, size=self.list_length)
        self.cursor = 0
        self.done = False
        self.steps = 0
        return self._get_obs()

    def _get_obs(self):
        # Normalize list values and cursor position
        normalized_list = np.concatenate((self.list / MAX_VALUE, np.zeros(self.max_list_length - self.list_length)))
        normalized_cursor = np.array([self.cursor / (self.list_length - 1)])
        obs = np.concatenate((normalized_list, normalized_cursor))
        return obs.astype(np.float32)

    def step(self, action):
        reward = 0
        self.steps += 1
        # Action definitions
        if action == 0:  # Move cursor left
            if self.cursor > 0:
                self.cursor -= 1
            else:
                reward -= 1  # Penalty for invalid move
        elif action == 1:  # Move cursor right
            if self.cursor < self.list_length - 2:
                self.cursor += 1
            else:
                reward -= 1  # Penalty for invalid move
        elif action == 2:  # Compare (no effect in this setup)
            pass
        elif action == 3:  # Swap
            # Give a little reward if swapping in the right way, and vice versa
            if self.list[self.cursor] > self.list[self.cursor + 1]:
                reward += SWAP_REWARD
            if self.list[self.cursor] < self.list[self.cursor + 1]:
                reward -= SWAP_REWARD
            # Swap elements at cursor and cursor + 1
            self.list[self.cursor], self.list[self.cursor + 1] = (
                self.list[self.cursor + 1],
                self.list[self.cursor],
            )
        else:
            reward -= 1  # Penalty for invalid action

        # Check if the list is sorted
        if np.all(self.list[:-1] <= self.list[1:]):
            reward += SUCCESS_REWARD  # Reward for sorting the list
            self.done = True
        else:
            reward -= STEP_PENALTY  # Small penalty to encourage efficiency

        # Limit the number of steps to prevent infinite episodes
        max_steps = MAX_STEPS #self.list_length * self.list_length
        if self.steps >= max_steps: 
            #print("MAX_STEP =", self.list_length * self.list_length)
            self.done = True

        obs = self._get_obs()
        info = {}
        return obs, reward, self.done, info

# Define the DQN neural network
class DQN(nn.Module):
    def __init__(self, observation_space, action_space):
        super(DQN, self).__init__()
        print("observation_space size =", observation_space.shape[0])
        self.fc = nn.Sequential(
            nn.Linear(observation_space.shape[0], HIDDEN_SIZE),
            nn.ReLU(),
            nn.Linear(HIDDEN_SIZE, HIDDEN_SIZE),
            nn.ReLU(),
            nn.Linear(HIDDEN_SIZE, HIDDEN_SIZE),
            nn.ReLU(),
            nn.Linear(HIDDEN_SIZE, action_space.n),
        )

    def forward(self, x):
        return self.fc(x)

# Replay memory to store transitions
class ReplayMemory:
    def __init__(self, capacity=20000):
        self.memory = deque(maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        batch = random.sample(self.memory, batch_size)
        return Transition(*zip(*batch))

    def __len__(self):
        return len(self.memory)
    
# Replay memory to store transitions
class BipartiteReplayMemory:
    def __init__(self, capacity=20000):
        self.pos_memory = deque(maxlen=capacity//2)
        self.neg_memory = deque(maxlen=capacity//2)

    def push(self, *args):
        transition = Transition(*args)
        reward = transition.reward.cpu().numpy()[0]
        if reward > SWAP_REWARD * 2:
            self.pos_memory.append(transition)
        else:
            self.neg_memory.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self.pos_memory, min(batch_size // 2, len(self.pos_memory) // 4))
        batch.extend(random.sample(self.neg_memory, batch_size - len(batch)))
        return Transition(*zip(*batch))

    def __len__(self):
        return len(self.pos_memory) + len(self.neg_memory)
    
# Replay memory to store transitions
class PrioritizedReplayMemory:
    def __init__(self, capacity=1000000):
        self.capacity = capacity
        self.memory = deque(maxlen=capacity)
        self.priorities = deque(maxlen=capacity)

    def push(self, *args):
        transition = Transition(*args)
        self.memory.append(transition)
        self.priorities.append(transition.reward.cpu().numpy()[0])

    def sample(self, batch_size):
        #batch = random.sample(self.memory, batch_size)
        #return Transition(*zip(*batch))

        priorities = np.array(self.priorities)
        indices = np.arange(len(self.memory))

        # Separate indices into positive and zero priorities
        positive_indices = indices[priorities > 0]
        negative_indices = indices[priorities <= 0]

        # Determine the number of positive samples
        half_batch = batch_size // 2
        num_positive = len(positive_indices)

        if num_positive >= half_batch:
            # Sample half of batch_size from positive indices
            positive_sample_indices = np.random.choice(positive_indices, half_batch, replace=False)
        else:
            # Use all positive indices
            positive_sample_indices = positive_indices

        num_positive_samples = len(positive_sample_indices)

        # Sample the remaining from zero priorities
        num_negative_samples = batch_size - num_positive_samples

        if len(negative_indices) >= num_negative_samples:
            negative_sample_indices = np.random.choice(negative_indices, num_negative_samples, replace=False)
        else:
            # Not enough zero priority samples; sample with replacement
            negative_sample_indices = np.random.choice(negative_indices, num_negative_samples, replace=True)

        # Combine positive and zero priority indices
        total_sample_indices = np.concatenate((positive_sample_indices, negative_sample_indices))

        # Shuffle the indices to mix positive and zero priority samples
        np.random.shuffle(total_sample_indices)

        # Retrieve transitions
        transitions = [self.memory[idx] for idx in total_sample_indices]

        # Create batch
        batch = Transition(*zip(*transitions))
        return batch

    def __len__(self):
        return len(self.memory)

    def num_positives(self):
        return sum(1 for x in self.priorities if x > 0)
    

# Initialize environment, networks, optimizer, and memory
env = SortingEnv(list_length=LIST_LENGTH)
n_actions = env.action_space.n
state_size = env.observation_space.shape[0]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

policy_net = DQN(env.observation_space, env.action_space).to(device)
#policy_net.load_state_dict(torch.load('datasets/dqn_4action_numeric/len6_maxlen16_3layer_hd128_20kepoch_accr8960_policynet.pth'))
target_net = DQN(env.observation_space, env.action_space).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LR)
scheduler = ExponentialLR(optimizer, gamma=LR_DECAY)

memory = BipartiteReplayMemory()
steps_done = 0
steps_positive = 0

Transition = namedtuple("Transition", ("state", "action", "next_state", "reward"))


# Epsilon-greedy action selection
def select_action(state):
    global steps_done
    global steps_positive
    steps_done += 1
    eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * min(steps_done, 20 * steps_positive) / EPS_DECAY)
    if random.random() < eps_threshold:
        return random.randrange(n_actions)
    else:
        with torch.no_grad():
            state = state.unsqueeze(0).to(device)  # Add batch dimension
            return policy_net(state).argmax(dim=1).item()

# Optimize the model
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*transitions)
    # Create masks and tensors
    non_final_mask = torch.tensor(
        tuple(map(lambda s: s is not None, batch.next_state)), dtype=torch.bool
    )
    non_final_next_states = torch.stack([s for s in batch.next_state if s is not None])
    state_batch = torch.stack(batch.state).to(device)
    action_batch = torch.cat(batch.action).view(-1, 1).to(device)
    reward_batch = torch.cat(batch.reward).to(device)
    
    # Compute Q(s_t, a)
    state_action_values = policy_net(state_batch).gather(1, action_batch)
    
    # Compute V(s_{t+1})
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    
    # Compute expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch
    
    # Compute loss
    loss = nn.functional.smooth_l1_loss(state_action_values.squeeze(), expected_state_action_values)
    
    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


# Main training loop
for i_episode in range(NUM_EPISODES):
    global steps_positive
    state = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device)
    total_reward = 0
    for t in range(NUM_STEPS_IN_EPISODE):
        action = select_action(state)
        action_tensor = torch.tensor([action], dtype=torch.long, device=device)
        next_state, reward, done, _ = env.step(action)
        if reward > 0:
            steps_positive += 1
            #print("steps_positive:", steps_positive)
        total_reward += reward
        reward = torch.tensor([reward], dtype=torch.float32, device=device)
        if not done:
            next_state = torch.tensor(next_state, dtype=torch.float32, device=device)
        else:
            next_state = None
        memory.push(state, action_tensor, next_state, reward)
        state = next_state
        optimize_model()
        if done:
            print(f"Episode {i_episode}, Total Reward: {total_reward}") #, Memory #positives: {memory.num_positives()}")
            break
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
    scheduler.step()

# Save the trained model
torch.save(policy_net.state_dict(), "datasets/sorting_dqn_model.pth")
# Out:
# Using device: cuda
# observation_space size = 17
# observation_space size = 17
# Episode 0, Total Reward: -55.79999999999994
# Episode 1, Total Reward: -6.099999999999986
# Episode 2, Total Reward: -0.9000000000000007
# Episode 3, Total Reward: -0.8000000000000005
# Episode 4, Total Reward: -1.7000000000000006
# Episode 5, Total Reward: -0.8000000000000004
# Episode 6, Total Reward: -1.6000000000000003
# Episode 7, Total Reward: -2.499999999999986
# Episode 8, Total Reward: -1.9000000000000006
# Episode 9, Total Reward: -0.29999999999999993
# Episode 10, Total Reward: -1.6000000000000005
# Episode 11, Total Reward: -0.8000000000000005
# Episode 12, Total Reward: -0.7000000000000004
# Episode 13, Total Reward: -1.9000000000000006
# Episode 14, Total Reward: -4.699999999999999
# Episode 15, Total Reward: -2.8
# Episode 16, Total Reward: -0.5999999999999999
# Episode 39998, Total Reward: -0.7999999999999998
# Episode 39999, Total Reward: -2.699999999999996

# %%
import gym
import numpy as np
import torch

# Assuming the DQN, SortingEnv classes, and other necessary imports are already defined as before

# Initialize the environment
env = SortingEnv(list_length=LIST_LENGTH)
n_actions = env.action_space.n
state_size = env.observation_space.shape[0]

# Initialize the policy network and load the trained model
policy_net = DQN(env.observation_space, env.action_space)
policy_net.load_state_dict(torch.load("sorting_dqn_model.pth"))
policy_net.eval()  # Set the network to evaluation mode

def test_model(num_episodes=10):
    success_count = 0
    for i_episode in range(num_episodes):
        state = env.reset()
        state = torch.tensor(state, dtype=torch.float32)
        total_reward = 0
        done = False
        steps = 0
        print(f"\nEpisode {i_episode + 1}")
        print("Initial list:", env.list)
        while not done:
            # Select action using the trained policy (no exploration)
            with torch.no_grad():
                state_input = state.unsqueeze(0)  # Add batch dimension
                action = policy_net(state_input).argmax(dim=1).item()

            next_state, reward, done, _ = env.step(action)
            total_reward += reward
            steps += 1

#             print(f"Step {steps}:")
#             print(f"  Cursor position: {env.cursor}")
#             print(f"  Action taken: {action} ({['Move Left', 'Move Right', 'Compare', 'Swap'][action]})")
#             print(f"  Current list: {env.list}")
#             print(f"  Reward: {reward}")
#             print(f"  Done: {done}")

            state = torch.tensor(next_state, dtype=torch.float32)

        # Check if the list is sorted
        if np.all(env.list[:-1] <= env.list[1:]):
            print("Successfully sorted the list!")
            success_count += 1
        else:
            print("Failed to sort the list.")
        print(f"Total reward: {total_reward}")

    print(f"\nModel successfully sorted the list in {success_count} out of {num_episodes} episodes.")
    print(f"Accuracy = {success_count / num_episodes}")

# Run the test
test_model(num_episodes=2000)
# Out:
# observation_space size = 17
#
# Episode 1
# Initial list: [13  6 22  4 28  8  2]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 2
# Initial list: [ 0 25 12  0 11 28  9]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 3
# Initial list: [ 8 28 28 26 12 19  7]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 4
# Initial list: [11 10  3 20 16 22 11]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 5
# Initial list: [ 6 18 22  3  7 15  7]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 6
# Initial list: [ 8 14 31  2 16  0 11]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 7
# Initial list: [14 24 15 11  0 29 20]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 8
# Initial list: [12 27 29 28 18  3 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 9
# Initial list: [13  6 20  8 29 26 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 10
# Initial list: [11 29 18 15  5  4  1]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 11
# Initial list: [11  0 11 22  3 15 31]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 12
# Initial list: [28 24  6 18  5  3  4]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 13
# Initial list: [28 16  5  4  3 20 27]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 14
# Initial list: [22  4  1 26 19 13  9]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 15
# Initial list: [31  2  6  9 21 16  4]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 16
# Initial list: [ 3  8  5 20  7 20 14]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 17
# Initial list: [ 1 12  4 18 31  4 22]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 18
# Initial list: [20 22  9 10  8 10 12]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 19
# Initial list: [23 11 26  0 12  7 21]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 20
# Initial list: [ 1 29  7 21 10  9 29]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 21
# Initial list: [ 7 14  3 30  0 25  3]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 22
# Initial list: [ 1 31 24 24 15 24 24]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 23
# Initial list: [17 23  6 18 22  2 17]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 24
# Initial list: [26  6 12  4  3 23  4]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 25
# Initial list: [29 15 21 20 20 11  4]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 26
# Initial list: [20 10  0 28 13 17 22]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 27
# Initial list: [ 0  4  8 31 25 12  5]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 28
# Initial list: [ 8 24 16  8  3  0 17]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 29
# Initial list: [31 23 19  6 14 13 28]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 30
# Initial list: [26 10 10 14  6 23  5]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 31
# Initial list: [13 16  6 19  7  4  0]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 32
# Initial list: [19 23 30 26 13 18 18]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 33
# Initial list: [ 9  5 20  0 23  1 22]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 34
# Initial list: [ 6 26  4  1 26 23 12]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 35
# Initial list: [28 13 26 27  7 16 12]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 36
# Initial list: [13 13  2 12 27 26 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 37
# Initial list: [ 6 24  3 30 26  9 30]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 38
# Initial list: [16 24 12 28  4 30  2]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 39
# Initial list: [16 20 11 18 24 27 31]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 40
# Initial list: [19  7 24 14 24 21  1]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 41
# Initial list: [ 6 10 24 10  7 15  5]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 42
# Initial list: [ 0 21  0 16  7  0  5]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 43
# Initial list: [31 19  1 26 14  5 28]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 44
# Initial list: [26 10 24  1  4  3 25]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 45
# Initial list: [23 24 15 21  2  6  8]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 46
# Initial list: [14  1 17  9 27 10  2]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 47
# Initial list: [13 16 16 18  2  7 15]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 48
# Initial list: [ 9 26 21 13 18 15 10]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 49
# Initial list: [27  2 22 18  2 10  1]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 50
# Initial list: [27 10 27 31 27 21 21]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 51
# Initial list: [19 31  4 26 14 31  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 52
# Initial list: [18 30 27  6 17 25  8]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 53
# Initial list: [ 6 28 26  4  8 10 20]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 54
# Initial list: [ 0  9 31 28 29 28 16]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 55
# Initial list: [11 14 30 18  8 27 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 56
# Initial list: [27 30 27  5  7 20 31]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 57
# Initial list: [14 27 28 17 26 11 26]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 58
# Initial list: [27 19  0 31 26 27 31]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 59
# Initial list: [ 5 29 25 23 28 23 11]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 60
# Initial list: [15 17 17 13 19 14 29]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 61
# Initial list: [ 6  1  2 21 24 25  5]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 62
# Initial list: [20  2 25  2 12  8 11]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 63
# Initial list: [15  1 18 18 25  3  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 64
# Initial list: [19 14 28 18 17  5 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 65
# Initial list: [18 26  4 26 14 26  3]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 66
# Initial list: [12 20  9 17  6 11 14]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 67
# Initial list: [17 19 13 27  7 10  8]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 68
# Initial list: [ 0 24 14 12 10  6  7]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 69
# Initial list: [ 2  9 10 18 27 13 23]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 70
# Initial list: [10  3  2 29  9 14 25]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 71
# Initial list: [11 29 31  6 15 22  7]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 72
# Initial list: [ 0 30  3  4  5  2 26]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 73
# Initial list: [13  0  1 14  8 24 19]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 74
# Initial list: [10  3  8 22 10  4 23]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 75
# Initial list: [26 28 14  9 23 23  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 76
# Initial list: [14 19  5 27 14 29  7]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 77
# Initial list: [ 7 18 27  7 22 29 17]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 78
# Initial list: [21 22 20 18  1 17  7]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 79
# Initial list: [14 31 22 22 18 31 15]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 80
# Initial list: [22 22  7 10  4  4  6]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 81
# Initial list: [13 12 13  6  8 29 22]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 82
# Initial list: [ 7 25  5 30 24 24 13]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 83
# Initial list: [15 16  3  6  6  6 10]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 84
# Initial list: [31  0 12 23  1  9 25]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 85
# Initial list: [13  9 31 30  7 20  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 86
# Initial list: [15 19  7 15 16  5 15]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 87
# Initial list: [12 13 17 11  2 16 23]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 88
# Initial list: [ 5 11 31  0 11 12  0]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 89
# Initial list: [ 0 23 31 24  1  6 28]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 90
# Initial list: [23  6 26 27 15 16  1]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 91
# Initial list: [22  6  4  6  7 10 11]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 92
# Initial list: [ 1 13 31  9 27 25 25]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 93
# Initial list: [25  6 12  5 15 26 23]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 94
# Initial list: [26 31  8 19 24 26  7]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 95
# Initial list: [ 9  8  4 12 17 20 27]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 96
# Initial list: [ 2 18  3 21 13 27 16]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 97
# Initial list: [31 19  3 28  1  1 10]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 98
# Initial list: [30 12 13 24 25  0 27]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 99
# Initial list: [19 19 30 31 15  5 30]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 100
# Initial list: [22 27 27  9 23  5 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 101
# Initial list: [13 31 17  9  9 23 14]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 102
# Initial list: [28 19 28 21 22  2 11]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 103
# Initial list: [10  7 26 10 17 30  9]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 104
# Initial list: [24  1 31 24  3 26  6]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 105
# Initial list: [18 12  9  2 24 25  0]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 106
# Initial list: [ 3 17  2 21 14 15 17]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 107
# Initial list: [ 5 22  7 24  8 17 27]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 108
# Initial list: [ 9 26 17 21 28  0 29]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 109
# Initial list: [19 26 26 19  5 14 21]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 110
# Initial list: [18  6 23  9 15 24 17]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 111
# Initial list: [ 1 12  7  5  8 31 29]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 112
# Initial list: [ 2 26 31  6 29 11 23]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 113
# Initial list: [27 31  7 29  9  3 20]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 114
# Initial list: [28 19  0 24  9 14 11]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 115
# Initial list: [29  2  8  9 15 20 12]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 116
# Initial list: [14 29 14 27 13  8  3]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 117
# Initial list: [17  7  4  1 10  8 29]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 118
# Initial list: [ 0  1 27  2 25 30 19]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 119
# Initial list: [20 26 18 16 21 24  7]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 120
# Initial list: [27 21 10 24 21 10  1]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 121
# Initial list: [25 14 24  2  1 19 30]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 122
# Initial list: [24  7 13  5 23 29  5]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 123
# Initial list: [26 22  3 30 18 20  9]
# Failed to sort the list.
# Total reward: -0.5000000000000003
#
# Episode 124
# Initial list: [31  1 15 22  1 30  8]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 125
# Initial list: [27  3  4 21 25  3 24]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 126
# Initial list: [10 13  7 10  3  4 27]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 127
# Initial list: [29 30 19 17  6 16  4]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 128
# Initial list: [ 6  6 17 15 27  4 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 129
# Initial list: [21 24 10 17 17  5 23]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 130
# Initial list: [ 7 21 21 11  6 20 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 131
# Initial list: [13  6 24 25 24  5 18]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 132
# Initial list: [26 26 29 25 30 26 28]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 133
# Initial list: [31 15 24 25 23 31 21]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 134
# Initial list: [29  2 16 11  6 29 15]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 135
# Initial list: [ 1 12  8  8  5  7 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 136
# Initial list: [12 26 31 20 29  4  7]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 137
# Initial list: [12 15 17 27 13 13 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 138
# Initial list: [ 6  6 13 24 15  0 21]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 139
# Initial list: [16  1  4 23 11 19  2]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 140
# Initial list: [ 1 10 19 10 17 19 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 141
# Initial list: [20 15 23  0 19 14 28]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 142
# Initial list: [ 2 23 20 13  9 10 14]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 143
# Initial list: [28  4 31  2 23  3 26]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 144
# Initial list: [ 3  2  8 22  4 14 31]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 145
# Initial list: [ 6 23  2  1 28  8 28]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 146
# Initial list: [11  1 16 31  6 10  1]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 147
# Initial list: [19 27 12 12 29  6 26]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 148
# Initial list: [31 20 11  0 22 24  3]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 149
# Initial list: [17 21 25 31 29 17 31]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 150
# Initial list: [24  5 26 27 20 26 14]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 151
# Initial list: [22  5 19  6 18  5 26]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 152
# Initial list: [30 17  9 20  5 14  9]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 153
# Initial list: [ 1  9  0 22 21 14 24]
# Failed to sort the list.
# Total reward: -0.9000000000000007
#
# Episode 154
# Initial list: [ 6 31  7 15  6 10 24]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 155
# Initial list: [19  1 19 28  5 10  8]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 156
# Initial list: [15  4  4 11 20  7  9]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 157
# Initial list: [12 29 24 12 29  6 12]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 158
# Initial list: [15 28 27 19  1 14  1]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 159
# Initial list: [15  7 28 21  9 25 29]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 160
# Initial list: [13 16 24 22 26 25 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 161
# Initial list: [ 6 21 18 24 22 26 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 162
# Initial list: [ 4 11  4 31 14 23 16]
# Failed to sort the list.
# Total reward: -0.9000000000000007
#
# Episode 163
# Initial list: [26 26 28 11 31 22 18]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 164
# Initial list: [24 15  0 25 29  3 21]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 165
# Initial list: [20  4  0 17 17 30 18]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 166
# Initial list: [12 20 23  1 26 30  0]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 167
# Initial list: [28  7 15 23 24  2 24]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 168
# Initial list: [ 2 26 30 30  7  1  1]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 169
# Initial list: [25 31 24  6 12 25 24]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 170
# Initial list: [ 0 13  1  5 30 26  8]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 171
# Initial list: [ 7  4 11 22 17  2 18]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 172
# Initial list: [10  4  3 16  1 26 10]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 173
# Initial list: [20 10  9 17 10 22 27]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 174
# Initial list: [25 16 26  6 27 23 28]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 175
# Initial list: [ 3 21 28 12 27  9  6]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 176
# Initial list: [18  4 21 16  9  3  0]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 177
# Initial list: [15 10  9 23  7 27  0]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 178
# Initial list: [20 31  4 24 11  9 17]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 179
# Initial list: [25 29  9 11 22 27 26]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 180
# Initial list: [ 1 28 17  2 30  3 28]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 181
# Initial list: [10 24 16 12 19 13 16]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 182
# Initial list: [21 25 11 19 23 27  9]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 183
# Initial list: [28 26  1 13 22  4 13]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 184
# Initial list: [23 13 11 24  5 28 15]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 185
# Initial list: [ 7 19 14 28 18  3 27]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 186
# Initial list: [26  6 10 10 17  7 19]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 187
# Initial list: [ 0 22 26 24 27 29 25]
# Failed to sort the list.
# Total reward: -0.9000000000000007
#
# Episode 188
# Initial list: [29 13 21  0 28 17 31]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 189
# Initial list: [ 5 24 21  2 13 10  1]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 190
# Initial list: [ 9  9 22 10 10 29 18]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 191
# Initial list: [25 16 22 19 28 24 20]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 192
# Initial list: [ 0 26 25 17 17  3 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 193
# Initial list: [12 14 14 24 26 16  9]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 194
# Initial list: [27 27  6  7  0 27 28]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 195
# Initial list: [11 30  7 18 15 27 25]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 196
# Initial list: [14  3 22 10 28  8 27]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 197
# Initial list: [22 23 20 22 31 13 10]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 198
# Initial list: [27 25 19 10 24 25 28]
# Failed to sort the list.
# Total reward: -0.4999999999999993
#
# Episode 199
# Initial list: [31 13 17 27  8 15  5]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 200
# Initial list: [24 21 10 21  0 23 23]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 201
# Initial list: [26 19 30  5 24 10 30]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 202
# Initial list: [ 8 16  6 28  4  3 29]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 203
# Initial list: [22 22  9 21  6 29 29]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 204
# Initial list: [25  4  3 21 16 12 14]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 205
# Initial list: [13 15 27  3 30  4 15]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 206
# Initial list: [ 8  0 13 20 27 28 13]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 207
# Initial list: [24 23  9 14 21 19 17]
# Failed to sort the list.
# Total reward: -0.4999999999999993
#
# Episode 208
# Initial list: [20 27  6 24 15 18 27]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 209
# Initial list: [ 8 26 15 25 11 29  8]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 210
# Initial list: [ 5 23  1 28  9 14  0]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 211
# Initial list: [22  7 18  5 23 22 26]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 212
# Initial list: [21  6 11 29 17  8 30]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 213
# Initial list: [ 3 30  3 20  9 21 31]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 214
# Initial list: [ 2  6 11 26 22  3  2]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 215
# Initial list: [19 24  6 28 17  1 13]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 216
# Initial list: [27 30  1  6 16  5 10]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 217
# Initial list: [ 7  2  7  8 12 21 27]
# Successfully sorted the list!
# Total reward: 10.1
#
# Episode 218
# Initial list: [18 29  6  8  0 17 12]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 219
# Initial list: [16  6  1 24 23 25  5]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 220
# Initial list: [11 25 26 23 16  9  2]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 221
# Initial list: [13 12  5  7 10  7 29]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 222
# Initial list: [10  7 12 15  8 23  6]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 223
# Initial list: [13 26  0 28 16 24 16]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 224
# Initial list: [31 29 24  2  9  2 21]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 225
# Initial list: [12 29  8 15 19 20  3]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 226
# Initial list: [27  5 26 21 10 17  6]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 227
# Initial list: [14 15 15 23 10  2 30]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 228
# Initial list: [10 23  2  6 13 20 30]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 229
# Initial list: [ 9 19  4 13 22  0  2]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 230
# Initial list: [29  4 26 15 11  0  1]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 231
# Initial list: [24  1  6 15  5  0 28]
# Failed to sort the list.
# Total reward: -0.4999999999999994
#
# Episode 232
# Initial list: [ 4  9  7 17  4 22 18]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 233
# Initial list: [19 29 23 17 31 19 25]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 234
# Initial list: [ 3  9 15 13  8 10  4]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 235
# Initial list: [ 1 20 20  3  6 24 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 236
# Initial list: [14  7 12  1 12 13 31]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 237
# Initial list: [17 27 19 23 21 26 30]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 238
# Initial list: [ 0 12 19 30 13 26  0]
# Failed to sort the list.
# Total reward: -0.9000000000000007
#
# Episode 239
# Initial list: [ 0  4 10  5 21  8 21]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 240
# Initial list: [13 19 19 13 11 23 29]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 241
# Initial list: [24 13 20 12  2 19 23]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 242
# Initial list: [ 6 29  6 20  0  1 10]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 243
# Initial list: [29  4 30  3  1  9 23]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 244
# Initial list: [18 11 26 24 31 10 25]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 245
# Initial list: [24 17 18  3 16  4 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 246
# Initial list: [21 14 18  3  3 29  6]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 247
# Initial list: [21 13 17 11 20 25 23]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 248
# Initial list: [ 0  8 28  2 18  8 31]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 249
# Initial list: [10  1 17 26 12 30  5]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 250
# Initial list: [19 13  3  9 18  7 13]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 251
# Initial list: [21 21 12 10  1 15 13]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 252
# Initial list: [ 4  4  3 21 16  4 28]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 253
# Initial list: [17 23 10 17 21 21  8]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 254
# Initial list: [18 10 12 31 27  4 12]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 255
# Initial list: [19 20 14 30 11 11  3]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 256
# Initial list: [ 0 27 12 24 13 19 22]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 257
# Initial list: [29 11 12  9 13 17  4]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 258
# Initial list: [29 25  2  3 16  9 10]
# Failed to sort the list.
# Total reward: -0.4999999999999993
#
# Episode 259
# Initial list: [25  7 22 31  7 27  8]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 260
# Initial list: [ 0 18 13  0 16 19 10]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 261
# Initial list: [11 21 22  5  7 28 18]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 262
# Initial list: [24  3 29 17 17 21 11]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 263
# Initial list: [29 29  5 24 19 15  3]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 264
# Initial list: [17 26 10  7 28 10 17]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 265
# Initial list: [28 29 21 23  9 17 22]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 266
# Initial list: [12  6 16 25 25 18 26]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 267
# Initial list: [23  7 31  7  6 19 25]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 268
# Initial list: [14 15 20 28  5 23 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 269
# Initial list: [ 0 23 18 22 21 31 30]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 270
# Initial list: [ 2  7 26 25  3  9 14]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 271
# Initial list: [ 8 17  4 31 15  0 31]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 272
# Initial list: [10 17 10 17 14 16 25]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 273
# Initial list: [16 30 21 12 27  2 26]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 274
# Initial list: [12  8 15 10  9  4 14]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 275
# Initial list: [ 9 27 27 24 21 30 27]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 276
# Initial list: [24  7 10 16 17 29 26]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 277
# Initial list: [ 7  1 13 12 10  4 31]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 278
# Initial list: [12 16 26 30 14  8 16]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 279
# Initial list: [ 5  7  5  2 27 23  5]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 280
# Initial list: [ 9  6 11 18  9 29 10]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 281
# Initial list: [ 5 30  8 31 11 28 14]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 282
# Initial list: [24  0  1 27 20 31 28]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 283
# Initial list: [ 0  3  6 12 21 25  9]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 284
# Initial list: [ 9  2 11 28  0 20 29]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 285
# Initial list: [24 28  0  9 20  2 14]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 286
# Initial list: [13 21 18 15  7 30 23]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 287
# Initial list: [ 0 29  5 26 18 24 22]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 288
# Initial list: [18 13 19 12  9 17  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 289
# Initial list: [19 29  3 20 14  2 21]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 290
# Initial list: [28  9 18 20 21 24 20]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 291
# Initial list: [ 6  3 12 22 20 14 26]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 292
# Initial list: [ 9 17  9  4  8 30  1]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 293
# Initial list: [30 17 27  2 15  9 14]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 294
# Initial list: [24  6 15 23 29 15 28]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 295
# Initial list: [15  9 10 14 15  5 20]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 296
# Initial list: [ 4 18 20  4  4 11  3]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 297
# Initial list: [ 9  5 10 29 16  8 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 298
# Initial list: [31 18  1 21  4 13 24]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 299
# Initial list: [ 3 17  3 18 19 12 17]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 300
# Initial list: [13  8 23 15  3  8 17]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 301
# Initial list: [19  7 14  2 25 23  3]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 302
# Initial list: [28 22 28  0 15 21  3]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 303
# Initial list: [14  1 16 21 22 26 14]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 304
# Initial list: [28 13 12 29 17 30 12]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 305
# Initial list: [ 8 11  1  8 25  1 24]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 306
# Initial list: [ 4 16  2 23 16  8 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 307
# Initial list: [ 3  0 17 20 29  1 31]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 308
# Initial list: [ 4  4 27  1 17 14 18]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 309
# Initial list: [16 25 26 16 23 19 28]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 310
# Initial list: [25 22  6  3 17 20  2]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 311
# Initial list: [23 17 30 10 25 29  7]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 312
# Initial list: [11 13 22  4 13  6 10]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 313
# Initial list: [11 30 20 30  0  8  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 314
# Initial list: [ 8  7 12  4 18 15 25]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 315
# Initial list: [17  2  5 28 16  6 12]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 316
# Initial list: [ 5 29 14 19  1 16 16]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 317
# Initial list: [17  0 27 27 16 30 21]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 318
# Initial list: [24  7  3  0 18  0 16]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 319
# Initial list: [25 28 19 24  4  6 22]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 320
# Initial list: [11 10 25 19  8  6 24]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 321
# Initial list: [ 6 25 11  3 22  4 16]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 322
# Initial list: [ 5 13 10  3  5  7 28]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 323
# Initial list: [20 26  3  3  1  7  8]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 324
# Initial list: [ 0 27 17 26 13 14 14]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 325
# Initial list: [ 4  5  6 14  2 10 14]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 326
# Initial list: [27 15 22 10 18  5  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 327
# Initial list: [ 6 14 20 27 10 18 29]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 328
# Initial list: [22 13  0 21  5  2  9]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 329
# Initial list: [ 4 22  1 25  7  7 18]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 330
# Initial list: [ 5  9 21  5  5 15 15]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 331
# Initial list: [23  8 18 22 21 26 27]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 332
# Initial list: [13 23 13  0 12 19 12]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 333
# Initial list: [ 6 27  4 17 24  8 11]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 334
# Initial list: [ 0 16 14 26  0  7 15]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 335
# Initial list: [ 9 21  7 13 17 26 13]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 336
# Initial list: [25  0 14 30 19 17  5]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 337
# Initial list: [31 11  7 18 29  0 29]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 338
# Initial list: [31  3 29  4 11  0 13]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 339
# Initial list: [21  5  1 22 30 11 20]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 340
# Initial list: [14 24 12 15 15 13  2]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 341
# Initial list: [ 3 18 25 14  3  5  6]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 342
# Initial list: [ 5  8  2 20 12 21 19]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 343
# Initial list: [19 18  8 29 28  2 24]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 344
# Initial list: [14 25  3 15  2  1 13]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 345
# Initial list: [14 25 30 29 29  3  9]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 346
# Initial list: [21  0  7  6 17 21 17]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 347
# Initial list: [ 3  1  3 24  0 16 17]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 348
# Initial list: [30  4  9 25 11 28  5]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 349
# Initial list: [ 7 29  3 30 17  9  9]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 350
# Initial list: [31  2 18 23  4 25 29]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 351
# Initial list: [16  0  4 24 15 25 25]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 352
# Initial list: [ 9  7 23  4 15 30 22]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 353
# Initial list: [ 8 19  2 25 19 27 29]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 354
# Initial list: [26  3 23 28  9  6 24]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 355
# Initial list: [29  8 21  5 25 16 30]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 356
# Initial list: [30 14 23 26 31  8  6]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 357
# Initial list: [20  6 15  5 30 29  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 358
# Initial list: [18  2 22 16 23 28 18]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 359
# Initial list: [15 12 12 23 23 13  9]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 360
# Initial list: [ 4 14  7  9  9 19  5]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 361
# Initial list: [19 25 21  3  5  3  8]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 362
# Initial list: [17  4  8 18  8 18 29]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 363
# Initial list: [30 18  9 19 21 26  3]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 364
# Initial list: [ 4  6 16 13  1 21 23]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 365
# Initial list: [18  9 20 21 11 16 24]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 366
# Initial list: [27  5 14 27 17  9 19]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 367
# Initial list: [14 14  4 28 22 24  6]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 368
# Initial list: [30  0  1 25  9  6  7]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 369
# Initial list: [21 25 24 10 10 16 10]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 370
# Initial list: [22 26 24 11 29 11 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 371
# Initial list: [ 8  6  9 16 11 27 28]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 372
# Initial list: [30 29 23  8 17 11  3]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 373
# Initial list: [31 14 26  6  9  9 24]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 374
# Initial list: [31 31 29 15 14 12  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 375
# Initial list: [22 17 22 11  6 11 24]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 376
# Initial list: [17 14  0 31 19 11  2]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 377
# Initial list: [26 11 16 23  8 12 30]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 378
# Initial list: [11 18 31 19  3  9 18]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 379
# Initial list: [ 9  8 29 16  0 16  9]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 380
# Initial list: [15 31  0 16 23 28 14]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 381
# Initial list: [15  5 27 30  0  1  0]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 382
# Initial list: [30 30 16 21 25  0  1]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 383
# Initial list: [12 22  3 31  4 10 17]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 384
# Initial list: [26 22 22 24 16 20 22]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 385
# Initial list: [23  7  9  2 24 29 15]
# Failed to sort the list.
# Total reward: -0.30000000000000027
#
# Episode 386
# Initial list: [ 6  6 14  0 18 15 13]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 387
# Initial list: [23  6  0 16 17  5  1]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 388
# Initial list: [ 3 25 22 18 18  6  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 389
# Initial list: [23  3  0 16 18 18 29]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 390
# Initial list: [11 10 26 14 15 16 27]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 391
# Initial list: [11 26 18  8 16 27  0]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 392
# Initial list: [16 14 18 28 27 25 29]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 393
# Initial list: [19 15  8 26 27 30  2]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 394
# Initial list: [28  0 19  3 13 24 19]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 395
# Initial list: [22 22  5 28 22 31 26]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 396
# Initial list: [18  1 18  2  4  3  3]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 397
# Initial list: [16  8 12 16 17  9  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 398
# Initial list: [28  3  5  4 12 10 29]
# Failed to sort the list.
# Total reward: -0.49999999999999906
#
# Episode 399
# Initial list: [18 10 26  1 12 21 15]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 400
# Initial list: [ 9 11 25 16 12 20 25]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 401
# Initial list: [15 12 14  4  8  8 27]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 402
# Initial list: [ 0 19 15 22 30  5 25]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 403
# Initial list: [10 27 28 22 25 26 16]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 404
# Initial list: [ 3  7  0 24 31 27 25]
# Failed to sort the list.
# Total reward: -0.9000000000000007
#
# Episode 405
# Initial list: [ 2 19  7 13  0 14 26]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 406
# Initial list: [14  0  8  9 19 30 24]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 407
# Initial list: [20 27 11  5 23 26 30]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 408
# Initial list: [ 3 27 22 12 28  9  7]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 409
# Initial list: [15  6 14 15 19 30  9]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 410
# Initial list: [16  1 22 12 18 18  7]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 411
# Initial list: [20 31 13 15  7 20  7]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 412
# Initial list: [ 6 10  5 14  7  2 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 413
# Initial list: [20 22  1 15 25  9 26]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 414
# Initial list: [23 25 28  3 19 14 21]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 415
# Initial list: [26 19 13 29 31 16  3]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 416
# Initial list: [25  0  5  9  7 24 19]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 417
# Initial list: [ 8 23  0  4 17  2 30]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 418
# Initial list: [27 14  8  1  5 15 23]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 419
# Initial list: [17 24 24 30 24 22 14]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 420
# Initial list: [ 7 16  2 24 10 17 29]
# Failed to sort the list.
# Total reward: -0.9000000000000007
#
# Episode 421
# Initial list: [25 12  9  5 20 19 16]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 422
# Initial list: [30  6 28 27 30 26  9]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 423
# Initial list: [27 26 10 11 31 23  7]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 424
# Initial list: [ 4 29 24 28 28 31 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 425
# Initial list: [18 11 24  7 24 22 27]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 426
# Initial list: [ 3 26  6 11 19 17  3]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 427
# Initial list: [13 25 12 14 22  0  5]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 428
# Initial list: [13 27 17 28  7 28  0]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 429
# Initial list: [ 0  1 30  4 22  1  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 430
# Initial list: [21 30 17  5  0 21 12]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 431
# Initial list: [29  5 27 22 18  6 28]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 432
# Initial list: [ 0 29 28 16 27 21 11]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 433
# Initial list: [ 1  8 10 19  2 17  7]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 434
# Initial list: [27 31  2 29 28  4 18]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 435
# Initial list: [28 25 22 31 24  6  9]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 436
# Initial list: [14 12 15 13  6  2 21]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 437
# Initial list: [ 2  1 11  6  1 25 27]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 438
# Initial list: [10 20 13 28  3 20 19]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 439
# Initial list: [20 23 31 19  9 12  0]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 440
# Initial list: [ 1 11  7  8  5 20  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 441
# Initial list: [24  5 17 26  0 29 14]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 442
# ...
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1857
# Initial list: [20 23 15  2 30 15  0]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 1858
# Initial list: [19  4 15 23  9 16  6]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1859
# Initial list: [26 26 16 24  9  6  9]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1860
# Initial list: [24  2  4 27 14  4 30]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1861
# Initial list: [26 13 28  6 30 27 22]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1862
# Initial list: [25 20 25 28  3 20 30]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1863
# Initial list: [17 21 25 25 14 28 29]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1864
# Initial list: [ 2 13 12 10 21 21  1]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1865
# Initial list: [18 21 10  0 10  3 26]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1866
# Initial list: [24 16 12 23 28 24 11]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1867
# Initial list: [25 25  5 16  0 15  4]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1868
# Initial list: [ 8  9 28 18 18  6 12]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1869
# Initial list: [31 29 31  3 30 29  2]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1870
# Initial list: [11 15 22  4 31  8 30]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1871
# Initial list: [ 7 14 14  7 31 31 29]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1872
# Initial list: [ 1 20  6 17 31 28 15]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 1873
# Initial list: [23 11  4  7  1  1 17]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1874
# Initial list: [ 0  2  5 11 26 28 13]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1875
# Initial list: [10 14 20 31 27 22 11]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1876
# Initial list: [16  3 28 17  2 13 15]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1877
# Initial list: [18 26  7  3 29 19 21]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1878
# Initial list: [30 31 29 13 18  8 26]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1879
# Initial list: [28  5  5 24  0 21 14]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1880
# Initial list: [ 6  0 30  3  5 20  8]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1881
# Initial list: [24  7  5 17  4 31  0]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1882
# Initial list: [25 27  4 16  9 12 15]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1883
# Initial list: [13 15 30 19 28 23  0]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1884
# Initial list: [22 17  4 26 20  3  5]
# Failed to sort the list.
# Total reward: -0.5000000000000003
#
# Episode 1885
# Initial list: [ 7 20  9 31 21 21 12]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1886
# Initial list: [ 1 17  2  6 28 10  9]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1887
# Initial list: [ 0 20 17 18 12  0 12]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1888
# Initial list: [11  0 16 18  3  1 31]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 1889
# Initial list: [20 22 11 31  5 27 15]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1890
# Initial list: [ 1 27 15 31 26  1  7]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1891
# Initial list: [ 2  7  3 19 17 18 15]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 1892
# Initial list: [ 9  5 27 12  6 19  7]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1893
# Initial list: [ 9 30 13 13 23  9 12]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1894
# Initial list: [ 8  4  2 27 24 21 24]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1895
# Initial list: [21 18 16  5  2 19 11]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1896
# Initial list: [ 9 28 13 18 30 17 12]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1897
# Initial list: [ 0 18 26 23  0  4 20]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1898
# Initial list: [19 13 29  6  5 12 25]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1899
# Initial list: [26 16 18  3 17  0 30]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1900
# Initial list: [ 5  1 20 27 27 24  0]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1901
# Initial list: [ 6 24 26 23 26 20 14]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1902
# Initial list: [30  4 22 11 31 29 26]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 1903
# Initial list: [11 23  1 13 25 15 30]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 1904
# Initial list: [ 9 22 26  7 23 31 11]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1905
# Initial list: [16  3 23  0 25  7 14]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1906
# Initial list: [26 31  3  3 31  9 13]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1907
# Initial list: [ 0  5 20 18 23 10 20]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1908
# Initial list: [26 24  1 19 22 23 28]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1909
# Initial list: [ 2 18 19 31 23 27 12]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1910
# Initial list: [30 18  4 13 27 14  8]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 1911
# Initial list: [17 27 19 26 11 20  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1912
# Initial list: [10 31 19 18 23 29 28]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 1913
# Initial list: [29  4 26 28 20 30 17]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1914
# Initial list: [18 10 14  3 12 21 22]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1915
# Initial list: [26 17 21  0 25 14  2]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1916
# Initial list: [27 31 23 21 12 18  9]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1917
# Initial list: [27  3 15 10  6  6 22]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 1918
# Initial list: [21  0 31  8  8 23  7]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1919
# Initial list: [19  2 17 22 24  4  1]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1920
# Initial list: [31  0 31  1 29 14  0]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1921
# Initial list: [28  2  4 10 18 14 15]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1922
# Initial list: [ 3 18  7  6 10  7 27]
# Failed to sort the list.
# Total reward: -0.4999999999999993
#
# Episode 1923
# Initial list: [29 24 27 20  9 16 24]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1924
# Initial list: [20  3  9 10 14  1 22]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1925
# Initial list: [28 19 26 23  3 28 17]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1926
# Initial list: [ 1 13 19 25  3 25 25]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1927
# Initial list: [17  2 12 31  2 30 31]
# Failed to sort the list.
# Total reward: -0.4999999999999994
#
# Episode 1928
# Initial list: [12 30 30 12 23 29 13]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1929
# Initial list: [ 3  4 13 10 17  2 21]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1930
# Initial list: [22 15 20 16 23 12 24]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1931
# Initial list: [13  0 16 12 23 28 29]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1932
# Initial list: [24  4  0 28  0 16 18]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1933
# Initial list: [24 24 26  9  2  0 22]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1934
# Initial list: [28 17 21 20 19 17 29]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1935
# Initial list: [23  6 16 15 12 15 28]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 1936
# Initial list: [20 10  8 17  7  0  3]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1937
# Initial list: [ 1 31 20  2  2 23  9]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1938
# Initial list: [ 0 12  0 26 19  7  4]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1939
# Initial list: [13 20  1 25  0  1 27]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1940
# Initial list: [ 3 19  9  5 20  9 27]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1941
# Initial list: [ 2  7  1 29 13 30 21]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 1942
# Initial list: [ 7 10 17 22 12 27 30]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 1943
# Initial list: [ 8 10  0  6 16  6 11]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1944
# Initial list: [23  3 11 18 18 15  1]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1945
# Initial list: [24 30 11 26 12 10 12]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1946
# Initial list: [22  6 28 17 29 28  4]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1947
# Initial list: [31 30 28  9 31  5 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1948
# Initial list: [ 1  6  2 20  0 20 27]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 1949
# Initial list: [10 15 15  6  7 13 13]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1950
# Initial list: [21 11 10 25 22  3 28]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1951
# Initial list: [ 6 17 27  2  4  1 13]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1952
# Initial list: [23  3  5  5  9  2  6]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1953
# Initial list: [ 4 14 27  9 11 28 26]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1954
# Initial list: [30 22 27 22  2 27  5]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1955
# Initial list: [ 9 10  8 15 24 14 29]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1956
# Initial list: [27 23 31 13  5  7 24]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1957
# Initial list: [13 23  7  6 30  2 16]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 1958
# Initial list: [ 4  1 24  9 31  8 19]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1959
# Initial list: [12 14  0 22 30 14 23]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 1960
# Initial list: [20  2 11 17  7  6 26]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1961
# Initial list: [23  0  1  0 12 29  2]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 1962
# Initial list: [26 13 16 18 22 16 22]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1963
# Initial list: [24 17  1 18  0  4 24]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1964
# Initial list: [16 26 17  2  5 26 21]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1965
# Initial list: [20 23 18 31 29 20  5]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1966
# Initial list: [ 4 19  8 29  1 16 23]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1967
# Initial list: [12 28 22  8 31 11 11]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1968
# Initial list: [12  5  2  1  8 20  3]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1969
# Initial list: [13 27  9 21  8 27  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1970
# Initial list: [13  9 19 20 12 27 31]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1971
# Initial list: [ 1 15  1 28 12 28 16]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1972
# Initial list: [19 27 22 30  2  0 29]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1973
# Initial list: [28 30  8  5 27 10  5]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1974
# Initial list: [ 9 21  4 11 11 29 26]
# Failed to sort the list.
# Total reward: -0.5999999999999995
#
# Episode 1975
# Initial list: [21 15  6  9  6 12 25]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1976
# Initial list: [ 3 16  1 24 16 18 29]
# Failed to sort the list.
# Total reward: -0.7999999999999998
#
# Episode 1977
# Initial list: [ 3 23 22  0 12 18 25]
# Failed to sort the list.
# Total reward: -0.7999999999999996
#
# Episode 1978
# Initial list: [20 23 28 19 17 19 20]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 1979
# Initial list: [19 22  7 28 20 22  3]
# Failed to sort the list.
# Total reward: -0.6999999999999995
#
# Episode 1980
# Initial list: [31 16 16 17 30 19 27]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 1981
# Initial list: [12 17  4 11 29 13 14]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1982
# Initial list: [19  4 26 30 30  8 21]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1983
# Initial list: [20  3  1 24 16  0 20]
# Failed to sort the list.
# Total reward: -0.5000000000000003
#
# Episode 1984
# Initial list: [31 12 26  0  6  0 31]
# Failed to sort the list.
# Total reward: -0.6999999999999994
#
# Episode 1985
# Initial list: [14  8 29 21  9 21  5]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1986
# Initial list: [20 11 29 30  5 29  2]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1987
# Initial list: [ 6 20  3  6  1 22  2]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1988
# Initial list: [ 0  8 31  8 25  9  3]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1989
# Initial list: [ 6  5  8 22  6  2 29]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1990
# Initial list: [10 23  9 30 22 13 17]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1991
# Initial list: [17 15 12 30 18  5  5]
# Failed to sort the list.
# Total reward: -0.6000000000000003
#
# Episode 1992
# Initial list: [25 29 14 10 29 11  6]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Episode 1993
# Initial list: [17 11 11  5  7 22 31]
# Failed to sort the list.
# Total reward: -0.5999999999999993
#
# Episode 1994
# Initial list: [26 21  2  2 15 20 25]
# Failed to sort the list.
# Total reward: -0.3999999999999991
#
# Episode 1995
# Initial list: [ 5 17 31 29 13 14 23]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1996
# Initial list: [22 29 24 19 17 27 19]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1997
# Initial list: [ 0 10 10 30 11 16 11]
# Failed to sort the list.
# Total reward: -0.8000000000000005
#
# Episode 1998
# Initial list: [23  6 31 10 18 28 17]
# Failed to sort the list.
# Total reward: -0.6999999999999997
#
# Episode 1999
# Initial list: [12 12 30  8 13 30  2]
# Failed to sort the list.
# Total reward: -0.8999999999999998
#
# Episode 2000
# Initial list: [16 22  4 12  4 27  3]
# Failed to sort the list.
# Total reward: -0.7000000000000004
#
# Model successfully sorted the list in 3 out of 2000 episodes.
# Accuracy = 0.0015

# %%
memory.memory[0].reward
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 memory.memory[0].reward
#
# AttributeError: 'BipartiteReplayMemory' object has no attribute 'memory'

# %%
#torch.save(policy_net.state_dict(), 'datasets/dqn_4action_numeric/len6_maxlen16_3layer_hd128_20kepoch_accr8960_policynet.pth')

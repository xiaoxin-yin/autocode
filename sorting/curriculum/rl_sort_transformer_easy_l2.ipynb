# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
import math
import random

NUM_POSITIONS = 16

MIN_LIST_LEN = 2
MAX_LIST_LEN = 2
MAX_STEPS = 10

SUCCESS_REWARD = 0.5
STEP_REWARD = -0.3
COMPARISON_ENTROPY_MULTIPLIER = -0.00
SWAP_REWARD = 1.0
INVALID_ACTION_REWARD = -10.0
LONGTERM_GAMMA = 0.99
SHORTTERM_GAMMA = 0.7

EPS_START = 0.5
EPS_END = 0.05
EPS_DECAY = 1000
LR_SCHEDULER_GAMMA = 0.93
NUM_EPISODES = 100000
EPISODES_SAVE = 1000
OUTPUT_DIR = '/home/mcwave/code/autocode/datasets/rl_sort_transformer_curriculum/list2_transformer4_192_gamma07_step10_v1'

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    'less': 2,
    'equal': 3,
    'more': 4,
    '0': 5,
    '1': 6,
    '2': 7,
    '3': 8,
    '4': 9,
    '5': 10,
    '6': 11,
    '7': 12,
    '8': 13,
    '9': 14,
    '10': 15,
    '11': 16,
    '12': 17,
    '13': 18,
    '14': 19,
    '15': 20,
    'len1': 21,
    'len2': 22,
    'len3': 23,
    'len4': 24,
    'len5': 25,
    'len6': 26,
    'len7': 27,
    'len8': 28,
    'len9': 29,
    'len10': 30,
    'len11': 31,
    'len12': 32,
    'len13': 33,
    'len14': 34,
    'len15': 35,
    'len16': 36,
    'start0': 37,
    'start1': 38,
    'start2': 39,
    'start3': 40,
    'start4': 41,
    'start5': 42,
    'start6': 43,
    'start7': 44,
    'start8': 45,
    'start9': 46,
    'start10': 47,
    'start11': 48,
    'start12': 49,
    'start13': 50,
    'start14': 51,
    'start15': 52,
}
inv_vocab = {v: k for k, v in vocab.items()}

def compute_entropy(N, alpha=1):
    K = 2**N
    values = np.arange(K)
    unnormalized_probs = np.exp(-alpha * values)
    Z = unnormalized_probs.sum()
    probs = unnormalized_probs / Z
    return values, -np.log2(probs)

_, int_entropy = compute_entropy(4)

def get_entropy_of_integer(x):
    x = min(15, abs(x))
    return int_entropy[x]

def compute_min_delta_entropy(comparisons):
    # Initialize the result list to store minDelta values
    min_delta = None

    # Iterate through each pair in the comparisons list
    i = len(comparisons) - 1
    xi, yi = comparisons[i]
    if i == 0:
        # For i = 0, use the first case directly
        min_delta = (xi, min(yi, yi - xi), 0)
    else:
        # For i > 0, compute all possible options and select the minimal one
        options = []

        # Simple Entropy
        simple_entropy = (xi, min(yi, yi - xi), 0)
        options.append(simple_entropy)

        # First Delta Entropy
        xi_prev, yi_prev = comparisons[i - 1]
        first_delta_entropy = (xi - xi_prev, yi - yi_prev, 0)
        options.append(first_delta_entropy)

        # Second Delta Entropy (only valid for i > 1)
        if i > 1:
            xi_prev2, yi_prev2 = comparisons[i - 2]
            second_delta_entropy = (
                (xi - xi_prev) - (xi_prev - xi_prev2),
                (yi - yi_prev) - (yi_prev - yi_prev2),
                0,
            )
            options.append(second_delta_entropy)

        # Arbitrary Position Entropy (only valid for i > 1)
        for j in range(i):
            xj, yj = comparisons[j]
            arbitrary_position_entropy = (
                xi - xj,
                yi - yj,
                min(j, i - j),
            )
            options.append(arbitrary_position_entropy)

        # Find the option with the minimal sum
        min_delta = min(options, key=lambda t: sum([get_entropy_of_integer(x) for x in t]))

    entropy = sum([get_entropy_of_integer(x) for x in min_delta])
    if len(comparisons) == 1:
        return 3 * entropy
    else:
        return entropy

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.start_pos = random.randint(0, NUM_POSITIONS // self.length - 1) * self.length
        self.list = [-1] * self.start_pos + [random.randint(1, 100) for _ in range(self.length)]
        while self.list == sorted(self.list):
            self.list = [-1] * self.start_pos + [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        length_token = 'len{}'.format(self.length)
        start_pos_token = 'start{}'.format(self.start_pos)
        return vocab[length_token], vocab[start_pos_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_length(self):
        return self.length
    
    def get_start_pos(self):
        return self.start_pos

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                print("Error! Comparison without 2 indices!")
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 < self.start_pos or index1 >= self.start_pos + self.length \
                or index2 < self.start_pos or index2 >= self.start_pos + self.length:
                print(f"Error! Comparison with invalid indices {index1} {index2}")
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = STEP_REWARD
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = STEP_REWARD * 2
            else:
                response_token = vocab['more']
                reward = STEP_REWARD
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = SUCCESS_REWARD
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = SWAP_REWARD
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -SWAP_REWARD
            else:
                reward = STEP_REWARD
            self.indices = None
        else:
            reward = INVALID_ACTION_REWARD
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()
# Out:
# Using device: cuda

# %%
# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=512):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=192, nhead=8, num_layers=4):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])


def save_checkpoint(model, optimizer, episode, folder, filename):
    """
    Save the model and optimizer state to the designated filepath.

    Args:
        model (nn.Module): The model to save.
        optimizer (torch.optim.Optimizer): The optimizer whose state to save.
        episode (int): The current episode number.
        filepath (str): The path where to save the checkpoint.
    """
    filepath = os.path.join(folder, filename)
    # Ensure the directory exists
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    # Save the checkpoint
    torch.save({
        'episode': episode,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, filepath)
    print(f"Checkpoint saved at episode {episode} to {filepath}")

def load_checkpoint(filepath, model, optimizer):
    """
    Load the model and optimizer state from the designated filepath.

    Args:
        filepath (str): The path from where to load the checkpoint.
        model (nn.Module): The model into which to load the state_dict.
        optimizer (torch.optim.Optimizer): The optimizer into which to load the state.

    Returns:
        int: The episode number to resume from.
    """
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        episode = checkpoint['episode']
        print(f"Checkpoint loaded from {filepath}, resuming from episode {episode}")
        return episode
    else:
        print(f"No checkpoint found at {filepath}, starting from scratch.")
        return 0

# %%
def compute_bellman_returns(raw_rewards, gamma):
    bellman_returns = []
    R = 0
    for r in raw_rewards[::-1]:
        R = r + gamma * R
        bellman_returns.insert(0, R)
    return bellman_returns

# Training Loop
def train(verbose=False):
    # Removed torch.autograd.set_detect_anomaly(True)
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Reduced learning rate
    scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=LR_SCHEDULER_GAMMA)
    
    # Optionally, load a checkpoint
    #checkpoint_path = os.path.join(OUTPUT_DIR, "ckpt_99000_0.9940_86.73.pth")
    #load_checkpoint(checkpoint_path, model, optimizer)

    episode_cnt = 0
    total_reward = 0.0
    num_successes = 0
    total_steps = 0
    
    for episode in range(NUM_EPISODES):
        t1 = time.time()
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, start_pos, current_list = env.reset()
        input_tokens = [initial_token_id, start_pos]
        log_probs = []
        rewards = []
        comparisons = []
        
        state = 'expect_action'
        done = False
        success = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
                #print(comparisons)
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
                output = model(input_seq)  # (seq_len, batch_size, vocab_size)
                # Get logits for the last token
                logits = output[-1, 0, :]  # (vocab_size)

                # Check for NaNs in logits
                if torch.isnan(logits).any():
                    print(f"Episode {episode}, NaNs in logits before masking.")
                    break

                # Get valid tokens based on state
                def get_valid_tokens(state):
                    action_tokens = [vocab['Comparison'], vocab['Swap']]
                    index_tokens = [vocab[str(i)] for i in range(env.get_start_pos(), env.get_start_pos() + env.get_length())]
                    if state == 'expect_action':
                        return action_tokens
                    elif state == 'expect_index1':
                        return index_tokens[:-1]
                    elif state == 'expect_index2':
                        return [x for x in index_tokens if x > input_tokens[-1]]
                    else:
                        # Handle unexpected states by defaulting to expect_action
                        return action_tokens

                valid_token_ids = get_valid_tokens(state)

                # Ensure valid_token_ids are within the vocab range
                if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                    print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                    break

                # Mask invalid tokens
                mask_value = -1e9  # Use a large negative value instead of -inf
                mask = torch.full_like(logits, mask_value).to(device)
                mask[valid_token_ids] = 0
                masked_logits = logits + mask

                # Sample action. Have some chance to randomly pick a valid action.
                eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
                if random.random() < eps_threshold:
                    masked_logits = masked_logits / 4

                # Check for NaNs in masked_logits
                if torch.isnan(masked_logits).any():
                    print(f"Episode {episode}, NaNs in masked_logits after masking.")
                    break

                # Compute probabilities
                probs = F.softmax(masked_logits, dim=0)

                # Check for NaNs in probs
                if torch.isnan(probs).any():
                    print(f"Episode {episode}, NaNs in probs after softmax.")
                    break

                try:
                    m = torch.distributions.Categorical(probs)
                    action_token = m.sample()
                    log_prob = m.log_prob(action_token)
                except ValueError as e:
                    print(f"Episode {episode}, error in sampling action: {e}")
                    break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            reward = 0.0
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        reward = INVALID_ACTION_REWARD
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    if done and reward == SUCCESS_REWARD:
                        success = True
                        if episode % 100 == 0:
                            print(decode(input_tokens, inv_vocab))
                    if verbose:
                        print("Reward:", reward)
                    state = 'expect_action'
                else:
                    reward = INVALID_ACTION_REWARD
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                comparisons.append((int(inv_vocab[index1_token.item()]), int(inv_vocab[index2_token.item()])))
                response_token, reward, done, current_list = env.step(action_tokens)
                if done and reward == SUCCESS_REWARD:
                    success = True
                    if episode % 100 == 0:
                        print(1, decode(input_tokens, inv_vocab))
                else:
                    pass
                    #reward += COMPARISON_ENTROPY_MULTIPLIER * compute_min_delta_entropy(comparisons)
                if verbose:
                    print("Reward:", reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                reward = INVALID_ACTION_REWARD
                done = True

            rewards.append(reward)
        #
        success_rewards = [0.0] * len(rewards)
        if success: 
            num_successes += 1
            success_rewards[-1] = SUCCESS_REWARD

        # Save checkpoint
        if episode > 0 and episode % EPISODES_SAVE == 0:
            avg_reward = total_reward / episode_cnt
            success_rate = num_successes / episode_cnt
            avg_steps = total_steps / episode_cnt
            episode_cnt = 0
            total_reward = 0.0
            num_successes = 0
            total_steps = 0
            save_checkpoint(model, optimizer, episode, OUTPUT_DIR, f"ckpt_{episode}_{success_rate:.4f}_{avg_steps:.2f}.pth")
            #
            # Reduce the lr
            scheduler.step()
            # Optionally, log the learning rate
            current_lr = scheduler.get_last_lr()[0]
            print(f"Learning rate = {current_lr:.6f}")
        #
        assert len(log_probs) == len(rewards), "log_probs and returns have different sizes!"

        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns and loss within autocast
        with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
            # Compute returns
            returns1 = compute_bellman_returns(rewards, SHORTTERM_GAMMA)
            returns2 = compute_bellman_returns(success_rewards, LONGTERM_GAMMA)
            returns = torch.tensor(np.array(returns1) + np.array(returns2)).to(device)

            # Check for NaNs in returns
            if torch.isnan(returns).any():
                print(f"Episode {episode}, NaNs in returns.")
                continue

            # Compute loss
            loss = 0
            for log_prob, R in zip(log_probs, returns):
                loss -= log_prob * R

            # Check for NaNs in loss
            if torch.isnan(loss):
                print(f"Episode {episode}, NaN in loss.")
                continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        episode_cnt += 1
        total_reward += sum(rewards)
        total_steps += len(rewards)
        t2 = time.time()
        if episode % 1 == 0:
            print(f"Episode {episode}, loss:{loss.item():.4f}, {'succeed' if success else 'fail'}, steps:{len(rewards)}, total reward:{sum(rewards):.4f}, {t2-t1} sec")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Episode 0, loss:-3.6604, fail, steps:1, total reward:-10.0000, 0.33774447441101074 sec
# Episode 1, loss:1.4148, succeed, steps:4, total reward:0.2000, 0.021348953247070312 sec
# Episode 2, loss:1.1502, succeed, steps:4, total reward:0.2000, 0.018983840942382812 sec
# Episode 3, loss:-0.1574, fail, steps:6, total reward:-0.6000, 0.027554035186767578 sec
# Episode 4, loss:0.6391, succeed, steps:4, total reward:0.2000, 0.018658161163330078 sec
# Episode 5, loss:0.6378, succeed, steps:4, total reward:0.2000, 0.018898725509643555 sec
# Episode 6, loss:0.1922, succeed, steps:4, total reward:0.2000, 0.01862788200378418 sec
# Episode 7, loss:0.2870, succeed, steps:4, total reward:0.2000, 0.018747806549072266 sec
# Episode 8, loss:-10.7224, fail, steps:1, total reward:-10.0000, 0.005882978439331055 sec
# Episode 9, loss:-0.3220, fail, steps:6, total reward:-0.6000, 0.02727484703063965 sec
# Episode 10, loss:0.4920, succeed, steps:4, total reward:0.2000, 0.018557071685791016 sec
# Episode 11, loss:0.2093, succeed, steps:4, total reward:0.2000, 0.019193172454833984 sec
# Episode 12, loss:0.2131, succeed, steps:4, total reward:0.2000, 0.018597126007080078 sec
# Episode 13, loss:0.1906, succeed, steps:4, total reward:0.2000, 0.01859426498413086 sec
# Episode 14, loss:-10.9875, fail, steps:1, total reward:-10.0000, 0.005893230438232422 sec
# Episode 15, loss:0.2100, succeed, steps:4, total reward:0.2000, 0.018456697463989258 sec
# Episode 16, loss:0.1990, succeed, steps:4, total reward:0.2000, 0.019229650497436523 sec
# Episode 17, loss:0.2057, succeed, steps:4, total reward:0.2000, 0.01912713050842285 sec
# Episode 18, loss:0.0700, succeed, steps:4, total reward:0.2000, 0.019205093383789062 sec
# Episode 19, loss:0.0976, succeed, steps:4, total reward:0.2000, 0.018793821334838867 sec
# Episode 20, loss:0.1167, succeed, steps:4, total reward:0.2000, 0.01974654197692871 sec
# Episode 21, loss:0.0528, succeed, steps:4, total reward:0.2000, 0.01857924461364746 sec
# Episode 22, loss:0.0573, succeed, steps:4, total reward:0.2000, 0.019894838333129883 sec
# Episode 23, loss:-0.4536, fail, steps:6, total reward:-0.6000, 0.027327537536621094 sec
# Episode 24, loss:0.0001, succeed, steps:4, total reward:0.2000, 0.018979549407958984 sec
# Episode 25, loss:0.0341, succeed, steps:4, total reward:0.2000, 0.019678831100463867 sec
# Episode 26, loss:0.0465, succeed, steps:4, total reward:0.2000, 0.019135236740112305 sec
# Episode 27, loss:0.0761, succeed, steps:4, total reward:0.2000, 0.019587993621826172 sec
# Episode 28, loss:0.0405, succeed, steps:4, total reward:0.2000, 0.019213438034057617 sec
# Episode 29, loss:0.0390, succeed, steps:4, total reward:0.2000, 0.019361257553100586 sec
# Episode 30, loss:0.0286, succeed, steps:4, total reward:0.2000, 0.01920914649963379 sec
# Episode 31, loss:0.0386, succeed, steps:4, total reward:0.2000, 0.01866006851196289 sec
# Episode 32, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019617795944213867 sec
# Episode 33, loss:0.0297, succeed, steps:4, total reward:0.2000, 0.018857479095458984 sec
# Episode 34, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019980907440185547 sec
# Episode 35, loss:0.0248, succeed, steps:4, total reward:0.2000, 0.019229412078857422 sec
# Episode 36, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019440889358520508 sec
# Episode 37, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01923537254333496 sec
# Episode 38, loss:0.0321, succeed, steps:4, total reward:0.2000, 0.019170284271240234 sec
# Episode 39, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01889777183532715 sec
# Episode 40, loss:0.0329, succeed, steps:4, total reward:0.2000, 0.01872730255126953 sec
# Episode 41, loss:0.0307, succeed, steps:4, total reward:0.2000, 0.018956422805786133 sec
# Episode 42, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019131898880004883 sec
# Episode 43, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019327402114868164 sec
# Episode 44, loss:0.0293, succeed, steps:4, total reward:0.2000, 0.018736600875854492 sec
# Episode 45, loss:0.0286, succeed, steps:4, total reward:0.2000, 0.019651174545288086 sec
# Episode 46, loss:0.0521, succeed, steps:4, total reward:0.2000, 0.019395828247070312 sec
# Episode 47, loss:0.0501, succeed, steps:4, total reward:0.2000, 0.019025087356567383 sec
# Episode 48, loss:0.0312, succeed, steps:4, total reward:0.2000, 0.01909613609313965 sec
# Episode 49, loss:0.0286, succeed, steps:4, total reward:0.2000, 0.019269466400146484 sec
# Episode 50, loss:0.0273, succeed, steps:4, total reward:0.2000, 0.019040346145629883 sec
# Episode 51, loss:-33.5582, fail, steps:1, total reward:-10.0000, 0.005988597869873047 sec
# Episode 52, loss:0.0314, succeed, steps:4, total reward:0.2000, 0.01935553550720215 sec
# Episode 53, loss:0.0427, succeed, steps:4, total reward:0.2000, 0.011493444442749023 sec
# Episode 54, loss:0.0192, succeed, steps:4, total reward:0.2000, 0.011435270309448242 sec
# Episode 55, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01130986213684082 sec
# Episode 56, loss:0.0255, succeed, steps:4, total reward:0.2000, 0.01191258430480957 sec
# Episode 57, loss:0.0436, succeed, steps:4, total reward:0.2000, 0.011518001556396484 sec
# Episode 58, loss:0.0155, succeed, steps:4, total reward:0.2000, 0.011107683181762695 sec
# Episode 59, loss:0.0156, succeed, steps:4, total reward:0.2000, 0.011258840560913086 sec
# Episode 60, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01149749755859375 sec
# Episode 61, loss:0.0170, succeed, steps:4, total reward:0.2000, 0.011429071426391602 sec
# Episode 62, loss:0.0143, succeed, steps:4, total reward:0.2000, 0.036667585372924805 sec
# Episode 63, loss:0.0433, succeed, steps:4, total reward:0.2000, 0.020772933959960938 sec
# Episode 64, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.020848512649536133 sec
# Episode 65, loss:0.0150, succeed, steps:4, total reward:0.2000, 0.021109819412231445 sec
# Episode 66, loss:0.0255, succeed, steps:4, total reward:0.2000, 0.07013678550720215 sec
# Episode 67, loss:0.0148, succeed, steps:4, total reward:0.2000, 0.07807707786560059 sec
# Episode 68, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.06132221221923828 sec
# Episode 69, loss:0.0145, succeed, steps:4, total reward:0.2000, 0.053006649017333984 sec
# Episode 70, loss:0.0396, succeed, steps:4, total reward:0.2000, 0.04880475997924805 sec
# Episode 71, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.02455306053161621 sec
# Episode 72, loss:0.0391, succeed, steps:4, total reward:0.2000, 0.02216172218322754 sec
# Episode 73, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03603053092956543 sec
# Episode 74, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03246879577636719 sec
# Episode 75, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03204631805419922 sec
# Episode 76, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03203582763671875 sec
# Episode 77, loss:0.0377, succeed, steps:4, total reward:0.2000, 0.029170513153076172 sec
# Episode 78, loss:0.0238, succeed, steps:4, total reward:0.2000, 0.011756420135498047 sec
# Episode 79, loss:0.0232, succeed, steps:4, total reward:0.2000, 0.01301717758178711 sec
# Episode 80, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01707744598388672 sec
# Episode 81, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.017996788024902344 sec
# Episode 82, loss:0.0236, succeed, steps:4, total reward:0.2000, 0.017370939254760742 sec
# Episode 83, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018487930297851562 sec
# Episode 84, loss:0.0361, succeed, steps:4, total reward:0.2000, 0.018271684646606445 sec
# Episode 85, loss:0.0227, succeed, steps:4, total reward:0.2000, 0.018194198608398438 sec
# Episode 86, loss:0.0240, succeed, steps:4, total reward:0.2000, 0.018396377563476562 sec
# Episode 87, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018556594848632812 sec
# Episode 88, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018541336059570312 sec
# Episode 89, loss:0.0347, succeed, steps:4, total reward:0.2000, 0.018569469451904297 sec
# Episode 90, loss:0.0364, succeed, steps:4, total reward:0.2000, 0.018232107162475586 sec
# Episode 91, loss:0.0350, succeed, steps:4, total reward:0.2000, 0.018307924270629883 sec
# Episode 92, loss:0.0236, succeed, steps:4, total reward:0.2000, 0.018416881561279297 sec
# Episode 93, loss:0.0121, succeed, steps:4, total reward:0.2000, 0.018280744552612305 sec
# Episode 94, loss:-0.5592, fail, steps:6, total reward:-0.6000, 0.027302980422973633 sec
# Episode 95, loss:0.0132, succeed, steps:4, total reward:0.2000, 0.018550872802734375 sec
# Episode 96, loss:0.0348, succeed, steps:4, total reward:0.2000, 0.018763065338134766 sec
# Episode 97, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01851797103881836 sec
# Episode 98, loss:0.0210, succeed, steps:4, total reward:0.2000, 0.018362760543823242 sec
# Episode 99, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018523454666137695 sec
# len2 start2 Comparison 2 3 more Swap
# Episode 100, loss:0.0116, succeed, steps:4, total reward:0.2000, 0.018924236297607422 sec
# Episode 101, loss:0.0227, succeed, steps:4, total reward:0.2000, 0.018703937530517578 sec
# Episode 102, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018369197845458984 sec
# Episode 103, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018482685089111328 sec
# Episode 104, loss:0.0212, succeed, steps:4, total reward:0.2000, 0.018285274505615234 sec
# Episode 105, loss:0.0355, succeed, steps:4, total reward:0.2000, 0.01868271827697754 sec
# Episode 106, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01868581771850586 sec
# Episode 107, loss:0.0113, succeed, steps:4, total reward:0.2000, 0.018530845642089844 sec
# Episode 108, loss:0.0225, succeed, steps:4, total reward:0.2000, 0.0185244083404541 sec
# Episode 109, loss:0.0120, succeed, steps:4, total reward:0.2000, 0.018523693084716797 sec
# Episode 110, loss:0.0220, succeed, steps:4, total reward:0.2000, 0.018792390823364258 sec
# Episode 111, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018500328063964844 sec
# Episode 112, loss:0.0331, succeed, steps:4, total reward:0.2000, 0.018784761428833008 sec
# Episode 113, loss:0.0317, succeed, steps:4, total reward:0.2000, 0.018810272216796875 sec
# Episode 114, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01859116554260254 sec
# Episode 115, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018428802490234375 sec
# Episode 116, loss:0.0117, succeed, steps:4, total reward:0.2000, 0.018270492553710938 sec
# Episode 117, loss:0.0324, succeed, steps:4, total reward:0.2000, 0.01889634132385254 sec
# Episode 118, loss:0.0204, succeed, steps:4, total reward:0.2000, 0.01900768280029297 sec
# Episode 119, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018711328506469727 sec
# Episode 120, loss:0.0305, succeed, steps:4, total reward:0.2000, 0.019734621047973633 sec
# Episode 121, loss:0.0204, succeed, steps:4, total reward:0.2000, 0.019156932830810547 sec
# Episode 122, loss:0.0119, succeed, steps:4, total reward:0.2000, 0.01969599723815918 sec
# Episode 123, loss:0.0319, succeed, steps:4, total reward:0.2000, 0.018788814544677734 sec
# Episode 124, loss:0.0109, succeed, steps:4, total reward:0.2000, 0.0198211669921875 sec
# Episode 125, loss:0.0323, succeed, steps:4, total reward:0.2000, 0.01899552345275879 sec
# Episode 126, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019028186798095703 sec
# Episode 127, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01874375343322754 sec
# Episode 128, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019726276397705078 sec
# Episode 129, loss:0.0317, succeed, steps:4, total reward:0.2000, 0.01869940757751465 sec
# Episode 130, loss:0.0300, succeed, steps:4, total reward:0.2000, 0.019895315170288086 sec
# Episode 131, loss:0.0193, succeed, steps:4, total reward:0.2000, 0.019179105758666992 sec
# Episode 132, loss:0.0299, succeed, steps:4, total reward:0.2000, 0.01949763298034668 sec
# Episode 133, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.0191042423248291 sec
# Episode 134, loss:0.0192, succeed, steps:4, total reward:0.2000, 0.019726991653442383 sec
# Episode 135, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018805742263793945 sec
# Episode 136, loss:0.0287, succeed, steps:4, total reward:0.2000, 0.019736051559448242 sec
# Episode 137, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01970839500427246 sec
# Episode 138, loss:0.0298, succeed, steps:4, total reward:0.2000, 0.019380807876586914 sec
# Episode 139, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018981218338012695 sec
# Episode 140, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019776344299316406 sec
# Episode 141, loss:0.0105, succeed, steps:4, total reward:0.2000, 0.01862335205078125 sec
# Episode 142, loss:0.0187, succeed, steps:4, total reward:0.2000, 0.019587993621826172 sec
# Episode 143, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019507884979248047 sec
# Episode 144, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018941879272460938 sec
# Episode 145, loss:0.0109, succeed, steps:4, total reward:0.2000, 0.01869368553161621 sec
# Episode 146, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019623994827270508 sec
# Episode 147, loss:0.0292, succeed, steps:4, total reward:0.2000, 0.019063234329223633 sec
# Episode 148, loss:0.0177, succeed, steps:4, total reward:0.2000, 0.019716501235961914 sec
# Episode 149, loss:0.0195, succeed, steps:4, total reward:0.2000, 0.018964767456054688 sec
# Episode 150, loss:0.0187, succeed, steps:4, total reward:0.2000, 0.019534587860107422 sec
# Episode 151, loss:0.0278, succeed, steps:4, total reward:0.2000, 0.019065380096435547 sec
# Episode 152, loss:0.0179, succeed, steps:4, total reward:0.2000, 0.019087553024291992 sec
# Episode 153, loss:0.0098, succeed, steps:4, total reward:0.2000, 0.018524885177612305 sec
# Episode 154, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.014627695083618164 sec
# Episode 155, loss:-0.5941, fail, steps:6, total reward:-0.6000, 0.016739845275878906 sec
# Episode 156, loss:0.0092, succeed, steps:4, total reward:0.2000, 0.01171565055847168 sec
# Episode 157, loss:0.0176, succeed, steps:4, total reward:0.2000, 0.011357784271240234 sec
# Episode 158, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011278629302978516 sec
# Episode 159, loss:0.0180, succeed, steps:4, total reward:0.2000, 0.01378774642944336 sec
# Episode 160, loss:0.0281, succeed, steps:4, total reward:0.2000, 0.011333465576171875 sec
# Episode 161, loss:0.0105, succeed, steps:4, total reward:0.2000, 0.011460065841674805 sec
# Episode 162, loss:0.0176, succeed, steps:4, total reward:0.2000, 0.011421680450439453 sec
# Episode 163, loss:0.0094, succeed, steps:4, total reward:0.2000, 0.09302234649658203 sec
# Episode 164, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.08430719375610352 sec
# Episode 165, loss:0.0274, succeed, steps:4, total reward:0.2000, 0.06409525871276855 sec
# Episode 166, loss:0.0102, succeed, steps:4, total reward:0.2000, 0.030794143676757812 sec
# Episode 167, loss:0.0095, succeed, steps:4, total reward:0.2000, 0.04951953887939453 sec
# Episode 168, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.044196128845214844 sec
# Episode 169, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.04443812370300293 sec
# Episode 170, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03744959831237793 sec
# Episode 171, loss:0.0089, succeed, steps:4, total reward:0.2000, 0.03405165672302246 sec
# Episode 172, loss:0.0173, succeed, steps:4, total reward:0.2000, 0.03311014175415039 sec
# Episode 173, loss:0.0092, succeed, steps:4, total reward:0.2000, 0.0321199893951416 sec
# Episode 174, loss:0.0089, succeed, steps:4, total reward:0.2000, 0.02104783058166504 sec
# Episode 175, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018825054168701172 sec
# Episode 176, loss:0.0257, succeed, steps:4, total reward:0.2000, 0.011270284652709961 sec
# Episode 177, loss:0.0171, succeed, steps:4, total reward:0.2000, 0.012334585189819336 sec
# Episode 178, loss:0.0088, succeed, steps:4, total reward:0.2000, 0.01189279556274414 sec
# Episode 179, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.017394065856933594 sec
# Episode 180, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018059968948364258 sec
# Episode 181, loss:0.0092, succeed, steps:4, total reward:0.2000, 0.018507719039916992 sec
# Episode 182, loss:0.0250, succeed, steps:4, total reward:0.2000, 0.01848888397216797 sec
# Episode 183, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018041610717773438 sec
# Episode 184, loss:0.0165, succeed, steps:4, total reward:0.2000, 0.01828289031982422 sec
# Episode 185, loss:0.0085, succeed, steps:4, total reward:0.2000, 0.018336057662963867 sec
# Episode 186, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01831793785095215 sec
# Episode 187, loss:0.0249, succeed, steps:4, total reward:0.2000, 0.01833629608154297 sec
# Episode 188, loss:0.0172, succeed, steps:4, total reward:0.2000, 0.017975568771362305 sec
# Episode 189, loss:0.0098, succeed, steps:4, total reward:0.2000, 0.0191648006439209 sec
# Episode 190, loss:0.0162, succeed, steps:4, total reward:0.2000, 0.018778085708618164 sec
# Episode 191, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01844000816345215 sec
# Episode 192, loss:0.0260, succeed, steps:4, total reward:0.2000, 0.018471479415893555 sec
# Episode 193, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01815199851989746 sec
# Episode 194, loss:0.0158, succeed, steps:4, total reward:0.2000, 0.018280744552612305 sec
# Episode 195, loss:0.0089, succeed, steps:4, total reward:0.2000, 0.018418073654174805 sec
# Episode 196, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018442392349243164 sec
# Episode 197, loss:0.0082, succeed, steps:4, total reward:0.2000, 0.018476486206054688 sec
# Episode 198, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01848626136779785 sec
# Episode 199, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018426179885864258 sec
# Episode 200, loss:-40.5652, fail, steps:1, total reward:-10.0000, 0.005957603454589844 sec
# Episode 201, loss:0.0240, succeed, steps:4, total reward:0.2000, 0.01916337013244629 sec
# Episode 202, loss:-40.0281, fail, steps:1, total reward:-10.0000, 0.006045341491699219 sec
# Episode 203, loss:0.0086, succeed, steps:4, total reward:0.2000, 0.018459796905517578 sec
# Episode 204, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018680810928344727 sec
# Episode 205, loss:0.0152, succeed, steps:4, total reward:0.2000, 0.018390655517578125 sec
# Episode 206, loss:0.0151, succeed, steps:4, total reward:0.2000, 0.018282651901245117 sec
# Episode 207, loss:0.0228, succeed, steps:4, total reward:0.2000, 0.018230676651000977 sec
# Episode 208, loss:0.0084, succeed, steps:4, total reward:0.2000, 0.018895864486694336 sec
# Episode 209, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018573999404907227 sec
# Episode 210, loss:0.0086, succeed, steps:4, total reward:0.2000, 0.018479585647583008 sec
# Episode 211, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018880605697631836 sec
# Episode 212, loss:0.0084, succeed, steps:4, total reward:0.2000, 0.01880192756652832 sec
# Episode 213, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018616437911987305 sec
# Episode 214, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018543720245361328 sec
# Episode 215, loss:0.0082, succeed, steps:4, total reward:0.2000, 0.01846909523010254 sec
# Episode 216, loss:0.0146, succeed, steps:4, total reward:0.2000, 0.01864767074584961 sec
# Episode 217, loss:0.0162, succeed, steps:4, total reward:0.2000, 0.016036272048950195 sec
# Episode 218, loss:0.0093, succeed, steps:4, total reward:0.2000, 0.01119375228881836 sec
# Episode 219, loss:0.0225, succeed, steps:4, total reward:0.2000, 0.01122140884399414 sec
# Episode 220, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011584281921386719 sec
# Episode 221, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011402130126953125 sec
# Episode 222, loss:0.0148, succeed, steps:4, total reward:0.2000, 0.011230707168579102 sec
# Episode 223, loss:0.0085, succeed, steps:4, total reward:0.2000, 0.011213302612304688 sec
# Episode 224, loss:0.0222, succeed, steps:4, total reward:0.2000, 0.03750109672546387 sec
# Episode 225, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.0431210994720459 sec
# Episode 226, loss:0.0085, succeed, steps:4, total reward:0.2000, 0.03907489776611328 sec
# Episode 227, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03683114051818848 sec
# Episode 228, loss:0.0233, succeed, steps:4, total reward:0.2000, 0.0344390869140625 sec
# Episode 229, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.032071590423583984 sec
# Episode 230, loss:0.0088, succeed, steps:4, total reward:0.2000, 0.0312657356262207 sec
# Episode 231, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.014875650405883789 sec
# Episode 232, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01208043098449707 sec
# Episode 233, loss:0.0137, succeed, steps:4, total reward:0.2000, 0.018761157989501953 sec
# Episode 234, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.016925334930419922 sec
# Episode 235, loss:0.0137, succeed, steps:4, total reward:0.2000, 0.018446683883666992 sec
# Episode 236, loss:0.0224, succeed, steps:4, total reward:0.2000, 0.011524438858032227 sec
# Episode 237, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011467218399047852 sec
# Episode 238, loss:0.0220, succeed, steps:4, total reward:0.2000, 0.011521577835083008 sec
# Episode 239, loss:0.0142, succeed, steps:4, total reward:0.2000, 0.011399984359741211 sec
# Episode 240, loss:0.0222, succeed, steps:4, total reward:0.2000, 0.011487722396850586 sec
# Episode 241, loss:0.0076, succeed, steps:4, total reward:0.2000, 0.018214941024780273 sec
# Episode 242, loss:0.0074, succeed, steps:4, total reward:0.2000, 0.018228769302368164 sec
# Episode 243, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01833319664001465 sec
# Episode 244, loss:0.0220, succeed, steps:4, total reward:0.2000, 0.018092870712280273 sec
# Episode 245, loss:0.0206, succeed, steps:4, total reward:0.2000, 0.018825292587280273 sec
# Episode 246, loss:0.0075, succeed, steps:4, total reward:0.2000, 0.018555879592895508 sec
# Episode 247, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01833796501159668 sec
# Episode 248, loss:0.0076, succeed, steps:4, total reward:0.2000, 0.018119096755981445 sec
# Episode 249, loss:0.0212, succeed, steps:4, total reward:0.2000, 0.017816543579101562 sec
# Episode 250, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018365144729614258 sec
# Episode 251, loss:0.0212, succeed, steps:4, total reward:0.2000, 0.0181276798248291 sec
# Episode 252, loss:0.0139, succeed, steps:4, total reward:0.2000, 0.01812911033630371 sec
# Episode 253, loss:0.0205, succeed, steps:4, total reward:0.2000, 0.01816391944885254 sec
# Episode 254, loss:0.0071, succeed, steps:4, total reward:0.2000, 0.018390655517578125 sec
# Episode 255, loss:0.0137, succeed, steps:4, total reward:0.2000, 0.018406152725219727 sec
# Episode 256, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018834590911865234 sec
# Episode 257, loss:0.0129, succeed, steps:4, total reward:0.2000, 0.018580198287963867 sec
# Episode 258, loss:0.0207, succeed, steps:4, total reward:0.2000, 0.018773555755615234 sec
# Episode 259, loss:0.0135, succeed, steps:4, total reward:0.2000, 0.018596410751342773 sec
# Episode 260, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01842188835144043 sec
# Episode 261, loss:0.0071, succeed, steps:4, total reward:0.2000, 0.018267154693603516 sec
# Episode 262, loss:0.0131, succeed, steps:4, total reward:0.2000, 0.01858353614807129 sec
# Episode 263, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018833637237548828 sec
# Episode 264, loss:0.0203, succeed, steps:4, total reward:0.2000, 0.01852703094482422 sec
# Episode 265, loss:0.0068, succeed, steps:4, total reward:0.2000, 0.01834559440612793 sec
# Episode 266, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01825690269470215 sec
# Episode 267, loss:0.0200, succeed, steps:4, total reward:0.2000, 0.018762826919555664 sec
# Episode 268, loss:0.0197, succeed, steps:4, total reward:0.2000, 0.018715858459472656 sec
# Episode 269, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018503904342651367 sec
# Episode 270, loss:0.0129, succeed, steps:4, total reward:0.2000, 0.018887996673583984 sec
# Episode 271, loss:0.0202, succeed, steps:4, total reward:0.2000, 0.018590211868286133 sec
# Episode 272, loss:0.0069, succeed, steps:4, total reward:0.2000, 0.018811464309692383 sec
# Episode 273, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018569469451904297 sec
# Episode 274, loss:0.0131, succeed, steps:4, total reward:0.2000, 0.01835799217224121 sec
# Episode 275, loss:0.0065, succeed, steps:4, total reward:0.2000, 0.018598079681396484 sec
# Episode 276, loss:0.0204, succeed, steps:4, total reward:0.2000, 0.01923394203186035 sec
# Episode 277, loss:0.0067, succeed, steps:4, total reward:0.2000, 0.018811941146850586 sec
# Episode 278, loss:0.0127, succeed, steps:4, total reward:0.2000, 0.01958918571472168 sec
# Episode 279, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019715070724487305 sec
# Episode 280, loss:0.0068, succeed, steps:4, total reward:0.2000, 0.018784761428833008 sec
# Episode 281, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019702434539794922 sec
# Episode 282, loss:0.0194, succeed, steps:4, total reward:0.2000, 0.01905035972595215 sec
# Episode 283, loss:0.0129, succeed, steps:4, total reward:0.2000, 0.01966118812561035 sec
# Episode 284, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01894664764404297 sec
# Episode 285, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018500566482543945 sec
# Episode 286, loss:0.0064, succeed, steps:4, total reward:0.2000, 0.01970696449279785 sec
# Episode 287, loss:0.0127, succeed, steps:4, total reward:0.2000, 0.019570112228393555 sec
# Episode 288, loss:0.0123, succeed, steps:4, total reward:0.2000, 0.01915907859802246 sec
# Episode 289, loss:0.0123, succeed, steps:4, total reward:0.2000, 0.015252113342285156 sec
# Episode 290, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011323690414428711 sec
# Episode 291, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011401891708374023 sec
# Episode 292, loss:0.0121, succeed, steps:4, total reward:0.2000, 0.0116119384765625 sec
# Episode 293, loss:0.0063, succeed, steps:4, total reward:0.2000, 0.01118326187133789 sec
# Episode 294, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.05942249298095703 sec
# Episode 295, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.056233882904052734 sec
# Episode 296, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.0470578670501709 sec
# Episode 297, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.04114842414855957 sec
# Episode 298, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.039948463439941406 sec
# Episode 299, loss:0.0118, succeed, steps:4, total reward:0.2000, 0.03486800193786621 sec
# len2 start10 Comparison 10 11 more Swap
# Episode 300, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03475213050842285 sec
# Episode 301, loss:0.0064, succeed, steps:4, total reward:0.2000, 0.032655954360961914 sec
# Episode 302, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01562666893005371 sec
# Episode 303, loss:0.0178, succeed, steps:4, total reward:0.2000, 0.01661849021911621 sec
# Episode 304, loss:0.0063, succeed, steps:4, total reward:0.2000, 0.017453432083129883 sec
# Episode 305, loss:0.0123, succeed, steps:4, total reward:0.2000, 0.01781177520751953 sec
# Episode 306, loss:0.0119, succeed, steps:4, total reward:0.2000, 0.017739534378051758 sec
# Episode 307, loss:0.0066, succeed, steps:4, total reward:0.2000, 0.01863884925842285 sec
# Episode 308, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01865077018737793 sec
# Episode 309, loss:0.0114, succeed, steps:4, total reward:0.2000, 0.018117666244506836 sec
# Episode 310, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018303871154785156 sec
# Episode 311, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018038034439086914 sec
# Episode 312, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.0180056095123291 sec
# Episode 313, loss:0.0062, succeed, steps:4, total reward:0.2000, 0.018419981002807617 sec
# Episode 314, loss:0.0118, succeed, steps:4, total reward:0.2000, 0.01865673065185547 sec
# Episode 315, loss:0.0062, succeed, steps:4, total reward:0.2000, 0.018563032150268555 sec
# Episode 316, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018205881118774414 sec
# Episode 317, loss:0.0114, succeed, steps:4, total reward:0.2000, 0.01837468147277832 sec
# Episode 318, loss:0.0061, succeed, steps:4, total reward:0.2000, 0.018175363540649414 sec
# Episode 319, loss:0.0064, succeed, steps:4, total reward:0.2000, 0.018732309341430664 sec
# Episode 320, loss:0.0114, succeed, steps:4, total reward:0.2000, 0.018549203872680664 sec
# Episode 321, loss:0.0062, succeed, steps:4, total reward:0.2000, 0.018355607986450195 sec
# Episode 322, loss:0.0064, succeed, steps:4, total reward:0.2000, 0.018222570419311523 sec
# Episode 323, loss:0.0063, succeed, steps:4, total reward:0.2000, 0.01811671257019043 sec
# Episode 324, loss:0.0116, succeed, steps:4, total reward:0.2000, 0.018079519271850586 sec
# Episode 325, loss:0.0172, succeed, steps:4, total reward:0.2000, 0.018448829650878906 sec
# Episode 326, loss:0.0175, succeed, steps:4, total reward:0.2000, 0.01845860481262207 sec
# Episode 327, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018466472625732422 sec
# Episode 328, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018642425537109375 sec
# Episode 329, loss:0.0119, succeed, steps:4, total reward:0.2000, 0.01833796501159668 sec
# Episode 330, loss:0.0118, succeed, steps:4, total reward:0.2000, 0.01842498779296875 sec
# Episode 331, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018332242965698242 sec
# Episode 332, loss:0.0118, succeed, steps:4, total reward:0.2000, 0.018161535263061523 sec
# Episode 333, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01844334602355957 sec
# Episode 334, loss:0.0176, succeed, steps:4, total reward:0.2000, 0.01866936683654785 sec
# Episode 335, loss:0.0114, succeed, steps:4, total reward:0.2000, 0.018642187118530273 sec
# Episode 336, loss:0.0118, succeed, steps:4, total reward:0.2000, 0.018497943878173828 sec
# Episode 337, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01825404167175293 sec
# Episode 338, loss:0.0114, succeed, steps:4, total reward:0.2000, 0.018494606018066406 sec
# Episode 339, loss:0.0110, succeed, steps:4, total reward:0.2000, 0.018311262130737305 sec
# Episode 340, loss:0.0062, succeed, steps:4, total reward:0.2000, 0.01873183250427246 sec
# Episode 341, loss:0.0056, succeed, steps:4, total reward:0.2000, 0.018567323684692383 sec
# Episode 342, loss:0.0110, succeed, steps:4, total reward:0.2000, 0.018816709518432617 sec
# Episode 343, loss:0.0169, succeed, steps:4, total reward:0.2000, 0.018918752670288086 sec
# Episode 344, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019247770309448242 sec
# Episode 345, loss:0.0174, succeed, steps:4, total reward:0.2000, 0.019281864166259766 sec
# Episode 346, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01941990852355957 sec
# Episode 347, loss:0.0058, succeed, steps:4, total reward:0.2000, 0.01921701431274414 sec
# Episode 348, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019394874572753906 sec
# Episode 349, loss:0.0110, succeed, steps:4, total reward:0.2000, 0.019111156463623047 sec
# Episode 350, loss:0.0105, succeed, steps:4, total reward:0.2000, 0.019188404083251953 sec
# Episode 351, loss:0.0114, succeed, steps:4, total reward:0.2000, 0.019121408462524414 sec
# Episode 352, loss:0.0058, succeed, steps:4, total reward:0.2000, 0.019046306610107422 sec
# Episode 353, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.0195615291595459 sec
# Episode 354, loss:0.0164, succeed, steps:4, total reward:0.2000, 0.019113779067993164 sec
# Episode 355, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019443988800048828 sec
# Episode 356, loss:0.0166, succeed, steps:4, total reward:0.2000, 0.019193172454833984 sec
# Episode 357, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019299983978271484 sec
# Episode 358, loss:0.0109, succeed, steps:4, total reward:0.2000, 0.017287731170654297 sec
# Episode 359, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01982855796813965 sec
# Episode 360, loss:0.0109, succeed, steps:4, total reward:0.2000, 0.013341188430786133 sec
# Episode 361, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011527299880981445 sec
# Episode 362, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011542558670043945 sec
# Episode 363, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011381149291992188 sec
# Episode 364, loss:0.0158, succeed, steps:4, total reward:0.2000, 0.011364936828613281 sec
# Episode 365, loss:0.0056, succeed, steps:4, total reward:0.2000, 0.011280298233032227 sec
# Episode 366, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.06572794914245605 sec
# Episode 367, loss:0.0109, succeed, steps:4, total reward:0.2000, 0.0611269474029541 sec
# Episode 368, loss:0.0160, succeed, steps:4, total reward:0.2000, 0.04870152473449707 sec
# Episode 369, loss:0.0166, succeed, steps:4, total reward:0.2000, 0.04381537437438965 sec
# Episode 370, loss:0.0161, succeed, steps:4, total reward:0.2000, 0.0269012451171875 sec
# Episode 371, loss:0.0158, succeed, steps:4, total reward:0.2000, 0.01964569091796875 sec
# Episode 372, loss:0.0102, succeed, steps:4, total reward:0.2000, 0.03177452087402344 sec
# Episode 373, loss:0.0109, succeed, steps:4, total reward:0.2000, 0.03498530387878418 sec
# Episode 374, loss:0.0109, succeed, steps:4, total reward:0.2000, 0.03455471992492676 sec
# Episode 375, loss:0.0056, succeed, steps:4, total reward:0.2000, 0.037354230880737305 sec
# Episode 376, loss:0.0107, succeed, steps:4, total reward:0.2000, 0.020651817321777344 sec
# Episode 377, loss:0.0104, succeed, steps:4, total reward:0.2000, 0.011687755584716797 sec
# Episode 378, loss:0.0058, succeed, steps:4, total reward:0.2000, 0.01667618751525879 sec
# Episode 379, loss:0.0104, succeed, steps:4, total reward:0.2000, 0.018197298049926758 sec
# Episode 380, loss:0.0099, succeed, steps:4, total reward:0.2000, 0.01763319969177246 sec
# Episode 381, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018280506134033203 sec
# Episode 382, loss:0.0104, succeed, steps:4, total reward:0.2000, 0.01865243911743164 sec
# Episode 383, loss:0.0105, succeed, steps:4, total reward:0.2000, 0.018248319625854492 sec
# Episode 384, loss:0.0102, succeed, steps:4, total reward:0.2000, 0.018296480178833008 sec
# Episode 385, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018149852752685547 sec
# Episode 386, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018736839294433594 sec
# Episode 387, loss:0.0101, succeed, steps:4, total reward:0.2000, 0.018568038940429688 sec
# Episode 388, loss:0.0156, succeed, steps:4, total reward:0.2000, 0.018311500549316406 sec
# Episode 389, loss:0.0101, succeed, steps:4, total reward:0.2000, 0.018378257751464844 sec
# Episode 390, loss:0.0151, succeed, steps:4, total reward:0.2000, 0.018777132034301758 sec
# Episode 391, loss:0.0154, succeed, steps:4, total reward:0.2000, 0.01877427101135254 sec
# Episode 392, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018541574478149414 sec
# Episode 393, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018153667449951172 sec
# Episode 394, loss:0.0150, succeed, steps:4, total reward:0.2000, 0.018514394760131836 sec
# Episode 395, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01883411407470703 sec
# Episode 396, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018527507781982422 sec
# Episode 397, loss:0.0098, succeed, steps:4, total reward:0.2000, 0.018441200256347656 sec
# Episode 398, loss:0.0053, succeed, steps:4, total reward:0.2000, 0.018475770950317383 sec
# Episode 399, loss:0.0054, succeed, steps:4, total reward:0.2000, 0.018511295318603516 sec
# len2 start2 Comparison 2 3 more Swap
# Episode 400, loss:0.0052, succeed, steps:4, total reward:0.2000, 0.018561124801635742 sec
# Episode 401, loss:0.0095, succeed, steps:4, total reward:0.2000, 0.019017696380615234 sec
# Episode 402, loss:0.0051, succeed, steps:4, total reward:0.2000, 0.018546104431152344 sec
# Episode 403, loss:-45.7288, fail, steps:1, total reward:-10.0000, 0.005708932876586914 sec
# Episode 404, loss:0.0095, succeed, steps:4, total reward:0.2000, 0.01849961280822754 sec
# Episode 405, loss:0.0053, succeed, steps:4, total reward:0.2000, 0.018666744232177734 sec
# Episode 406, loss:0.0095, succeed, steps:4, total reward:0.2000, 0.01890850067138672 sec
# Episode 407, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01892375946044922 sec
# Episode 408, loss:0.0101, succeed, steps:4, total reward:0.2000, 0.018744707107543945 sec
# Episode 409, loss:0.0147, succeed, steps:4, total reward:0.2000, 0.018540620803833008 sec
# Episode 410, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.017393827438354492 sec
# Episode 411, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018777132034301758 sec
# Episode 412, loss:0.0093, succeed, steps:4, total reward:0.2000, 0.018442153930664062 sec
# Episode 413, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018830299377441406 sec
# Episode 414, loss:0.0145, succeed, steps:4, total reward:0.2000, 0.018368005752563477 sec
# Episode 415, loss:0.0053, succeed, steps:4, total reward:0.2000, 0.01867055892944336 sec
# Episode 416, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01904439926147461 sec
# Episode 417, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01923680305480957 sec
# Episode 418, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019635677337646484 sec
# Episode 419, loss:0.0092, succeed, steps:4, total reward:0.2000, 0.01900315284729004 sec
# Episode 420, loss:0.0146, succeed, steps:4, total reward:0.2000, 0.019245624542236328 sec
# Episode 421, loss:0.0146, succeed, steps:4, total reward:0.2000, 0.019179344177246094 sec
# Episode 422, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01950860023498535 sec
# Episode 423, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018586397171020508 sec
# Episode 424, loss:0.0053, succeed, steps:4, total reward:0.2000, 0.019727706909179688 sec
# Episode 425, loss:0.0093, succeed, steps:4, total reward:0.2000, 0.019097566604614258 sec
# Episode 426, loss:0.0144, succeed, steps:4, total reward:0.2000, 0.019596099853515625 sec
# Episode 427, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01927947998046875 sec
# Episode 428, loss:0.0089, succeed, steps:4, total reward:0.2000, 0.01943373680114746 sec
# Episode 429, loss:0.0145, succeed, steps:4, total reward:0.2000, 0.019047975540161133 sec
# Episode 430, loss:0.0092, succeed, steps:4, total reward:0.2000, 0.019221782684326172 sec
# Episode 431, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018965959548950195 sec
# Episode 432, loss:0.0086, succeed, steps:4, total reward:0.2000, 0.019078493118286133 sec
# Episode 433, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01858830451965332 sec
# Episode 434, loss:0.0053, succeed, steps:4, total reward:0.2000, 0.0198514461517334 sec
# Episode 435, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018729209899902344 sec
# Episode 436, loss:0.0053, succeed, steps:4, total reward:0.2000, 0.019681930541992188 sec
# Episode 437, loss:0.0051, succeed, steps:4, total reward:0.2000, 0.019161701202392578 sec
# Episode 438, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019265174865722656 sec
# Episode 439, loss:0.0051, succeed, steps:4, total reward:0.2000, 0.018848896026611328 sec
# Episode 440, loss:0.0050, succeed, steps:4, total reward:0.2000, 0.018870830535888672 sec
# Episode 441, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01853466033935547 sec
# Episode 442, loss:0.0049, succeed, steps:4, total reward:0.2000, 0.019210338592529297 sec
# Episode 443, loss:0.0135, succeed, steps:4, total reward:0.2000, 0.018644094467163086 sec
# Episode 444, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01923346519470215 sec
# Episode 445, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019056320190429688 sec
# Episode 446, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01955437660217285 sec
# Episode 447, loss:0.0138, succeed, steps:4, total reward:0.2000, 0.019614219665527344 sec
# Episode 448, loss:0.0085, succeed, steps:4, total reward:0.2000, 0.019007205963134766 sec
# Episode 449, loss:0.0089, succeed, steps:4, total reward:0.2000, 0.019329071044921875 sec
# Episode 450, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01899099349975586 sec
# Episode 451, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019265174865722656 sec
# Episode 452, loss:0.0087, succeed, steps:4, total reward:0.2000, 0.019166231155395508 sec
# Episode 453, loss:0.0137, succeed, steps:4, total reward:0.2000, 0.011294841766357422 sec
# Episode 454, loss:0.0086, succeed, steps:4, total reward:0.2000, 0.011320114135742188 sec
# Episode 455, loss:0.0048, succeed, steps:4, total reward:0.2000, 0.011296987533569336 sec
# Episode 456, loss:0.0136, succeed, steps:4, total reward:0.2000, 0.011192560195922852 sec
# Episode 457, loss:0.0086, succeed, steps:4, total reward:0.2000, 0.011285781860351562 sec
# Episode 458, loss:0.0049, succeed, steps:4, total reward:0.2000, 0.01119375228881836 sec
# Episode 459, loss:0.0086, succeed, steps:4, total reward:0.2000, 0.011430501937866211 sec
# Episode 460, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.10388422012329102 sec
# Episode 461, loss:0.0087, succeed, steps:4, total reward:0.2000, 0.08970212936401367 sec
# Episode 462, loss:0.0082, succeed, steps:4, total reward:0.2000, 0.06705641746520996 sec
# Episode 463, loss:0.0089, succeed, steps:4, total reward:0.2000, 0.053470611572265625 sec
# Episode 464, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.04600691795349121 sec
# Episode 465, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.042284488677978516 sec
# Episode 466, loss:0.0046, succeed, steps:4, total reward:0.2000, 0.03900456428527832 sec
# Episode 467, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.03609347343444824 sec
# Episode 468, loss:0.0047, succeed, steps:4, total reward:0.2000, 0.033373355865478516 sec
# Episode 469, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.030731678009033203 sec
# Episode 470, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.014618873596191406 sec
# Episode 471, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011689186096191406 sec
# Episode 472, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011650323867797852 sec
# Episode 473, loss:0.0045, succeed, steps:4, total reward:0.2000, 0.018033742904663086 sec
# Episode 474, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01828908920288086 sec
# Episode 475, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01804184913635254 sec
# Episode 476, loss:0.0046, succeed, steps:4, total reward:0.2000, 0.017474651336669922 sec
# Episode 477, loss:0.0085, succeed, steps:4, total reward:0.2000, 0.018233299255371094 sec
# Episode 478, loss:0.0084, succeed, steps:4, total reward:0.2000, 0.018310546875 sec
# Episode 479, loss:0.0130, succeed, steps:4, total reward:0.2000, 0.018341779708862305 sec
# Episode 480, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01860523223876953 sec
# Episode 481, loss:0.0082, succeed, steps:4, total reward:0.2000, 0.018517732620239258 sec
# Episode 482, loss:0.0081, succeed, steps:4, total reward:0.2000, 0.018423080444335938 sec
# Episode 483, loss:0.0130, succeed, steps:4, total reward:0.2000, 0.01831650733947754 sec
# Episode 484, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018367767333984375 sec
# Episode 485, loss:0.0084, succeed, steps:4, total reward:0.2000, 0.018268346786499023 sec
# Episode 486, loss:0.0045, succeed, steps:4, total reward:0.2000, 0.0181121826171875 sec
# Episode 487, loss:0.0045, succeed, steps:4, total reward:0.2000, 0.018205881118774414 sec
# Episode 488, loss:0.0081, succeed, steps:4, total reward:0.2000, 0.018143892288208008 sec
# Episode 489, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018195390701293945 sec
# Episode 490, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018269062042236328 sec
# Episode 491, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018364429473876953 sec
# Episode 492, loss:0.0043, succeed, steps:4, total reward:0.2000, 0.01828145980834961 sec
# Episode 493, loss:0.0126, succeed, steps:4, total reward:0.2000, 0.018152236938476562 sec
# Episode 494, loss:0.0046, succeed, steps:4, total reward:0.2000, 0.018301963806152344 sec
# Episode 495, loss:0.0044, succeed, steps:4, total reward:0.2000, 0.018213987350463867 sec
# Episode 496, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018230438232421875 sec
# Episode 497, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018465280532836914 sec
# Episode 498, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018275022506713867 sec
# Episode 499, loss:0.0044, succeed, steps:4, total reward:0.2000, 0.01837778091430664 sec
# len2 start10 Comparison 10 11 more Swap
# Episode 500, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018473386764526367 sec
# Episode 501, loss:0.0045, succeed, steps:4, total reward:0.2000, 0.018754005432128906 sec
# Episode 502, loss:0.0043, succeed, steps:4, total reward:0.2000, 0.018492937088012695 sec
# Episode 503, loss:0.0078, succeed, steps:4, total reward:0.2000, 0.018493175506591797 sec
# Episode 504, loss:0.0081, succeed, steps:4, total reward:0.2000, 0.018604278564453125 sec
# Episode 505, loss:0.0043, succeed, steps:4, total reward:0.2000, 0.01874518394470215 sec
# Episode 506, loss:0.0046, succeed, steps:4, total reward:0.2000, 0.018599987030029297 sec
# Episode 507, loss:0.0120, succeed, steps:4, total reward:0.2000, 0.01895284652709961 sec
# Episode 508, loss:0.0044, succeed, steps:4, total reward:0.2000, 0.018576383590698242 sec
# Episode 509, loss:0.0050, succeed, steps:4, total reward:0.2000, 0.018378496170043945 sec
# Episode 510, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.018407583236694336 sec
# Episode 511, loss:0.0045, succeed, steps:4, total reward:0.2000, 0.01845097541809082 sec
# Episode 512, loss:0.0121, succeed, steps:4, total reward:0.2000, 0.019965410232543945 sec
# Episode 513, loss:0.0124, succeed, steps:4, total reward:0.2000, 0.01893138885498047 sec
# Episode 514, loss:0.0078, succeed, steps:4, total reward:0.2000, 0.019214153289794922 sec
# Episode 515, loss:0.0042, succeed, steps:4, total reward:0.2000, 0.018990039825439453 sec
# Episode 516, loss:0.0125, succeed, steps:4, total reward:0.2000, 0.019316673278808594 sec
# Episode 517, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01917743682861328 sec
# Episode 518, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019079923629760742 sec
# Episode 519, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019145965576171875 sec
# Episode 520, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.019702434539794922 sec
# Episode 521, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.014878034591674805 sec
# Episode 522, loss:0.0043, succeed, steps:4, total reward:0.2000, 0.011154890060424805 sec
# Episode 523, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011221170425415039 sec
# Episode 524, loss:0.0119, succeed, steps:4, total reward:0.2000, 0.011685609817504883 sec
# Episode 525, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011465072631835938 sec
# Episode 526, loss:0.0041, succeed, steps:4, total reward:0.2000, 0.012646913528442383 sec
# Episode 527, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011188268661499023 sec
# Episode 528, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.051744937896728516 sec
# Episode 529, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.05262184143066406 sec
# ...
# Episode 10873, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010615825653076172 sec
# Episode 10874, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010662555694580078 sec
# Episode 10875, loss:0.0002, succeed, steps:4, total reward:0.2000, 0.010670661926269531 sec
# Episode 10876, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010655403137207031 sec
# Episode 10877, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010745763778686523 sec
# Episode 10878, loss:0.0001, succeed, steps:4, total reward:0.2000, 0.010880231857299805 sec
# Episode 10879, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010882139205932617 sec
# Episode 10880, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010839462280273438 sec
# Episode 10881, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010905027389526367 sec
# Episode 10882, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010895729064941406 sec
# Episode 10883, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01084280014038086 sec
# Episode 10884, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01089620590209961 sec
# Episode 10885, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010847091674804688 sec
# Episode 10886, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011017322540283203 sec
# Episode 10887, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011130094528198242 sec
# Episode 10888, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010730504989624023 sec
# Episode 10889, loss:0.0001, succeed, steps:4, total reward:0.2000, 0.010652780532836914 sec
# Episode 10890, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01070261001586914 sec
# Episode 10891, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010890007019042969 sec
# Episode 10892, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010797739028930664 sec
# Episode 10893, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010858535766601562 sec
# Episode 10894, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010837793350219727 sec
# Episode 10895, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010902166366577148 sec
# Episode 10896, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010886669158935547 sec
# Episode 10897, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01071929931640625 sec
# Episode 10898, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01065683364868164 sec
# Episode 10899, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010630369186401367 sec
# len2 start14 Comparison 14 15 more Swap
# Episode 10900, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01105809211730957 sec
# Episode 10901, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011754512786865234 sec
# Episode 10902, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010856389999389648 sec
# Episode 10903, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010693073272705078 sec
# Episode 10904, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010616540908813477 sec
# Episode 10905, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01165461540222168 sec
# Episode 10906, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011372566223144531 sec
# Episode 10907, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011125564575195312 sec
# Episode 10908, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011082887649536133 sec
# Episode 10909, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.012441158294677734 sec
# Episode 10910, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011589288711547852 sec
# Episode 10911, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010973453521728516 sec
# Episode 10912, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011227846145629883 sec
# Episode 10913, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011190176010131836 sec
# Episode 10914, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011306047439575195 sec
# Episode 10915, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011118888854980469 sec
# Episode 10916, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010900020599365234 sec
# Episode 10917, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010802745819091797 sec
# Episode 10918, loss:0.0001, succeed, steps:4, total reward:0.2000, 0.010631799697875977 sec
# Episode 10919, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010575532913208008 sec
# Episode 10920, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010658740997314453 sec
# Episode 10921, loss:0.0001, succeed, steps:4, total reward:0.2000, 0.010584354400634766 sec
# Episode 10922, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010586977005004883 sec
# Episode 10923, loss:0.0002, succeed, steps:4, total reward:0.2000, 0.011073112487792969 sec
# Episode 10924, loss:0.0001, succeed, steps:4, total reward:0.2000, 0.010753631591796875 sec
# Episode 10925, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01056218147277832 sec
# Episode 10926, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010596513748168945 sec
# Episode 10927, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010565996170043945 sec
# Episode 10928, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010594367980957031 sec
# Episode 10929, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010612010955810547 sec
# Episode 10930, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010653495788574219 sec
# Episode 10931, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010580778121948242 sec
# Episode 10932, loss:0.0002, succeed, steps:4, total reward:0.2000, 0.010637998580932617 sec
# Episode 10933, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01058816909790039 sec
# Episode 10934, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010657072067260742 sec
# Episode 10935, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010605812072753906 sec
# Episode 10936, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010584354400634766 sec
# Episode 10937, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01060795783996582 sec
# Episode 10938, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010631084442138672 sec
# Episode 10939, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010602951049804688 sec
# Episode 10940, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010607481002807617 sec
# Episode 10941, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010622978210449219 sec
# Episode 10942, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011044502258300781 sec
# Episode 10943, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010721445083618164 sec
# Episode 10944, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010599374771118164 sec
# Episode 10945, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010591745376586914 sec
# Episode 10946, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010586977005004883 sec
# Episode 10947, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01059269905090332 sec
# Episode 10948, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010626554489135742 sec
# Episode 10949, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010617971420288086 sec
# Episode 10950, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010608434677124023 sec
# Episode 10951, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010574102401733398 sec
# Episode 10952, loss:0.0002, succeed, steps:4, total reward:0.2000, 0.010627031326293945 sec
# Episode 10953, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010566234588623047 sec
# Episode 10954, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010578155517578125 sec
# Episode 10955, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010587930679321289 sec
# Episode 10956, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010565757751464844 sec
# Episode 10957, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010602474212646484 sec
# Episode 10958, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010599613189697266 sec
# Episode 10959, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010576486587524414 sec
# Episode 10960, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010581731796264648 sec
# Episode 10961, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011063575744628906 sec
# Episode 10962, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010697126388549805 sec
# Episode 10963, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010599613189697266 sec
# Episode 10964, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01055908203125 sec
# Episode 10965, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010608673095703125 sec
# Episode 10966, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010628223419189453 sec
# Episode 10967, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010640621185302734 sec
# Episode 10968, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010571002960205078 sec
# Episode 10969, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010664701461791992 sec
# Episode 10970, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010625839233398438 sec
# Episode 10971, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010597944259643555 sec
# Episode 10972, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010575056076049805 sec
# Episode 10973, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010642290115356445 sec
# Episode 10974, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010547876358032227 sec
# Episode 10975, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01081991195678711 sec
# Episode 10976, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010572671890258789 sec
# Episode 10977, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010563850402832031 sec
# Episode 10978, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010606765747070312 sec
# Episode 10979, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010607004165649414 sec
# Episode 10980, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01089930534362793 sec
# Episode 10981, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010733842849731445 sec
# Episode 10982, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010607004165649414 sec
# Episode 10983, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010598421096801758 sec
# Episode 10984, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010596990585327148 sec
# Episode 10985, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01060795783996582 sec
# Episode 10986, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011098146438598633 sec
# Episode 10987, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011036157608032227 sec
# Episode 10988, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010946273803710938 sec
# Episode 10989, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010982990264892578 sec
# Episode 10990, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010952949523925781 sec
# Episode 10991, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010936737060546875 sec
# Episode 10992, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011039972305297852 sec
# Episode 10993, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010937213897705078 sec
# Episode 10994, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010949134826660156 sec
# Episode 10995, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010971546173095703 sec
# Episode 10996, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010579109191894531 sec
# Episode 10997, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01060032844543457 sec
# Episode 10998, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01058340072631836 sec
# Episode 10999, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.011238336563110352 sec
# len2 start0 Comparison 0 1 more Swap
# Checkpoint saved at episode 11000 to /home/mcwave/code/autocode/datasets/rl_sort_transformer_curriculum/list2_transformer4_192_gamma07_step10_v1/ckpt_11000_1.0000_4.00.pth
# Learning rate = 0.000045
# Episode 11000, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.039319753646850586 sec
# Episode 11001, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01096200942993164 sec
# Episode 11002, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01058053970336914 sec
# Episode 11003, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010583877563476562 sec
# Episode 11004, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010601997375488281 sec
# Episode 11005, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01062321662902832 sec
# Episode 11006, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010556221008300781 sec
# Episode 11007, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010598897933959961 sec
# Episode 11008, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01059269905090332 sec
# Episode 11009, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01061391830444336 sec
# Episode 11010, loss:0.0002, succeed, steps:4, total reward:0.2000, 0.010629415512084961 sec
# Episode 11011, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010586261749267578 sec
# Episode 11012, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01057291030883789 sec
# Episode 11013, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010563373565673828 sec
# Episode 11014, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010612010955810547 sec
# Episode 11015, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010918617248535156 sec
# Episode 11016, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010772943496704102 sec
# Episode 11017, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010620355606079102 sec
# Episode 11018, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010645151138305664 sec
# Episode 11019, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010621786117553711 sec
# Episode 11020, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010584592819213867 sec
# Episode 11021, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010654211044311523 sec
# Episode 11022, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010641336441040039 sec
# Episode 11023, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01064300537109375 sec
# Episode 11024, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010573148727416992 sec
# Episode 11025, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010603189468383789 sec
# Episode 11026, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010596513748168945 sec
# Episode 11027, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010630607604980469 sec
# Episode 11028, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010567903518676758 sec
# Episode 11029, loss:0.0001, succeed, steps:4, total reward:0.2000, 0.010599374771118164 sec
# Episode 11030, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010599374771118164 sec
# Episode 11031, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010628461837768555 sec
# Episode 11032, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010575532913208008 sec
# Episode 11033, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010596036911010742 sec
# Episode 11034, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01106572151184082 sec
# Episode 11035, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010652542114257812 sec
# Episode 11036, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010592937469482422 sec
# Episode 11037, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.01062631607055664 sec
# Episode 11038, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010609865188598633 sec
# Episode 11039, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010622501373291016 sec
# Episode 11040, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010582208633422852 sec
# Episode 11041, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010574102401733398 sec
# Episode 11042, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010614871978759766 sec
# Episode 11043, loss:0.0000, succeed, steps:4, total reward:0.2000, 0.010556459426879883 sec
# KeyboardInterrupt

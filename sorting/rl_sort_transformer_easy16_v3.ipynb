# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
import math
import random

MIN_LIST_LEN = 16
MAX_LIST_LEN = 16
MAX_STEPS = 640

SUCCESS_REWARD = 0.5
STEP_REWARD = -0.3
COMPARISON_ENTROPY_MULTIPLIER = -0.00
SWAP_REWARD = 1.0
INVALID_ACTION_REWARD = -10.0
LONGTERM_GAMMA = 0.99
SHORTTERM_GAMMA = 0.7

EPS_START = 0.5
EPS_END = 0.05
EPS_DECAY = 1000
LR_SCHEDULER_GAMMA = 0.96
NUM_EPISODES = 200000
EPISODES_SAVE = 1000
OUTPUT_DIR = '/home/mcwave/code/autocode/datasets/rl_sort_transformer_easy/list16_transformer4_192_gamma07_step640_v3'

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    'less': 2,
    'equal': 3,
    'more': 4,
    '0': 5,
    '1': 6,
    '2': 7,
    '3': 8,
    '4': 9,
    '5': 10,
    '6': 11,
    '7': 12,
    '8': 13,
    '9': 14,
    '10': 15,
    '11': 16,
    '12': 17,
    '13': 18,
    '14': 19,
    '15': 20,
    'len1': 21,
    'len2': 22,
    'len3': 23,
    'len4': 24,
    'len5': 25,
    'len6': 26,
    'len7': 27,
    'len8': 28,
    'len9': 29,
    'len10': 30,
    'len11': 31,
    'len12': 32,
    'len13': 33,
    'len14': 34,
    'len15': 35,
    'len16': 36,
}
inv_vocab = {v: k for k, v in vocab.items()}

def compute_entropy(N, alpha=1):
    K = 2**N
    values = np.arange(K)
    unnormalized_probs = np.exp(-alpha * values)
    Z = unnormalized_probs.sum()
    probs = unnormalized_probs / Z
    return values, -np.log2(probs)

_, int_entropy = compute_entropy(4)

def get_entropy_of_integer(x):
    x = min(15, abs(x))
    return int_entropy[x]

def compute_min_delta_entropy(comparisons):
    # Initialize the result list to store minDelta values
    min_delta = None

    # Iterate through each pair in the comparisons list
    i = len(comparisons) - 1
    xi, yi = comparisons[i]
    if i == 0:
        # For i = 0, use the first case directly
        min_delta = (xi, min(yi, yi - xi), 0)
    else:
        # For i > 0, compute all possible options and select the minimal one
        options = []

        # Simple Entropy
        simple_entropy = (xi, min(yi, yi - xi), 0)
        options.append(simple_entropy)

        # First Delta Entropy
        xi_prev, yi_prev = comparisons[i - 1]
        first_delta_entropy = (xi - xi_prev, yi - yi_prev, 0)
        options.append(first_delta_entropy)

        # Second Delta Entropy (only valid for i > 1)
        if i > 1:
            xi_prev2, yi_prev2 = comparisons[i - 2]
            second_delta_entropy = (
                (xi - xi_prev) - (xi_prev - xi_prev2),
                (yi - yi_prev) - (yi_prev - yi_prev2),
                0,
            )
            options.append(second_delta_entropy)

        # Arbitrary Position Entropy (only valid for i > 1)
        for j in range(i):
            xj, yj = comparisons[j]
            arbitrary_position_entropy = (
                xi - xj,
                yi - yj,
                min(j, i - j),
            )
            options.append(arbitrary_position_entropy)

        # Find the option with the minimal sum
        min_delta = min(options, key=lambda t: sum([get_entropy_of_integer(x) for x in t]))

    entropy = sum([get_entropy_of_integer(x) for x in min_delta])
    if len(comparisons) == 1:
        return 3 * entropy
    else:
        return entropy

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.list = [random.randint(1, 100) for _ in range(self.length)]
        while self.list == sorted(self.list):
            self.list = [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        initial_token = 'len{}'.format(self.length)
        return vocab[initial_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_list_len(self):
        return len(self.list)

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 >= self.length or index2 >= self.length or index1 < 0 or index2 < 0:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = STEP_REWARD
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = STEP_REWARD * 2
            else:
                response_token = vocab['more']
                reward = STEP_REWARD
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = SUCCESS_REWARD
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = SWAP_REWARD
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -SWAP_REWARD
            else:
                reward = STEP_REWARD
            self.indices = None
        else:
            reward = INVALID_ACTION_REWARD
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()
# Out:
# Using device: cuda

# %%
# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=640):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=192, nhead=8, num_layers=4):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])


def save_checkpoint(model, optimizer, episode, folder, filename):
    """
    Save the model and optimizer state to the designated filepath.

    Args:
        model (nn.Module): The model to save.
        optimizer (torch.optim.Optimizer): The optimizer whose state to save.
        episode (int): The current episode number.
        filepath (str): The path where to save the checkpoint.
    """
    filepath = os.path.join(folder, filename)
    # Ensure the directory exists
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    # Save the checkpoint
    torch.save({
        'episode': episode,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, filepath)
    print(f"Checkpoint saved at episode {episode} to {filepath}")

def load_checkpoint(filepath, model, optimizer):
    """
    Load the model and optimizer state from the designated filepath.

    Args:
        filepath (str): The path from where to load the checkpoint.
        model (nn.Module): The model into which to load the state_dict.
        optimizer (torch.optim.Optimizer): The optimizer into which to load the state.

    Returns:
        int: The episode number to resume from.
    """
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        episode = checkpoint['episode']
        print(f"Checkpoint loaded from {filepath}, resuming from episode {episode}")
        return episode
    else:
        print(f"No checkpoint found at {filepath}, starting from scratch.")
        return 0

# %%
def compute_bellman_returns(raw_rewards, gamma):
    bellman_returns = []
    R = 0
    for r in raw_rewards[::-1]:
        R = r + gamma * R
        bellman_returns.insert(0, R)
    return bellman_returns

# Training Loop
def train(verbose=False):
    # Removed torch.autograd.set_detect_anomaly(True)
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=2.3e-5)  # Reduced learning rate
    scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=LR_SCHEDULER_GAMMA)
    
    # Optionally, load a checkpoint
    checkpoint_path = os.path.join(OUTPUT_DIR, "ckpt_36000_0.6820_426.26.pth")
    load_checkpoint(checkpoint_path, model, optimizer)

    episode_cnt = 0
    total_reward = 0.0
    num_successes = 0
    success_step_cnts = []
    
    for episode in range(NUM_EPISODES):
        t1 = time.time()
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, current_list = env.reset()
        input_tokens = [initial_token_id]
        log_probs = []
        rewards = []
        comparisons = []
        steps = 0
        
        state = 'expect_action'
        done = False
        success = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
                print(comparisons)
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
                output = model(input_seq)  # (seq_len, batch_size, vocab_size)
                # Get logits for the last token
                logits = output[-1, 0, :]  # (vocab_size)

                # Check for NaNs in logits
                if torch.isnan(logits).any():
                    print(f"Episode {episode}, NaNs in logits before masking.")
                    break

                # Get valid tokens based on state
                def get_valid_tokens(state):
                    action_tokens = [vocab['Comparison'], vocab['Swap']]
                    index_tokens = [vocab[str(i)] for i in range(env.length)]
                    if state == 'expect_action':
                        return action_tokens
                    elif state == 'expect_index1':
                        return index_tokens[:-1]
                    elif state == 'expect_index2':
                        return [x for x in index_tokens if x > input_tokens[-1]]
                    else:
                        # Handle unexpected states by defaulting to expect_action
                        return action_tokens

                valid_token_ids = get_valid_tokens(state)

                # Ensure valid_token_ids are within the vocab range
                if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                    print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                    break

                # Mask invalid tokens
                mask_value = -1e9  # Use a large negative value instead of -inf
                mask = torch.full_like(logits, mask_value).to(device)
                mask[valid_token_ids] = 0
                masked_logits = logits + mask

                # Sample action. Have some chance to randomly pick a valid action.
                eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
                if random.random() < eps_threshold:
                    masked_logits = masked_logits / 4

                # Check for NaNs in masked_logits
                if torch.isnan(masked_logits).any():
                    print(f"Episode {episode}, NaNs in masked_logits after masking.")
                    break

                # Compute probabilities
                probs = F.softmax(masked_logits, dim=0)

                # Check for NaNs in probs
                if torch.isnan(probs).any():
                    print(f"Episode {episode}, NaNs in probs after softmax.")
                    break

                try:
                    m = torch.distributions.Categorical(probs)
                    action_token = m.sample()
                    log_prob = m.log_prob(action_token)
                except ValueError as e:
                    print(f"Episode {episode}, error in sampling action: {e}")
                    break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            reward = 0.0
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        reward = INVALID_ACTION_REWARD
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    steps += 1
                    if done and reward == SUCCESS_REWARD:
                        success = True
                        if episode % 100 == 0:
                            print(decode(input_tokens, inv_vocab))
                    if verbose:
                        print("Reward:", reward)
                    state = 'expect_action'
                else:
                    reward = INVALID_ACTION_REWARD
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                comparisons.append((int(inv_vocab[index1_token.item()]), 
                                    int(inv_vocab[index2_token.item()])))
                response_token, reward, done, current_list = env.step(action_tokens)
                steps += 1
                if done and reward == SUCCESS_REWARD:
                    success = True
                    if episode % 100 == 0:
                        print(1, decode(input_tokens, inv_vocab))
                else:
                    reward += COMPARISON_ENTROPY_MULTIPLIER * compute_min_delta_entropy(comparisons)
                if verbose:
                    print("Reward:", reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                reward = INVALID_ACTION_REWARD
                done = True

            rewards.append(reward)
        #
        # Post processing of each episode
        success_rewards = [0.0] * len(rewards)
        if success: 
            num_successes += 1
            success_rewards[-1] = SUCCESS_REWARD
            success_step_cnts.append(steps)
        #
        assert len(log_probs) == len(rewards), "log_probs and returns have different sizes!"

        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns and loss within autocast
        with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
            # Compute returns
            returns1 = compute_bellman_returns(rewards, SHORTTERM_GAMMA)
            returns2 = compute_bellman_returns(success_rewards, LONGTERM_GAMMA)
            returns = torch.tensor(np.array(returns1) + np.array(returns2)).to(device)

            # Check for NaNs in returns
            if torch.isnan(returns).any():
                print(f"Episode {episode}, NaNs in returns.")
                continue

            # Compute loss
            loss = 0
            for log_prob, R in zip(log_probs, returns):
                loss -= log_prob * R

            # Check for NaNs in loss
            if torch.isnan(loss):
                print(f"Episode {episode}, NaN in loss.")
                continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        episode_cnt += 1
        total_reward += sum(rewards)
        t2 = time.time()
        if episode % 1 == 0:
            print(f"Episode {episode}, loss:{loss.item():.4f}, {'succeed' if success else 'fail'}, steps:{steps}, total reward:{sum(rewards):.4f}, {t2-t1} sec")
            
        # Save checkpoint
        if episode > 0 and episode % EPISODES_SAVE == 0:
            avg_reward = total_reward / episode_cnt
            #assert len(success_step_cnts) == num_successes
            success_rate = num_successes / episode_cnt
            avg_steps = sum(success_step_cnts) / len(success_step_cnts)
            episode_cnt = 0
            total_reward = 0.0
            num_successes = 0
            total_steps = 0
            save_checkpoint(model, optimizer, episode, OUTPUT_DIR, f"ckpt_{episode}_{success_rate:.4f}_{avg_steps:.2f}.pth")
            #
            # Reduce the lr
            scheduler.step()
            # Optionally, log the learning rate
            current_lr = scheduler.get_last_lr()[0]
            print(f"Learning rate = {current_lr:.6f}")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Checkpoint loaded from /home/mcwave/code/autocode/datasets/rl_sort_transformer_easy/list16_transformer4_192_gamma07_step640_v3/ckpt_36000_0.6820_426.26.pth, resuming from episode 36000
# Episode 0, loss:-12.1249, fail, steps:205, total reward:14.7000, 2.1134471893310547 sec
# Episode 1, loss:-18.4284, fail, steps:205, total reward:16.5000, 1.5575354099273682 sec
# Episode 2, loss:-12.8559, fail, steps:201, total reward:11.2000, 1.6232504844665527 sec
# Episode 3, loss:-3.7204, fail, steps:205, total reward:17.2000, 1.660752534866333 sec
# Episode 4, loss:-37.2764, fail, steps:199, total reward:2.5000, 1.7681288719177246 sec
# Episode 5, loss:2.4569, succeed, steps:176, total reward:5.5000, 1.5079686641693115 sec
# Episode 6, loss:-13.2953, succeed, steps:175, total reward:-7.5000, 1.566814661026001 sec
# Episode 7, loss:7.1159, succeed, steps:199, total reward:9.1000, 1.7064220905303955 sec
# Episode 8, loss:-33.6386, fail, steps:192, total reward:-1.7000, 1.6696302890777588 sec
# Episode 9, loss:-39.7963, fail, steps:194, total reward:-2.3000, 1.7538084983825684 sec
# Episode 10, loss:-15.2459, fail, steps:204, total reward:14.3000, 1.727330207824707 sec
# Episode 11, loss:-21.1316, fail, steps:205, total reward:15.9000, 1.6846001148223877 sec
# Episode 12, loss:-17.5415, fail, steps:207, total reward:19.8000, 1.7278027534484863 sec
# Episode 13, loss:-16.8002, succeed, steps:191, total reward:-1.2000, 1.742077350616455 sec
# Episode 14, loss:-7.2450, succeed, steps:190, total reward:4.7000, 1.6598553657531738 sec
# Episode 15, loss:-1.3185, succeed, steps:187, total reward:5.9000, 1.6067442893981934 sec
# Episode 16, loss:18.1844, succeed, steps:148, total reward:17.9000, 1.1536381244659424 sec
# Episode 17, loss:-35.4879, fail, steps:196, total reward:0.3000, 1.7493677139282227 sec
# Episode 18, loss:1.4713, succeed, steps:188, total reward:-1.0000, 1.6889491081237793 sec
# Episode 19, loss:14.2960, succeed, steps:191, total reward:14.7000, 1.6076555252075195 sec
# Episode 20, loss:-19.1466, fail, steps:202, total reward:10.8000, 1.7353403568267822 sec
# Episode 21, loss:5.1676, fail, steps:208, total reward:20.2000, 1.7219789028167725 sec
# Episode 22, loss:20.7083, succeed, steps:194, total reward:23.9000, 1.643646240234375 sec
# Episode 23, loss:-19.8260, fail, steps:199, total reward:8.0000, 1.7396326065063477 sec
# Episode 24, loss:-28.3477, fail, steps:205, total reward:14.7000, 1.7376174926757812 sec
# Episode 25, loss:-12.6498, fail, steps:204, total reward:15.5000, 1.7108924388885498 sec
# Episode 26, loss:15.7557, succeed, steps:145, total reward:17.8000, 1.1855502128601074 sec
# Episode 27, loss:4.1846, succeed, steps:153, total reward:8.6000, 1.2877371311187744 sec
# Episode 28, loss:-27.2782, fail, steps:202, total reward:12.2000, 1.7684884071350098 sec
# Episode 29, loss:-14.5985, fail, steps:208, total reward:21.5000, 1.7229700088500977 sec
# Episode 30, loss:1.1935, fail, steps:210, total reward:23.2000, 1.7106177806854248 sec
# Episode 31, loss:-6.6816, fail, steps:203, total reward:13.3000, 1.7548673152923584 sec
# Episode 32, loss:-14.7015, fail, steps:207, total reward:19.8000, 1.6963460445404053 sec
# Episode 33, loss:-23.3820, fail, steps:205, total reward:16.5000, 1.685100793838501 sec
# Episode 34, loss:-8.2212, fail, steps:201, total reward:11.2000, 1.7285208702087402 sec
# Episode 35, loss:2.6189, succeed, steps:177, total reward:-1.8000, 1.6126017570495605 sec
# Episode 36, loss:-10.8009, fail, steps:208, total reward:20.2000, 1.768843412399292 sec
# Episode 37, loss:15.2348, succeed, steps:145, total reward:13.2000, 1.2190399169921875 sec
# Episode 38, loss:-26.0287, fail, steps:195, total reward:2.0000, 1.8262989521026611 sec
# Episode 39, loss:-32.3971, fail, steps:195, total reward:2.6000, 1.6848223209381104 sec
# Episode 40, loss:-25.6100, fail, steps:195, total reward:1.4000, 1.7289495468139648 sec
# Episode 41, loss:-7.1619, fail, steps:220, total reward:36.5000, 1.7341670989990234 sec
# Episode 42, loss:-44.2624, fail, steps:182, total reward:-17.1000, 1.6882438659667969 sec
# Episode 43, loss:10.9837, fail, steps:211, total reward:24.5000, 1.7117295265197754 sec
# Episode 44, loss:-3.0752, fail, steps:212, total reward:26.5000, 1.768996238708496 sec
# Episode 45, loss:-14.0011, fail, steps:207, total reward:18.9000, 1.7198195457458496 sec
# Episode 46, loss:-23.0739, fail, steps:207, total reward:17.7000, 1.7246613502502441 sec
# Episode 47, loss:14.5755, succeed, steps:134, total reward:8.8000, 1.1545979976654053 sec
# Episode 48, loss:14.9096, succeed, steps:198, total reward:24.1000, 1.6239943504333496 sec
# Episode 49, loss:-44.5502, fail, steps:187, total reward:-13.4000, 1.6712470054626465 sec
# Episode 50, loss:-10.3169, fail, steps:207, total reward:18.0000, 1.7200376987457275 sec
# Episode 51, loss:-34.2786, fail, steps:198, total reward:5.4000, 1.691706657409668 sec
# Episode 52, loss:-1.9702, succeed, steps:168, total reward:5.6000, 1.5347425937652588 sec
# Episode 53, loss:-25.2115, fail, steps:199, total reward:6.8000, 1.8038787841796875 sec
# Episode 54, loss:13.0650, succeed, steps:152, total reward:18.9000, 1.2497451305389404 sec
# Episode 55, loss:-14.0989, fail, steps:205, total reward:14.4000, 1.8324787616729736 sec
# Episode 56, loss:-2.6020, succeed, steps:133, total reward:-2.7000, 1.209136724472046 sec
# Episode 57, loss:-20.5620, fail, steps:203, total reward:14.5000, 1.9360110759735107 sec
# Episode 58, loss:-14.1256, fail, steps:200, total reward:9.0000, 1.7044246196746826 sec
# Episode 59, loss:-30.8570, fail, steps:195, total reward:1.7000, 1.7005832195281982 sec
# Episode 60, loss:11.7394, succeed, steps:174, total reward:16.9000, 1.435455560684204 sec
# Episode 61, loss:-19.7193, fail, steps:202, total reward:12.2000, 1.8833646774291992 sec
# Episode 62, loss:-5.3750, succeed, steps:152, total reward:1.8000, 1.321695327758789 sec
# Episode 63, loss:4.1659, succeed, steps:162, total reward:13.3000, 1.3024559020996094 sec
# Episode 64, loss:-31.1371, fail, steps:202, total reward:12.0000, 1.7445316314697266 sec
# Episode 65, loss:6.9504, succeed, steps:186, total reward:9.1000, 1.5945756435394287 sec
# Episode 66, loss:12.7051, succeed, steps:183, total reward:19.7000, 1.556692361831665 sec
# Episode 67, loss:4.0170, succeed, steps:161, total reward:10.5000, 1.2779686450958252 sec
# Episode 68, loss:12.0567, succeed, steps:180, total reward:18.7000, 1.3282365798950195 sec
# Episode 69, loss:13.4048, succeed, steps:163, total reward:18.2000, 1.1962711811065674 sec
# Episode 70, loss:2.1715, succeed, steps:193, total reward:7.9000, 1.6584467887878418 sec
# Episode 71, loss:6.7766, succeed, steps:116, total reward:1.6000, 0.978980541229248 sec
# Episode 72, loss:15.2958, succeed, steps:150, total reward:27.7000, 1.1061604022979736 sec
# Episode 73, loss:-1.0321, succeed, steps:197, total reward:3.3000, 1.823697566986084 sec
# Episode 74, loss:10.2158, succeed, steps:191, total reward:9.8000, 1.607872486114502 sec
# Episode 75, loss:-9.1789, succeed, steps:188, total reward:-8.7000, 1.6810712814331055 sec
# Episode 76, loss:4.6646, succeed, steps:150, total reward:8.9000, 1.3000755310058594 sec
# Episode 77, loss:-10.3340, fail, steps:207, total reward:19.8000, 1.891219139099121 sec
# Episode 78, loss:2.7501, fail, steps:212, total reward:27.4000, 1.6954731941223145 sec
# Episode 79, loss:10.0154, succeed, steps:182, total reward:9.9000, 1.5420870780944824 sec
# Episode 80, loss:-37.6359, fail, steps:191, total reward:-9.0000, 1.7570867538452148 sec
# Episode 81, loss:16.2223, succeed, steps:155, total reward:19.1000, 1.2624757289886475 sec
# Episode 82, loss:-13.0431, fail, steps:209, total reward:22.8000, 1.8979616165161133 sec
# Episode 83, loss:-24.8451, fail, steps:202, total reward:10.7000, 1.6953098773956299 sec
# Episode 84, loss:-3.6680, fail, steps:211, total reward:26.4000, 1.7477898597717285 sec
# Episode 85, loss:13.7520, succeed, steps:179, total reward:21.6000, 1.4662246704101562 sec
# Episode 86, loss:-22.3873, fail, steps:202, total reward:12.2000, 1.8394768238067627 sec
# Episode 87, loss:3.8796, succeed, steps:194, total reward:13.3000, 1.6545546054840088 sec
# Episode 88, loss:10.5755, succeed, steps:208, total reward:27.2000, 1.6926286220550537 sec
# Episode 89, loss:-17.6698, fail, steps:202, total reward:12.6000, 1.7223477363586426 sec
# Episode 90, loss:-0.8651, succeed, steps:146, total reward:-1.9000, 1.3780906200408936 sec
# Episode 91, loss:-20.0591, fail, steps:205, total reward:14.4000, 1.8467352390289307 sec
# Episode 92, loss:12.1040, succeed, steps:127, total reward:7.6000, 1.1219196319580078 sec
# Episode 93, loss:4.9097, succeed, steps:107, total reward:2.5000, 0.8583855628967285 sec
# Episode 94, loss:20.5262, succeed, steps:195, total reward:31.4000, 1.4312350749969482 sec
# Episode 95, loss:-9.6437, fail, steps:207, total reward:19.5000, 1.7678391933441162 sec
# Episode 96, loss:-32.9448, fail, steps:198, total reward:4.5000, 1.6864008903503418 sec
# Episode 97, loss:-21.0945, fail, steps:202, total reward:10.7000, 1.7238752841949463 sec
# Episode 98, loss:1.7919, succeed, steps:170, total reward:9.6000, 1.4617316722869873 sec
# Episode 99, loss:-18.0128, fail, steps:205, total reward:16.0000, 1.8613512516021729 sec
# Episode 100, loss:-18.5110, fail, steps:205, total reward:16.0000, 1.6974968910217285 sec
# Episode 101, loss:-21.6055, fail, steps:206, total reward:17.3000, 1.7457289695739746 sec
# Episode 102, loss:7.7647, fail, steps:209, total reward:22.2000, 1.723792314529419 sec
# Episode 103, loss:-6.6047, fail, steps:205, total reward:16.6000, 1.7235782146453857 sec
# Episode 104, loss:-25.5389, fail, steps:196, total reward:3.6000, 1.771385669708252 sec
# Episode 105, loss:-3.2186, succeed, steps:187, total reward:3.7000, 1.6391932964324951 sec
# Episode 106, loss:-16.9872, fail, steps:197, total reward:2.3000, 1.7666399478912354 sec
# Episode 107, loss:-24.9704, fail, steps:205, total reward:17.5000, 1.760216236114502 sec
# Episode 108, loss:-39.7817, fail, steps:198, total reward:4.8000, 1.7665600776672363 sec
# Episode 109, loss:7.3235, succeed, steps:151, total reward:16.8000, 1.2192280292510986 sec
# Episode 110, loss:12.5562, succeed, steps:189, total reward:21.8000, 1.5144095420837402 sec
# Episode 111, loss:-12.8481, fail, steps:202, total reward:13.5000, 1.733628273010254 sec
# Episode 112, loss:-0.8083, succeed, steps:172, total reward:7.1000, 1.4692747592926025 sec
# Episode 113, loss:10.3077, succeed, steps:176, total reward:13.0000, 1.445807695388794 sec
# Episode 114, loss:-20.9654, fail, steps:196, total reward:3.4000, 1.713240623474121 sec
# Episode 115, loss:-26.6235, fail, steps:196, total reward:2.1000, 1.6771259307861328 sec
# Episode 116, loss:0.8620, succeed, steps:193, total reward:2.8000, 1.6592090129852295 sec
# Episode 117, loss:9.9669, succeed, steps:205, total reward:22.5000, 1.7443809509277344 sec
# Episode 118, loss:15.6431, succeed, steps:185, total reward:27.2000, 1.4708116054534912 sec
# Episode 119, loss:-22.2033, fail, steps:193, total reward:-0.3000, 1.7718925476074219 sec
# Episode 120, loss:-7.5927, fail, steps:208, total reward:21.2000, 1.7103281021118164 sec
# Episode 121, loss:-28.6608, fail, steps:196, total reward:2.8000, 1.7675135135650635 sec
# Episode 122, loss:12.7869, succeed, steps:183, total reward:24.3000, 1.5029103755950928 sec
# Episode 123, loss:-6.5111, succeed, steps:191, total reward:1.4000, 1.711914300918579 sec
# Episode 124, loss:-33.0056, fail, steps:192, total reward:-4.1000, 1.752819538116455 sec
# Episode 125, loss:9.8790, succeed, steps:173, total reward:17.8000, 1.4965369701385498 sec
# Episode 126, loss:-0.3696, succeed, steps:172, total reward:8.2000, 1.396453619003296 sec
# Episode 127, loss:-15.7248, fail, steps:208, total reward:20.8000, 1.7580506801605225 sec
# Episode 128, loss:-26.3272, fail, steps:204, total reward:12.8000, 1.7094151973724365 sec
# Episode 129, loss:-19.1602, fail, steps:205, total reward:17.2000, 1.782668113708496 sec
# Episode 130, loss:-16.3108, fail, steps:200, total reward:8.4000, 1.7275376319885254 sec
# Episode 131, loss:-26.8769, fail, steps:204, total reward:14.0000, 1.7276437282562256 sec
# Episode 132, loss:10.9733, succeed, steps:155, total reward:12.9000, 1.3056507110595703 sec
# Episode 133, loss:9.0486, succeed, steps:172, total reward:21.4000, 1.3406693935394287 sec
# Episode 134, loss:-37.7319, fail, steps:195, total reward:-1.3000, 1.7933735847473145 sec
# Episode 135, loss:7.8011, succeed, steps:158, total reward:14.9000, 1.3202533721923828 sec
# Episode 136, loss:-12.7740, succeed, steps:172, total reward:-8.1000, 1.5067334175109863 sec
# Episode 137, loss:20.4794, succeed, steps:166, total reward:18.4000, 1.2400867938995361 sec
# Episode 138, loss:-14.1089, fail, steps:202, total reward:11.6000, 1.759657382965088 sec
# Episode 139, loss:10.9371, succeed, steps:202, total reward:19.7000, 1.7173972129821777 sec
# Episode 140, loss:1.9945, succeed, steps:163, total reward:10.8000, 1.4004192352294922 sec
# Episode 141, loss:-14.5122, fail, steps:202, total reward:11.0000, 1.8065297603607178 sec
# Episode 142, loss:-21.4337, fail, steps:197, total reward:3.5000, 1.7173984050750732 sec
# Episode 143, loss:-23.1789, fail, steps:199, total reward:5.8000, 1.780116319656372 sec
# Episode 144, loss:-24.4972, fail, steps:197, total reward:3.8000, 1.7366056442260742 sec
# Episode 145, loss:-9.8474, fail, steps:205, total reward:15.9000, 1.7238879203796387 sec
# Episode 146, loss:-16.8156, fail, steps:202, total reward:12.3000, 1.723132610321045 sec
# Episode 147, loss:-12.7930, fail, steps:210, total reward:23.2000, 1.7712428569793701 sec
# Episode 148, loss:1.2442, succeed, steps:168, total reward:13.8000, 1.4215373992919922 sec
# Episode 149, loss:17.8463, succeed, steps:153, total reward:20.9000, 1.1664917469024658 sec
# Episode 150, loss:14.2640, succeed, steps:163, total reward:17.9000, 1.1992595195770264 sec
# Episode 151, loss:-85.6390, fail, steps:2, total reward:-9.3000, 0.06852865219116211 sec
# Episode 152, loss:9.6057, succeed, steps:197, total reward:21.1000, 1.376837968826294 sec
# Episode 153, loss:9.2931, succeed, steps:187, total reward:22.7000, 1.4499013423919678 sec
# Episode 154, loss:13.4292, succeed, steps:176, total reward:20.4000, 1.2758536338806152 sec
# Episode 155, loss:-22.6384, fail, steps:201, total reward:11.2000, 1.694917917251587 sec
# Episode 156, loss:-21.9885, fail, steps:195, total reward:-0.1000, 1.6654198169708252 sec
# Episode 157, loss:-16.0657, fail, steps:211, total reward:24.0000, 1.7479398250579834 sec
# Episode 158, loss:-17.9992, fail, steps:205, total reward:15.1000, 1.7086138725280762 sec
# Episode 159, loss:8.5920, succeed, steps:144, total reward:9.1000, 1.222188949584961 sec
# Episode 160, loss:7.7276, succeed, steps:191, total reward:16.3000, 1.523484230041504 sec
# Episode 161, loss:14.5484, succeed, steps:190, total reward:16.3000, 1.536832332611084 sec
# Episode 162, loss:-32.9855, fail, steps:199, total reward:6.7000, 1.8332436084747314 sec
# Episode 163, loss:-44.2474, fail, steps:193, total reward:-2.1000, 1.7044658660888672 sec
# Episode 164, loss:4.2325, succeed, steps:177, total reward:6.6000, 1.5220322608947754 sec
# Episode 165, loss:8.9725, succeed, steps:162, total reward:3.1000, 1.334122896194458 sec
# Episode 166, loss:-14.6779, fail, steps:207, total reward:18.9000, 1.745368480682373 sec
# Episode 167, loss:14.7237, succeed, steps:167, total reward:28.7000, 1.3910636901855469 sec
# Episode 168, loss:12.1721, succeed, steps:101, total reward:8.2000, 0.817086935043335 sec
# Episode 169, loss:-50.6943, fail, steps:187, total reward:-16.2000, 1.7288570404052734 sec
# Episode 170, loss:6.0011, succeed, steps:190, total reward:11.4000, 1.5372061729431152 sec
# Episode 171, loss:-10.3386, fail, steps:205, total reward:17.8000, 1.7690763473510742 sec
# Episode 172, loss:-18.5407, fail, steps:203, total reward:14.5000, 1.6786613464355469 sec
# Episode 173, loss:-2.2979, succeed, steps:144, total reward:0.5000, 1.289048671722412 sec
# Episode 174, loss:10.8127, succeed, steps:151, total reward:11.4000, 1.2079384326934814 sec
# Episode 175, loss:21.6697, succeed, steps:164, total reward:17.9000, 1.1986751556396484 sec
# Episode 176, loss:-7.7610, succeed, steps:164, total reward:9.5000, 1.2297887802124023 sec
# Episode 177, loss:-11.0748, fail, steps:209, total reward:21.9000, 1.7919158935546875 sec
# Episode 178, loss:20.6041, succeed, steps:173, total reward:30.8000, 1.3613808155059814 sec
# Episode 179, loss:12.6642, succeed, steps:207, total reward:28.4000, 1.7542095184326172 sec
# Episode 180, loss:7.3331, succeed, steps:182, total reward:17.7000, 1.5096256732940674 sec
# Episode 181, loss:2.5503, succeed, steps:192, total reward:6.9000, 1.7308392524719238 sec
# Episode 182, loss:-22.7044, fail, steps:200, total reward:9.0000, 1.7265114784240723 sec
# Episode 183, loss:-3.3740, succeed, steps:149, total reward:0.3000, 1.3452038764953613 sec
# Episode 184, loss:-30.1162, fail, steps:195, total reward:-2.5000, 1.825821876525879 sec
# Episode 185, loss:25.6338, succeed, steps:190, total reward:29.3000, 1.5035817623138428 sec
# Episode 186, loss:19.5945, succeed, steps:193, total reward:23.5000, 1.6486856937408447 sec
# Episode 187, loss:11.9805, succeed, steps:192, total reward:19.4000, 1.6038494110107422 sec
# Episode 188, loss:16.2482, succeed, steps:203, total reward:20.9000, 1.704829216003418 sec
# Episode 189, loss:10.3301, succeed, steps:186, total reward:13.6000, 1.5543601512908936 sec
# Episode 190, loss:10.0821, succeed, steps:187, total reward:16.1000, 1.5101289749145508 sec
# Episode 191, loss:-14.6805, fail, steps:203, total reward:14.5000, 1.8178822994232178 sec
# Episode 192, loss:-11.8153, fail, steps:204, total reward:15.5000, 1.6908783912658691 sec
# Episode 193, loss:-42.6084, fail, steps:181, total reward:-20.3000, 1.6916546821594238 sec
# Episode 194, loss:-29.0600, fail, steps:196, total reward:3.1000, 1.698265790939331 sec
# Episode 195, loss:15.6616, succeed, steps:204, total reward:29.3000, 1.6844003200531006 sec
# Episode 196, loss:22.0578, succeed, steps:115, total reward:14.4000, 0.912614107131958 sec
# Episode 197, loss:7.7850, succeed, steps:188, total reward:15.1000, 1.4204418659210205 sec
# Episode 198, loss:-22.2093, fail, steps:202, total reward:12.0000, 1.70127272605896 sec
# Episode 199, loss:-0.8299, succeed, steps:196, total reward:8.4000, 1.6781947612762451 sec
# len16 Comparison 9 10 less Comparison 1 2 more Swap Comparison 8 9 more Swap Comparison 7 11 more Swap Comparison 6 7 more Swap Comparison 5 6 more Swap Comparison 4 5 more Swap Comparison 0 1 less Comparison 3 4 more Swap Comparison 0 1 less Comparison 7 8 more Swap Comparison 2 3 more Swap Comparison 10 11 more Swap Comparison 11 12 more Swap Comparison 12 13 more Swap Comparison 13 14 less Comparison 13 14 less Comparison 14 15 more Swap Comparison 9 10 more Swap Comparison 8 9 more Swap Comparison 6 7 less Comparison 5 6 more Swap Comparison 4 5 less Comparison 3 4 more Swap Comparison 2 6 less Comparison 10 11 more Swap Comparison 3 4 less Comparison 12 13 less Comparison 1 2 more Swap Comparison 13 14 more Swap Comparison 9 10 more Swap Comparison 8 9 more Swap Comparison 7 8 more Swap Comparison 6 7 more Swap Comparison 2 3 less Comparison 5 6 equal Comparison 4 5 more Swap Comparison 10 11 less Comparison 11 12 more Swap Comparison 14 15 less Comparison 3 4 less Comparison 8 9 less Comparison 12 13 more Swap Comparison 9 10 less Comparison 7 8 more Swap Comparison 5 6 more Swap Comparison 6 7 more Swap Comparison 4 5 equal Comparison 3 4 less Comparison 10 11 more Swap Comparison 9 10 less Comparison 8 9 more Swap Comparison 11 12 more Swap Comparison 7 8 more Swap Comparison 13 14 more Swap Comparison 6 7 less Comparison 9 10 more Swap Comparison 5 6 less Comparison 11 12 less Comparison 8 9 more Swap Comparison 7 8 less Comparison 4 5 equal Comparison 12 13 more Swap Comparison 10 11 more Swap Comparison 2 3 less Comparison 9 10 more Swap Comparison 7 8 less Comparison 6 7 less Comparison 8 9 more Swap Comparison 5 6 less Comparison 4 11 less Comparison 5 6 less Comparison 9 10 less Comparison 11 12 more Swap Comparison 7 8 more Swap Comparison 12 13 less Comparison 13 14 less Comparison 9 10 less Comparison 2 3 less Comparison 1 2 less Comparison 7 8 less Comparison 14 15 more Swap Comparison 6 7 more Swap Comparison 4 5 equal Comparison 5 6 more Swap Comparison 3 4 less Comparison 0 1 less Comparison 9 10 less Comparison 10 13 more Swap Comparison 10 11 more Swap Comparison 8 9 less Comparison 11 12 more Swap Comparison 13 14 more Swap Comparison 8 9 less Comparison 7 8 less Comparison 6 7 less Comparison 1 2 less Comparison 5 6 less Comparison 4 5 more Swap Comparison 3 4 less Comparison 11 12 less Comparison 2 3 less Comparison 10 11 less Comparison 12 13 equal Comparison 9 10 less Comparison 13 14 less Comparison 13 14 less Comparison 1 2 less Comparison 2 3 less Comparison 9 10 less Comparison 8 9 less Comparison 7 8 less Comparison 14 15 more Swap
# Episode 200, loss:13.5889, succeed, steps:165, total reward:16.1000, 1.4161450862884521 sec
# Episode 201, loss:-18.8270, fail, steps:205, total reward:17.8000, 1.8304777145385742 sec
# Episode 202, loss:-20.1315, fail, steps:199, total reward:6.8000, 1.6836581230163574 sec
# Episode 203, loss:6.8559, succeed, steps:163, total reward:18.9000, 1.3277051448822021 sec
# Episode 204, loss:8.7874, succeed, steps:158, total reward:15.2000, 1.2845790386199951 sec
# Episode 205, loss:4.4360, succeed, steps:173, total reward:17.8000, 1.2870829105377197 sec
# Episode 206, loss:9.6211, succeed, steps:188, total reward:13.2000, 1.555919885635376 sec
# Episode 207, loss:15.1761, succeed, steps:183, total reward:22.5000, 1.4802277088165283 sec
# Episode 208, loss:-10.6618, fail, steps:199, total reward:8.6000, 1.775125503540039 sec
# Episode 209, loss:19.6019, succeed, steps:184, total reward:22.0000, 1.5258100032806396 sec
# Episode 210, loss:-9.5432, fail, steps:204, total reward:12.2000, 1.801603078842163 sec
# Episode 211, loss:1.1137, succeed, steps:177, total reward:17.8000, 1.4381673336029053 sec
# Episode 212, loss:8.9351, succeed, steps:209, total reward:21.7000, 1.7740147113800049 sec
# Episode 213, loss:0.5949, succeed, steps:206, total reward:26.1000, 1.6724693775177002 sec
# Episode 214, loss:-23.4531, fail, steps:196, total reward:0.4000, 1.7899088859558105 sec
# Episode 215, loss:-0.0293, succeed, steps:182, total reward:3.8000, 1.6290960311889648 sec
# Episode 216, loss:3.6692, succeed, steps:152, total reward:7.6000, 1.2522697448730469 sec
# Episode 217, loss:6.7454, succeed, steps:184, total reward:14.9000, 1.3891611099243164 sec
# Episode 218, loss:-17.0880, fail, steps:202, total reward:13.5000, 1.7763044834136963 sec
# Episode 219, loss:-28.1960, fail, steps:200, total reward:6.9000, 1.7171711921691895 sec
# Episode 220, loss:-10.0466, fail, steps:208, total reward:20.6000, 1.6848576068878174 sec
# Episode 221, loss:-13.3026, fail, steps:205, total reward:15.9000, 1.737487554550171 sec
# Episode 222, loss:-0.3332, succeed, steps:191, total reward:9.9000, 1.6113646030426025 sec
# Episode 223, loss:2.8985, succeed, steps:185, total reward:14.2000, 1.5845654010772705 sec
# Episode 224, loss:-14.8054, fail, steps:199, total reward:9.2000, 1.800558090209961 sec
# Episode 225, loss:-20.6263, fail, steps:200, total reward:6.6000, 1.6926701068878174 sec
# Episode 226, loss:8.9083, succeed, steps:192, total reward:14.8000, 1.6285076141357422 sec
# Episode 227, loss:-22.8148, fail, steps:206, total reward:17.9000, 1.8244993686676025 sec
# Episode 228, loss:3.0216, succeed, steps:181, total reward:12.8000, 1.5302276611328125 sec
# Episode 229, loss:-19.6840, fail, steps:207, total reward:17.1000, 1.7829248905181885 sec
# Episode 230, loss:8.6065, succeed, steps:152, total reward:12.5000, 1.3007941246032715 sec
# Episode 231, loss:-9.8651, fail, steps:207, total reward:19.8000, 1.8445963859558105 sec
# Episode 232, loss:-12.4116, fail, steps:206, total reward:18.8000, 1.7729086875915527 sec
# Episode 233, loss:-5.6367, succeed, steps:182, total reward:10.6000, 1.5162343978881836 sec
# Episode 234, loss:4.3132, succeed, steps:162, total reward:2.7000, 1.3526206016540527 sec
# Episode 235, loss:-5.9752, fail, steps:205, total reward:14.4000, 1.7484440803527832 sec
# Episode 236, loss:10.2491, succeed, steps:201, total reward:14.6000, 1.7508671283721924 sec
# Episode 237, loss:1.5973, fail, steps:211, total reward:26.1000, 1.7402048110961914 sec
# Episode 238, loss:-0.4319, succeed, steps:174, total reward:8.3000, 1.481698989868164 sec
# Episode 239, loss:-8.6970, fail, steps:205, total reward:14.4000, 1.825101375579834 sec
# Episode 240, loss:-13.7489, fail, steps:208, total reward:22.1000, 1.77809739112854 sec
# Episode 241, loss:2.0568, fail, steps:208, total reward:20.8000, 1.7310540676116943 sec
# Episode 242, loss:12.0381, succeed, steps:115, total reward:14.1000, 0.9687023162841797 sec
# Episode 243, loss:-22.6979, fail, steps:197, total reward:1.7000, 1.9271876811981201 sec
# Episode 244, loss:-38.8428, fail, steps:196, total reward:0.7000, 1.7080776691436768 sec
# Episode 245, loss:13.6587, succeed, steps:145, total reward:13.2000, 1.2164998054504395 sec
# Episode 246, loss:10.4879, succeed, steps:192, total reward:11.9000, 1.6333484649658203 sec
# Episode 247, loss:1.2403, succeed, steps:168, total reward:14.8000, 1.2651076316833496 sec
# Episode 248, loss:-13.1353, fail, steps:204, total reward:15.5000, 1.7758331298828125 sec
# Episode 249, loss:-2.4513, succeed, steps:187, total reward:12.3000, 1.5496606826782227 sec
# Episode 250, loss:3.2827, succeed, steps:199, total reward:13.9000, 1.7679364681243896 sec
# Episode 251, loss:-32.3780, fail, steps:200, total reward:9.3000, 1.7252285480499268 sec
# Episode 252, loss:6.2229, succeed, steps:157, total reward:18.7000, 1.2982289791107178 sec
# Episode 253, loss:1.1644, succeed, steps:167, total reward:7.9000, 1.3394825458526611 sec
# Episode 254, loss:-0.9666, succeed, steps:176, total reward:7.7000, 1.33842134475708 sec
# Episode 255, loss:-15.0405, fail, steps:207, total reward:17.7000, 1.7823293209075928 sec
# Episode 256, loss:10.0947, succeed, steps:190, total reward:19.2000, 1.5973734855651855 sec
# Episode 257, loss:-17.9896, fail, steps:200, total reward:9.6000, 1.7557871341705322 sec
# Episode 258, loss:4.9122, succeed, steps:138, total reward:7.5000, 1.1889903545379639 sec
# Episode 259, loss:-2.0473, fail, steps:218, total reward:36.0000, 1.9054911136627197 sec
# Episode 260, loss:-84.8074, fail, steps:5, total reward:-8.9000, 0.10289907455444336 sec
# Episode 261, loss:-24.3705, fail, steps:204, total reward:14.6000, 1.557344675064087 sec
# Episode 262, loss:-35.2134, fail, steps:195, total reward:2.6000, 1.6228256225585938 sec
# Episode 263, loss:-16.5523, fail, steps:211, total reward:23.6000, 1.6459088325500488 sec
# Episode 264, loss:14.4034, succeed, steps:159, total reward:23.0000, 1.2775352001190186 sec
# Episode 265, loss:-29.2383, fail, steps:196, total reward:1.6000, 1.845876693725586 sec
# Episode 266, loss:-18.1899, fail, steps:201, total reward:9.4000, 1.766272783279419 sec
# Episode 267, loss:-18.4781, fail, steps:204, total reward:14.3000, 1.7048516273498535 sec
# Episode 268, loss:-31.3466, fail, steps:196, total reward:4.9000, 1.7052292823791504 sec
# Episode 269, loss:0.8040, succeed, steps:178, total reward:14.1000, 1.514122724533081 sec
# Episode 270, loss:4.1676, succeed, steps:197, total reward:13.2000, 1.7750623226165771 sec
# Episode 271, loss:-30.6663, fail, steps:191, total reward:-5.1000, 1.6965906620025635 sec
# Episode 272, loss:7.0393, succeed, steps:173, total reward:12.4000, 1.4797172546386719 sec
# Episode 273, loss:3.2659, succeed, steps:158, total reward:16.9000, 1.2187891006469727 sec
# Episode 274, loss:-19.8181, fail, steps:204, total reward:11.9000, 1.7602362632751465 sec
# Episode 275, loss:-12.3829, fail, steps:211, total reward:23.3000, 1.7571606636047363 sec
# Episode 276, loss:14.9991, succeed, steps:175, total reward:22.8000, 1.4155189990997314 sec
# Episode 277, loss:-26.1736, fail, steps:196, total reward:3.6000, 1.8124725818634033 sec
# Episode 278, loss:-10.6580, fail, steps:207, total reward:18.9000, 1.707932949066162 sec
# Episode 279, loss:2.8335, succeed, steps:175, total reward:13.5000, 1.4344534873962402 sec
# Episode 280, loss:7.7242, succeed, steps:166, total reward:12.5000, 1.3810768127441406 sec
# Episode 281, loss:-22.4900, fail, steps:203, total reward:12.1000, 1.7719635963439941 sec
# Episode 282, loss:6.5883, succeed, steps:204, total reward:23.8000, 1.6621193885803223 sec
# Episode 283, loss:-7.8616, fail, steps:205, total reward:14.2000, 1.7513322830200195 sec
# Episode 284, loss:6.3622, succeed, steps:127, total reward:8.2000, 1.1749906539916992 sec
# Episode 285, loss:-17.6645, fail, steps:204, total reward:11.9000, 1.9095687866210938 sec
# Episode 286, loss:4.5215, succeed, steps:195, total reward:17.1000, 1.6305863857269287 sec
# Episode 287, loss:1.5578, succeed, steps:165, total reward:2.7000, 1.4317684173583984 sec
# Episode 288, loss:-19.0783, fail, steps:196, total reward:3.6000, 1.784362554550171 sec
# Episode 289, loss:-21.1815, fail, steps:200, total reward:9.3000, 1.7732083797454834 sec
# Episode 290, loss:-12.1467, fail, steps:203, total reward:14.5000, 1.6660676002502441 sec
# Episode 291, loss:-4.0047, fail, steps:205, total reward:15.6000, 1.771331787109375 sec
# Episode 292, loss:26.8634, succeed, steps:197, total reward:33.4000, 1.5737533569335938 sec
# Episode 293, loss:-7.8413, fail, steps:214, total reward:29.4000, 1.8632543087005615 sec
# Episode 294, loss:-0.8339, succeed, steps:199, total reward:8.5000, 1.6897437572479248 sec
# Episode 295, loss:1.0064, fail, steps:217, total reward:33.1000, 1.7566595077514648 sec
# Episode 296, loss:-4.6896, fail, steps:207, total reward:19.8000, 1.7159011363983154 sec
# Episode 297, loss:-30.1126, fail, steps:207, total reward:18.3000, 1.71728515625 sec
# Episode 298, loss:-4.8930, succeed, steps:187, total reward:-3.7000, 1.6857655048370361 sec
# Episode 299, loss:23.2125, succeed, steps:188, total reward:14.6000, 1.5960443019866943 sec
# len16 Comparison 9 10 less Comparison 8 9 less Comparison 7 8 more Swap Comparison 6 7 less Comparison 5 6 more Swap Comparison 4 5 more Swap Comparison 3 4 more Swap Comparison 2 3 more Swap Comparison 1 2 more Swap Comparison 0 1 less Comparison 10 11 more Swap Comparison 11 12 more Swap Comparison 13 14 equal Comparison 14 15 less Comparison 9 10 more Swap Comparison 8 9 more Swap Comparison 7 8 more Swap Comparison 6 7 more Swap Comparison 5 6 more Swap Comparison 4 5 more Swap Comparison 3 4 more Swap Comparison 2 3 more Swap Comparison 10 11 more Swap Comparison 11 12 less Comparison 1 2 more Swap Comparison 12 13 more Swap Comparison 9 10 more Swap Comparison 8 9 more Swap Comparison 7 8 more Swap Comparison 5 6 less Comparison 13 14 more Swap Comparison 3 11 less Comparison 6 7 more Swap Comparison 4 5 more Swap Comparison 3 4 more Swap Comparison 2 3 less Comparison 9 10 less Comparison 11 12 more Swap Comparison 13 14 less Comparison 9 10 less Comparison 7 8 less Comparison 11 12 less Comparison 5 6 more Swap Comparison 4 5 more Swap Comparison 3 4 more Swap Comparison 10 11 more Swap Comparison 8 9 more Swap Comparison 7 8 more Swap Comparison 9 10 more Swap Comparison 1 2 less Comparison 6 7 less Comparison 5 6 less Comparison 8 9 more Swap Comparison 7 8 more Swap Comparison 4 5 less Comparison 10 11 more Swap Comparison 11 12 more Swap Comparison 12 13 more Swap Comparison 3 4 less Comparison 9 10 less Comparison 8 9 less Comparison 10 11 more Swap Comparison 7 8 less Comparison 14 15 more Swap Comparison 6 7 more Swap Comparison 5 6 more Swap Comparison 11 12 more Swap Comparison 9 10 less Comparison 13 14 more Swap Comparison 8 9 less Comparison 7 8 less Comparison 10 11 more Swap Comparison 9 10 more Swap Comparison 3 4 less Comparison 6 7 less Comparison 2 3 less Comparison 5 6 less Comparison 8 9 more Swap Comparison 11 12 less Comparison 12 13 more Swap Comparison 13 14 less Comparison 7 8 more Swap Comparison 14 15 more Swap Comparison 5 6 less Comparison 7 8 less Comparison 1 2 less Comparison 4 5 less Comparison 9 10 less Comparison 0 1 more Swap Comparison 3 4 less Comparison 2 3 less Comparison 6 7 more Swap Comparison 10 11 less Comparison 3 4 less Comparison 11 12 less Comparison 5 6 equal Comparison 9 10 less Comparison 1 2 less Comparison 8 9 less Comparison 10 11 less Comparison 12 13 less Comparison 13 14 more Swap
# Episode 300, loss:9.7950, succeed, steps:156, total reward:22.3000, 1.2150821685791016 sec
# Episode 301, loss:15.1738, succeed, steps:188, total reward:23.1000, 1.3877475261688232 sec
# Episode 302, loss:1.9995, succeed, steps:198, total reward:9.5000, 1.7402455806732178 sec
# Episode 303, loss:-72.0620, fail, steps:3, total reward:-9.6000, 0.09222698211669922 sec
# Episode 304, loss:6.3807, succeed, steps:162, total reward:16.6000, 1.1483445167541504 sec
# Episode 305, loss:7.6360, succeed, steps:201, total reward:16.8000, 1.7055575847625732 sec
# Episode 306, loss:4.0451, succeed, steps:158, total reward:15.2000, 1.2497570514678955 sec
# Episode 307, loss:-20.0507, fail, steps:212, total reward:26.5000, 1.8183553218841553 sec
# Episode 308, loss:-22.4868, fail, steps:196, total reward:4.6000, 1.7531476020812988 sec
# Episode 309, loss:-13.0904, fail, steps:210, total reward:23.8000, 1.7100038528442383 sec
# Episode 310, loss:-23.6692, fail, steps:202, total reward:12.0000, 1.7096936702728271 sec
# Episode 311, loss:-15.8731, fail, steps:202, total reward:10.4000, 1.742966651916504 sec
# Episode 312, loss:1.5396, succeed, steps:173, total reward:17.8000, 1.4991023540496826 sec
# Episode 313, loss:13.4320, succeed, steps:163, total reward:23.4000, 1.2272820472717285 sec
# Episode 314, loss:8.5851, succeed, steps:124, total reward:15.6000, 0.9209718704223633 sec
# Episode 315, loss:3.2167, succeed, steps:194, total reward:9.3000, 1.6159512996673584 sec
# Episode 316, loss:14.7515, succeed, steps:197, total reward:33.2000, 1.4990198612213135 sec
# Episode 317, loss:-15.3696, fail, steps:201, total reward:10.6000, 1.8313302993774414 sec
# Episode 318, loss:-1.0052, fail, steps:209, total reward:21.9000, 1.7225990295410156 sec
# Episode 319, loss:-3.4429, fail, steps:211, total reward:25.5000, 1.7581956386566162 sec
# Episode 320, loss:4.5831, succeed, steps:165, total reward:21.6000, 1.3793573379516602 sec
# Episode 321, loss:-1.8497, succeed, steps:191, total reward:10.3000, 1.7187199592590332 sec
# Episode 322, loss:2.8103, succeed, steps:195, total reward:10.3000, 1.7014148235321045 sec
# Episode 323, loss:-27.6299, fail, steps:199, total reward:3.4000, 1.7870638370513916 sec
# Episode 324, loss:17.9823, succeed, steps:196, total reward:20.7000, 1.6310861110687256 sec
# Episode 325, loss:17.0926, succeed, steps:161, total reward:13.0000, 1.3044989109039307 sec
# Episode 326, loss:-17.7260, fail, steps:206, total reward:16.1000, 1.8423945903778076 sec
# Episode 327, loss:-9.2367, succeed, steps:193, total reward:5.2000, 1.7190985679626465 sec
# Episode 328, loss:2.5450, succeed, steps:185, total reward:14.3000, 1.5691335201263428 sec
# Episode 329, loss:3.3222, succeed, steps:180, total reward:21.7000, 1.3799471855163574 sec
# Episode 330, loss:-27.9486, fail, steps:202, total reward:8.3000, 1.7405486106872559 sec
# Episode 331, loss:5.5573, succeed, steps:122, total reward:6.8000, 1.0689780712127686 sec
# Episode 332, loss:3.5486, succeed, steps:194, total reward:21.3000, 1.6296067237854004 sec
# Episode 333, loss:-17.7452, fail, steps:206, total reward:15.8000, 1.7311859130859375 sec
# Episode 334, loss:2.5092, succeed, steps:145, total reward:-0.7000, 1.292618751525879 sec
# Episode 335, loss:-12.9841, fail, steps:211, total reward:24.2000, 1.8694586753845215 sec
# Episode 336, loss:-2.1002, succeed, steps:165, total reward:9.5000, 1.3938539028167725 sec
# Episode 337, loss:0.0915, succeed, steps:166, total reward:4.3000, 1.4370429515838623 sec
# Episode 338, loss:12.9854, succeed, steps:201, total reward:34.1000, 1.5710699558258057 sec
# Episode 339, loss:2.3259, succeed, steps:165, total reward:22.2000, 1.2639074325561523 sec
# Episode 340, loss:-19.1574, fail, steps:202, total reward:12.2000, 1.774324655532837 sec
# Episode 341, loss:-11.4754, fail, steps:207, total reward:17.7000, 1.733510971069336 sec
# Episode 342, loss:-0.2031, succeed, steps:181, total reward:3.7000, 1.6269352436065674 sec
# Episode 343, loss:-8.2910, fail, steps:211, total reward:22.7000, 1.7747747898101807 sec
# Episode 344, loss:-6.0473, fail, steps:207, total reward:19.8000, 1.7447755336761475 sec
# Episode 345, loss:2.1934, fail, steps:220, total reward:38.0000, 1.773547649383545 sec
# Episode 346, loss:-12.8879, fail, steps:204, total reward:14.9000, 1.7843444347381592 sec
# Episode 347, loss:9.9526, succeed, steps:149, total reward:14.6000, 1.2852394580841064 sec
# Episode 348, loss:-14.2441, fail, steps:199, total reward:9.2000, 1.8832604885101318 sec
# Episode 349, loss:-8.9345, succeed, steps:197, total reward:4.0000, 1.676940679550171 sec
# Episode 350, loss:-0.4187, succeed, steps:181, total reward:7.3000, 1.555966854095459 sec
# Episode 351, loss:-12.4640, fail, steps:215, total reward:29.6000, 1.8708953857421875 sec
# Episode 352, loss:-20.4621, fail, steps:201, total reward:9.1000, 1.7140591144561768 sec
# Episode 353, loss:-1.1720, succeed, steps:166, total reward:1.7000, 1.4763550758361816 sec
# Episode 354, loss:1.4489, succeed, steps:150, total reward:5.2000, 1.2366738319396973 sec
# Episode 355, loss:-2.6308, succeed, steps:190, total reward:4.9000, 1.6934609413146973 sec
# Episode 356, loss:-13.1629, fail, steps:213, total reward:27.5000, 1.725825548171997 sec
# Episode 357, loss:4.1352, succeed, steps:194, total reward:7.6000, 1.6844613552093506 sec
# Episode 358, loss:10.1235, succeed, steps:113, total reward:11.1000, 0.9332835674285889 sec
# Episode 359, loss:8.3623, succeed, steps:164, total reward:21.2000, 1.2103474140167236 sec
# Episode 360, loss:-15.2415, fail, steps:202, total reward:12.2000, 1.8731703758239746 sec
# Episode 361, loss:1.3498, succeed, steps:159, total reward:5.1000, 1.3832824230194092 sec
# Episode 362, loss:12.5944, succeed, steps:167, total reward:25.8000, 1.2452192306518555 sec
# Episode 363, loss:-17.7378, fail, steps:201, total reward:10.9000, 1.796194314956665 sec
# Episode 364, loss:-32.4453, fail, steps:191, total reward:-10.2000, 1.7872109413146973 sec
# Episode 365, loss:8.3967, succeed, steps:128, total reward:15.4000, 1.0888628959655762 sec
# Episode 366, loss:9.7180, succeed, steps:148, total reward:14.3000, 1.159961462020874 sec
# Episode 367, loss:-11.9179, fail, steps:199, total reward:9.2000, 1.8458943367004395 sec
# Episode 368, loss:3.9909, succeed, steps:181, total reward:14.7000, 1.4936678409576416 sec
# Episode 369, loss:-3.0031, succeed, steps:185, total reward:2.3000, 1.6721303462982178 sec
# Episode 370, loss:4.6288, succeed, steps:175, total reward:14.6000, 1.5599873065948486 sec
# Episode 371, loss:4.6355, succeed, steps:168, total reward:18.1000, 1.2977001667022705 sec
# Episode 372, loss:-22.9647, fail, steps:199, total reward:9.2000, 1.7643582820892334 sec
# Episode 373, loss:-9.8938, fail, steps:208, total reward:20.8000, 1.7308435440063477 sec
# Episode 374, loss:14.4940, succeed, steps:161, total reward:20.1000, 1.4332966804504395 sec
# Episode 375, loss:10.7511, succeed, steps:203, total reward:19.9000, 1.8259789943695068 sec
# Episode 376, loss:14.5775, succeed, steps:159, total reward:17.5000, 1.3441534042358398 sec
# Episode 377, loss:9.3545, succeed, steps:176, total reward:14.7000, 1.3992018699645996 sec
# Episode 378, loss:9.6774, succeed, steps:137, total reward:14.8000, 1.0053691864013672 sec
# Episode 379, loss:2.9149, succeed, steps:172, total reward:15.3000, 1.2278733253479004 sec
# Episode 380, loss:-12.8345, fail, steps:202, total reward:12.2000, 1.7924747467041016 sec
# Episode 381, loss:-40.2828, fail, steps:187, total reward:-10.7000, 1.6979680061340332 sec
# Episode 382, loss:10.2181, succeed, steps:189, total reward:18.9000, 1.5619373321533203 sec
# Episode 383, loss:15.0002, succeed, steps:126, total reward:18.7000, 0.9804079532623291 sec
# Episode 384, loss:-6.7400, succeed, steps:176, total reward:7.0000, 1.409118413925171 sec
# Episode 385, loss:-17.4808, fail, steps:202, total reward:12.2000, 1.7806813716888428 sec
# Episode 386, loss:5.1895, succeed, steps:154, total reward:9.7000, 1.3333699703216553 sec
# Episode 387, loss:-14.9866, fail, steps:205, total reward:17.8000, 1.897515058517456 sec
# Episode 388, loss:-23.6182, fail, steps:194, total reward:0.1000, 1.704348087310791 sec
# Episode 389, loss:12.9271, succeed, steps:177, total reward:25.4000, 1.4768428802490234 sec
# Episode 390, loss:5.9877, succeed, steps:169, total reward:11.6000, 1.3389997482299805 sec
# Episode 391, loss:5.6338, succeed, steps:148, total reward:11.9000, 1.0994226932525635 sec
# Episode 392, loss:-14.0127, fail, steps:201, total reward:10.9000, 1.811086893081665 sec
# Episode 393, loss:2.3960, succeed, steps:135, total reward:12.5000, 1.1343743801116943 sec
# Episode 394, loss:-2.1518, succeed, steps:179, total reward:22.6000, 1.444056749343872 sec
# Episode 395, loss:-14.1570, fail, steps:202, total reward:12.2000, 1.7764039039611816 sec
# Episode 396, loss:-37.3817, fail, steps:192, total reward:-1.7000, 1.7115025520324707 sec
# Episode 397, loss:4.5352, succeed, steps:169, total reward:13.2000, 1.41538405418396 sec
# Episode 398, loss:6.1830, succeed, steps:151, total reward:7.3000, 1.2959637641906738 sec
# Episode 399, loss:12.4863, succeed, steps:161, total reward:27.0000, 1.123887300491333 sec
# Episode 400, loss:-16.5828, fail, steps:209, total reward:23.1000, 1.802739143371582 sec
# Episode 401, loss:9.0699, succeed, steps:157, total reward:23.4000, 1.2697856426239014 sec
# Episode 402, loss:8.7646, succeed, steps:147, total reward:20.1000, 1.112781047821045 sec
# Episode 403, loss:6.0563, succeed, steps:191, total reward:4.5000, 1.8112120628356934 sec
# Episode 404, loss:-13.8226, fail, steps:209, total reward:23.1000, 1.7396607398986816 sec
# Episode 405, loss:-7.6931, fail, steps:211, total reward:26.4000, 1.725060224533081 sec
# Episode 406, loss:-10.6008, fail, steps:205, total reward:14.7000, 1.7393646240234375 sec
# Episode 407, loss:10.6486, succeed, steps:155, total reward:14.0000, 1.2726647853851318 sec
# Episode 408, loss:8.0729, succeed, steps:162, total reward:19.3000, 1.304382562637329 sec
# Episode 409, loss:-15.4056, fail, steps:202, total reward:12.2000, 1.8057301044464111 sec
# Episode 410, loss:-5.9071, succeed, steps:191, total reward:13.0000, 1.577864170074463 sec
# Episode 411, loss:-18.1668, fail, steps:203, total reward:14.5000, 1.7417371273040771 sec
# Episode 412, loss:14.4940, succeed, steps:155, total reward:23.2000, 1.2738113403320312 sec
# Episode 413, loss:-20.3646, fail, steps:202, total reward:11.4000, 1.9624943733215332 sec
# Episode 414, loss:-21.7362, fail, steps:194, total reward:0.7000, 1.7447872161865234 sec
# Episode 415, loss:8.5942, succeed, steps:174, total reward:9.7000, 1.5022339820861816 sec
# Episode 416, loss:4.8284, succeed, steps:171, total reward:15.8000, 1.3627314567565918 sec
# Episode 417, loss:7.1268, fail, steps:223, total reward:42.4000, 1.8498375415802002 sec
# Episode 418, loss:-7.8436, fail, steps:210, total reward:22.3000, 1.6957118511199951 sec
# Episode 419, loss:17.0164, succeed, steps:139, total reward:13.1000, 1.203291654586792 sec
# Episode 420, loss:14.5592, succeed, steps:200, total reward:12.3000, 1.8966553211212158 sec
# Episode 421, loss:-35.6224, fail, steps:194, total reward:-0.8000, 1.7040514945983887 sec
# Episode 422, loss:-8.4774, fail, steps:210, total reward:22.0000, 1.8269317150115967 sec
# Episode 423, loss:-8.9397, fail, steps:202, total reward:13.5000, 1.719409704208374 sec
# Episode 424, loss:-4.1495, succeed, steps:154, total reward:7.9000, 1.3518950939178467 sec
# Episode 425, loss:-26.5788, fail, steps:196, total reward:2.1000, 1.8883693218231201 sec
# Episode 426, loss:12.9920, succeed, steps:159, total reward:18.8000, 1.3277344703674316 sec
# Episode 427, loss:17.7937, succeed, steps:156, total reward:16.4000, 1.2719371318817139 sec
# Episode 428, loss:-18.0014, fail, steps:202, total reward:10.7000, 1.8259556293487549 sec
# Episode 429, loss:-17.6014, fail, steps:202, total reward:12.2000, 1.7503259181976318 sec
# Episode 430, loss:6.6149, succeed, steps:158, total reward:9.2000, 1.345090627670288 sec
# Episode 431, loss:5.0326, succeed, steps:193, total reward:13.1000, 1.8221769332885742 sec
# Episode 432, loss:-17.3304, fail, steps:205, total reward:17.8000, 1.7681279182434082 sec
# Episode 433, loss:10.6217, succeed, steps:177, total reward:18.0000, 1.4872372150421143 sec
# Episode 434, loss:-13.2391, fail, steps:206, total reward:18.8000, 1.85719633102417 sec
# Episode 435, loss:-0.7442, succeed, steps:201, total reward:9.3000, 1.727104902267456 sec
# Episode 436, loss:-6.9831, fail, steps:200, total reward:8.1000, 1.808048963546753 sec
# Episode 437, loss:-19.9689, fail, steps:208, total reward:17.0000, 1.7480309009552002 sec
# Episode 438, loss:-2.6316, succeed, steps:174, total reward:9.3000, 1.5328953266143799 sec
# Episode 439, loss:1.7691, succeed, steps:187, total reward:4.8000, 1.6866471767425537 sec
# Episode 440, loss:4.4137, succeed, steps:174, total reward:3.7000, 1.486950397491455 sec
# Episode 441, loss:17.4880, succeed, steps:189, total reward:18.3000, 1.4450690746307373 sec
# Episode 442, loss:-14.6169, fail, steps:204, total reward:14.0000, 1.7436914443969727 sec
# Episode 443, loss:-19.5197, fail, steps:193, total reward:0.6000, 1.7455244064331055 sec
# Episode 444, loss:-3.0199, succeed, steps:174, total reward:-4.1000, 1.668424367904663 sec
# Episode 445, loss:-8.5293, fail, steps:194, total reward:-1.1000, 1.8137152194976807 sec
# Episode 446, loss:9.1171, succeed, steps:197, total reward:13.2000, 1.7106964588165283 sec
# Episode 447, loss:-30.2524, fail, steps:190, total reward:-8.5000, 1.7578234672546387 sec
# Episode 448, loss:13.7631, succeed, steps:178, total reward:21.5000, 1.4879672527313232 sec
# Episode 449, loss:11.9804, succeed, steps:200, total reward:20.2000, 1.7855620384216309 sec
# Episode 450, loss:-3.6828, succeed, steps:194, total reward:9.3000, 1.7031259536743164 sec
# Episode 451, loss:-26.0262, fail, steps:192, total reward:-1.7000, 1.7321150302886963 sec
# Episode 452, loss:-21.0665, fail, steps:205, total reward:12.6000, 1.7355773448944092 sec
# Episode 453, loss:-0.9364, succeed, steps:173, total reward:-4.1000, 1.5572080612182617 sec
# Episode 454, loss:-13.8082, fail, steps:210, total reward:23.5000, 1.880821943283081 sec
# Episode 455, loss:-4.3239, succeed, steps:172, total reward:-0.0000, 1.5359673500061035 sec
# Episode 456, loss:5.7022, succeed, steps:185, total reward:13.6000, 1.559704065322876 sec
# Episode 457, loss:1.9466, succeed, steps:199, total reward:16.5000, 1.7217929363250732 sec
# Episode 458, loss:16.5146, succeed, steps:198, total reward:30.8000, 1.6782171726226807 sec
# Episode 459, loss:13.7479, succeed, steps:135, total reward:22.1000, 1.0329861640930176 sec
# Episode 460, loss:8.3136, succeed, steps:197, total reward:23.6000, 1.4977216720581055 sec
# Episode 461, loss:-25.7031, fail, steps:202, total reward:11.3000, 1.7221078872680664 sec
# Episode 462, loss:-21.6008, fail, steps:205, total reward:15.3000, 1.7094123363494873 sec
# Episode 463, loss:-17.9291, fail, steps:202, total reward:13.5000, 1.7967243194580078 sec
# Episode 464, loss:0.7621, succeed, steps:162, total reward:9.6000, 1.4137852191925049 sec
# Episode 465, loss:-18.0324, fail, steps:201, total reward:11.2000, 1.8882780075073242 sec
# Episode 466, loss:11.6080, succeed, steps:175, total reward:30.9000, 1.391688346862793 sec
# Episode 467, loss:4.8909, succeed, steps:188, total reward:17.6000, 1.5606050491333008 sec
# Episode 468, loss:1.9514, succeed, steps:159, total reward:9.2000, 1.2549653053283691 sec
# Episode 469, loss:-11.6154, fail, steps:210, total reward:22.6000, 1.8148934841156006 sec
# Episode 470, loss:4.5492, succeed, steps:175, total reward:18.5000, 1.4526424407958984 sec
# ...
# Episode 10005, loss:5.4707, succeed, steps:187, total reward:44.8000, 2.1046946048736572 sec
# Episode 10006, loss:5.8218, succeed, steps:194, total reward:31.4000, 2.36258602142334 sec
# Episode 10007, loss:5.3133, succeed, steps:166, total reward:36.2000, 1.9388511180877686 sec
# Episode 10008, loss:3.0077, succeed, steps:184, total reward:21.4000, 2.369307279586792 sec
# Episode 10009, loss:-1.8267, succeed, steps:153, total reward:20.3000, 1.8990352153778076 sec
# Episode 10010, loss:-1.8288, fail, steps:218, total reward:35.1000, 3.0079851150512695 sec
# Episode 10011, loss:5.8520, succeed, steps:134, total reward:27.0000, 1.754784107208252 sec
# Episode 10012, loss:6.6441, succeed, steps:185, total reward:28.5000, 2.475921869277954 sec
# Episode 10013, loss:-5.1168, fail, steps:200, total reward:7.8000, 2.946192979812622 sec
# Episode 10014, loss:8.4039, succeed, steps:179, total reward:22.5000, 2.476529598236084 sec
# Episode 10015, loss:7.2529, succeed, steps:135, total reward:31.5000, 1.7411398887634277 sec
# Episode 10016, loss:3.4581, succeed, steps:204, total reward:30.6000, 2.593726634979248 sec
# Episode 10017, loss:-9.4956, fail, steps:215, total reward:31.7000, 2.934077739715576 sec
# Episode 10018, loss:4.6205, succeed, steps:140, total reward:20.9000, 2.0129754543304443 sec
# Episode 10019, loss:2.9521, succeed, steps:195, total reward:21.4000, 2.6432507038116455 sec
# Episode 10020, loss:-2.5421, succeed, steps:182, total reward:8.0000, 2.479970693588257 sec
# Episode 10021, loss:2.4139, succeed, steps:131, total reward:7.0000, 1.8188788890838623 sec
# Episode 10022, loss:4.9978, succeed, steps:203, total reward:27.1000, 2.604849100112915 sec
# Episode 10023, loss:5.7189, succeed, steps:139, total reward:31.9000, 1.6957671642303467 sec
# Episode 10024, loss:6.1966, succeed, steps:188, total reward:36.7000, 2.3511953353881836 sec
# Episode 10025, loss:9.5102, succeed, steps:163, total reward:33.5000, 1.9487388134002686 sec
# Episode 10026, loss:3.9664, succeed, steps:147, total reward:28.2000, 1.7672183513641357 sec
# Episode 10027, loss:3.6958, succeed, steps:188, total reward:25.7000, 2.324069023132324 sec
# Episode 10028, loss:1.8597, succeed, steps:158, total reward:20.1000, 1.9266557693481445 sec
# Episode 10029, loss:3.2956, succeed, steps:189, total reward:18.0000, 2.499300718307495 sec
# Episode 10030, loss:5.4363, succeed, steps:149, total reward:21.6000, 1.8649532794952393 sec
# Episode 10031, loss:2.9479, succeed, steps:190, total reward:12.7000, 2.478367328643799 sec
# Episode 10032, loss:-4.3237, fail, steps:205, total reward:16.5000, 2.932717800140381 sec
# Episode 10033, loss:-5.1209, fail, steps:216, total reward:32.7000, 3.0269978046417236 sec
# Episode 10034, loss:-2.4175, fail, steps:219, total reward:35.8000, 2.9111599922180176 sec
# Episode 10035, loss:1.8692, fail, steps:213, total reward:27.2000, 2.972285270690918 sec
# Episode 10036, loss:6.1996, succeed, steps:160, total reward:16.5000, 2.303377151489258 sec
# Episode 10037, loss:-0.7670, fail, steps:202, total reward:10.4000, 3.160329580307007 sec
# Episode 10038, loss:5.3983, succeed, steps:130, total reward:13.8000, 1.8641555309295654 sec
# Episode 10039, loss:0.0793, succeed, steps:131, total reward:13.5000, 1.7741379737854004 sec
# Episode 10040, loss:4.6287, succeed, steps:149, total reward:19.5000, 1.8481764793395996 sec
# Episode 10041, loss:7.3831, succeed, steps:150, total reward:28.4000, 1.75651216506958 sec
# Episode 10042, loss:8.4365, succeed, steps:199, total reward:37.3000, 2.448197364807129 sec
# Episode 10043, loss:4.9029, succeed, steps:155, total reward:22.0000, 1.9935734272003174 sec
# Episode 10044, loss:4.7921, succeed, steps:158, total reward:28.8000, 1.8271331787109375 sec
# Episode 10045, loss:2.5862, succeed, steps:165, total reward:28.0000, 1.9790854454040527 sec
# Episode 10046, loss:2.1525, succeed, steps:131, total reward:23.9000, 1.490797519683838 sec
# Episode 10047, loss:-2.2727, fail, steps:208, total reward:20.8000, 3.074106216430664 sec
# Episode 10048, loss:4.2590, succeed, steps:136, total reward:22.4000, 1.8713243007659912 sec
# Episode 10049, loss:7.8423, succeed, steps:155, total reward:30.7000, 2.034578323364258 sec
# Episode 10050, loss:1.6712, succeed, steps:156, total reward:21.1000, 1.9949314594268799 sec
# Episode 10051, loss:-12.1440, fail, steps:203, total reward:12.7000, 3.01224422454834 sec
# Episode 10052, loss:0.5200, succeed, steps:165, total reward:7.2000, 2.3503575325012207 sec
# Episode 10053, loss:0.0761, succeed, steps:123, total reward:4.3000, 1.7470088005065918 sec
# Episode 10054, loss:-8.3388, fail, steps:206, total reward:17.6000, 3.0878546237945557 sec
# Episode 10055, loss:3.7202, succeed, steps:182, total reward:24.9000, 2.510037899017334 sec
# Episode 10056, loss:6.2189, succeed, steps:209, total reward:37.0000, 2.8173937797546387 sec
# Episode 10057, loss:2.9924, succeed, steps:178, total reward:14.8000, 2.510455369949341 sec
# Episode 10058, loss:-2.0688, succeed, steps:172, total reward:3.9000, 2.3810389041900635 sec
# Episode 10059, loss:1.5636, succeed, steps:106, total reward:9.5000, 1.3311572074890137 sec
# Episode 10060, loss:0.4206, succeed, steps:202, total reward:29.0000, 2.650179624557495 sec
# Episode 10061, loss:7.1052, succeed, steps:205, total reward:21.2000, 2.8545849323272705 sec
# Episode 10062, loss:5.1289, succeed, steps:170, total reward:15.0000, 2.4862818717956543 sec
# Episode 10063, loss:2.2394, succeed, steps:168, total reward:20.7000, 2.240273952484131 sec
# Episode 10064, loss:6.2006, succeed, steps:159, total reward:25.9000, 1.9652721881866455 sec
# Episode 10065, loss:4.4236, succeed, steps:168, total reward:41.4000, 1.936370849609375 sec
# Episode 10066, loss:-2.7332, succeed, steps:155, total reward:13.9000, 1.8852102756500244 sec
# Episode 10067, loss:1.4388, succeed, steps:168, total reward:25.5000, 2.0299057960510254 sec
# Episode 10068, loss:5.8629, succeed, steps:139, total reward:18.9000, 1.6697072982788086 sec
# Episode 10069, loss:4.5531, succeed, steps:121, total reward:18.5000, 1.4909911155700684 sec
# Episode 10070, loss:2.4609, succeed, steps:134, total reward:14.0000, 1.5916380882263184 sec
# Episode 10071, loss:3.1702, succeed, steps:108, total reward:17.8000, 1.2640817165374756 sec
# Episode 10072, loss:5.1847, succeed, steps:123, total reward:21.2000, 1.4287972450256348 sec
# Episode 10073, loss:4.0628, succeed, steps:167, total reward:26.5000, 2.02810001373291 sec
# Episode 10074, loss:-6.2893, fail, steps:209, total reward:23.1000, 2.9035751819610596 sec
# Episode 10075, loss:1.7179, succeed, steps:149, total reward:22.8000, 2.0261213779449463 sec
# Episode 10076, loss:5.1814, succeed, steps:185, total reward:23.1000, 2.457646369934082 sec
# Episode 10077, loss:0.4286, succeed, steps:137, total reward:14.3000, 1.7796409130096436 sec
# Episode 10078, loss:4.0339, succeed, steps:147, total reward:20.8000, 1.7842624187469482 sec
# Episode 10079, loss:6.8489, succeed, steps:172, total reward:28.5000, 2.0588667392730713 sec
# Episode 10080, loss:-7.1107, fail, steps:205, total reward:16.0000, 2.8777735233306885 sec
# Episode 10081, loss:1.2288, succeed, steps:151, total reward:10.6000, 2.103132486343384 sec
# Episode 10082, loss:3.2273, succeed, steps:168, total reward:18.1000, 2.2976536750793457 sec
# Episode 10083, loss:2.8706, succeed, steps:168, total reward:19.6000, 2.1198253631591797 sec
# Episode 10084, loss:2.9624, succeed, steps:140, total reward:27.4000, 1.7029099464416504 sec
# Episode 10085, loss:5.1844, succeed, steps:151, total reward:21.8000, 1.8748300075531006 sec
# Episode 10086, loss:0.5322, succeed, steps:93, total reward:9.3000, 1.1460976600646973 sec
# Episode 10087, loss:-0.9051, succeed, steps:193, total reward:24.7000, 2.499650001525879 sec
# Episode 10088, loss:2.6782, succeed, steps:135, total reward:11.0000, 1.695303201675415 sec
# Episode 10089, loss:-6.9683, fail, steps:207, total reward:16.2000, 3.003647565841675 sec
# Episode 10090, loss:0.1925, fail, steps:216, total reward:32.7000, 2.9716193675994873 sec
# Episode 10091, loss:1.5945, succeed, steps:207, total reward:23.6000, 2.8985695838928223 sec
# Episode 10092, loss:2.9232, succeed, steps:206, total reward:40.4000, 2.7728962898254395 sec
# Episode 10093, loss:1.4917, succeed, steps:152, total reward:31.0000, 1.8260526657104492 sec
# Episode 10094, loss:-0.4160, fail, steps:212, total reward:25.9000, 2.9858334064483643 sec
# Episode 10095, loss:1.2292, succeed, steps:133, total reward:25.9000, 1.6762306690216064 sec
# Episode 10096, loss:3.6783, succeed, steps:171, total reward:16.9000, 2.3999881744384766 sec
# Episode 10097, loss:3.1040, succeed, steps:181, total reward:36.2000, 2.167905569076538 sec
# Episode 10098, loss:7.2862, succeed, steps:195, total reward:37.2000, 2.376138925552368 sec
# Episode 10099, loss:-3.4276, succeed, steps:182, total reward:15.2000, 2.386901617050171 sec
# len16 Comparison 9 10 less Comparison 8 9 more Swap Comparison 7 8 more Swap Comparison 6 7 more Swap Comparison 5 6 more Swap Comparison 4 5 less Comparison 3 4 more Swap Comparison 2 3 more Swap Comparison 1 2 less Comparison 0 1 more Swap Comparison 10 11 more Swap Comparison 11 12 less Comparison 12 13 more Swap Comparison 13 14 more Swap Comparison 14 15 more Swap Comparison 9 10 more Swap Comparison 8 9 less Comparison 7 8 less Comparison 6 7 more Swap Comparison 5 6 less Comparison 4 5 more Swap Comparison 3 4 equal Comparison 2 3 less Comparison 1 2 less Comparison 10 11 more Swap Comparison 11 12 more Swap Comparison 12 13 more Swap Comparison 13 14 more Swap Comparison 9 10 less Comparison 8 9 less Comparison 7 8 more Swap Comparison 6 7 less Comparison 5 6 more Swap Comparison 4 5 less Comparison 3 4 equal Comparison 2 3 less Comparison 10 11 more Swap Comparison 11 12 more Swap Comparison 12 13 more Swap Comparison 9 10 more Swap Comparison 8 9 less Comparison 4 5 less Comparison 7 8 less Comparison 6 7 more Swap Comparison 5 6 less Comparison 3 4 equal Comparison 10 11 more Swap Comparison 11 12 more Swap Comparison 9 10 more Swap Comparison 8 9 more Swap Comparison 7 8 more Swap Comparison 6 7 equal Comparison 5 6 less Comparison 5 6 less Comparison 4 5 less Comparison 12 13 less Comparison 13 14 less Comparison 8 9 more Swap Comparison 10 11 more Swap Comparison 8 9 less Comparison 7 8 less Comparison 6 7 equal Comparison 9 10 more Swap Comparison 6 7 equal Comparison 10 11 more Swap Comparison 8 9 more Swap Comparison 4 5 less Comparison 11 12 more Swap Comparison 2 3 less Comparison 9 10 less Comparison 7 8 more Swap Comparison 1 2 less Comparison 12 13 more Swap Comparison 10 11 less Comparison 0 1 less Comparison 8 9 less Comparison 13 14 more Swap Comparison 5 6 less Comparison 8 9 less Comparison 14 15 more Swap Comparison 9 10 less Comparison 7 8 less Comparison 6 7 more Swap Comparison 4 5 less Comparison 11 12 less Comparison 3 4 equal Comparison 10 11 less Comparison 2 3 less Comparison 12 13 less Comparison 13 14 more Swap
# Episode 10100, loss:2.2176, succeed, steps:132, total reward:12.4000, 1.6309139728546143 sec
# Episode 10101, loss:4.7847, succeed, steps:168, total reward:25.3000, 2.130671739578247 sec
# Episode 10102, loss:0.2194, succeed, steps:179, total reward:14.8000, 2.224466562271118 sec
# Episode 10103, loss:3.1650, succeed, steps:197, total reward:26.2000, 2.7012410163879395 sec
# Episode 10104, loss:-14.0618, fail, steps:193, total reward:-5.5000, 3.0240073204040527 sec
# Episode 10105, loss:5.8174, succeed, steps:161, total reward:28.0000, 2.1745545864105225 sec
# Episode 10106, loss:2.7880, fail, steps:221, total reward:37.6000, 3.188631534576416 sec
# Episode 10107, loss:-5.9474, succeed, steps:167, total reward:-6.9000, 2.492133140563965 sec
# Episode 10108, loss:-2.0672, succeed, steps:123, total reward:8.1000, 1.7528326511383057 sec
# Episode 10109, loss:-1.4551, fail, steps:211, total reward:24.3000, 3.0836565494537354 sec
# Episode 10110, loss:4.6110, succeed, steps:177, total reward:28.3000, 2.369504928588867 sec
# Episode 10111, loss:1.7181, succeed, steps:120, total reward:22.1000, 1.6207809448242188 sec
# Episode 10112, loss:2.7342, succeed, steps:182, total reward:19.4000, 2.291266441345215 sec
# Episode 10113, loss:0.4560, succeed, steps:140, total reward:26.2000, 1.6602692604064941 sec
# Episode 10114, loss:0.3677, succeed, steps:78, total reward:-2.0000, 1.0256626605987549 sec
# Episode 10115, loss:3.0580, succeed, steps:128, total reward:12.8000, 1.5464894771575928 sec
# Episode 10116, loss:-4.1850, fail, steps:216, total reward:32.7000, 2.9870059490203857 sec
# Episode 10117, loss:2.7573, succeed, steps:165, total reward:12.4000, 2.296121120452881 sec
# Episode 10118, loss:2.5133, succeed, steps:142, total reward:28.1000, 1.7707428932189941 sec
# Episode 10119, loss:7.2508, succeed, steps:155, total reward:26.2000, 1.835057258605957 sec
# Episode 10120, loss:1.9807, succeed, steps:132, total reward:27.5000, 1.485609769821167 sec
# Episode 10121, loss:4.3857, succeed, steps:168, total reward:29.7000, 1.9473299980163574 sec
# Episode 10122, loss:0.6324, succeed, steps:165, total reward:9.9000, 2.152827262878418 sec
# Episode 10123, loss:-12.1978, fail, steps:201, total reward:8.8000, 2.9919803142547607 sec
# Episode 10124, loss:3.3829, succeed, steps:165, total reward:30.3000, 2.2157344818115234 sec
# Episode 10125, loss:3.7471, succeed, steps:167, total reward:23.4000, 2.170261859893799 sec
# Episode 10126, loss:1.0241, succeed, steps:117, total reward:10.4000, 1.49009370803833 sec
# Episode 10127, loss:9.9168, succeed, steps:120, total reward:19.4000, 1.3866639137268066 sec
# Episode 10128, loss:1.7984, succeed, steps:156, total reward:11.6000, 1.9008073806762695 sec
# Episode 10129, loss:1.4397, succeed, steps:196, total reward:30.4000, 2.528836250305176 sec
# Episode 10130, loss:3.1297, succeed, steps:195, total reward:24.2000, 2.5849227905273438 sec
# Episode 10131, loss:9.2631, succeed, steps:141, total reward:28.7000, 1.7521488666534424 sec
# Episode 10132, loss:6.4500, succeed, steps:200, total reward:37.0000, 2.4765994548797607 sec
# Episode 10133, loss:2.4344, succeed, steps:144, total reward:26.2000, 1.727442741394043 sec
# Episode 10134, loss:3.7406, succeed, steps:188, total reward:19.0000, 2.3697078227996826 sec
# Episode 10135, loss:3.3569, succeed, steps:147, total reward:27.0000, 1.87550687789917 sec
# Episode 10136, loss:12.0113, succeed, steps:192, total reward:29.0000, 2.341671943664551 sec
# Episode 10137, loss:2.5479, succeed, steps:130, total reward:17.8000, 1.6955409049987793 sec
# Episode 10138, loss:3.7217, succeed, steps:155, total reward:25.3000, 1.8118960857391357 sec
# Episode 10139, loss:3.2143, succeed, steps:160, total reward:39.9000, 1.8244664669036865 sec
# Episode 10140, loss:-4.7745, fail, steps:218, total reward:33.9000, 3.0742931365966797 sec
# Episode 10141, loss:4.3270, succeed, steps:184, total reward:23.7000, 2.49102520942688 sec
# Episode 10142, loss:9.5476, succeed, steps:220, total reward:42.7000, 2.9191527366638184 sec
# Episode 10143, loss:8.4854, succeed, steps:169, total reward:22.0000, 1.506601333618164 sec
# Episode 10144, loss:2.0336, succeed, steps:165, total reward:25.9000, 1.2861576080322266 sec
# Episode 10145, loss:4.1776, succeed, steps:217, total reward:34.5000, 2.026834011077881 sec
# Episode 10146, loss:-10.6917, fail, steps:205, total reward:17.8000, 1.8493094444274902 sec
# Episode 10147, loss:6.7666, succeed, steps:201, total reward:36.7000, 1.7340335845947266 sec
# Episode 10148, loss:5.7757, succeed, steps:165, total reward:39.4000, 1.2556796073913574 sec
# Episode 10149, loss:2.2897, succeed, steps:146, total reward:22.7000, 1.0322983264923096 sec
# Episode 10150, loss:1.9588, succeed, steps:147, total reward:16.5000, 1.1110739707946777 sec
# Episode 10151, loss:-5.4266, fail, steps:207, total reward:18.9000, 1.9100089073181152 sec
# Episode 10152, loss:5.8946, fail, steps:223, total reward:41.5000, 1.861752986907959 sec
# Episode 10153, loss:1.3146, succeed, steps:146, total reward:23.7000, 1.2515604496002197 sec
# Episode 10154, loss:-1.1460, succeed, steps:215, total reward:42.7000, 2.062361717224121 sec
# KeyboardInterrupt

# %%
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import random

MIN_LIST_LEN = 8
MAX_LIST_LEN = 8
MAX_STEPS = 210

SUCCESS_REWARD = 2.0
STEP_REWARD = -0.1
SWAP_REWARD = 1.0
INVALID_ACTION_REWARD = -10.0

EPS_START = 0.5
EPS_END = 0.05
EPS_DECAY = 1000
GAMMA = 0.8
NUM_EPISODES = 100000
EPISODES_SAVE = 1000
OUTPUT_DIR = 'datasets/rl_sort_transformer_easy/list6_transformer3_128_gamma08_step210_v1'

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    '0': 2,
    '1': 3,
    '2': 4,
    '3': 5,
    '4': 6,
    '5': 7,
    '6': 8,
    '7': 9,
    'less': 10,
    'equal': 11,
    'more': 12,
    'len1': 13,
    'len2': 14,
    'len3': 15,
    'len4': 16,
    'len5': 17,
    'len6': 18,
    'len7': 19,
    'len8': 20,
}
inv_vocab = {v: k for k, v in vocab.items()}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.list = [random.randint(1, 100) for _ in range(self.length)]
        while self.list == sorted(self.list):
            self.list = [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        initial_token = 'len{}'.format(self.length)
        return vocab[initial_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_list_len(self):
        return len(self.list)

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 >= self.length or index2 >= self.length or index1 < 0 or index2 < 0:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = STEP_REWARD
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = STEP_REWARD * 2
            else:
                response_token = vocab['more']
                reward = STEP_REWARD
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = INVALID_ACTION_REWARD
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = SUCCESS_REWARD
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = SWAP_REWARD
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -SWAP_REWARD
            else:
                reward = STEP_REWARD
            self.indices = None
        else:
            reward = INVALID_ACTION_REWARD
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()
# Out:
# Using device: cuda

# %%
# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=256):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=128, nhead=8, num_layers=3):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])


def save_checkpoint(model, optimizer, episode, folder, filename):
    """
    Save the model and optimizer state to the designated filepath.

    Args:
        model (nn.Module): The model to save.
        optimizer (torch.optim.Optimizer): The optimizer whose state to save.
        episode (int): The current episode number.
        filepath (str): The path where to save the checkpoint.
    """
    filepath = os.path.join(folder, filename)
    # Ensure the directory exists
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    # Save the checkpoint
    torch.save({
        'episode': episode,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, filepath)
    print(f"Checkpoint saved at episode {episode} to {filepath}")

def load_checkpoint(filepath, model, optimizer):
    """
    Load the model and optimizer state from the designated filepath.

    Args:
        filepath (str): The path from where to load the checkpoint.
        model (nn.Module): The model into which to load the state_dict.
        optimizer (torch.optim.Optimizer): The optimizer into which to load the state.

    Returns:
        int: The episode number to resume from.
    """
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        episode = checkpoint['episode']
        print(f"Checkpoint loaded from {filepath}, resuming from episode {episode}")
        return episode
    else:
        print(f"No checkpoint found at {filepath}, starting from scratch.")
        return 0

# %%
# Training Loop
def train(verbose=False):
    # Removed torch.autograd.set_detect_anomaly(True)
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Reduced learning rate
    # Optionally, load a checkpoint
    # load_checkpoint("path_to_checkpoint", model, optimizer)

    episode_cnt = 0
    total_reward = 0.0
    num_successes = 0
    total_steps = 0
    
    for episode in range(NUM_EPISODES):
        t1 = time.time()
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, current_list = env.reset()
        input_tokens = [initial_token_id]
        log_probs = []
        rewards = []
        
        state = 'expect_action'
        done = False
        success = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
                output = model(input_seq)  # (seq_len, batch_size, vocab_size)
                # Get logits for the last token
                logits = output[-1, 0, :]  # (vocab_size)

                # Check for NaNs in logits
                if torch.isnan(logits).any():
                    print(f"Episode {episode}, NaNs in logits before masking.")
                    break

                # Get valid tokens based on state
                def get_valid_tokens(state):
                    action_tokens = [vocab['Comparison'], vocab['Swap']]
                    index_tokens = [vocab[str(i)] for i in range(env.length)]
                    if state == 'expect_action':
                        return action_tokens
                    elif state == 'expect_index1':
                        return index_tokens[:-1]
                    elif state == 'expect_index2':
                        return [x for x in index_tokens if x > input_tokens[-1]]
                    else:
                        # Handle unexpected states by defaulting to expect_action
                        return action_tokens

                valid_token_ids = get_valid_tokens(state)

                # Ensure valid_token_ids are within the vocab range
                if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                    print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                    break

                # Mask invalid tokens
                mask_value = -1e9  # Use a large negative value instead of -inf
                mask = torch.full_like(logits, mask_value).to(device)
                mask[valid_token_ids] = 0
                masked_logits = logits + mask

                # Sample action. Have some chance to randomly pick a valid action.
                eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
                if random.random() < eps_threshold:
                    masked_logits = masked_logits / 4

                # Check for NaNs in masked_logits
                if torch.isnan(masked_logits).any():
                    print(f"Episode {episode}, NaNs in masked_logits after masking.")
                    break

                # Compute probabilities
                probs = F.softmax(masked_logits, dim=0)

                # Check for NaNs in probs
                if torch.isnan(probs).any():
                    print(f"Episode {episode}, NaNs in probs after softmax.")
                    break

                try:
                    m = torch.distributions.Categorical(probs)
                    action_token = m.sample()
                    log_prob = m.log_prob(action_token)
                except ValueError as e:
                    print(f"Episode {episode}, error in sampling action: {e}")
                    break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            reward = 0.0
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        reward = INVALID_ACTION_REWARD
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    if done and reward == SUCCESS_REWARD:
                        success = True
                    if verbose:
                        print("Reward:", reward)
                    state = 'expect_action'
                else:
                    reward = INVALID_ACTION_REWARD
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                response_token, reward, done, current_list = env.step(action_tokens)
                if done and reward == SUCCESS_REWARD:
                    success = True
                if verbose:
                    print("Reward:", reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                reward = INVALID_ACTION_REWARD
                done = True

            rewards.append(reward)
        #
        if success: 
            num_successes += 1
        # Save checkpoint
        if episode > 0 and episode % EPISODES_SAVE == 0:
            avg_reward = total_reward / episode_cnt
            success_rate = num_successes / episode_cnt
            avg_steps = total_steps / episode_cnt
            episode_cnt = 0
            total_reward = 0.0
            num_successes = 0
            total_steps = 0
            save_checkpoint(model, optimizer, episode, OUTPUT_DIR, f"ckpt_{episode}_{success_rate:.4f}_{avg_steps:.2f}.pth")
        #
        assert len(log_probs) == len(rewards), "log_probs and returns have different sizes!"

        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns and loss within autocast
        with torch.autocast(device_type=device.type, dtype=torch.bfloat16):
            # Compute returns
            returns = []
            R = 0
            gamma = GAMMA
            for r in rewards[::-1]:
                R = r + gamma * R
                returns.insert(0, R)
            returns = torch.tensor(returns).to(device)

            # Check for NaNs in returns
            if torch.isnan(returns).any():
                print(f"Episode {episode}, NaNs in returns.")
                continue

            # Compute loss
            loss = 0
            for log_prob, R in zip(log_probs, returns):
                loss -= log_prob * R

            # Check for NaNs in loss
            if torch.isnan(loss):
                print(f"Episode {episode}, NaN in loss.")
                continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        episode_cnt += 1
        total_reward += sum(rewards)
        total_steps += len(rewards)
        t2 = time.time()
        if episode % 1 == 0:
            print(f"Episode {episode}, loss:{loss.item():.4f}, {'succeed' if success else 'fail'}, steps:{len(rewards)}, total reward:{sum(rewards):.4f}, {t2-t1} sec")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Episode 0, loss:-47.1221, fail, steps:8, total reward:-11.2000, 0.3784205913543701 sec
# Episode 1, loss:-43.4430, fail, steps:11, total reward:-9.3000, 0.026682376861572266 sec
# Episode 2, loss:-5.9498, fail, steps:1, total reward:-10.0000, 0.0031452178955078125 sec
# Episode 3, loss:-3.2463, fail, steps:1, total reward:-10.0000, 0.0028829574584960938 sec
# Episode 4, loss:-58.3752, fail, steps:46, total reward:-12.4000, 0.10956645011901855 sec
# Episode 5, loss:-48.6245, fail, steps:14, total reward:-9.4000, 0.030432939529418945 sec
# Episode 6, loss:-7.0790, fail, steps:1, total reward:-10.0000, 0.003426074981689453 sec
# Episode 7, loss:-9.6680, fail, steps:1, total reward:-10.0000, 0.002936124801635742 sec
# Episode 8, loss:-59.8424, fail, steps:108, total reward:-11.3000, 0.32430577278137207 sec
# Episode 9, loss:-91.3233, fail, steps:18, total reward:-10.5000, 0.04279661178588867 sec
# Episode 10, loss:-75.9857, fail, steps:137, total reward:-14.4000, 0.300731897354126 sec
# Episode 11, loss:-13.0471, fail, steps:1, total reward:-10.0000, 0.009737014770507812 sec
# Episode 12, loss:-60.0682, fail, steps:85, total reward:-13.3000, 0.17770004272460938 sec
# Episode 13, loss:-43.6890, fail, steps:159, total reward:-7.9000, 0.355499267578125 sec
# Episode 14, loss:-66.1009, fail, steps:130, total reward:-13.2000, 0.2922830581665039 sec
# Episode 15, loss:-9.1611, fail, steps:159, total reward:-2.0000, 0.3548698425292969 sec
# Episode 16, loss:-72.7061, fail, steps:129, total reward:-14.2000, 0.29575443267822266 sec
# Episode 17, loss:-16.9959, fail, steps:158, total reward:-3.2000, 0.3532290458679199 sec
# Episode 18, loss:-75.2995, fail, steps:65, total reward:-11.1000, 0.15348529815673828 sec
# Episode 19, loss:-3.9608, fail, steps:159, total reward:-1.0000, 0.35025787353515625 sec
# Episode 20, loss:-39.8345, fail, steps:159, total reward:-7.1000, 0.35808563232421875 sec
# Episode 21, loss:-28.8443, fail, steps:158, total reward:-5.2000, 0.35753297805786133 sec
# Episode 22, loss:-26.9345, fail, steps:158, total reward:-5.1000, 0.35970377922058105 sec
# Episode 23, loss:-14.2417, fail, steps:158, total reward:-3.2000, 0.35990333557128906 sec
# Episode 24, loss:-21.5453, fail, steps:158, total reward:-4.1000, 0.3607168197631836 sec
# Episode 25, loss:-19.8727, fail, steps:1, total reward:-10.0000, 0.014194726943969727 sec
# Episode 26, loss:-27.2589, fail, steps:158, total reward:-5.4000, 0.339066743850708 sec
# Episode 27, loss:-83.1339, fail, steps:62, total reward:-13.0000, 0.14130711555480957 sec
# Episode 28, loss:-20.2445, fail, steps:1, total reward:-10.0000, 0.0063517093658447266 sec
# Episode 29, loss:-23.5633, fail, steps:158, total reward:-4.1000, 0.3285677433013916 sec
# Episode 30, loss:-67.0723, fail, steps:17, total reward:-9.5000, 0.043875932693481445 sec
# Episode 31, loss:-64.1186, fail, steps:20, total reward:-9.6000, 0.04249167442321777 sec
# Episode 32, loss:-40.8864, fail, steps:158, total reward:-7.2000, 0.3308260440826416 sec
# Episode 33, loss:-85.8084, fail, steps:89, total reward:-12.8000, 0.19941949844360352 sec
# Episode 34, loss:-15.3228, fail, steps:158, total reward:-3.1000, 0.34359049797058105 sec
# Episode 35, loss:-14.0930, fail, steps:158, total reward:-3.2000, 0.3534207344055176 sec
# Episode 36, loss:-9.8479, fail, steps:158, total reward:-2.1000, 0.37467479705810547 sec
# Episode 37, loss:-28.6979, fail, steps:158, total reward:-5.2000, 0.3584606647491455 sec
# Episode 38, loss:-21.2632, fail, steps:158, total reward:-4.1000, 0.3599557876586914 sec
# Episode 39, loss:-26.2857, fail, steps:158, total reward:-5.1000, 0.36018896102905273 sec
# Episode 40, loss:-19.4234, fail, steps:157, total reward:-4.2000, 0.35957789421081543 sec
# Episode 41, loss:-89.6803, fail, steps:124, total reward:-15.0000, 0.28631043434143066 sec
# Episode 42, loss:-30.8538, fail, steps:157, total reward:-6.2000, 0.3569467067718506 sec
# Episode 43, loss:-28.0322, fail, steps:158, total reward:-5.3000, 0.3588407039642334 sec
# Episode 44, loss:-23.6704, fail, steps:157, total reward:-5.2000, 0.4061400890350342 sec
# Episode 45, loss:-71.7097, fail, steps:110, total reward:-12.6000, 0.25580787658691406 sec
# Episode 46, loss:-77.6840, fail, steps:126, total reward:-12.1000, 0.2831404209136963 sec
# Episode 47, loss:-88.4124, fail, steps:89, total reward:-14.8000, 0.20145893096923828 sec
# Episode 48, loss:-24.3478, fail, steps:158, total reward:-5.2000, 0.35143613815307617 sec
# Episode 49, loss:-22.2168, fail, steps:158, total reward:-5.1000, 0.3593451976776123 sec
# Episode 50, loss:-18.6888, fail, steps:159, total reward:-3.1000, 0.3602330684661865 sec
# Episode 51, loss:-22.8682, fail, steps:1, total reward:-10.0000, 0.014093399047851562 sec
# Episode 52, loss:-7.3674, fail, steps:158, total reward:-2.4000, 0.3288278579711914 sec
# Episode 53, loss:-25.6202, fail, steps:158, total reward:-5.1000, 0.3468344211578369 sec
# Episode 54, loss:-15.2400, fail, steps:158, total reward:-3.6000, 0.35379648208618164 sec
# Episode 55, loss:-23.1494, fail, steps:1, total reward:-10.0000, 0.01325225830078125 sec
# Episode 56, loss:-19.6011, fail, steps:158, total reward:-4.1000, 0.3332374095916748 sec
# Episode 57, loss:-87.3780, fail, steps:135, total reward:-13.3000, 0.29682040214538574 sec
# Episode 58, loss:-14.0599, fail, steps:158, total reward:-4.1000, 0.34974074363708496 sec
# Episode 59, loss:-19.3645, fail, steps:158, total reward:-4.1000, 0.35645604133605957 sec
# Episode 60, loss:-23.1142, fail, steps:1, total reward:-10.0000, 0.013501882553100586 sec
# Episode 61, loss:5.7685, fail, steps:159, total reward:-1.1000, 0.3310108184814453 sec
# Episode 62, loss:-78.7368, fail, steps:151, total reward:-13.9000, 0.3331115245819092 sec
# Episode 63, loss:-91.0099, fail, steps:145, total reward:-14.6000, 0.3243906497955322 sec
# Episode 64, loss:-14.2932, fail, steps:158, total reward:-4.1000, 0.35855603218078613 sec
# Episode 65, loss:-43.8645, fail, steps:33, total reward:-9.0000, 0.08334851264953613 sec
# Episode 66, loss:-23.6789, fail, steps:1, total reward:-10.0000, 0.005285739898681641 sec
# Episode 67, loss:-11.2330, fail, steps:159, total reward:-2.0000, 0.331157922744751 sec
# Episode 68, loss:-13.8442, fail, steps:159, total reward:-3.0000, 0.34989452362060547 sec
# Episode 69, loss:-45.0335, fail, steps:101, total reward:-8.1000, 0.22930121421813965 sec
# Episode 70, loss:-58.9936, fail, steps:55, total reward:-9.6000, 0.12418866157531738 sec
# Episode 71, loss:-37.2027, fail, steps:138, total reward:-6.5000, 0.29682493209838867 sec
# Episode 72, loss:-6.6208, fail, steps:160, total reward:0.1000, 0.35618019104003906 sec
# Episode 73, loss:-43.3876, fail, steps:12, total reward:-8.3000, 0.038520097732543945 sec
# Episode 74, loss:-24.2114, fail, steps:1, total reward:-10.0000, 0.0040934085845947266 sec
# Episode 75, loss:-60.3137, fail, steps:32, total reward:-8.9000, 0.0670771598815918 sec
# Episode 76, loss:5.0411, fail, steps:160, total reward:2.7000, 0.33716464042663574 sec
# Episode 77, loss:-4.8303, fail, steps:158, total reward:-1.6000, 0.35089540481567383 sec
# Episode 78, loss:0.4324, fail, steps:160, total reward:3.1000, 0.3576531410217285 sec
# Episode 79, loss:6.5832, fail, steps:160, total reward:3.0000, 0.36165952682495117 sec
# Episode 80, loss:-44.2921, fail, steps:22, total reward:-7.6000, 0.060285091400146484 sec
# Episode 81, loss:-46.6132, fail, steps:17, total reward:-6.4000, 0.03825116157531738 sec
# Episode 82, loss:-20.4167, fail, steps:158, total reward:-4.1000, 0.33081984519958496 sec
# Episode 83, loss:7.6682, fail, steps:160, total reward:3.8000, 0.40312886238098145 sec
# Episode 84, loss:-3.5173, fail, steps:160, total reward:0.1000, 0.3599588871002197 sec
# Episode 85, loss:9.9095, fail, steps:160, total reward:6.1000, 0.36077404022216797 sec
# Episode 86, loss:2.4640, fail, steps:159, total reward:2.0000, 0.3606855869293213 sec
# Episode 87, loss:-57.0736, fail, steps:12, total reward:-10.3000, 0.039730072021484375 sec
# Episode 88, loss:8.3697, fail, steps:160, total reward:3.9000, 0.33879899978637695 sec
# Episode 89, loss:-3.8710, fail, steps:158, total reward:-0.1000, 0.35108470916748047 sec
# Episode 90, loss:-11.7745, fail, steps:95, total reward:0.3000, 0.219557523727417 sec
# Episode 91, loss:-0.2282, fail, steps:160, total reward:1.0000, 0.3510458469390869 sec
# Episode 92, loss:-1.4131, fail, steps:160, total reward:3.1000, 0.3614506721496582 sec
# Episode 93, loss:-32.2701, fail, steps:68, total reward:-5.0000, 0.16035079956054688 sec
# Episode 94, loss:3.8853, fail, steps:158, total reward:-0.1000, 0.3439908027648926 sec
# Episode 95, loss:1.9031, fail, steps:159, total reward:1.0000, 0.35780858993530273 sec
# Episode 96, loss:14.5926, fail, steps:160, total reward:5.1000, 0.3662145137786865 sec
# Episode 97, loss:-9.1198, fail, steps:159, total reward:-0.4000, 0.36095690727233887 sec
# Episode 98, loss:4.9960, fail, steps:160, total reward:3.1000, 0.3644695281982422 sec
# Episode 99, loss:14.1326, fail, steps:160, total reward:5.1000, 0.3646979331970215 sec
# Episode 100, loss:-42.0095, fail, steps:12, total reward:-8.3000, 0.039658308029174805 sec
# Episode 101, loss:-6.5579, fail, steps:159, total reward:1.0000, 0.33654212951660156 sec
# Episode 102, loss:3.0482, fail, steps:159, total reward:3.0000, 0.35297703742980957 sec
# Episode 103, loss:28.0112, fail, steps:161, total reward:7.9000, 0.36558032035827637 sec
# Episode 104, loss:7.6228, fail, steps:160, total reward:3.1000, 0.3613612651824951 sec
# Episode 105, loss:4.6008, fail, steps:160, total reward:2.8000, 0.3635590076446533 sec
# Episode 106, loss:2.8247, fail, steps:160, total reward:2.1000, 0.36405253410339355 sec
# Episode 107, loss:8.9188, fail, steps:159, total reward:3.3000, 0.3627738952636719 sec
# Episode 108, loss:-35.2669, fail, steps:44, total reward:-4.2000, 0.10901951789855957 sec
# Episode 109, loss:-7.9420, fail, steps:160, total reward:2.1000, 0.3453223705291748 sec
# Episode 110, loss:-60.7610, fail, steps:121, total reward:-5.6000, 0.27855539321899414 sec
# Episode 111, loss:14.5586, fail, steps:160, total reward:6.0000, 0.35546040534973145 sec
# Episode 112, loss:16.6355, fail, steps:160, total reward:6.1000, 0.36174631118774414 sec
# Episode 113, loss:-29.9615, fail, steps:160, total reward:-2.9000, 0.3646688461303711 sec
# Episode 114, loss:33.8230, succeed, steps:101, total reward:9.0000, 0.2348337173461914 sec
# Episode 115, loss:-46.0337, fail, steps:13, total reward:-7.3000, 0.03725481033325195 sec
# Episode 116, loss:38.5049, fail, steps:162, total reward:11.2000, 0.3416585922241211 sec
# Episode 117, loss:-5.2264, fail, steps:159, total reward:-0.0000, 0.3578324317932129 sec
# Episode 118, loss:-44.3195, fail, steps:117, total reward:-4.5000, 0.26681971549987793 sec
# Episode 119, loss:4.5691, fail, steps:161, total reward:5.1000, 0.35774970054626465 sec
# Episode 120, loss:2.9473, fail, steps:159, total reward:2.0000, 0.3601500988006592 sec
# Episode 121, loss:-60.9760, fail, steps:80, total reward:-7.4000, 0.18611383438110352 sec
# Episode 122, loss:-76.3350, fail, steps:74, total reward:-9.3000, 0.20908761024475098 sec
# Episode 123, loss:-47.8284, fail, steps:107, total reward:-5.2000, 0.23304963111877441 sec
# Episode 124, loss:-47.3566, fail, steps:42, total reward:-6.2000, 0.09616851806640625 sec
# Episode 125, loss:12.9193, fail, steps:160, total reward:5.5000, 0.34722185134887695 sec
# Episode 126, loss:-33.4349, fail, steps:77, total reward:-4.2000, 0.17556476593017578 sec
# Episode 127, loss:7.2643, fail, steps:160, total reward:4.1000, 0.34899067878723145 sec
# Episode 128, loss:-56.0716, fail, steps:21, total reward:-8.6000, 0.05641651153564453 sec
# Episode 129, loss:17.2183, fail, steps:160, total reward:6.1000, 0.3392958641052246 sec
# Episode 130, loss:-50.4241, fail, steps:65, total reward:-6.9000, 0.14842700958251953 sec
# Episode 131, loss:14.4153, succeed, steps:102, total reward:4.9000, 0.22132086753845215 sec
# Episode 132, loss:26.6057, fail, steps:162, total reward:10.3000, 0.35515475273132324 sec
# Episode 133, loss:8.2662, succeed, steps:145, total reward:5.6000, 0.33275532722473145 sec
# Episode 134, loss:27.3254, fail, steps:161, total reward:9.2000, 0.36212635040283203 sec
# Episode 135, loss:9.0737, fail, steps:160, total reward:5.1000, 0.3636035919189453 sec
# Episode 136, loss:26.0336, fail, steps:160, total reward:8.0000, 0.36388444900512695 sec
# Episode 137, loss:20.5205, fail, steps:161, total reward:8.2000, 0.36646270751953125 sec
# Episode 138, loss:-37.8079, fail, steps:37, total reward:-5.0000, 0.0931406021118164 sec
# Episode 139, loss:12.1268, succeed, steps:53, total reward:4.3000, 0.11438822746276855 sec
# Episode 140, loss:20.4519, fail, steps:160, total reward:8.1000, 0.34781932830810547 sec
# Episode 141, loss:-57.0208, fail, steps:133, total reward:-8.4000, 0.3076047897338867 sec
# Episode 142, loss:17.0351, succeed, steps:142, total reward:6.3000, 0.3182518482208252 sec
# Episode 143, loss:-3.6885, fail, steps:160, total reward:1.9000, 0.3595569133758545 sec
# Episode 144, loss:-0.9704, fail, steps:159, total reward:1.9000, 0.35923290252685547 sec
# Episode 145, loss:21.9021, fail, steps:161, total reward:8.2000, 0.3653542995452881 sec
# Episode 146, loss:-6.2555, fail, steps:160, total reward:2.1000, 0.37023115158081055 sec
# Episode 147, loss:8.9250, fail, steps:159, total reward:3.0000, 0.3741950988769531 sec
# Episode 148, loss:-12.3572, fail, steps:158, total reward:-1.1000, 0.38252782821655273 sec
# Episode 149, loss:-55.2613, fail, steps:72, total reward:-7.2000, 0.17091846466064453 sec
# Episode 150, loss:-7.0642, fail, steps:160, total reward:0.8000, 0.3495330810546875 sec
# Episode 151, loss:-34.8441, fail, steps:146, total reward:-3.4000, 0.3298947811126709 sec
# Episode 152, loss:-49.8119, fail, steps:55, total reward:-8.7000, 0.13042759895324707 sec
# Episode 153, loss:16.4540, fail, steps:161, total reward:6.2000, 0.3508782386779785 sec
# Episode 154, loss:-82.1823, fail, steps:160, total reward:-7.0000, 0.3599662780761719 sec
# Episode 155, loss:8.0624, fail, steps:160, total reward:4.1000, 0.3627943992614746 sec
# Episode 156, loss:-52.5829, fail, steps:22, total reward:-7.6000, 0.06096982955932617 sec
# Episode 157, loss:36.8919, succeed, steps:114, total reward:9.6000, 0.24196553230285645 sec
# Episode 158, loss:-57.0960, fail, steps:9, total reward:-8.2000, 0.02696990966796875 sec
# Episode 159, loss:10.0622, fail, steps:159, total reward:3.0000, 0.3332955837249756 sec
# Episode 160, loss:4.6168, fail, steps:160, total reward:3.9000, 0.3545956611633301 sec
# Episode 161, loss:-48.4106, fail, steps:83, total reward:-5.5000, 0.19082331657409668 sec
# Episode 162, loss:-3.0846, fail, steps:159, total reward:0.7000, 0.352508544921875 sec
# Episode 163, loss:15.6003, succeed, steps:81, total reward:4.5000, 0.18691682815551758 sec
# Episode 164, loss:19.7751, succeed, steps:130, total reward:7.0000, 0.33046483993530273 sec
# Episode 165, loss:21.5168, fail, steps:161, total reward:8.2000, 0.3578469753265381 sec
# Episode 166, loss:9.6554, fail, steps:160, total reward:5.0000, 0.3611636161804199 sec
# Episode 167, loss:-3.3690, fail, steps:159, total reward:2.0000, 0.362224817276001 sec
# Episode 168, loss:23.3206, fail, steps:161, total reward:8.2000, 0.37108898162841797 sec
# Episode 169, loss:-11.6110, fail, steps:160, total reward:1.1000, 0.3682260513305664 sec
# Episode 170, loss:0.2022, fail, steps:162, total reward:5.2000, 0.3690218925476074 sec
# Episode 171, loss:-5.1239, fail, steps:160, total reward:3.1000, 0.36556053161621094 sec
# Episode 172, loss:9.7690, fail, steps:159, total reward:4.0000, 0.3631119728088379 sec
# Episode 173, loss:-50.7555, fail, steps:35, total reward:-7.0000, 0.08925199508666992 sec
# Episode 174, loss:18.4018, fail, steps:160, total reward:7.1000, 0.34241604804992676 sec
# Episode 175, loss:8.8030, succeed, steps:36, total reward:2.9000, 0.08802056312561035 sec
# Episode 176, loss:15.7219, fail, steps:162, total reward:7.2000, 0.34975695610046387 sec
# Episode 177, loss:30.0361, succeed, steps:71, total reward:6.9000, 0.16364073753356934 sec
# Episode 178, loss:-27.9729, fail, steps:1, total reward:-10.0000, 0.007729768753051758 sec
# Episode 179, loss:-66.4363, fail, steps:128, total reward:-1.7000, 0.26445865631103516 sec
# Episode 180, loss:8.1913, fail, steps:159, total reward:3.0000, 0.34531736373901367 sec
# Episode 181, loss:9.5310, fail, steps:159, total reward:4.0000, 0.3554046154022217 sec
# Episode 182, loss:15.9014, succeed, steps:115, total reward:4.4000, 0.262157678604126 sec
# Episode 183, loss:7.5976, succeed, steps:155, total reward:6.3000, 0.34601593017578125 sec
# Episode 184, loss:-43.7262, fail, steps:42, total reward:-6.2000, 0.10503530502319336 sec
# Episode 185, loss:6.1520, fail, steps:161, total reward:5.1000, 0.3470301628112793 sec
# Episode 186, loss:21.1964, fail, steps:160, total reward:8.1000, 0.3567042350769043 sec
# Episode 187, loss:28.2703, fail, steps:161, total reward:8.2000, 0.3638033866882324 sec
# Episode 188, loss:25.4871, succeed, steps:98, total reward:9.0000, 0.22624754905700684 sec
# Episode 189, loss:-1.6484, fail, steps:159, total reward:1.8000, 0.3533635139465332 sec
# Episode 190, loss:4.7634, fail, steps:160, total reward:3.3000, 0.3625655174255371 sec
# Episode 191, loss:11.6588, fail, steps:159, total reward:4.0000, 0.36226654052734375 sec
# Episode 192, loss:34.4433, succeed, steps:89, total reward:9.4000, 0.20630335807800293 sec
# Episode 193, loss:3.6548, succeed, steps:123, total reward:2.7000, 0.27242517471313477 sec
# Episode 194, loss:-35.7212, fail, steps:53, total reward:-2.6000, 0.1222066879272461 sec
# Episode 195, loss:-91.0948, fail, steps:37, total reward:-9.0000, 0.08188509941101074 sec
# Episode 196, loss:31.6216, succeed, steps:148, total reward:10.6000, 0.3139669895172119 sec
# Episode 197, loss:18.7665, succeed, steps:112, total reward:6.7000, 0.2491757869720459 sec
# Episode 198, loss:-45.9893, fail, steps:37, total reward:-7.0000, 0.0862429141998291 sec
# Episode 199, loss:25.9910, succeed, steps:110, total reward:8.7000, 0.23392987251281738 sec
# Episode 200, loss:6.4770, fail, steps:160, total reward:4.1000, 0.3531379699707031 sec
# Episode 201, loss:-6.9997, fail, steps:159, total reward:1.8000, 0.35782361030578613 sec
# Episode 202, loss:34.1083, succeed, steps:101, total reward:9.0000, 0.23142123222351074 sec
# Episode 203, loss:-3.5653, fail, steps:159, total reward:0.8000, 0.35197973251342773 sec
# Episode 204, loss:17.3536, fail, steps:160, total reward:6.1000, 0.36169886589050293 sec
# Episode 205, loss:-48.8754, fail, steps:67, total reward:-6.3000, 0.20686626434326172 sec
# Episode 206, loss:7.9099, fail, steps:159, total reward:4.0000, 0.3460569381713867 sec
# Episode 207, loss:13.0090, fail, steps:160, total reward:6.1000, 0.36347055435180664 sec
# Episode 208, loss:8.2577, fail, steps:160, total reward:4.1000, 0.36309385299682617 sec
# Episode 209, loss:15.6136, fail, steps:160, total reward:5.8000, 0.3626840114593506 sec
# Episode 210, loss:21.4313, fail, steps:161, total reward:9.1000, 0.36638784408569336 sec
# Episode 211, loss:-4.3272, fail, steps:159, total reward:1.6000, 0.3631253242492676 sec
# Episode 212, loss:-5.9799, fail, steps:160, total reward:3.0000, 0.36910343170166016 sec
# Episode 213, loss:-29.2249, fail, steps:1, total reward:-10.0000, 0.014424800872802734 sec
# Episode 214, loss:-30.0399, fail, steps:1, total reward:-10.0000, 0.0036203861236572266 sec
# Episode 215, loss:7.5244, fail, steps:160, total reward:4.1000, 0.3315122127532959 sec
# Episode 216, loss:25.7350, fail, steps:160, total reward:8.1000, 0.35234951972961426 sec
# Episode 217, loss:19.8714, fail, steps:160, total reward:7.0000, 0.3578755855560303 sec
# Episode 218, loss:27.9366, succeed, steps:157, total reward:9.2000, 0.3536386489868164 sec
# Episode 219, loss:31.2138, succeed, steps:92, total reward:9.3000, 0.21184849739074707 sec
# Episode 220, loss:-20.0424, fail, steps:158, total reward:-2.7000, 0.3479604721069336 sec
# Episode 221, loss:-57.4464, fail, steps:27, total reward:-8.9000, 0.07183694839477539 sec
# Episode 222, loss:23.6754, succeed, steps:158, total reward:6.9000, 0.3445580005645752 sec
# Episode 223, loss:7.4347, fail, steps:160, total reward:4.9000, 0.3587162494659424 sec
# Episode 224, loss:24.1263, fail, steps:160, total reward:8.1000, 0.3599677085876465 sec
# Episode 225, loss:10.9464, fail, steps:160, total reward:5.0000, 0.36266303062438965 sec
# Episode 226, loss:-48.9857, fail, steps:12, total reward:-8.3000, 0.039618492126464844 sec
# Episode 227, loss:2.0976, fail, steps:160, total reward:4.1000, 0.33765149116516113 sec
# Episode 228, loss:22.8962, fail, steps:161, total reward:7.1000, 0.36096835136413574 sec
# Episode 229, loss:-13.8885, fail, steps:159, total reward:-1.4000, 0.35643553733825684 sec
# Episode 230, loss:14.4126, fail, steps:160, total reward:5.0000, 0.3618662357330322 sec
# Episode 231, loss:-0.0609, fail, steps:159, total reward:0.9000, 0.3608977794647217 sec
# Episode 232, loss:8.2116, fail, steps:159, total reward:4.0000, 0.3607795238494873 sec
# Episode 233, loss:7.6932, fail, steps:159, total reward:4.0000, 0.3624746799468994 sec
# Episode 234, loss:-2.3583, fail, steps:159, total reward:0.7000, 0.36557888984680176 sec
# Episode 235, loss:11.5261, fail, steps:160, total reward:6.0000, 0.3649024963378906 sec
# Episode 236, loss:30.9785, succeed, steps:123, total reward:9.3000, 0.2845141887664795 sec
# Episode 237, loss:3.2639, fail, steps:159, total reward:2.0000, 0.35712265968322754 sec
# Episode 238, loss:-48.4682, fail, steps:95, total reward:-2.8000, 0.22057008743286133 sec
# Episode 239, loss:12.1213, fail, steps:160, total reward:5.0000, 0.3541858196258545 sec
# Episode 240, loss:-43.5751, fail, steps:33, total reward:-5.9000, 0.08322024345397949 sec
# Episode 241, loss:14.0942, succeed, steps:149, total reward:5.4000, 0.3228001594543457 sec
# Episode 242, loss:34.8536, fail, steps:162, total reward:12.3000, 0.3659842014312744 sec
# Episode 243, loss:-44.5760, fail, steps:66, total reward:-5.9000, 0.15455269813537598 sec
# Episode 244, loss:22.7237, succeed, steps:118, total reward:7.3000, 0.2563939094543457 sec
# Episode 245, loss:14.2849, fail, steps:160, total reward:6.1000, 0.35280418395996094 sec
# Episode 246, loss:47.0521, fail, steps:162, total reward:14.3000, 0.3648395538330078 sec
# Episode 247, loss:-2.2395, fail, steps:160, total reward:2.1000, 0.41147398948669434 sec
# Episode 248, loss:-30.4115, fail, steps:1, total reward:-10.0000, 0.014096975326538086 sec
# Episode 249, loss:24.5785, fail, steps:161, total reward:10.2000, 0.3403968811035156 sec
# Episode 250, loss:-56.2156, fail, steps:92, total reward:-5.8000, 0.20353150367736816 sec
# Episode 251, loss:6.4819, fail, steps:160, total reward:4.1000, 0.3478062152862549 sec
# Episode 252, loss:5.3119, fail, steps:160, total reward:4.1000, 0.35958075523376465 sec
# Episode 253, loss:29.4001, succeed, steps:118, total reward:10.5000, 0.2712361812591553 sec
# Episode 254, loss:-48.0411, fail, steps:5, total reward:-9.1000, 0.02063441276550293 sec
# Episode 255, loss:27.1058, fail, steps:161, total reward:10.2000, 0.33656787872314453 sec
# Episode 256, loss:23.7866, succeed, steps:96, total reward:7.1000, 0.21370625495910645 sec
# Episode 257, loss:12.3871, succeed, steps:154, total reward:6.0000, 0.3412017822265625 sec
# Episode 258, loss:15.4517, fail, steps:160, total reward:6.1000, 0.35767126083374023 sec
# Episode 259, loss:-53.5330, fail, steps:46, total reward:-5.3000, 0.11000680923461914 sec
# Episode 260, loss:11.4823, fail, steps:161, total reward:7.1000, 0.3456454277038574 sec
# Episode 261, loss:25.7024, fail, steps:162, total reward:12.3000, 0.36134958267211914 sec
# Episode 262, loss:17.3001, fail, steps:160, total reward:7.1000, 0.36205124855041504 sec
# Episode 263, loss:-46.1544, fail, steps:23, total reward:-6.6000, 0.06254196166992188 sec
# Episode 264, loss:-35.6520, fail, steps:133, total reward:-2.2000, 0.2856161594390869 sec
# Episode 265, loss:17.9293, fail, steps:160, total reward:8.1000, 0.3537464141845703 sec
# Episode 266, loss:17.1526, succeed, steps:140, total reward:5.7000, 0.31638622283935547 sec
# Episode 267, loss:5.5376, fail, steps:161, total reward:5.1000, 0.36116719245910645 sec
# Episode 268, loss:2.9072, succeed, steps:155, total reward:4.9000, 0.35195422172546387 sec
# Episode 269, loss:-61.0346, fail, steps:133, total reward:-8.8000, 0.30388927459716797 sec
# Episode 270, loss:24.5513, succeed, steps:153, total reward:8.3000, 0.34593653678894043 sec
# Episode 271, loss:22.2191, succeed, steps:149, total reward:7.4000, 0.3440709114074707 sec
# Episode 272, loss:-31.5304, fail, steps:1, total reward:-10.0000, 0.013286352157592773 sec
# Episode 273, loss:-9.1518, fail, steps:160, total reward:1.0000, 0.33308935165405273 sec
# Episode 274, loss:30.5402, succeed, steps:134, total reward:12.7000, 0.29520535469055176 sec
# Episode 275, loss:37.2917, succeed, steps:131, total reward:11.1000, 0.29097509384155273 sec
# Episode 276, loss:8.6810, fail, steps:160, total reward:6.1000, 0.35491180419921875 sec
# Episode 277, loss:-52.6767, fail, steps:152, total reward:-7.8000, 0.34328532218933105 sec
# Episode 278, loss:18.8166, fail, steps:161, total reward:8.2000, 0.3677396774291992 sec
# Episode 279, loss:19.0662, succeed, steps:86, total reward:6.4000, 0.1991269588470459 sec
# Episode 280, loss:-6.9821, fail, steps:160, total reward:1.0000, 0.35135746002197266 sec
# Episode 281, loss:15.6804, fail, steps:160, total reward:6.1000, 0.3603394031524658 sec
# Episode 282, loss:18.0852, fail, steps:160, total reward:6.1000, 0.3626575469970703 sec
# Episode 283, loss:17.3528, succeed, steps:78, total reward:4.6000, 0.18213653564453125 sec
# Episode 284, loss:-44.6498, fail, steps:46, total reward:-5.3000, 0.10414361953735352 sec
# Episode 285, loss:16.7439, succeed, steps:101, total reward:5.7000, 0.21490168571472168 sec
# Episode 286, loss:8.1719, succeed, steps:136, total reward:3.7000, 0.30690455436706543 sec
# Episode 287, loss:2.1538, fail, steps:160, total reward:4.1000, 0.3542780876159668 sec
# Episode 288, loss:14.3131, fail, steps:161, total reward:7.1000, 0.3628818988800049 sec
# Episode 289, loss:18.5237, succeed, steps:74, total reward:6.8000, 0.1727445125579834 sec
# Episode 290, loss:9.8575, fail, steps:159, total reward:4.0000, 0.3481109142303467 sec
# Episode 291, loss:11.8616, fail, steps:162, total reward:7.2000, 0.41333651542663574 sec
# Episode 292, loss:-15.9092, fail, steps:158, total reward:-3.1000, 0.3641841411590576 sec
# Episode 293, loss:2.8848, fail, steps:159, total reward:2.0000, 0.36150431632995605 sec
# Episode 294, loss:-1.2306, fail, steps:160, total reward:3.0000, 0.39847540855407715 sec
# Episode 295, loss:5.8904, succeed, steps:55, total reward:3.3000, 0.1781299114227295 sec
# Episode 296, loss:28.2345, succeed, steps:93, total reward:10.3000, 0.22210907936096191 sec
# Episode 297, loss:6.3113, fail, steps:160, total reward:4.6000, 0.3798344135284424 sec
# Episode 298, loss:8.7002, fail, steps:160, total reward:4.6000, 0.38762760162353516 sec
# Episode 299, loss:-0.1657, fail, steps:159, total reward:2.6000, 0.3711397647857666 sec
# Episode 300, loss:31.7272, succeed, steps:126, total reward:9.2000, 0.28988027572631836 sec
# Episode 301, loss:27.4845, succeed, steps:72, total reward:7.7000, 0.16529512405395508 sec
# Episode 302, loss:11.7283, fail, steps:160, total reward:6.1000, 0.3503568172454834 sec
# Episode 303, loss:-4.6136, fail, steps:159, total reward:2.0000, 0.35898804664611816 sec
# Episode 304, loss:-3.1193, fail, steps:159, total reward:1.0000, 0.36243295669555664 sec
# Episode 305, loss:4.1182, fail, steps:159, total reward:3.0000, 0.38632750511169434 sec
# Episode 306, loss:-43.8402, fail, steps:9, total reward:-8.2000, 0.033701181411743164 sec
# Episode 307, loss:18.2846, succeed, steps:89, total reward:6.3000, 0.18613076210021973 sec
# Episode 308, loss:18.5332, fail, steps:160, total reward:7.1000, 0.34439682960510254 sec
# Episode 309, loss:-33.7845, fail, steps:1, total reward:-10.0000, 0.012475252151489258 sec
# Episode 310, loss:11.3820, fail, steps:160, total reward:6.1000, 0.3348653316497803 sec
# Episode 311, loss:14.7533, fail, steps:160, total reward:6.1000, 0.35216331481933594 sec
# Episode 312, loss:42.0759, fail, steps:162, total reward:14.3000, 0.3647594451904297 sec
# Episode 313, loss:9.4913, fail, steps:160, total reward:5.0000, 0.36623120307922363 sec
# Episode 314, loss:-36.5804, fail, steps:78, total reward:-4.3000, 0.1816093921661377 sec
# Episode 315, loss:-24.3647, fail, steps:72, total reward:-1.0000, 0.16042089462280273 sec
# Episode 316, loss:12.4517, fail, steps:161, total reward:6.2000, 0.3500211238861084 sec
# Episode 317, loss:28.7786, succeed, steps:113, total reward:11.7000, 0.25821924209594727 sec
# Episode 318, loss:15.1116, succeed, steps:157, total reward:7.7000, 0.3493311405181885 sec
# Episode 319, loss:15.7711, succeed, steps:99, total reward:5.8000, 0.22813820838928223 sec
# Episode 320, loss:14.9723, fail, steps:161, total reward:7.1000, 0.35666966438293457 sec
# Episode 321, loss:21.9776, succeed, steps:99, total reward:8.8000, 0.23262333869934082 sec
# Episode 322, loss:6.2063, fail, steps:160, total reward:3.7000, 0.35576295852661133 sec
# Episode 323, loss:-76.4906, fail, steps:133, total reward:-4.0000, 0.30382609367370605 sec
# Episode 324, loss:3.0280, fail, steps:161, total reward:3.5000, 0.3616518974304199 sec
# Episode 325, loss:-48.6272, fail, steps:66, total reward:-3.9000, 0.15635895729064941 sec
# Episode 326, loss:25.0889, fail, steps:161, total reward:10.0000, 0.35146546363830566 sec
# Episode 327, loss:7.7442, succeed, steps:149, total reward:3.7000, 0.3370542526245117 sec
# Episode 328, loss:28.5506, succeed, steps:123, total reward:9.3000, 0.28507208824157715 sec
# Episode 329, loss:14.4009, succeed, steps:148, total reward:7.5000, 0.3317716121673584 sec
# Episode 330, loss:20.7548, succeed, steps:121, total reward:7.3000, 0.3286597728729248 sec
# Episode 331, loss:36.6782, succeed, steps:143, total reward:13.8000, 0.32184910774230957 sec
# Episode 332, loss:13.8069, fail, steps:160, total reward:5.0000, 0.3620595932006836 sec
# Episode 333, loss:2.8338, fail, steps:160, total reward:3.0000, 0.3641488552093506 sec
# Episode 334, loss:24.9840, succeed, steps:100, total reward:8.0000, 0.233900785446167 sec
# Episode 335, loss:13.3949, fail, steps:160, total reward:5.0000, 0.35852694511413574 sec
# Episode 336, loss:16.1083, fail, steps:160, total reward:8.1000, 0.3635213375091553 sec
# Episode 337, loss:27.9619, succeed, steps:50, total reward:7.6000, 0.12127852439880371 sec
# Episode 338, loss:1.9688, fail, steps:160, total reward:2.9000, 0.3471217155456543 sec
# Episode 339, loss:-52.1245, fail, steps:17, total reward:-6.4000, 0.047971248626708984 sec
# Episode 340, loss:24.9259, fail, steps:161, total reward:10.2000, 0.3421342372894287 sec
# Episode 341, loss:25.3032, fail, steps:161, total reward:10.2000, 0.35744261741638184 sec
# Episode 342, loss:15.5606, fail, steps:161, total reward:7.1000, 0.36782264709472656 sec
# Episode 343, loss:-39.1762, fail, steps:96, total reward:-4.9000, 0.22380661964416504 sec
# Episode 344, loss:19.6194, fail, steps:161, total reward:9.1000, 0.3553328514099121 sec
# Episode 345, loss:17.0905, fail, steps:160, total reward:6.1000, 0.3612494468688965 sec
# Episode 346, loss:-60.6969, fail, steps:29, total reward:-6.8000, 0.07555627822875977 sec
# Episode 347, loss:14.5526, succeed, steps:142, total reward:6.6000, 0.30264997482299805 sec
# Episode 348, loss:-0.3078, fail, steps:160, total reward:2.7000, 0.35446906089782715 sec
# Episode 349, loss:5.4345, fail, steps:159, total reward:3.8000, 0.3798840045928955 sec
# Episode 350, loss:33.6514, fail, steps:162, total reward:12.3000, 0.3677356243133545 sec
# Episode 351, loss:23.2832, fail, steps:160, total reward:8.1000, 0.36422204971313477 sec
# Episode 352, loss:-50.7262, fail, steps:8, total reward:-9.2000, 0.030259370803833008 sec
# Episode 353, loss:12.6075, fail, steps:160, total reward:6.0000, 0.3365325927734375 sec
# Episode 354, loss:17.5797, succeed, steps:126, total reward:6.0000, 0.27989697456359863 sec
# Episode 355, loss:18.3143, fail, steps:160, total reward:6.1000, 0.3536832332611084 sec
# Episode 356, loss:22.3227, fail, steps:160, total reward:8.1000, 0.36774682998657227 sec
# Episode 357, loss:13.3177, fail, steps:160, total reward:6.1000, 0.36290669441223145 sec
# Episode 358, loss:-60.7239, fail, steps:17, total reward:-9.5000, 0.049626827239990234 sec
# Episode 359, loss:22.7408, succeed, steps:84, total reward:7.5000, 0.1764848232269287 sec
# Episode 360, loss:30.3951, succeed, steps:150, total reward:11.5000, 0.3231642246246338 sec
# Episode 361, loss:9.5042, fail, steps:159, total reward:4.0000, 0.353381872177124 sec
# Episode 362, loss:9.6682, fail, steps:160, total reward:5.0000, 0.3609130382537842 sec
# Episode 363, loss:-7.2746, fail, steps:159, total reward:-0.0000, 0.3659038543701172 sec
# Episode 364, loss:-52.5630, fail, steps:45, total reward:-6.3000, 0.10979962348937988 sec
# Episode 365, loss:4.2879, fail, steps:161, total reward:5.1000, 0.34691691398620605 sec
# Episode 366, loss:8.4477, fail, steps:160, total reward:5.0000, 0.4092414379119873 sec
# Episode 367, loss:20.0050, succeed, steps:121, total reward:7.3000, 0.2765004634857178 sec
# Episode 368, loss:25.0354, succeed, steps:109, total reward:9.2000, 0.24591946601867676 sec
# Episode 369, loss:32.2590, fail, steps:161, total reward:11.2000, 0.3565375804901123 sec
# Episode 370, loss:6.5928, succeed, steps:151, total reward:3.2000, 0.3475058078765869 sec
# Episode 371, loss:13.8859, fail, steps:161, total reward:7.5000, 0.36415982246398926 sec
# Episode 372, loss:28.0582, fail, steps:161, total reward:11.2000, 0.36769556999206543 sec
# Episode 373, loss:27.7265, succeed, steps:137, total reward:10.9000, 0.3146188259124756 sec
# Episode 374, loss:10.6717, succeed, steps:56, total reward:4.2000, 0.13204097747802734 sec
# Episode 375, loss:4.6930, fail, steps:159, total reward:2.0000, 0.3445546627044678 sec
# Episode 376, loss:28.8073, fail, steps:161, total reward:12.2000, 0.36161017417907715 sec
# Episode 377, loss:10.1685, fail, steps:160, total reward:4.2000, 0.36710453033447266 sec
# Episode 378, loss:26.0534, fail, steps:161, total reward:9.1000, 0.36586642265319824 sec
# Episode 379, loss:-1.3785, fail, steps:159, total reward:2.0000, 0.3620188236236572 sec
# Episode 380, loss:20.7502, fail, steps:161, total reward:7.9000, 0.36703062057495117 sec
# Episode 381, loss:-5.2164, fail, steps:158, total reward:-1.1000, 0.36168432235717773 sec
# Episode 382, loss:-31.3446, fail, steps:119, total reward:-0.5000, 0.2758002281188965 sec
# Episode 383, loss:17.3865, fail, steps:161, total reward:8.7000, 0.36423730850219727 sec
# Episode 384, loss:-55.1081, fail, steps:57, total reward:-5.6000, 0.1367199420928955 sec
# Episode 385, loss:17.6174, succeed, steps:63, total reward:8.1000, 0.13873648643493652 sec
# Episode 386, loss:-5.4921, fail, steps:159, total reward:0.7000, 0.34300971031188965 sec
# Episode 387, loss:-39.2605, fail, steps:98, total reward:-3.1000, 0.2227935791015625 sec
# Episode 388, loss:0.0318, fail, steps:160, total reward:3.0000, 0.35203051567077637 sec
# Episode 389, loss:6.0932, fail, steps:159, total reward:3.0000, 0.3594503402709961 sec
# Episode 390, loss:-3.9826, fail, steps:159, total reward:0.3000, 0.3656322956085205 sec
# Episode 391, loss:12.4510, fail, steps:160, total reward:6.1000, 0.3636481761932373 sec
# Episode 392, loss:20.1413, succeed, steps:142, total reward:9.7000, 0.32564878463745117 sec
# Episode 393, loss:17.0737, fail, steps:160, total reward:6.1000, 0.36211156845092773 sec
# Episode 394, loss:29.8618, fail, steps:161, total reward:12.2000, 0.3665742874145508 sec
# Episode 395, loss:5.1893, succeed, steps:88, total reward:3.3000, 0.20622968673706055 sec
# Episode 396, loss:32.2161, succeed, steps:138, total reward:11.9000, 0.3052670955657959 sec
# Episode 397, loss:27.9165, fail, steps:161, total reward:9.1000, 0.3632798194885254 sec
# Episode 398, loss:26.2600, succeed, steps:154, total reward:12.4000, 0.34957456588745117 sec
# Episode 399, loss:0.3263, fail, steps:160, total reward:4.1000, 0.36216163635253906 sec
# Episode 400, loss:18.5350, fail, steps:160, total reward:8.1000, 0.3640310764312744 sec
# Episode 401, loss:13.3067, succeed, steps:101, total reward:5.9000, 0.2345287799835205 sec
# Episode 402, loss:-46.6075, fail, steps:32, total reward:-6.9000, 0.0763709545135498 sec
# Episode 403, loss:0.9458, fail, steps:159, total reward:2.0000, 0.39052319526672363 sec
# Episode 404, loss:33.2757, succeed, steps:130, total reward:13.8000, 0.2927365303039551 sec
# Episode 405, loss:23.1771, succeed, steps:100, total reward:8.0000, 0.2270519733428955 sec
# Episode 406, loss:31.1013, succeed, steps:102, total reward:10.0000, 0.2263805866241455 sec
# Episode 407, loss:31.4200, fail, steps:161, total reward:10.1000, 0.3535640239715576 sec
# Episode 408, loss:23.1607, succeed, steps:133, total reward:10.0000, 0.30167198181152344 sec
# Episode 409, loss:8.4809, fail, steps:161, total reward:5.7000, 0.36118292808532715 sec
# Episode 410, loss:9.9991, fail, steps:159, total reward:4.0000, 0.36197543144226074 sec
# Episode 411, loss:25.8381, fail, steps:161, total reward:9.1000, 0.3676795959472656 sec
# Episode 412, loss:-11.2517, fail, steps:160, total reward:1.6000, 0.3638589382171631 sec
# Episode 413, loss:3.1324, fail, steps:159, total reward:4.0000, 0.3632216453552246 sec
# Episode 414, loss:-8.1257, fail, steps:158, total reward:-0.1000, 0.3612642288208008 sec
# Episode 415, loss:25.7520, fail, steps:161, total reward:10.2000, 0.3672935962677002 sec
# Episode 416, loss:21.5227, fail, steps:161, total reward:9.1000, 0.37235093116760254 sec
# Episode 417, loss:2.0343, fail, steps:159, total reward:2.0000, 0.364285945892334 sec
# Episode 418, loss:21.1988, fail, steps:161, total reward:9.1000, 0.36798667907714844 sec
# Episode 419, loss:23.0426, succeed, steps:145, total reward:10.7000, 0.3331763744354248 sec
# Episode 420, loss:-2.8055, fail, steps:159, total reward:2.0000, 0.361666202545166 sec
# Episode 421, loss:-42.4615, fail, steps:92, total reward:-2.7000, 0.21454572677612305 sec
# Episode 422, loss:25.7096, fail, steps:161, total reward:10.2000, 0.358745813369751 sec
# Episode 423, loss:21.1178, fail, steps:161, total reward:9.2000, 0.3647942543029785 sec
# Episode 424, loss:10.7690, fail, steps:160, total reward:6.1000, 0.36346912384033203 sec
# Episode 425, loss:3.7338, fail, steps:160, total reward:3.0000, 0.36626172065734863 sec
# Episode 426, loss:-11.4973, fail, steps:159, total reward:-1.0000, 0.36347174644470215 sec
# Episode 427, loss:10.7119, fail, steps:160, total reward:6.1000, 0.36524081230163574 sec
# Episode 428, loss:21.9044, fail, steps:161, total reward:9.1000, 0.3718092441558838 sec
# Episode 429, loss:-3.9604, fail, steps:159, total reward:1.0000, 0.36467742919921875 sec
# Episode 430, loss:19.6479, fail, steps:160, total reward:7.1000, 0.36566638946533203 sec
# Episode 431, loss:-1.8730, fail, steps:159, total reward:2.0000, 0.36348795890808105 sec
# Episode 432, loss:15.7221, fail, steps:160, total reward:7.3000, 0.36527228355407715 sec
# Episode 433, loss:40.8678, fail, steps:162, total reward:16.3000, 0.3704047203063965 sec
# Episode 434, loss:25.6924, fail, steps:161, total reward:10.2000, 0.42270326614379883 sec
# Episode 435, loss:-1.1421, fail, steps:161, total reward:4.2000, 0.3688061237335205 sec
# Episode 436, loss:13.7934, succeed, steps:135, total reward:6.9000, 0.3123204708099365 sec
# Episode 437, loss:8.3100, fail, steps:159, total reward:4.0000, 0.3595292568206787 sec
# Episode 438, loss:17.1521, succeed, steps:140, total reward:7.7000, 0.32079505920410156 sec
# Episode 439, loss:10.9444, succeed, steps:122, total reward:7.4000, 0.27982521057128906 sec
# Episode 440, loss:-11.1444, fail, steps:158, total reward:-1.1000, 0.3639366626739502 sec
# Episode 441, loss:13.6604, fail, steps:160, total reward:6.1000, 0.3671905994415283 sec
# Episode 442, loss:24.5912, fail, steps:161, total reward:10.2000, 0.366534948348999 sec
# Episode 443, loss:17.7342, fail, steps:160, total reward:6.1000, 0.3650972843170166 sec
# Episode 444, loss:5.1344, fail, steps:161, total reward:6.2000, 0.3669884204864502 sec
# Episode 445, loss:25.4999, succeed, steps:88, total reward:8.4000, 0.20726346969604492 sec
# Episode 446, loss:12.8030, succeed, steps:92, total reward:6.2000, 0.20704984664916992 sec
# Episode 447, loss:12.4175, fail, steps:160, total reward:6.1000, 0.3531670570373535 sec
# Episode 448, loss:22.1536, succeed, steps:89, total reward:9.4000, 0.20609164237976074 sec
# Episode 449, loss:9.9786, fail, steps:160, total reward:5.0000, 0.3527798652648926 sec
# Episode 450, loss:1.0442, fail, steps:159, total reward:3.0000, 0.3588285446166992 sec
# Episode 451, loss:-63.8134, fail, steps:82, total reward:-6.5000, 0.19048714637756348 sec
# Episode 452, loss:-0.1312, fail, steps:161, total reward:5.1000, 0.3525991439819336 sec
# Episode 453, loss:9.0318, fail, steps:160, total reward:4.5000, 0.3664991855621338 sec
# Episode 454, loss:13.0111, fail, steps:160, total reward:7.0000, 0.3627779483795166 sec
# Episode 455, loss:-1.9935, fail, steps:159, total reward:0.9000, 0.3631417751312256 sec
# Episode 456, loss:-1.8103, fail, steps:160, total reward:3.0000, 0.36649060249328613 sec
# Episode 457, loss:15.0573, fail, steps:162, total reward:9.2000, 0.36800551414489746 sec
# Episode 458, loss:-6.3908, fail, steps:158, total reward:-0.1000, 0.36118173599243164 sec
# Episode 459, loss:15.2264, fail, steps:160, total reward:6.0000, 0.3686518669128418 sec
# Episode 460, loss:18.8800, fail, steps:161, total reward:9.2000, 0.36809253692626953 sec
# Episode 461, loss:21.7363, fail, steps:161, total reward:9.1000, 0.3675568103790283 sec
# Episode 462, loss:14.9144, fail, steps:161, total reward:6.2000, 0.36817455291748047 sec
# Episode 463, loss:9.1429, fail, steps:160, total reward:4.4000, 0.3656649589538574 sec
# Episode 464, loss:10.7552, fail, steps:160, total reward:5.9000, 0.3653066158294678 sec
# Episode 465, loss:22.3099, succeed, steps:159, total reward:8.1000, 0.3678879737854004 sec
# Episode 466, loss:14.9040, succeed, steps:92, total reward:6.1000, 0.21511220932006836 sec
# Episode 467, loss:14.5270, succeed, steps:138, total reward:5.7000, 0.35044384002685547 sec
# Episode 468, loss:12.2457, succeed, steps:98, total reward:6.0000, 0.22340774536132812 sec
# Episode 469, loss:18.9113, fail, steps:161, total reward:9.1000, 0.35526418685913086 sec
# Episode 470, loss:22.0128, succeed, steps:122, total reward:8.3000, 0.28003358840942383 sec
# Episode 471, loss:14.1866, fail, steps:160, total reward:5.3000, 0.35936474800109863 sec
# Episode 472, loss:7.1084, fail, steps:159, total reward:3.6000, 0.3616788387298584 sec
# Episode 473, loss:31.4510, succeed, steps:96, total reward:10.2000, 0.22282814979553223 sec
# Episode 474, loss:15.8962, fail, steps:160, total reward:6.1000, 0.3543872833251953 sec
# Episode 475, loss:33.5184, fail, steps:162, total reward:13.2000, 0.36645054817199707 sec
# Episode 476, loss:4.2930, fail, steps:159, total reward:3.0000, 0.362499475479126 sec
# Episode 477, loss:17.4768, succeed, steps:127, total reward:9.3000, 0.2917931079864502 sec
# Episode 478, loss:-4.5397, fail, steps:159, total reward:-0.3000, 0.362030029296875 sec
# Episode 479, loss:9.5497, fail, steps:160, total reward:6.1000, 0.36396050453186035 sec
# Episode 480, loss:-54.5936, fail, steps:63, total reward:-6.9000, 0.14936470985412598 sec
# Episode 481, loss:35.5577, fail, steps:162, total reward:13.2000, 0.3520374298095703 sec
# Episode 482, loss:24.1684, succeed, steps:143, total reward:10.7000, 0.3244946002960205 sec
# Episode 483, loss:-38.7577, fail, steps:30, total reward:-5.8000, 0.0756068229675293 sec
# Episode 484, loss:39.3021, fail, steps:162, total reward:14.3000, 0.345564603805542 sec
# Episode 485, loss:1.8172, fail, steps:159, total reward:2.0000, 0.3586399555206299 sec
# Episode 486, loss:13.8856, fail, steps:160, total reward:6.1000, 0.3616983890533447 sec
# Episode 487, loss:15.8041, fail, steps:160, total reward:5.0000, 0.3624255657196045 sec
# Episode 488, loss:11.7705, fail, steps:161, total reward:8.2000, 0.36565136909484863 sec
# Episode 489, loss:25.9659, succeed, steps:133, total reward:11.1000, 0.3041548728942871 sec
# Episode 490, loss:11.1700, succeed, steps:47, total reward:4.6000, 0.1112372875213623 sec
# Episode 491, loss:18.2156, fail, steps:160, total reward:8.1000, 0.34414172172546387 sec
# Episode 492, loss:25.9416, fail, steps:161, total reward:8.8000, 0.36466240882873535 sec
# Episode 493, loss:11.9613, fail, steps:159, total reward:4.0000, 0.35993027687072754 sec
# Episode 494, loss:-37.3510, fail, steps:1, total reward:-10.0000, 0.013976335525512695 sec
# Episode 495, loss:14.8521, succeed, steps:99, total reward:6.6000, 0.20365238189697266 sec
# Episode 496, loss:-23.2431, fail, steps:150, total reward:2.6000, 0.32214879989624023 sec
# Episode 497, loss:-2.2656, fail, steps:159, total reward:0.9000, 0.35193920135498047 sec
# Episode 498, loss:33.1654, succeed, steps:124, total reward:13.1000, 0.2812464237213135 sec
# Episode 499, loss:-57.4071, fail, steps:40, total reward:-5.1000, 0.09397220611572266 sec
# Episode 500, loss:25.1872, succeed, steps:142, total reward:9.7000, 0.3091278076171875 sec
# Episode 501, loss:18.6118, fail, steps:160, total reward:7.1000, 0.35430192947387695 sec
# Episode 502, loss:26.2341, fail, steps:161, total reward:11.2000, 0.362210750579834 sec
# Episode 503, loss:24.5589, succeed, steps:133, total reward:10.0000, 0.3032054901123047 sec
# Episode 504, loss:-49.8153, fail, steps:5, total reward:-9.1000, 0.021728515625 sec
# Episode 505, loss:28.4410, succeed, steps:112, total reward:10.7000, 0.23244619369506836 sec
# Episode 506, loss:16.9291, fail, steps:160, total reward:7.6000, 0.34647035598754883 sec
# Episode 507, loss:32.8578, fail, steps:161, total reward:10.2000, 0.4100687503814697 sec
# Episode 508, loss:15.7679, succeed, steps:116, total reward:5.4000, 0.269179105758667 sec
# Episode 509, loss:19.2204, fail, steps:160, total reward:7.1000, 0.3616349697113037 sec
# Episode 510, loss:4.5962, fail, steps:159, total reward:1.8000, 0.36597347259521484 sec
# Episode 511, loss:29.9005, succeed, steps:111, total reward:12.8000, 0.25539112091064453 sec
# Episode 512, loss:0.1424, fail, steps:160, total reward:3.4000, 0.3551514148712158 sec
# Episode 513, loss:-42.5020, fail, steps:79, total reward:-3.4000, 0.1830615997314453 sec
# Episode 514, loss:29.6031, fail, steps:161, total reward:11.2000, 0.35840773582458496 sec
# Episode 515, loss:5.2711, fail, steps:160, total reward:3.0000, 0.3601198196411133 sec
# Episode 516, loss:23.6615, succeed, steps:115, total reward:11.7000, 0.26285791397094727 sec
# Episode 517, loss:23.9245, fail, steps:161, total reward:9.1000, 0.3594779968261719 sec
# Episode 518, loss:9.5628, fail, steps:160, total reward:4.4000, 0.3614637851715088 sec
# Episode 519, loss:5.3206, fail, steps:159, total reward:2.0000, 0.36229872703552246 sec
# Episode 520, loss:10.7977, fail, steps:159, total reward:4.0000, 0.3667478561401367 sec
# Episode 521, loss:18.0952, fail, steps:160, total reward:8.1000, 0.3639249801635742 sec
# Episode 522, loss:17.4221, fail, steps:161, total reward:9.1000, 0.3678584098815918 sec
# Episode 523, loss:8.6978, fail, steps:159, total reward:4.0000, 0.363178014755249 sec
# Episode 524, loss:21.0599, fail, steps:161, total reward:9.6000, 0.36736011505126953 sec
# Episode 525, loss:-5.9966, fail, steps:159, total reward:0.3000, 0.3635251522064209 sec
# Episode 526, loss:13.2943, succeed, steps:107, total reward:5.7000, 0.25348377227783203 sec
# Episode 527, loss:17.8320, fail, steps:160, total reward:7.1000, 0.3573932647705078 sec
# Episode 528, loss:18.8776, succeed, steps:134, total reward:7.7000, 0.30693483352661133 sec
# Episode 529, loss:13.2572, fail, steps:160, total reward:7.5000, 0.35990262031555176 sec
# Episode 530, loss:12.0468, fail, steps:160, total reward:6.1000, 0.3640139102935791 sec
# Episode 531, loss:14.4597, fail, steps:160, total reward:8.1000, 0.36446094512939453 sec
# Episode 532, loss:11.6626, fail, steps:160, total reward:6.1000, 0.3699195384979248 sec
# ...
# Episode 12138, loss:4.0057, succeed, steps:146, total reward:13.7000, 0.60845947265625 sec
# Episode 12139, loss:3.0389, succeed, steps:138, total reward:14.5000, 0.580155611038208 sec
# Episode 12140, loss:0.6206, fail, steps:161, total reward:12.2000, 0.7013700008392334 sec
# Episode 12141, loss:2.1397, succeed, steps:57, total reward:8.4000, 0.23358511924743652 sec
# Episode 12142, loss:4.1925, succeed, steps:92, total reward:9.3000, 0.3546936511993408 sec
# Episode 12143, loss:3.6562, succeed, steps:138, total reward:15.0000, 0.6110424995422363 sec
# Episode 12144, loss:1.7764, succeed, steps:103, total reward:14.1000, 0.4538726806640625 sec
# Episode 12145, loss:0.0352, succeed, steps:86, total reward:6.4000, 0.3417956829071045 sec
# Episode 12146, loss:2.9488, succeed, steps:101, total reward:15.2000, 0.40225911140441895 sec
# Episode 12147, loss:0.0411, succeed, steps:84, total reward:4.3000, 0.44621753692626953 sec
# Episode 12148, loss:6.5303, succeed, steps:97, total reward:11.2000, 0.3821115493774414 sec
# Episode 12149, loss:1.7533, succeed, steps:120, total reward:8.2000, 0.5584344863891602 sec
# Episode 12150, loss:0.3141, succeed, steps:97, total reward:14.3000, 0.3860018253326416 sec
# Episode 12151, loss:1.4299, succeed, steps:97, total reward:11.2000, 0.44820666313171387 sec
# Episode 12152, loss:1.0446, succeed, steps:135, total reward:12.0000, 0.536736011505127 sec
# Episode 12153, loss:10.7533, fail, steps:162, total reward:16.3000, 0.7247588634490967 sec
# Episode 12154, loss:0.5870, succeed, steps:112, total reward:10.7000, 0.5193815231323242 sec
# Episode 12155, loss:1.5015, succeed, steps:161, total reward:13.2000, 0.6814866065979004 sec
# Episode 12156, loss:3.1483, succeed, steps:119, total reward:14.6000, 0.5418977737426758 sec
# Episode 12157, loss:5.4212, succeed, steps:137, total reward:17.1000, 0.543384313583374 sec
# Episode 12158, loss:3.6263, fail, steps:161, total reward:11.2000, 0.7577877044677734 sec
# Episode 12159, loss:0.5687, succeed, steps:159, total reward:14.3000, 0.6845047473907471 sec
# Episode 12160, loss:0.4581, succeed, steps:52, total reward:6.5000, 0.26617932319641113 sec
# Episode 12161, loss:3.1058, fail, steps:161, total reward:11.2000, 0.7162590026855469 sec
# Episode 12162, loss:1.0803, succeed, steps:127, total reward:9.1000, 0.5089950561523438 sec
# Episode 12163, loss:0.1975, succeed, steps:103, total reward:7.9000, 0.49523234367370605 sec
# Episode 12164, loss:4.6473, succeed, steps:143, total reward:10.6000, 0.5651693344116211 sec
# Episode 12165, loss:1.2471, succeed, steps:123, total reward:9.3000, 0.5738787651062012 sec
# Episode 12166, loss:0.7723, succeed, steps:149, total reward:13.6000, 0.6211178302764893 sec
# Episode 12167, loss:0.3229, succeed, steps:58, total reward:6.3000, 0.2384040355682373 sec
# Episode 12168, loss:2.0512, succeed, steps:156, total reward:11.1000, 0.6906435489654541 sec
# Episode 12169, loss:2.5992, fail, steps:161, total reward:12.2000, 0.6721804141998291 sec
# Episode 12170, loss:2.3589, succeed, steps:99, total reward:12.7000, 0.4105806350708008 sec
# Episode 12171, loss:2.2840, succeed, steps:130, total reward:16.3000, 0.6186249256134033 sec
# Episode 12172, loss:1.3627, succeed, steps:150, total reward:14.6000, 0.647296667098999 sec
# Episode 12173, loss:5.2935, succeed, steps:84, total reward:13.5000, 0.33854174613952637 sec
# Episode 12174, loss:0.3954, succeed, steps:106, total reward:10.9000, 0.5207579135894775 sec
# Episode 12175, loss:0.4421, succeed, steps:96, total reward:13.3000, 0.3798489570617676 sec
# Episode 12176, loss:0.0418, succeed, steps:46, total reward:6.7000, 0.18448638916015625 sec
# Episode 12177, loss:4.6308, succeed, steps:147, total reward:11.6000, 0.6530900001525879 sec
# Episode 12178, loss:1.4097, succeed, steps:123, total reward:8.7000, 0.5273616313934326 sec
# Episode 12179, loss:3.1116, fail, steps:162, total reward:13.1000, 0.6432664394378662 sec
# Episode 12180, loss:1.4669, succeed, steps:82, total reward:8.6000, 0.4277212619781494 sec
# Episode 12181, loss:2.0414, succeed, steps:101, total reward:12.1000, 0.3985426425933838 sec
# Episode 12182, loss:3.8804, succeed, steps:74, total reward:9.8000, 0.29721736907958984 sec
# Episode 12183, loss:1.5310, succeed, steps:23, total reward:2.2000, 0.19266939163208008 sec
# Episode 12184, loss:2.2650, succeed, steps:76, total reward:11.9000, 0.3164982795715332 sec
# Episode 12185, loss:0.8448, succeed, steps:67, total reward:9.1000, 0.262620210647583 sec
# Episode 12186, loss:2.0930, succeed, steps:111, total reward:12.8000, 0.42380189895629883 sec
# Episode 12187, loss:3.4240, succeed, steps:92, total reward:12.4000, 0.4456326961517334 sec
# Episode 12188, loss:1.4730, succeed, steps:105, total reward:13.0000, 0.42969846725463867 sec
# Episode 12189, loss:3.0508, succeed, steps:106, total reward:13.9000, 0.4885993003845215 sec
# Episode 12190, loss:1.8249, succeed, steps:89, total reward:12.5000, 0.35926175117492676 sec
# Episode 12191, loss:1.2102, succeed, steps:80, total reward:6.3000, 0.3696317672729492 sec
# Episode 12192, loss:7.3875, succeed, steps:144, total reward:21.0000, 0.6011395454406738 sec
# Episode 12193, loss:6.1229, succeed, steps:85, total reward:11.6000, 0.3416576385498047 sec
# Episode 12194, loss:1.9901, succeed, steps:109, total reward:13.7000, 0.48279261589050293 sec
# Episode 12195, loss:6.9788, succeed, steps:113, total reward:17.9000, 0.4643580913543701 sec
# Episode 12196, loss:0.7699, succeed, steps:88, total reward:8.4000, 0.4295973777770996 sec
# Episode 12197, loss:1.5798, succeed, steps:82, total reward:11.7000, 0.32256293296813965 sec
# Episode 12198, loss:0.8158, succeed, steps:92, total reward:9.3000, 0.3462669849395752 sec
# Episode 12199, loss:4.3388, succeed, steps:120, total reward:9.4000, 0.5633680820465088 sec
# Episode 12200, loss:1.0345, fail, steps:162, total reward:13.2000, 0.6495859622955322 sec
# Episode 12201, loss:2.2280, succeed, steps:78, total reward:10.8000, 0.3583993911743164 sec
# Episode 12202, loss:1.2019, succeed, steps:62, total reward:7.1000, 0.25180768966674805 sec
# Episode 12203, loss:0.7421, succeed, steps:110, total reward:11.8000, 0.47521162033081055 sec
# Episode 12204, loss:1.9613, succeed, steps:119, total reward:8.4000, 0.4772913455963135 sec
# Episode 12205, loss:4.5838, succeed, steps:93, total reward:13.4000, 0.45899438858032227 sec
# Episode 12206, loss:0.4931, succeed, steps:108, total reward:9.8000, 0.42659521102905273 sec
# Episode 12207, loss:0.0945, fail, steps:160, total reward:7.0000, 0.7239913940429688 sec
# Episode 12208, loss:0.9887, succeed, steps:108, total reward:12.4000, 0.43333959579467773 sec
# Episode 12209, loss:1.2841, succeed, steps:28, total reward:4.2000, 0.11659741401672363 sec
# Episode 12210, loss:1.6739, succeed, steps:99, total reward:16.3000, 0.5044639110565186 sec
# Episode 12211, loss:4.0860, fail, steps:161, total reward:11.2000, 0.6449840068817139 sec
# Episode 12212, loss:2.3606, fail, steps:160, total reward:7.1000, 0.6634130477905273 sec
# Episode 12213, loss:0.2917, succeed, steps:99, total reward:7.0000, 0.42204928398132324 sec
# Episode 12214, loss:-0.0852, fail, steps:161, total reward:9.1000, 0.64996337890625 sec
# Episode 12215, loss:0.3230, succeed, steps:107, total reward:5.7000, 0.4695851802825928 sec
# Episode 12216, loss:1.7174, succeed, steps:118, total reward:7.4000, 0.5041344165802002 sec
# Episode 12217, loss:1.1652, fail, steps:162, total reward:13.1000, 0.7004492282867432 sec
# Episode 12218, loss:1.9747, succeed, steps:59, total reward:7.2000, 0.24440312385559082 sec
# Episode 12219, loss:0.5847, succeed, steps:103, total reward:11.0000, 0.4714043140411377 sec
# Episode 12220, loss:0.8093, succeed, steps:63, total reward:8.2000, 0.2510528564453125 sec
# Episode 12221, loss:1.6740, succeed, steps:59, total reward:10.4000, 0.23169660568237305 sec
# Episode 12222, loss:6.8725, succeed, steps:120, total reward:12.5000, 0.5366382598876953 sec
# Episode 12223, loss:3.3975, succeed, steps:130, total reward:10.1000, 0.5570521354675293 sec
# Episode 12224, loss:0.3767, succeed, steps:46, total reward:3.6000, 0.18637657165527344 sec
# Episode 12225, loss:0.7472, succeed, steps:108, total reward:12.9000, 0.4246714115142822 sec
# Episode 12226, loss:0.3099, succeed, steps:103, total reward:11.0000, 0.5395514965057373 sec
# Episode 12227, loss:5.8481, succeed, steps:78, total reward:10.8000, 0.3088650703430176 sec
# Episode 12228, loss:4.1822, fail, steps:161, total reward:10.2000, 0.7226409912109375 sec
# Episode 12229, loss:1.1034, succeed, steps:86, total reward:12.6000, 0.3515322208404541 sec
# Episode 12230, loss:-0.3265, fail, steps:162, total reward:13.2000, 0.7299587726593018 sec
# Episode 12231, loss:1.3687, succeed, steps:71, total reward:10.0000, 0.29068970680236816 sec
# Episode 12232, loss:1.8938, succeed, steps:80, total reward:9.7000, 0.2872743606567383 sec
# Episode 12233, loss:-0.1855, fail, steps:161, total reward:11.2000, 0.7181723117828369 sec
# Episode 12234, loss:3.1953, succeed, steps:83, total reward:12.7000, 0.33974647521972656 sec
# Episode 12235, loss:0.5139, succeed, steps:67, total reward:6.0000, 0.3593595027923584 sec
# Episode 12236, loss:1.0535, fail, steps:161, total reward:10.2000, 0.6314818859100342 sec
# Episode 12237, loss:1.5222, fail, steps:162, total reward:15.3000, 0.748436450958252 sec
# Episode 12238, loss:-0.4825, fail, steps:160, total reward:8.1000, 0.7024631500244141 sec
# Episode 12239, loss:2.7353, succeed, steps:85, total reward:11.6000, 0.3495192527770996 sec
# Episode 12240, loss:-0.2448, fail, steps:161, total reward:12.2000, 0.7022175788879395 sec
# Episode 12241, loss:-1.5191, fail, steps:159, total reward:4.0000, 0.6556346416473389 sec
# Episode 12242, loss:4.1047, fail, steps:162, total reward:13.2000, 0.7346694469451904 sec
# Episode 12243, loss:0.7793, succeed, steps:62, total reward:7.2000, 0.2588491439819336 sec
# Episode 12244, loss:-0.5216, fail, steps:159, total reward:3.0000, 0.6647148132324219 sec
# Episode 12245, loss:1.5064, succeed, steps:115, total reward:16.8000, 0.5485405921936035 sec
# Episode 12246, loss:0.2797, succeed, steps:63, total reward:8.2000, 0.2590336799621582 sec
# Episode 12247, loss:1.7814, succeed, steps:143, total reward:10.7000, 0.6515293121337891 sec
# Episode 12248, loss:-0.1809, fail, steps:160, total reward:5.0000, 0.6901431083679199 sec
# Episode 12249, loss:1.8686, succeed, steps:83, total reward:9.6000, 0.3704376220703125 sec
# Episode 12250, loss:2.9083, succeed, steps:77, total reward:9.8000, 0.3052823543548584 sec
# Episode 12251, loss:5.0401, succeed, steps:89, total reward:12.5000, 0.3437981605529785 sec
# Episode 12252, loss:3.0550, fail, steps:161, total reward:10.2000, 0.711566686630249 sec
# Episode 12253, loss:1.5267, fail, steps:161, total reward:11.1000, 0.68359375 sec
# Episode 12254, loss:2.4956, fail, steps:161, total reward:10.2000, 0.644122838973999 sec
# Episode 12255, loss:4.9274, succeed, steps:109, total reward:10.8000, 0.5265991687774658 sec
# Episode 12256, loss:4.8204, succeed, steps:121, total reward:16.6000, 0.48263120651245117 sec
# Episode 12257, loss:-1.9997, fail, steps:160, total reward:4.9000, 0.6958651542663574 sec
# Episode 12258, loss:1.3588, succeed, steps:95, total reward:15.4000, 0.49190640449523926 sec
# Episode 12259, loss:3.4550, fail, steps:161, total reward:10.2000, 0.6434757709503174 sec
# Episode 12260, loss:1.3193, fail, steps:160, total reward:7.1000, 0.756842851638794 sec
# Episode 12261, loss:3.3161, succeed, steps:88, total reward:14.6000, 0.3591752052307129 sec
# Episode 12262, loss:0.5742, fail, steps:161, total reward:11.2000, 0.6898040771484375 sec
# Episode 12263, loss:0.8290, succeed, steps:69, total reward:8.0000, 0.36586618423461914 sec
# Episode 12264, loss:0.9941, succeed, steps:69, total reward:8.0000, 0.2756073474884033 sec
# Episode 12265, loss:0.5198, succeed, steps:48, total reward:8.7000, 0.1630864143371582 sec
# Episode 12266, loss:2.2504, succeed, steps:110, total reward:14.9000, 0.43216514587402344 sec
# Episode 12267, loss:1.8077, fail, steps:161, total reward:12.2000, 0.7226307392120361 sec
# Episode 12268, loss:2.2641, succeed, steps:22, total reward:1.3000, 0.09690165519714355 sec
# Episode 12269, loss:3.4885, succeed, steps:129, total reward:15.3000, 0.5639941692352295 sec
# Episode 12270, loss:-0.5365, fail, steps:161, total reward:10.2000, 0.6867258548736572 sec
# Episode 12271, loss:1.9465, succeed, steps:113, total reward:11.7000, 0.45587873458862305 sec
# Episode 12272, loss:1.1049, succeed, steps:119, total reward:14.6000, 0.5470137596130371 sec
# Episode 12273, loss:-0.7306, fail, steps:160, total reward:5.0000, 0.6725361347198486 sec
# Episode 12274, loss:1.4732, succeed, steps:131, total reward:11.1000, 0.5375545024871826 sec
# Episode 12275, loss:0.9162, succeed, steps:88, total reward:11.5000, 0.39467477798461914 sec
# Episode 12276, loss:1.6827, succeed, steps:111, total reward:12.8000, 0.4443366527557373 sec
# Episode 12277, loss:0.1196, succeed, steps:51, total reward:8.6000, 0.312546968460083 sec
# Episode 12278, loss:3.5781, succeed, steps:141, total reward:14.9000, 0.5515551567077637 sec
# Episode 12279, loss:5.8418, fail, steps:163, total reward:17.3000, 0.7397701740264893 sec
# Episode 12280, loss:0.0496, succeed, steps:43, total reward:3.6000, 0.17804455757141113 sec
# Episode 12281, loss:-0.2760, fail, steps:159, total reward:3.0000, 0.7024397850036621 sec
# Episode 12282, loss:0.9613, succeed, steps:93, total reward:16.5000, 0.38668227195739746 sec
# Episode 12283, loss:2.9415, succeed, steps:144, total reward:11.4000, 0.584996223449707 sec
# Episode 12284, loss:2.4553, succeed, steps:51, total reward:8.6000, 0.20856881141662598 sec
# Episode 12285, loss:2.6198, succeed, steps:126, total reward:18.5000, 0.6016888618469238 sec
# Episode 12286, loss:0.0846, succeed, steps:63, total reward:8.2000, 0.2567026615142822 sec
# Episode 12287, loss:0.8246, succeed, steps:133, total reward:13.1000, 0.6057291030883789 sec
# Episode 12288, loss:0.3652, succeed, steps:64, total reward:9.2000, 0.2969205379486084 sec
# Episode 12289, loss:0.6780, succeed, steps:52, total reward:9.6000, 0.2050173282623291 sec
# Episode 12290, loss:3.0204, succeed, steps:132, total reward:14.7000, 0.5240025520324707 sec
# Episode 12291, loss:0.0822, succeed, steps:53, total reward:7.5000, 0.32810115814208984 sec
# Episode 12292, loss:0.7359, succeed, steps:105, total reward:6.5000, 0.42699193954467773 sec
# Episode 12293, loss:1.6444, succeed, steps:150, total reward:17.7000, 0.6146504878997803 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 199
#     196             print(f"Episode {episode}, loss:{loss.item():.4f}, {'succeed' if success else 'fail'}, steps:{len(rewards)}, total reward:{sum(rewards):.4f}, {t2-t1} sec")
#     198 if __name__ == "__main__":
# --> 199     train(verbose=False)
#
# Cell In[3], line 91, in train(verbose)
#      88     break
#      90 try:
# ---> 91     m = torch.distributions.Categorical(probs)
#      92     action_token = m.sample()
#      93     log_prob = m.log_prob(action_token)
#
# File ~/.local/lib/python3.10/site-packages/torch/distributions/categorical.py:70, in Categorical.__init__(self, probs, logits, validate_args)
#      66 self._num_events = self._param.size()[-1]
#      67 batch_shape = (
#      68     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      69 )
# ---> 70 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/.local/lib/python3.10/site-packages/torch/distributions/distribution.py:67, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      65         value = getattr(self, param)
#      66         valid = constraint.check(value)
# ---> 67         if not valid.all():
#      68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# KeyboardInterrupt:

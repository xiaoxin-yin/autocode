# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import random

MIN_LIST_LEN = 6
MAX_LIST_LEN = 6
MAX_STEPS = 120
SUCCESS_REWARD = 10.0
EPS_START = 0.5
EPS_END = 0.05
EPS_DECAY = 1000
GAMMA = 0.98
NUM_EPISODES = 100000
EPISODES_SAVE = 1000
OUTPUT_DIR = 'datasets/rl_sort_transformer_easy/list6_transformer3_128_gamma098_step120'

# Define the vocabulary
vocab = {
    'Comparison': 0,
    'Swap': 1,
    '0': 2,
    '1': 3,
    '2': 4,
    '3': 5,
    '4': 6,
    '5': 7,
    '6': 8,
    '7': 9,
    'less': 10,
    'equal': 11,
    'more': 12,
    'len1': 13,
    'len2': 14,
    'len3': 15,
    'len4': 16,
    'len5': 17,
    'len6': 18,
    'len7': 19,
    'len8': 20,
}
inv_vocab = {v: k for k, v in vocab.items()}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the environment
class SortingEnv:
    def __init__(self):
        self.max_steps = MAX_STEPS

    def reset(self):
        self.length = random.randint(MIN_LIST_LEN, MAX_LIST_LEN)
        self.list = [random.randint(1, 100) for _ in range(self.length)]
        while self.list == sorted(self.list):
            self.list = [random.randint(1, 100) for _ in range(self.length)]
        self.indices = None
        self.current_step = 0
        self.done = False
        initial_token = 'len{}'.format(self.length)
        return vocab[initial_token], self.list.copy()
    
    def get_list(self):
        return self.list
    
    def get_list_len(self):
        return len(self.list)

    def step(self, action_tokens):
        action = action_tokens[0]
        reward = -0.01  # default penalty
        response_token = None

        if action == vocab['Comparison']:
            if len(action_tokens) != 3:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1 = action_tokens[1] - vocab['0']
            index2 = action_tokens[2] - vocab['0']
            if index1 >= self.length or index2 >= self.length or index1 < 0 or index2 < 0:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            self.indices = (index1, index2)
            if self.list[index1] < self.list[index2]:
                response_token = vocab['less']
                reward = -0.01
            elif self.list[index1] == self.list[index2]:
                response_token = vocab['equal']
                reward = -0.02
            else:
                response_token = vocab['more']
                reward = -0.01
        elif action == vocab['Swap']:
            if self.indices is None:
                reward = -1.0
                self.done = True
                return response_token, reward, self.done, self.list.copy()
            index1, index2 = self.indices
            prev_list = self.list.copy()
            self.list[index1], self.list[index2] = self.list[index2], self.list[index1]
            if self.list == sorted(self.list):
                reward = SUCCESS_REWARD
                self.done = True
            #elif prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]:
            #    reward = 0.1
            elif (index1 < index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]):
                reward = 0.1
            elif (index1 < index2 and prev_list[index1] < prev_list[index2] and self.list[index1] >= self.list[index2]) or \
                (index1 > index2 and prev_list[index1] > prev_list[index2] and self.list[index1] <= self.list[index2]):
                reward = -0.1
            else:
                reward = -0.01
            self.indices = None
        else:
            reward = -1.0
            self.done = True

        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True
        return response_token, reward, self.done, self.list.copy()
# Out:
# Using device: cuda

# %%
# Positional Encoding for Transformer
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=256):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # Even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # Odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# Transformer Model
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=128, nhead=8, num_layers=3):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.decoder = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embedding.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output)
        return output

def decode(input_tokens, inv_vocab):
    return ' '.join([inv_vocab[x] for x in input_tokens])


def save_checkpoint(model, optimizer, episode, folder, filename):
    """
    Save the model and optimizer state to the designated filepath.

    Args:
        model (nn.Module): The model to save.
        optimizer (torch.optim.Optimizer): The optimizer whose state to save.
        episode (int): The current episode number.
        filepath (str): The path where to save the checkpoint.
    """
    filepath = os.path.join(folder, filename)
    # Ensure the directory exists
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    # Save the checkpoint
    torch.save({
        'episode': episode,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, filepath)
    print(f"Checkpoint saved at episode {episode} to {filepath}")

def load_checkpoint(filepath, model, optimizer):
    """
    Load the model and optimizer state from the designated filepath.

    Args:
        filepath (str): The path from where to load the checkpoint.
        model (nn.Module): The model into which to load the state_dict.
        optimizer (torch.optim.Optimizer): The optimizer into which to load the state.

    Returns:
        int: The episode number to resume from.
    """
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        episode = checkpoint['episode']
        print(f"Checkpoint loaded from {filepath}, resuming from episode {episode}")
        return episode
    else:
        print(f"No checkpoint found at {filepath}, starting from scratch.")
        return 0

# %%
# Training Loop
def train(verbose=False):
    torch.autograd.set_detect_anomaly(True)  # Detect anomalies in autograd
    vocab_size = len(vocab)
    model = TransformerModel(vocab_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Reduced learning rate
    #load_checkpoint("datasets/rl_sort_transformer_easy/list6_transformer3_128_gamma098/ckpt_7000_0.9286.pth", model, optimizer)

    episode_cnt = 0
    total_reward = 0.0
    for episode in range(NUM_EPISODES):
        model.train()  # Set model to training mode
        env = SortingEnv()
        initial_token_id, current_list = env.reset()
        input_tokens = [initial_token_id]
        log_probs = []
        rewards = []
        state = 'expect_action'
        done = False

        while not done and len(input_tokens) < env.max_steps:
            if verbose:
                print(decode(input_tokens, inv_vocab))
                print(env.get_list())
            # Prepare input tensor
            input_seq = torch.tensor(input_tokens, dtype=torch.long, device=device).unsqueeze(1)  # (seq_len, batch_size)
            # Get model output
            output = model(input_seq)  # (seq_len, batch_size, vocab_size)
            # Get logits for the last token
            logits = output[-1, 0, :]  # (vocab_size)

            # Check for NaNs in logits
            if torch.isnan(logits).any():
                print(f"Episode {episode}, NaNs in logits before masking.")
                break

            # Get valid tokens based on state
            def get_valid_tokens(state):
                action_tokens = [vocab['Comparison'], vocab['Swap']]
                index_tokens = [vocab[str(i)] for i in range(env.length)]
                if state == 'expect_action':
                    return action_tokens
                elif state == 'expect_index1':
                    return index_tokens[:-1]
                elif state == 'expect_index2':
                    return [x for x in index_tokens if x > input_tokens[-1]]
                else:
                    # Handle unexpected states by defaulting to expect_action
                    return action_tokens

            valid_token_ids = get_valid_tokens(state)

            # Ensure valid_token_ids are within the vocab range
            if any(idx >= vocab_size or idx < 0 for idx in valid_token_ids):
                print(f"Episode {episode}, invalid indices in valid_token_ids: {valid_token_ids}")
                break

            # Mask invalid tokens
            mask_value = -1e9  # Use a large negative value instead of -inf
            mask = torch.full_like(logits, mask_value).to(device)
            mask[valid_token_ids] = 0
            masked_logits = logits + mask
            
            # Sample action. Have some chance to randomly pick a valid action.
            eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-1.0 * episode / EPS_DECAY)
            if random.random() < eps_threshold:
                masked_logits = masked_logits / 4

            # Check for NaNs in masked_logits
            if torch.isnan(masked_logits).any():
                print(f"Episode {episode}, NaNs in masked_logits after masking.")
                break

            # Compute probabilities
            probs = F.softmax(masked_logits, dim=0)

            # Check for NaNs in probs
            if torch.isnan(probs).any():
                print(f"Episode {episode}, NaNs in probs after softmax.")
                break

            try:
                m = torch.distributions.Categorical(probs)
                action_token = m.sample()
                log_prob = m.log_prob(action_token)
            except ValueError as e:
                print(f"Episode {episode}, error in sampling action: {e}")
                break

            log_probs.append(log_prob)
            input_tokens.append(action_token.item())

            action = action_token.item()
            reward = 0.0
            if state == 'expect_action':
                if action == vocab['Comparison']:
                    state = 'expect_index1'
                elif action == vocab['Swap']:
                    if env.indices is None:
                        # Can't perform Swap without a previous Comparison
                        reward = -1.0
                        rewards.append(reward)
                        done = True
                        continue
                    action_tokens = [vocab['Swap']]
                    response_token, reward, done, current_list = env.step(action_tokens)
                    if verbose:
                        print("Reward:", reward)
                    #rewards.append(reward)
                    state = 'expect_action'
                else:
                    # Invalid action, end the episode
                    reward = -1.0
                    #rewards.append(reward)
                    done = True
            elif state == 'expect_index1':
                index1_token = action_token
                state = 'expect_index2'
            elif state == 'expect_index2':
                index2_token = action_token
                action_tokens = [vocab['Comparison'], index1_token.item(), index2_token.item()]
                response_token, reward, done, current_list = env.step(action_tokens)
                if verbose:
                    print("Reward:", reward)
                #rewards.append(reward)
                if response_token is not None:
                    input_tokens.append(response_token)
                state = 'expect_action'
            else:
                # Invalid state, end the episode
                reward = -1.0
                #rewards.append(reward)
                done = True
            #
            rewards.append(reward)
        #
        # Save checkpoint
        if episode > 0 and episode % EPISODES_SAVE == 0:
            avg_reward = total_reward / (episode_cnt + 0.00001)
            episode_cnt = 0
            total_reward = 0.0
            save_checkpoint(model, optimizer, episode, OUTPUT_DIR, f"ckpt_{episode}_{avg_reward:.4f}.pth")
        #
        #print(decode(input_tokens, inv_vocab))
        #print(env.get_list())
        #print("rewards:", rewards)
        assert len(log_probs) == len(rewards), "log_probs and returns have different sizes!"
        
        if len(log_probs) == 0:
            continue  # Skip if no actions were taken

        # Compute returns
        returns = []
        R = 0
        gamma = GAMMA
        for r in rewards[::-1]:
            R = r + gamma * R
            returns.insert(0, R)
        returns = torch.tensor(returns)
        #print(returns)

        # Check for NaNs in returns
        if torch.isnan(returns).any():
            print(f"Episode {episode}, NaNs in returns.")
            continue

#         if returns.std() != 0 and not torch.isnan(returns.std()):
#             returns = (returns - returns.mean()) / (returns.std() + 1e-9)
#         else:
#             pass #returns = returns - returns.mean()

        # Check for NaNs in standardized returns
        if torch.isnan(returns).any():
            print(f"Episode {episode}, NaNs in standardized returns.")
            continue

        # Compute loss
        loss = 0
        #print("log_probs:", log_probs)
        #print("returns:", returns)
        assert len(log_probs) == len(returns), "log_probs and returns have different sizes!"
        for log_prob, R in zip(log_probs, returns):
            loss -= log_prob * R

        # Check for NaNs in loss
        if torch.isnan(loss):
            print(f"Episode {episode}, NaN in loss.")
            continue

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()

        episode_cnt += 1
        total_reward += sum(rewards)
        if episode % 1 == 0:
            print(f"Episode {episode}, loss: {loss.item():.4f}, total reward: {sum(rewards):.4f}")

if __name__ == "__main__":
    train(verbose=False)
# Out:
# /home/mcwave/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Episode 0, loss: -0.3107, total reward: -1.0000
# Episode 1, loss: -11.1479, total reward: -0.9300
# Episode 2, loss: -4.6589, total reward: -1.1100
# Episode 3, loss: -26.1625, total reward: -1.2300
# Episode 4, loss: -1.8698, total reward: -1.0000
# Episode 5, loss: -2.7978, total reward: -1.1100
# Episode 6, loss: -4.2947, total reward: -0.9100
# Episode 7, loss: -18.5414, total reward: -1.1500
# Episode 8, loss: -3.9510, total reward: -0.1900
# Episode 9, loss: -1.2770, total reward: -1.0000
# Episode 10, loss: -9.7477, total reward: -0.3900
# Episode 11, loss: -34.5162, total reward: -1.2100
# Episode 12, loss: -6.1891, total reward: -0.2900
# Episode 13, loss: -10.5901, total reward: -1.1400
# Episode 14, loss: -10.0464, total reward: -0.4900
# Episode 15, loss: -3.6458, total reward: -0.1900
# Episode 16, loss: -22.5109, total reward: -1.0600
# Episode 17, loss: -0.5602, total reward: 0.0100
# Episode 18, loss: -3.3806, total reward: -0.1900
# Episode 19, loss: -33.6686, total reward: -1.2800
# Episode 20, loss: -3.4824, total reward: -0.2900
# Episode 21, loss: -7.1609, total reward: -0.2900
# Episode 22, loss: -7.8392, total reward: -0.2900
# Episode 23, loss: -6.9964, total reward: -0.2900
# Episode 24, loss: -2.4479, total reward: -0.1800
# Episode 25, loss: -26.7090, total reward: -1.2100
# Episode 26, loss: -6.0147, total reward: -0.3000
# Episode 27, loss: -12.1148, total reward: -0.5800
# Episode 28, loss: -8.8260, total reward: -0.4900
# Episode 29, loss: -35.4322, total reward: -1.1300
# Episode 30, loss: -12.6736, total reward: -1.0600
# Episode 31, loss: -26.6712, total reward: -1.1600
# Episode 32, loss: 0.2392, total reward: -0.0900
# Episode 33, loss: -24.0653, total reward: -1.0400
# Episode 34, loss: -6.5529, total reward: -0.2900
# Episode 35, loss: -28.2462, total reward: -1.0200
# Episode 36, loss: -1.6310, total reward: -1.0000
# Episode 37, loss: -32.2485, total reward: -1.2600
# Episode 38, loss: -12.1091, total reward: -1.1600
# Episode 39, loss: -8.8495, total reward: -0.3800
# Episode 40, loss: -4.2893, total reward: -0.1900
# Episode 41, loss: -28.0382, total reward: -1.1200
# Episode 42, loss: -6.4285, total reward: -0.3900
# Episode 43, loss: -9.5106, total reward: -0.4900
# Episode 44, loss: -38.0805, total reward: -1.2800
# Episode 45, loss: -5.9125, total reward: -0.3100
# Episode 46, loss: -8.7753, total reward: -0.3900
# Episode 47, loss: -10.5542, total reward: -0.4900
# Episode 48, loss: -4.2734, total reward: -0.0900
# Episode 49, loss: -21.2357, total reward: -1.2800
# Episode 50, loss: -24.6728, total reward: -1.1200
# Episode 51, loss: -1.9542, total reward: -1.0000
# Episode 52, loss: -10.8159, total reward: -0.4000
# Episode 53, loss: -6.7788, total reward: -0.3000
# Episode 54, loss: -10.2753, total reward: -0.3900
# Episode 55, loss: -5.6114, total reward: -0.3000
# Episode 56, loss: -9.8390, total reward: -0.4900
# Episode 57, loss: -2.5730, total reward: -0.1900
# Episode 58, loss: -6.1305, total reward: -0.3000
# Episode 59, loss: -6.0907, total reward: -0.3000
# Episode 60, loss: -7.8777, total reward: -0.3900
# Episode 61, loss: -3.4311, total reward: -0.1900
# Episode 62, loss: -5.9715, total reward: -0.3000
# Episode 63, loss: -37.7079, total reward: -1.1400
# Episode 64, loss: -5.3566, total reward: -0.2900
# Episode 65, loss: -9.8972, total reward: -0.4900
# Episode 66, loss: -10.2487, total reward: -0.3900
# Episode 67, loss: -2.0553, total reward: -1.0000
# Episode 68, loss: -14.3325, total reward: -1.0400
# Episode 69, loss: -2.2954, total reward: -0.0900
# Episode 70, loss: 2.0103, total reward: 0.0200
# Episode 71, loss: -5.0601, total reward: -0.1900
# Episode 72, loss: -3.3434, total reward: -0.1900
# Episode 73, loss: -26.0370, total reward: -1.2000
# Episode 74, loss: -16.7085, total reward: -1.1500
# Episode 75, loss: -3.0052, total reward: -0.1900
# Episode 76, loss: -3.0770, total reward: -0.1900
# Episode 77, loss: -7.0072, total reward: -0.2900
# Episode 78, loss: -4.8981, total reward: -0.2900
# Episode 79, loss: -2.2779, total reward: -1.0000
# Episode 80, loss: -5.4182, total reward: -0.3900
# Episode 81, loss: -7.6796, total reward: -0.2900
# Episode 82, loss: -4.2521, total reward: -0.2900
# Episode 83, loss: -3.1324, total reward: -0.1900
# Episode 84, loss: -8.0933, total reward: -0.2900
# Episode 85, loss: -3.6255, total reward: -0.1900
# Episode 86, loss: -0.7702, total reward: 0.0100
# Episode 87, loss: -5.7426, total reward: -0.3000
# Episode 88, loss: -2.2693, total reward: -1.0000
# Episode 89, loss: -1.1628, total reward: -0.1100
# Episode 90, loss: -6.8777, total reward: -0.3000
# Episode 91, loss: -9.0388, total reward: -0.3900
# Episode 92, loss: -8.3709, total reward: -0.3900
# Episode 93, loss: -6.4779, total reward: -0.3000
# Episode 94, loss: -12.5810, total reward: -0.5900
# Episode 95, loss: -3.4091, total reward: -0.1900
# Episode 96, loss: -3.1223, total reward: -0.1900
# Episode 97, loss: -6.3795, total reward: -0.3000
# Episode 98, loss: -25.7368, total reward: -1.0400
# Episode 99, loss: -5.9815, total reward: -0.3000
# Episode 100, loss: -7.3319, total reward: -0.2900
# Episode 101, loss: -5.4477, total reward: -0.2900
# Episode 102, loss: -2.1467, total reward: -0.0900
# Episode 103, loss: -6.8652, total reward: -0.3000
# Episode 104, loss: -3.1391, total reward: -0.1900
# Episode 105, loss: -6.6244, total reward: -0.2900
# Episode 106, loss: -8.8326, total reward: -0.4900
# Episode 107, loss: -4.9069, total reward: -0.1200
# Episode 108, loss: -7.7955, total reward: -0.3900
# Episode 109, loss: -3.9865, total reward: -0.1400
# Episode 110, loss: -5.6275, total reward: -0.3000
# Episode 111, loss: -3.5684, total reward: -0.0900
# Episode 112, loss: -4.5431, total reward: -0.1900
# Episode 113, loss: -2.7097, total reward: -0.1900
# Episode 114, loss: 1.1502, total reward: 0.0000
# Episode 115, loss: -19.7562, total reward: -1.0800
# Episode 116, loss: -23.7154, total reward: -0.8800
# Episode 117, loss: -6.3536, total reward: -0.3000
# Episode 118, loss: -7.6465, total reward: -0.3900
# Episode 119, loss: -6.0368, total reward: -0.2900
# Episode 120, loss: -0.6119, total reward: -0.0900
# Episode 121, loss: -6.9935, total reward: -0.3000
# Episode 122, loss: -3.4983, total reward: -0.1900
# Episode 123, loss: -7.8833, total reward: -0.2900
# Episode 124, loss: -2.5814, total reward: -0.2000
# Episode 125, loss: -33.1436, total reward: -1.1600
# Episode 126, loss: -8.0543, total reward: -0.2900
# Episode 127, loss: -30.5551, total reward: -1.0500
# Episode 128, loss: 1.5116, total reward: 0.0200
# Episode 129, loss: -3.4381, total reward: -0.1900
# Episode 130, loss: -30.3423, total reward: -1.2700
# Episode 131, loss: -8.4536, total reward: -0.4000
# Episode 132, loss: -19.3256, total reward: -1.1300
# Episode 133, loss: 282.5116, total reward: 10.0100
# Episode 134, loss: -0.9080, total reward: -0.1800
# Episode 135, loss: 0.1280, total reward: 0.0100
# Episode 136, loss: 0.0720, total reward: 0.1200
# Episode 137, loss: -2.1860, total reward: -0.1900
# Episode 138, loss: -5.2692, total reward: -0.9200
# Episode 139, loss: -19.4628, total reward: -0.8600
# Episode 140, loss: 182.0189, total reward: 9.9600
# Episode 141, loss: -13.7839, total reward: -0.9100
# Episode 142, loss: -30.6233, total reward: -0.9600
# Episode 143, loss: 5.8300, total reward: 0.4200
# Episode 144, loss: -19.4434, total reward: -1.0100
# Episode 145, loss: -20.6405, total reward: -0.9700
# Episode 146, loss: -8.0256, total reward: -0.8200
# Episode 147, loss: -15.0198, total reward: -0.5600
# Episode 148, loss: -6.1101, total reward: -0.8200
# Episode 149, loss: -11.5261, total reward: -0.7600
# Episode 150, loss: -18.6744, total reward: -1.0500
# Episode 151, loss: -3.4956, total reward: -0.0900
# Episode 152, loss: -0.7427, total reward: 0.0700
# Episode 153, loss: 10.0628, total reward: 0.6300
# Episode 154, loss: 2.9310, total reward: 0.2300
# Episode 155, loss: -15.6429, total reward: -1.0500
# Episode 156, loss: 102.6721, total reward: 10.2000
# Episode 157, loss: -0.3807, total reward: 0.0200
# Episode 158, loss: -0.9423, total reward: 0.0100
# Episode 159, loss: -10.8690, total reward: -0.9000
# Episode 160, loss: -16.2775, total reward: -1.0400
# Episode 161, loss: -1.1402, total reward: 0.0500
# Episode 162, loss: 3.4209, total reward: 0.2200
# Episode 163, loss: -18.4005, total reward: -0.8600
# Episode 164, loss: -3.9181, total reward: -0.1900
# Episode 165, loss: -14.7053, total reward: -0.8000
# Episode 166, loss: -2.6023, total reward: -0.9100
# Episode 167, loss: 1.3416, total reward: 0.0200
# Episode 168, loss: -19.7596, total reward: -1.1300
# Episode 169, loss: -24.5095, total reward: -0.8600
# Episode 170, loss: 234.2079, total reward: 10.2300
# Episode 171, loss: -5.9485, total reward: -0.2900
# Episode 172, loss: -0.3839, total reward: 0.1200
# Episode 173, loss: 3.2650, total reward: 0.1200
# Episode 174, loss: -0.2433, total reward: 0.1300
# Episode 175, loss: 1.2813, total reward: 0.1200
# Episode 176, loss: 0.2047, total reward: 0.1100
# Episode 177, loss: -0.2644, total reward: 0.0200
# Episode 178, loss: -3.2346, total reward: 0.0200
# Episode 179, loss: 8.3340, total reward: 0.5300
# Episode 180, loss: -2.2372, total reward: -1.0000
# Episode 181, loss: 6.4319, total reward: 0.3200
# Episode 182, loss: -8.1026, total reward: -0.1800
# Episode 183, loss: 5.9354, total reward: 0.4300
# Episode 184, loss: -2.9575, total reward: -0.0900
# Episode 185, loss: 198.7773, total reward: 10.0700
# Episode 186, loss: -15.0174, total reward: -1.1400
# Episode 187, loss: 3.0161, total reward: 0.3200
# Episode 188, loss: -29.9254, total reward: -0.8800
# Episode 189, loss: -0.0455, total reward: 0.1200
# Episode 190, loss: -11.0777, total reward: -1.0400
# Episode 191, loss: -0.3268, total reward: 0.1100
# Episode 192, loss: 257.2178, total reward: 10.2300
# Episode 193, loss: 230.3672, total reward: 10.2200
# Episode 194, loss: -2.1657, total reward: -1.0000
# Episode 195, loss: 1.0205, total reward: 0.2800
# Episode 196, loss: -3.8985, total reward: -0.0900
# Episode 197, loss: -9.3069, total reward: -0.7500
# Episode 198, loss: 5.4528, total reward: 0.5300
# Episode 199, loss: -2.2207, total reward: 0.0100
# Episode 200, loss: -1.4433, total reward: 0.0000
# Episode 201, loss: 268.4665, total reward: 10.1800
# Episode 202, loss: 10.0859, total reward: 0.5300
# Episode 203, loss: 219.2682, total reward: 10.1300
# Episode 204, loss: 3.5463, total reward: 0.2200
# Episode 205, loss: -3.3082, total reward: -0.9100
# Episode 206, loss: 4.0141, total reward: 0.2300
# Episode 207, loss: 220.2177, total reward: 10.0600
# Episode 208, loss: -22.2763, total reward: -0.6700
# Episode 209, loss: -36.6407, total reward: -0.9300
# Episode 210, loss: 132.4699, total reward: 10.4400
# Episode 211, loss: -21.3426, total reward: -0.6600
# Episode 212, loss: -14.2715, total reward: -0.2600
# Episode 213, loss: -2.2629, total reward: 0.0200
# Episode 214, loss: 0.7074, total reward: 0.0000
# Episode 215, loss: 140.8709, total reward: 10.2200
# Episode 216, loss: -9.6190, total reward: -0.8400
# Episode 217, loss: 5.2333, total reward: 0.2100
# Episode 218, loss: 259.6479, total reward: 10.2100
# Episode 219, loss: 285.7276, total reward: 10.5700
# Episode 220, loss: 0.8498, total reward: 0.2200
# Episode 221, loss: 259.3066, total reward: 10.2300
# Episode 222, loss: -5.8116, total reward: -0.9100
# Episode 223, loss: -3.8717, total reward: 0.0200
# Episode 224, loss: 1.7363, total reward: 0.2300
# Episode 225, loss: 326.4986, total reward: 10.0600
# Episode 226, loss: 181.2164, total reward: 10.0200
# Episode 227, loss: 12.7539, total reward: 0.4300
# Episode 228, loss: 3.3137, total reward: 0.3200
# Episode 229, loss: 6.2617, total reward: 0.3200
# Episode 230, loss: -12.6062, total reward: -0.6700
# Episode 231, loss: 5.4251, total reward: 0.3200
# Episode 232, loss: 287.8661, total reward: 10.5100
# Episode 233, loss: 314.5066, total reward: 10.5600
# Episode 234, loss: 14.1500, total reward: 0.5300
# Episode 235, loss: -19.8082, total reward: -0.9600
# Episode 236, loss: 0.0664, total reward: 0.0200
# Episode 237, loss: 0.2604, total reward: 0.3200
# Episode 238, loss: 4.7886, total reward: 0.4300
# Episode 239, loss: -1.2290, total reward: -0.0900
# Episode 240, loss: -21.8763, total reward: -0.8100
# Episode 241, loss: -8.8309, total reward: -0.8300
# Episode 242, loss: -4.2038, total reward: -0.0900
# Episode 243, loss: 180.1099, total reward: 10.2100
# Episode 244, loss: -4.4546, total reward: -0.0900
# Episode 245, loss: -0.7013, total reward: 0.0200
# Episode 246, loss: 2.2265, total reward: 0.1200
# Episode 247, loss: -1.8488, total reward: 0.0300
# Episode 248, loss: -7.6930, total reward: -0.1900
# Episode 249, loss: 1.4193, total reward: 0.0200
# Episode 250, loss: 0.7605, total reward: 0.1100
# Episode 251, loss: -8.9759, total reward: -0.1900
# Episode 252, loss: 5.8761, total reward: 0.6300
# Episode 253, loss: 3.0353, total reward: 0.2300
# Episode 254, loss: 133.6364, total reward: 10.2300
# Episode 255, loss: 5.4837, total reward: 0.3200
# Episode 256, loss: 252.0874, total reward: 10.3400
# Episode 257, loss: -8.2948, total reward: -0.7300
# Episode 258, loss: 221.2260, total reward: 10.1500
# Episode 259, loss: 341.7646, total reward: 10.2700
# Episode 260, loss: 2.6941, total reward: 0.2200
# Episode 261, loss: 238.6215, total reward: 10.1200
# Episode 262, loss: 2.5710, total reward: 0.2200
# Episode 263, loss: 5.7182, total reward: 0.4300
# Episode 264, loss: -3.9617, total reward: -0.0900
# Episode 265, loss: 250.5635, total reward: 10.3300
# Episode 266, loss: 310.1778, total reward: 10.3000
# Episode 267, loss: 6.0503, total reward: 0.4200
# Episode 268, loss: 2.6537, total reward: 0.2200
# Episode 269, loss: -4.9052, total reward: -0.1800
# Episode 270, loss: 0.2378, total reward: 0.2200
# Episode 271, loss: -1.7653, total reward: 0.1200
# Episode 272, loss: 3.1776, total reward: 0.3200
# Episode 273, loss: 271.1742, total reward: 10.4400
# Episode 274, loss: 5.4123, total reward: 0.3200
# Episode 275, loss: 8.8564, total reward: 0.7300
# Episode 276, loss: 272.4255, total reward: 10.1000
# Episode 277, loss: 9.8631, total reward: 0.4300
# Episode 278, loss: -2.5960, total reward: -1.0000
# Episode 279, loss: 0.1261, total reward: 0.0200
# Episode 280, loss: -4.2092, total reward: -0.1900
# Episode 281, loss: 2.0172, total reward: 0.1200
# Episode 282, loss: 138.7060, total reward: 10.2200
# Episode 283, loss: -11.8629, total reward: -0.8500
# Episode 284, loss: -3.3350, total reward: -0.9100
# Episode 285, loss: 289.4084, total reward: 10.4400
# Episode 286, loss: -11.9399, total reward: -0.8600
# Episode 287, loss: 215.5194, total reward: 10.2400
# Episode 288, loss: -15.3596, total reward: -0.6900
# Episode 289, loss: 0.4088, total reward: 0.0200
# Episode 290, loss: -1.1946, total reward: 0.0100
# Episode 291, loss: -24.0960, total reward: -0.9500
# Episode 292, loss: -0.3005, total reward: 0.1100
# Episode 293, loss: 7.3684, total reward: 0.5200
# Episode 294, loss: 3.0224, total reward: 0.3200
# Episode 295, loss: 3.2262, total reward: 0.4200
# Episode 296, loss: -11.6456, total reward: -0.9500
# Episode 297, loss: 173.4500, total reward: 10.0000
# Episode 298, loss: 312.6225, total reward: 10.5400
# Episode 299, loss: 221.2171, total reward: 10.0400
# Episode 300, loss: 9.9106, total reward: 0.5300
# Episode 301, loss: -4.8640, total reward: 0.2300
# Episode 302, loss: 2.5210, total reward: 0.5200
# Episode 303, loss: -2.8093, total reward: -1.0000
# Episode 304, loss: 6.7986, total reward: 0.3200
# Episode 305, loss: 234.6833, total reward: 10.1100
# Episode 306, loss: -23.1283, total reward: -0.6600
# Episode 307, loss: -0.9213, total reward: -0.0900
# Episode 308, loss: -2.6100, total reward: 0.1000
# Episode 309, loss: -12.9815, total reward: -0.8500
# Episode 310, loss: -1.5072, total reward: 0.2200
# Episode 311, loss: 3.0489, total reward: 0.3200
# Episode 312, loss: 221.2695, total reward: 10.3600
# Episode 313, loss: -13.6375, total reward: -0.8900
# Episode 314, loss: -1.2580, total reward: 0.2200
# Episode 315, loss: 7.0812, total reward: 0.6300
# Episode 316, loss: 6.5193, total reward: 0.5300
# Episode 317, loss: -0.8718, total reward: 0.0100
# Episode 318, loss: 280.0157, total reward: 10.0200
# Episode 319, loss: -1.7774, total reward: 0.1200
# Episode 320, loss: 5.7337, total reward: 0.3200
# Episode 321, loss: -2.8492, total reward: -1.0000
# Episode 322, loss: 95.1680, total reward: 10.0600
# Episode 323, loss: 179.4999, total reward: 10.1700
# Episode 324, loss: 286.4514, total reward: 10.4700
# Episode 325, loss: 261.2133, total reward: 10.1500
# Episode 326, loss: 4.9731, total reward: 0.3200
# Episode 327, loss: 1.2245, total reward: 0.0100
# Episode 328, loss: 242.5877, total reward: 10.2400
# Episode 329, loss: 3.2553, total reward: 0.2200
# Episode 330, loss: 4.1335, total reward: 0.1900
# Episode 331, loss: 12.4102, total reward: 0.6300
# Episode 332, loss: 179.1394, total reward: 10.3600
# Episode 333, loss: 1.8055, total reward: 0.4300
# Episode 334, loss: 267.7041, total reward: 10.4200
# Episode 335, loss: 2.1308, total reward: 0.2200
# Episode 336, loss: -1.5896, total reward: 0.0200
# Episode 337, loss: 3.2949, total reward: 0.2200
# Episode 338, loss: 197.0166, total reward: 10.2800
# Episode 339, loss: 0.2191, total reward: 0.2200
# Episode 340, loss: 311.2283, total reward: 10.4600
# Episode 341, loss: 6.3382, total reward: 0.5200
# Episode 342, loss: 2.3915, total reward: 0.2000
# Episode 343, loss: 265.6197, total reward: 10.3200
# Episode 344, loss: 303.3691, total reward: 10.4100
# Episode 345, loss: 5.1081, total reward: 0.1200
# Episode 346, loss: -10.1673, total reward: -0.7400
# Episode 347, loss: 287.4665, total reward: 10.4400
# Episode 348, loss: 2.8181, total reward: 0.2200
# Episode 349, loss: 276.8141, total reward: 10.0800
# Episode 350, loss: 78.0819, total reward: 10.1500
# Episode 351, loss: -9.0461, total reward: -0.8400
# Episode 352, loss: 6.4302, total reward: 0.4200
# Episode 353, loss: 5.1220, total reward: 0.4200
# Episode 354, loss: -2.1334, total reward: 0.0100
# Episode 355, loss: -2.8688, total reward: -1.0000
# Episode 356, loss: 8.1676, total reward: 0.4300
# Episode 357, loss: 288.8863, total reward: 9.9500
# Episode 358, loss: 2.8854, total reward: 0.2300
# Episode 359, loss: 275.8664, total reward: 10.0800
# Episode 360, loss: 274.1246, total reward: 10.3500
# Episode 361, loss: 7.4916, total reward: 0.4100
# Episode 362, loss: 187.8455, total reward: 10.0900
# Episode 363, loss: 4.1546, total reward: 0.4300
# Episode 364, loss: 244.4422, total reward: 10.1900
# Episode 365, loss: 11.9819, total reward: 0.7300
# Episode 366, loss: 205.6964, total reward: 10.3400
# Episode 367, loss: -17.5978, total reward: -0.6400
# Episode 368, loss: 197.7809, total reward: 10.5400
# Episode 369, loss: 7.9930, total reward: 0.5300
# Episode 370, loss: 290.3190, total reward: 10.1800
# Episode 371, loss: 7.8157, total reward: 0.5200
# Episode 372, loss: -2.3725, total reward: -0.0900
# Episode 373, loss: 246.2054, total reward: 10.4700
# Episode 374, loss: 8.2276, total reward: 0.5200
# Episode 375, loss: 254.8548, total reward: 10.5100
# Episode 376, loss: -16.0597, total reward: -0.5400
# Episode 377, loss: -3.4867, total reward: -0.0900
# Episode 378, loss: 3.5293, total reward: 0.4200
# Episode 379, loss: 0.0631, total reward: 0.2300
# Episode 380, loss: 243.4852, total reward: 10.1200
# Episode 381, loss: 3.1183, total reward: 0.3200
# Episode 382, loss: 8.0058, total reward: 0.4200
# Episode 383, loss: 3.3246, total reward: 0.3200
# Episode 384, loss: 2.4404, total reward: 0.2300
# Episode 385, loss: 287.3647, total reward: 10.2700
# Episode 386, loss: 8.2625, total reward: 0.5200
# Episode 387, loss: 134.8520, total reward: 10.2200
# Episode 388, loss: -18.1769, total reward: -0.6400
# Episode 389, loss: 90.0466, total reward: 10.3400
# Episode 390, loss: 9.7477, total reward: 0.6300
# Episode 391, loss: 3.2285, total reward: 0.3200
# Episode 392, loss: 3.6391, total reward: 0.3200
# Episode 393, loss: -12.3405, total reward: -0.9300
# Episode 394, loss: -3.9884, total reward: -0.0900
# Episode 395, loss: 4.9903, total reward: 0.5200
# Episode 396, loss: 203.3294, total reward: 10.4300
# Episode 397, loss: 7.7537, total reward: 0.5300
# Episode 398, loss: 1.2102, total reward: 0.1100
# Episode 399, loss: 1.8460, total reward: 0.4300
# Episode 400, loss: -7.3374, total reward: -0.9200
# Episode 401, loss: 12.7358, total reward: 0.6300
# Episode 402, loss: 196.1278, total reward: 10.1700
# Episode 403, loss: -2.9368, total reward: -1.0000
# Episode 404, loss: 275.3651, total reward: 9.9800
# Episode 405, loss: 157.5295, total reward: 9.9800
# Episode 406, loss: 6.0516, total reward: 0.3200
# Episode 407, loss: 260.8520, total reward: 10.2600
# Episode 408, loss: 235.5300, total reward: 10.3200
# Episode 409, loss: 6.6366, total reward: 0.5200
# Episode 410, loss: -3.0184, total reward: -0.0600
# Episode 411, loss: -6.0583, total reward: -0.9100
# Episode 412, loss: 6.0735, total reward: 0.5200
# Episode 413, loss: 253.6987, total reward: 10.5800
# Episode 414, loss: 5.8791, total reward: 0.4200
# Episode 415, loss: 206.2753, total reward: 9.8600
# Episode 416, loss: -7.7297, total reward: -0.8200
# Episode 417, loss: 4.1725, total reward: 0.5200
# Episode 418, loss: -1.5690, total reward: 0.1100
# Episode 419, loss: 3.1373, total reward: 0.1700
# Episode 420, loss: 263.8542, total reward: 10.4600
# Episode 421, loss: 3.3386, total reward: 0.3200
# Episode 422, loss: 4.2324, total reward: 0.3000
# Episode 423, loss: 272.7151, total reward: 10.3900
# Episode 424, loss: -1.4732, total reward: 0.1100
# Episode 425, loss: 6.7245, total reward: 0.4300
# Episode 426, loss: 8.5731, total reward: 0.6300
# Episode 427, loss: -8.3940, total reward: -0.1900
# Episode 428, loss: 3.8283, total reward: 0.2200
# Episode 429, loss: -2.9704, total reward: 0.2400
# Episode 430, loss: 285.0220, total reward: 10.2900
# Episode 431, loss: 6.5375, total reward: 0.5200
# Episode 432, loss: 264.2936, total reward: 10.4400
# Episode 433, loss: 1.7912, total reward: 0.3300
# Episode 434, loss: 252.5154, total reward: 10.1600
# Episode 435, loss: 191.5453, total reward: 10.2000
# Episode 436, loss: -3.3225, total reward: 0.1200
# Episode 437, loss: -5.3655, total reward: -0.2400
# Episode 438, loss: 0.7165, total reward: 0.2200
# Episode 439, loss: 194.0544, total reward: 10.1700
# Episode 440, loss: 2.6538, total reward: 0.3200
# Episode 441, loss: 268.4181, total reward: 10.3300
# Episode 442, loss: -1.0209, total reward: -0.0900
# Episode 443, loss: 87.9326, total reward: 10.1500
# Episode 444, loss: 0.5863, total reward: 0.2200
# Episode 445, loss: 185.6863, total reward: 9.9200
# Episode 446, loss: 2.1388, total reward: 0.3200
# Episode 447, loss: 0.7003, total reward: 0.1200
# Episode 448, loss: 5.4442, total reward: 0.6300
# Episode 449, loss: -4.8859, total reward: 0.0200
# Episode 450, loss: -4.6979, total reward: -0.1900
# Episode 451, loss: -0.0461, total reward: 0.1200
# Episode 452, loss: 2.6767, total reward: 0.4200
# Episode 453, loss: -2.4877, total reward: -0.0000
# Episode 454, loss: 1.1788, total reward: 0.3200
# Episode 455, loss: 3.4302, total reward: 0.4200
# Episode 456, loss: 1.2057, total reward: 0.4200
# Episode 457, loss: 1.2101, total reward: 0.2600
# Episode 458, loss: 2.6497, total reward: 0.2500
# Episode 459, loss: 193.5991, total reward: 10.0500
# Episode 460, loss: 0.1842, total reward: 0.1100
# Episode 461, loss: 133.7185, total reward: 10.1100
# Episode 462, loss: -18.6091, total reward: -1.0500
# Episode 463, loss: 4.4606, total reward: 0.4200
# Episode 464, loss: 7.4377, total reward: 0.2600
# Episode 465, loss: 4.1718, total reward: 0.4200
# Episode 466, loss: -1.1117, total reward: 0.0200
# Episode 467, loss: 2.0491, total reward: 0.4000
# Episode 468, loss: -0.9978, total reward: 0.0900
# Episode 469, loss: 7.2984, total reward: 0.6100
# Episode 470, loss: -1.1673, total reward: 0.1100
# Episode 471, loss: 3.3168, total reward: 0.4300
# Episode 472, loss: 286.2923, total reward: 10.1800
# Episode 473, loss: -0.7419, total reward: 0.0200
# Episode 474, loss: 192.2722, total reward: 10.0100
# Episode 475, loss: -3.4588, total reward: -0.0800
# Episode 476, loss: 302.6826, total reward: 10.0200
# Episode 477, loss: 228.9378, total reward: 10.1100
# Episode 478, loss: 240.8268, total reward: 10.4000
# Episode 479, loss: 3.7454, total reward: 0.4300
# Episode 480, loss: -0.3627, total reward: -0.0100
# Episode 481, loss: 3.9222, total reward: 0.3200
# Episode 482, loss: -1.4508, total reward: 0.1100
# Episode 483, loss: 155.6631, total reward: 10.0800
# Episode 484, loss: 295.6559, total reward: 10.5200
# Episode 485, loss: 271.9988, total reward: 9.9300
# Episode 486, loss: 2.3676, total reward: 0.2200
# Episode 487, loss: 0.3815, total reward: 0.1100
# Episode 488, loss: 7.9114, total reward: 0.4200
# Episode 489, loss: -0.2700, total reward: 0.0200
# Episode 490, loss: -1.3691, total reward: 0.0100
# Episode 491, loss: -3.2186, total reward: -0.1900
# Episode 492, loss: 259.0811, total reward: 10.5100
# Episode 493, loss: -10.9437, total reward: -0.4700
# Episode 494, loss: -0.4346, total reward: 0.2200
# Episode 495, loss: 2.9759, total reward: 0.4300
# Episode 496, loss: 2.0889, total reward: 0.3200
# Episode 497, loss: 303.5439, total reward: 9.8900
# Episode 498, loss: 4.9435, total reward: 0.4200
# Episode 499, loss: 215.6706, total reward: 9.9300
# Episode 500, loss: 0.9510, total reward: 0.3900
# Episode 501, loss: 199.6430, total reward: 10.1800
# Episode 502, loss: 6.4992, total reward: 0.3200
# Episode 503, loss: 1.7478, total reward: 0.2200
# Episode 504, loss: 125.6557, total reward: 10.0300
# Episode 505, loss: 7.1281, total reward: 0.7300
# Episode 506, loss: 231.2024, total reward: 10.2000
# Episode 507, loss: 4.1961, total reward: 0.5300
# Episode 508, loss: 153.9921, total reward: 9.9200
# Episode 509, loss: 277.7294, total reward: 10.5400
# Episode 510, loss: -16.8180, total reward: -0.6300
# Episode 511, loss: 4.7742, total reward: 0.4200
# Episode 512, loss: -9.5172, total reward: -0.7300
# Episode 513, loss: 235.4372, total reward: 10.2100
# Episode 514, loss: 191.9195, total reward: 10.4300
# Episode 515, loss: -3.6121, total reward: -0.0900
# Episode 516, loss: 101.7388, total reward: 10.3400
# Episode 517, loss: 5.6329, total reward: 0.3200
# Episode 518, loss: 8.4335, total reward: 0.6300
# Episode 519, loss: -1.6697, total reward: 0.1100
# Episode 520, loss: 4.4009, total reward: 0.6300
# Episode 521, loss: 3.4835, total reward: 0.3200
# Episode 522, loss: 227.2059, total reward: 10.2500
# Episode 523, loss: 228.6162, total reward: 10.3900
# Episode 524, loss: -0.1516, total reward: 0.1500
# Episode 525, loss: 7.5554, total reward: 0.5200
# Episode 526, loss: -1.7377, total reward: 0.0200
# Episode 527, loss: 6.8034, total reward: 0.5200
# Episode 528, loss: 4.9257, total reward: 0.4200
# Episode 529, loss: 2.5591, total reward: 0.3200
# Episode 530, loss: -3.7352, total reward: 0.0200
# Episode 531, loss: -6.3568, total reward: -0.9200
# Episode 532, loss: 215.8352, total reward: 10.1900
# Episode 533, loss: 1.8862, total reward: 0.4200
# Episode 534, loss: -2.1972, total reward: 0.0100
# Episode 535, loss: 4.8698, total reward: 0.4200
# Episode 536, loss: 0.1779, total reward: 0.0100
# Episode 537, loss: -2.0800, total reward: 0.0200
# Episode 538, loss: 2.4091, total reward: 0.2200
# Episode 539, loss: 263.7960, total reward: 10.0700
# Episode 540, loss: 7.7482, total reward: 0.7300
# Episode 541, loss: 252.2774, total reward: 10.0500
# Episode 542, loss: -1.6376, total reward: 0.3200
# Episode 543, loss: -1.3964, total reward: 0.0200
# Episode 544, loss: 7.8305, total reward: 0.4200
# Episode 545, loss: 240.2537, total reward: 10.0900
# Episode 546, loss: 157.7062, total reward: 10.1800
# Episode 547, loss: -8.2069, total reward: -0.8300
# Episode 548, loss: -2.6845, total reward: 0.0200
# Episode 549, loss: 3.4967, total reward: 0.2200
# Episode 550, loss: 175.9190, total reward: 10.2300
# Episode 551, loss: 253.2951, total reward: 10.3200
# Episode 552, loss: 277.0754, total reward: 10.4500
# Episode 553, loss: -1.0151, total reward: 0.2200
# Episode 554, loss: 145.4123, total reward: 10.1700
# Episode 555, loss: 3.2737, total reward: 0.2200
# Episode 556, loss: -3.7695, total reward: -0.1900
# Episode 557, loss: 2.5488, total reward: 0.4200
# Episode 558, loss: -4.8339, total reward: -0.2900
# Episode 559, loss: 1.1821, total reward: 0.1100
# Episode 560, loss: 6.8948, total reward: 0.5200
# Episode 561, loss: -1.7594, total reward: 0.1100
# Episode 562, loss: -0.2224, total reward: 0.0200
# Episode 563, loss: 214.6948, total reward: 10.2600
# Episode 564, loss: -0.6412, total reward: 0.1100
# Episode 565, loss: 3.2928, total reward: 0.3200
# Episode 566, loss: 4.1735, total reward: 0.4300
# Episode 567, loss: -1.0349, total reward: 0.2200
# Episode 568, loss: 3.1727, total reward: 0.2200
# Episode 569, loss: -2.0674, total reward: -0.0900
# Episode 570, loss: 0.0413, total reward: 0.1100
# Episode 571, loss: 6.0295, total reward: 0.5300
# Episode 572, loss: 94.9770, total reward: 10.0300
# Episode 573, loss: 237.3350, total reward: 10.3800
# Episode 574, loss: -0.3322, total reward: 0.1200
# Episode 575, loss: -3.3586, total reward: 0.0100
# Episode 576, loss: 264.0590, total reward: 10.3700
# Episode 577, loss: 0.2615, total reward: 0.2200
# Episode 578, loss: 0.7481, total reward: 0.0200
# Episode 579, loss: 248.9796, total reward: 10.3800
# Episode 580, loss: 102.2271, total reward: 10.2300
# Episode 581, loss: 221.5567, total reward: 10.1000
# Episode 582, loss: 248.5580, total reward: 10.2800
# Episode 583, loss: 240.4579, total reward: 10.2200
# Episode 584, loss: 169.7475, total reward: 10.4600
# Episode 585, loss: -18.7345, total reward: -0.7800
# Episode 586, loss: 250.8315, total reward: 10.1100
# Episode 587, loss: 3.7236, total reward: 0.3100
# Episode 588, loss: 6.2813, total reward: 0.4200
# Episode 589, loss: 263.3508, total reward: 10.4300
# Episode 590, loss: 242.3793, total reward: 10.4000
# Episode 591, loss: 0.4983, total reward: 0.1100
# Episode 592, loss: 248.9959, total reward: 10.4100
# Episode 593, loss: 0.1651, total reward: 0.0100
# Episode 594, loss: 264.2328, total reward: 10.3500
# Episode 595, loss: 284.7937, total reward: 10.7400
# Episode 596, loss: 224.0305, total reward: 10.2300
# Episode 597, loss: 6.3165, total reward: 0.3200
# Episode 598, loss: 244.5248, total reward: 10.2600
# Episode 599, loss: 107.5158, total reward: 10.3200
# Episode 600, loss: 4.5177, total reward: 0.4200
# Episode 601, loss: 279.0370, total reward: 10.3300
# Episode 602, loss: 284.4564, total reward: 10.7300
# Episode 603, loss: 0.5417, total reward: 0.3200
# Episode 604, loss: 4.4371, total reward: 0.4200
# Episode 605, loss: 161.5273, total reward: 10.2900
# Episode 606, loss: 152.1029, total reward: 10.1900
# Episode 607, loss: -2.8896, total reward: -0.1700
# Episode 608, loss: 240.9559, total reward: 10.7700
# Episode 609, loss: 0.6725, total reward: 0.2200
# Episode 610, loss: 258.7260, total reward: 10.1200
# Episode 611, loss: 242.5778, total reward: 10.3100
# Episode 612, loss: -1.8043, total reward: 0.0100
# Episode 613, loss: -10.8839, total reward: -0.6800
# Episode 614, loss: 2.2955, total reward: 0.4200
# Episode 615, loss: 175.2434, total reward: 10.5600
# Episode 616, loss: -19.9359, total reward: -0.5900
# Episode 617, loss: 5.9298, total reward: 0.4200
# Episode 618, loss: 5.0275, total reward: 0.2200
# Episode 619, loss: 170.1315, total reward: 10.1800
# Episode 620, loss: -20.7510, total reward: -0.4700
# Episode 621, loss: 241.4591, total reward: 10.7300
# Episode 622, loss: -5.9363, total reward: -0.9200
# Episode 623, loss: -11.7650, total reward: -0.9300
# Episode 624, loss: 239.7505, total reward: 10.3600
# Episode 625, loss: 232.4283, total reward: 10.6100
# Episode 626, loss: 250.1378, total reward: 9.9000
# Episode 627, loss: 1.4992, total reward: 0.1200
# Episode 628, loss: 213.2150, total reward: 10.2700
# Episode 629, loss: 5.1432, total reward: 0.4200
# Episode 630, loss: 156.3130, total reward: 9.9600
# Episode 631, loss: -7.8187, total reward: -0.8400
# Episode 632, loss: 0.5512, total reward: 0.0100
# Episode 633, loss: 205.2421, total reward: 10.3400
# Episode 634, loss: 5.1163, total reward: 0.4300
# Episode 635, loss: 11.1508, total reward: 0.6300
# Episode 636, loss: 268.4449, total reward: 10.7800
# Episode 637, loss: 198.9563, total reward: 10.4100
# Episode 638, loss: 4.3081, total reward: 0.5200
# Episode 639, loss: 107.4684, total reward: 9.9100
# Episode 640, loss: 299.1659, total reward: 10.0300
# Episode 641, loss: 211.5285, total reward: 10.3800
# Episode 642, loss: 131.6876, total reward: 10.2300
# Episode 643, loss: 264.2975, total reward: 10.5300
# Episode 644, loss: 2.8257, total reward: 0.2200
# Episode 645, loss: 212.9614, total reward: 10.5300
# Episode 646, loss: 231.6961, total reward: 10.4300
# Episode 647, loss: 213.2534, total reward: 10.0200
# Episode 648, loss: 295.3411, total reward: 9.9300
# Episode 649, loss: 6.2036, total reward: 0.5200
# Episode 650, loss: -3.2529, total reward: -0.0900
# Episode 651, loss: 219.3978, total reward: 10.1300
# Episode 652, loss: -8.5787, total reward: -0.7300
# Episode 653, loss: 200.7921, total reward: 10.4900
# Episode 654, loss: 3.2283, total reward: 0.1100
# Episode 655, loss: 9.6579, total reward: 0.5200
# Episode 656, loss: 258.2847, total reward: 10.4800
# Episode 657, loss: 2.3576, total reward: 0.4200
# Episode 658, loss: 269.6890, total reward: 10.2100
# Episode 659, loss: 9.8223, total reward: 0.7300
# Episode 660, loss: 164.9636, total reward: 10.1500
# Episode 661, loss: 225.5075, total reward: 10.4000
# Episode 662, loss: 195.8318, total reward: 10.5300
# Episode 663, loss: 165.7020, total reward: 10.2800
# Episode 664, loss: 218.7765, total reward: 10.5200
# Episode 665, loss: 3.3620, total reward: 0.2200
# Episode 666, loss: 247.5488, total reward: 10.3900
# Episode 667, loss: 7.0011, total reward: 0.4300
# Episode 668, loss: 259.9960, total reward: 10.5100
# Episode 669, loss: 171.7975, total reward: 10.4300
# Episode 670, loss: 206.9852, total reward: 10.0400
# Episode 671, loss: 8.3602, total reward: 0.5200
# Episode 672, loss: 232.0054, total reward: 10.7900
# Episode 673, loss: 1.6599, total reward: 0.2200
# Episode 674, loss: 3.1306, total reward: 0.2200
# Episode 675, loss: 126.2347, total reward: 10.0800
# Episode 676, loss: 4.8927, total reward: 0.4300
# Episode 677, loss: 4.8380, total reward: 0.3200
# Episode 678, loss: 169.2645, total reward: 10.2800
# Episode 679, loss: 1.6535, total reward: 0.2200
# Episode 680, loss: -1.6785, total reward: -0.1100
# Episode 681, loss: 213.0778, total reward: 10.3000
# Episode 682, loss: 195.5930, total reward: 10.0300
# Episode 683, loss: 4.0775, total reward: 0.2200
# Episode 684, loss: 0.3866, total reward: 0.3200
# Episode 685, loss: 124.2705, total reward: 10.1000
# Episode 686, loss: -0.2980, total reward: 0.2200
# Episode 687, loss: 209.9957, total reward: 10.1200
# Episode 688, loss: 139.8512, total reward: 10.0000
# Episode 689, loss: 88.5188, total reward: 9.9800
# Episode 690, loss: 212.0937, total reward: 10.1700
# Episode 691, loss: 5.9520, total reward: 0.6300
# Episode 692, loss: 37.2347, total reward: 10.0800
# Episode 693, loss: 223.6433, total reward: 10.2900
# Episode 694, loss: 0.5916, total reward: 0.0100
# Episode 695, loss: 3.3696, total reward: 0.5200
# Episode 696, loss: -6.0649, total reward: -0.9100
# Episode 697, loss: 1.0133, total reward: 0.3200
# Episode 698, loss: 5.9706, total reward: 0.3200
# Episode 699, loss: 1.2224, total reward: 0.2200
# Episode 700, loss: 166.8519, total reward: 10.0200
# Episode 701, loss: -5.8161, total reward: -0.8200
# Episode 702, loss: 3.6754, total reward: 0.3200
# Episode 703, loss: 234.0074, total reward: 10.2600
# Episode 704, loss: 222.2969, total reward: 10.3300
# Episode 705, loss: 1.3313, total reward: 0.0200
# Episode 706, loss: -15.1878, total reward: -0.7500
# Episode 707, loss: 1.8566, total reward: 0.3300
# Episode 708, loss: 3.9165, total reward: 0.3200
# Episode 709, loss: 243.4890, total reward: 10.5900
# Episode 710, loss: -1.3038, total reward: 0.0100
# Episode 711, loss: -3.9739, total reward: -0.1300
# Episode 712, loss: 178.0150, total reward: 10.3400
# Episode 713, loss: 248.7097, total reward: 10.4200
# Episode 714, loss: 1.2267, total reward: 0.2000
# Episode 715, loss: 231.4488, total reward: 10.0800
# Episode 716, loss: 168.3984, total reward: 10.4600
# Episode 717, loss: 131.8824, total reward: 10.0900
# Episode 718, loss: 5.5271, total reward: 0.2200
# Episode 719, loss: 2.8477, total reward: 0.4200
# Episode 720, loss: 4.4827, total reward: 0.4200
# Episode 721, loss: 193.5558, total reward: 10.1700
# Episode 722, loss: 1.1632, total reward: 0.1100
# Episode 723, loss: -4.9297, total reward: -0.9100
# Episode 724, loss: 275.9471, total reward: 10.3200
# Episode 725, loss: -2.2869, total reward: 0.1100
# Episode 726, loss: 213.5719, total reward: 10.3500
# Episode 727, loss: 229.3090, total reward: 10.0200
# Episode 728, loss: -3.2664, total reward: -1.0000
# Episode 729, loss: 3.6880, total reward: 0.5200
# Episode 730, loss: 238.4003, total reward: 10.7500
# Episode 731, loss: 3.0922, total reward: 0.2400
# Episode 732, loss: 226.0649, total reward: 10.1400
# Episode 733, loss: 3.2793, total reward: 0.3200
# Episode 734, loss: 164.4614, total reward: 10.2800
# Episode 735, loss: 252.3884, total reward: 10.1700
# Episode 736, loss: 300.0837, total reward: 10.3300
# Episode 737, loss: 191.5535, total reward: 10.3200
# Episode 738, loss: 237.8308, total reward: 10.4000
# Episode 739, loss: 6.5459, total reward: 0.6300
# Episode 740, loss: 10.3343, total reward: 0.7300
# Episode 741, loss: 174.1264, total reward: 10.5200
# Episode 742, loss: 107.5712, total reward: 10.1300
# Episode 743, loss: 4.3506, total reward: 0.2700
# Episode 744, loss: 234.4332, total reward: 10.2700
# Episode 745, loss: 3.1703, total reward: 0.3200
# Episode 746, loss: 10.8037, total reward: 0.6300
# Episode 747, loss: 7.2492, total reward: 0.7300
# Episode 748, loss: 7.6928, total reward: 0.5200
# Episode 749, loss: 135.1001, total reward: 9.9500
# Episode 750, loss: 203.2144, total reward: 10.7700
# Episode 751, loss: 2.7317, total reward: 0.4200
# Episode 752, loss: -5.3059, total reward: -0.3000
# Episode 753, loss: 8.0466, total reward: 0.5300
# Episode 754, loss: 173.1676, total reward: 10.5500
# Episode 755, loss: 3.9700, total reward: 0.4200
# Episode 756, loss: -0.1815, total reward: -0.0900
# Episode 757, loss: 214.5712, total reward: 10.0400
# Episode 758, loss: 3.3468, total reward: 0.2200
# Episode 759, loss: 229.1255, total reward: 10.2100
# Episode 760, loss: 4.8955, total reward: 0.5000
# Episode 761, loss: 3.2663, total reward: 0.3200
# Episode 762, loss: 199.3456, total reward: 10.2100
# Episode 763, loss: 190.7762, total reward: 10.1500
# Episode 764, loss: 271.8639, total reward: 10.4500
# Episode 765, loss: 258.4122, total reward: 10.5600
# Episode 766, loss: 9.2141, total reward: 0.7300
# Episode 767, loss: 165.4055, total reward: 10.4100
# Episode 768, loss: 257.4533, total reward: 10.0200
# Episode 769, loss: 259.6410, total reward: 10.2800
# Episode 770, loss: 198.6805, total reward: 10.3300
# Episode 771, loss: 2.6780, total reward: 0.3200
# Episode 772, loss: -2.9062, total reward: -0.1300
# Episode 773, loss: 4.0253, total reward: 0.3200
# Episode 774, loss: 277.4777, total reward: 10.3400
# Episode 775, loss: -16.6556, total reward: -0.6700
# Episode 776, loss: 55.6991, total reward: 10.0700
# Episode 777, loss: 153.3004, total reward: 10.1800
# Episode 778, loss: 8.2478, total reward: 0.6300
# Episode 779, loss: 121.4302, total reward: 10.1100
# Episode 780, loss: 249.0272, total reward: 10.2600
# Episode 781, loss: 6.6088, total reward: 0.5200
# Episode 782, loss: 274.7108, total reward: 10.3200
# Episode 783, loss: 247.4377, total reward: 10.2800
# Episode 784, loss: 206.4269, total reward: 10.1000
# Episode 785, loss: 6.1236, total reward: 0.5200
# Episode 786, loss: -9.6481, total reward: -0.7700
# Episode 787, loss: -11.3229, total reward: -0.4200
# Episode 788, loss: 4.7167, total reward: 0.6300
# Episode 789, loss: 2.9890, total reward: 0.4200
# Episode 790, loss: 178.4613, total reward: 10.2300
# Episode 791, loss: 216.5436, total reward: 10.0200
# Episode 792, loss: 219.0016, total reward: 10.4700
# Episode 793, loss: 7.1020, total reward: 0.4200
# Episode 794, loss: 264.9305, total reward: 10.4500
# Episode 795, loss: 207.0706, total reward: 10.2700
# Episode 796, loss: 236.9805, total reward: 10.1700
# Episode 797, loss: 190.7779, total reward: 10.3800
# Episode 798, loss: 152.8789, total reward: 9.9800
# Episode 799, loss: 187.2433, total reward: 10.1800
# Episode 800, loss: 193.6860, total reward: 10.2500
# Episode 801, loss: 118.9082, total reward: 10.2200
# Episode 802, loss: 255.8953, total reward: 10.3100
# Episode 803, loss: 101.0748, total reward: 10.1400
# Episode 804, loss: 235.4600, total reward: 10.4400
# Episode 805, loss: 242.0803, total reward: 10.3900
# Episode 806, loss: 236.2979, total reward: 10.2200
# Episode 807, loss: 100.5599, total reward: 10.3300
# Episode 808, loss: 242.7409, total reward: 10.3900
# Episode 809, loss: -13.6254, total reward: -0.6000
# Episode 810, loss: 5.4815, total reward: 0.4200
# Episode 811, loss: 2.3599, total reward: 0.2200
# Episode 812, loss: 1.5050, total reward: 0.0100
# Episode 813, loss: 5.1992, total reward: 0.5200
# Episode 814, loss: 107.7854, total reward: 10.5200
# Episode 815, loss: 7.6854, total reward: 0.5200
# Episode 816, loss: 164.8877, total reward: 10.0800
# Episode 817, loss: 251.9776, total reward: 10.2900
# Episode 818, loss: 2.2301, total reward: 0.3200
# Episode 819, loss: 200.4599, total reward: 10.2900
# Episode 820, loss: 1.3049, total reward: 0.0200
# Episode 821, loss: 10.8268, total reward: 0.7300
# Episode 822, loss: 7.2800, total reward: 0.7300
# Episode 823, loss: -1.5164, total reward: 0.0100
# Episode 824, loss: 214.3634, total reward: 10.4100
# Episode 825, loss: 241.3362, total reward: 10.4100
# Episode 826, loss: 157.3026, total reward: 10.3800
# Episode 827, loss: 9.5046, total reward: 0.6300
# Episode 828, loss: 6.1191, total reward: 0.4300
# Episode 829, loss: 266.5269, total reward: 10.5500
# Episode 830, loss: 10.6013, total reward: 0.8100
# Episode 831, loss: 7.5030, total reward: 0.5200
# Episode 832, loss: 156.3374, total reward: 10.5500
# Episode 833, loss: -4.3950, total reward: -0.0900
# Episode 834, loss: -2.4839, total reward: 0.0100
# Episode 835, loss: 5.0364, total reward: 0.2200
# Episode 836, loss: -29.0794, total reward: -0.9700
# Episode 837, loss: 3.9965, total reward: 0.3200
# Episode 838, loss: 135.8987, total reward: 10.1900
# Episode 839, loss: 244.8810, total reward: 10.1400
# Episode 840, loss: 206.2394, total reward: 10.4400
# Episode 841, loss: 6.7782, total reward: 0.6300
# Episode 842, loss: 212.8190, total reward: 10.1300
# Episode 843, loss: -6.9455, total reward: -0.8300
# Episode 844, loss: 4.1114, total reward: 0.2200
# Episode 845, loss: 254.5581, total reward: 10.7900
# Episode 846, loss: 5.7514, total reward: 0.5200
# Episode 847, loss: 182.8127, total reward: 10.7100
# Episode 848, loss: -16.9574, total reward: -0.6300
# Episode 849, loss: 216.9240, total reward: 10.3100
# Episode 850, loss: 177.5686, total reward: 9.9900
# Episode 851, loss: 16.7826, total reward: 9.9800
# Episode 852, loss: 253.1320, total reward: 9.9700
# Episode 853, loss: 1.1852, total reward: 0.2200
# Episode 854, loss: 181.9234, total reward: 10.0200
# Episode 855, loss: -2.1197, total reward: 0.0100
# Episode 856, loss: 3.0995, total reward: 0.5200
# Episode 857, loss: 181.4153, total reward: 10.5400
# Episode 858, loss: 8.6744, total reward: 0.6300
# Episode 859, loss: -18.8649, total reward: -0.5300
# Episode 860, loss: 2.3818, total reward: 0.4200
# Episode 861, loss: 244.2461, total reward: 10.2100
# Episode 862, loss: 5.2907, total reward: 0.5200
# Episode 863, loss: 10.4050, total reward: 0.6300
# Episode 864, loss: 1.4443, total reward: 0.2200
# Episode 865, loss: 1.0446, total reward: 0.4200
# Episode 866, loss: 167.0392, total reward: 10.2200
# Episode 867, loss: 225.1807, total reward: 10.4600
# Episode 868, loss: 7.6034, total reward: 0.4200
# Episode 869, loss: 2.7192, total reward: 0.1300
# Episode 870, loss: -9.2381, total reward: -0.9400
# Episode 871, loss: 0.5455, total reward: 0.2300
# Episode 872, loss: -4.5109, total reward: -0.9100
# Episode 873, loss: 4.7100, total reward: 0.4200
# Episode 874, loss: 1.7076, total reward: 0.0100
# Episode 875, loss: 211.2335, total reward: 10.5200
# Episode 876, loss: 214.7357, total reward: 10.5100
# Episode 877, loss: 206.4266, total reward: 10.2800
# Episode 878, loss: 259.7138, total reward: 9.8400
# Episode 879, loss: 181.8339, total reward: 10.2200
# Episode 880, loss: 232.4229, total reward: 10.5100
# Episode 881, loss: 3.9266, total reward: 0.4200
# Episode 882, loss: 11.8147, total reward: 0.8300
# Episode 883, loss: 119.4154, total reward: 9.9800
# Episode 884, loss: 228.6751, total reward: 10.5700
# Episode 885, loss: 12.5859, total reward: 0.7300
# Episode 886, loss: 108.6357, total reward: 10.1100
# Episode 887, loss: 4.3319, total reward: 0.2200
# Episode 888, loss: 236.6638, total reward: 10.0700
# Episode 889, loss: -15.2671, total reward: -0.4100
# Episode 890, loss: 7.1263, total reward: 0.5200
# Episode 891, loss: -1.3688, total reward: 0.0100
# Episode 892, loss: 3.4437, total reward: 0.6300
# Episode 893, loss: 214.0679, total reward: 10.3400
# Episode 894, loss: -18.6459, total reward: -0.7600
# Episode 895, loss: 249.7526, total reward: 10.6600
# Episode 896, loss: 183.0244, total reward: 10.3400
# Episode 897, loss: 171.4243, total reward: 10.3400
# Episode 898, loss: 0.4845, total reward: 0.2200
# Episode 899, loss: 3.9766, total reward: 0.3200
# Episode 900, loss: 250.7044, total reward: 10.0300
# Episode 901, loss: -16.1644, total reward: -0.8200
# Episode 902, loss: 214.6860, total reward: 10.0700
# Episode 903, loss: -11.6195, total reward: -0.5900
# Episode 904, loss: 208.5330, total reward: 10.2700
# Episode 905, loss: 6.2227, total reward: 0.5200
# Episode 906, loss: 197.5371, total reward: 10.3400
# Episode 907, loss: 188.6526, total reward: 10.8500
# Episode 908, loss: 212.8120, total reward: 10.6600
# Episode 909, loss: 150.6441, total reward: 10.3500
# Episode 910, loss: -0.1633, total reward: 0.1100
# Episode 911, loss: 1.8613, total reward: 0.2200
# Episode 912, loss: 132.0695, total reward: 9.9600
# Episode 913, loss: 181.8909, total reward: 10.4700
# Episode 914, loss: 270.6891, total reward: 10.4600
# Episode 915, loss: 7.5921, total reward: 0.7300
# Episode 916, loss: 172.9063, total reward: 10.4800
# Episode 917, loss: 4.7728, total reward: 0.2200
# Episode 918, loss: 191.0594, total reward: 10.2500
# Episode 919, loss: 3.6499, total reward: 0.4200
# Episode 920, loss: 3.2106, total reward: 0.2700
# Episode 921, loss: 217.6891, total reward: 10.5600
# Episode 922, loss: 153.5352, total reward: 10.2200
# Episode 923, loss: 3.9358, total reward: 0.2200
# Episode 924, loss: 228.8483, total reward: 10.2600
# Episode 925, loss: 162.0546, total reward: 10.2300
# Episode 926, loss: 6.9279, total reward: 0.5200
# Episode 927, loss: -1.4583, total reward: 0.0400
# Episode 928, loss: 204.0246, total reward: 10.4900
# Episode 929, loss: 0.6101, total reward: 0.1100
# Episode 930, loss: 2.7495, total reward: 0.1100
# Episode 931, loss: 1.6784, total reward: 0.0100
# Episode 932, loss: 160.8605, total reward: 10.0800
# Episode 933, loss: -2.3386, total reward: -0.0900
# Episode 934, loss: -0.9312, total reward: 0.1100
# Episode 935, loss: 2.9755, total reward: 0.1200
# Episode 936, loss: -1.9331, total reward: 0.0100
# Episode 937, loss: 1.9011, total reward: 0.2000
# Episode 938, loss: 3.6980, total reward: 0.5200
# Episode 939, loss: 2.3125, total reward: 0.3200
# Episode 940, loss: 5.5907, total reward: 0.6300
# Episode 941, loss: 4.3650, total reward: 0.3200
# Episode 942, loss: 0.4597, total reward: 0.0100
# Episode 943, loss: 4.5990, total reward: 0.3200
# Episode 944, loss: 5.7558, total reward: 0.4200
# Episode 945, loss: 2.2732, total reward: 0.1100
# Episode 946, loss: 3.1044, total reward: 0.1100
# Episode 947, loss: -2.0844, total reward: -0.0900
# Episode 948, loss: -23.2795, total reward: -0.9100
# Episode 949, loss: 3.3340, total reward: 0.2200
# Episode 950, loss: 5.6306, total reward: 0.4200
# Episode 951, loss: 116.2095, total reward: 10.5300
# Episode 952, loss: 173.3535, total reward: 10.0400
# Episode 953, loss: 204.9488, total reward: 10.7600
# Episode 954, loss: -0.4396, total reward: 0.1200
# Episode 955, loss: 203.3053, total reward: 9.9200
# Episode 956, loss: 274.8822, total reward: 10.3400
# Episode 957, loss: 4.9325, total reward: 0.4200
# Episode 958, loss: -1.1522, total reward: 0.0100
# Episode 959, loss: 209.0101, total reward: 10.4100
# ...
# Episode 13656, loss: 0.2710, total reward: 0.3900
# Episode 13657, loss: 31.9193, total reward: 10.4500
# Episode 13658, loss: 2.3681, total reward: 10.3800
# Episode 13659, loss: 1.3041, total reward: 10.2800
# Episode 13660, loss: 0.4013, total reward: 10.0400
# Episode 13661, loss: 0.0094, total reward: 0.2200
# Episode 13662, loss: 2.9244, total reward: 10.0300
# Episode 13663, loss: 0.3413, total reward: 0.4200
# Episode 13664, loss: 1.4084, total reward: 10.1400
# Episode 13665, loss: 2.9360, total reward: 10.3500
# Episode 13666, loss: 4.2106, total reward: 10.3800
# Episode 13667, loss: 1.9849, total reward: 10.3300
# Episode 13668, loss: 14.8967, total reward: 10.2600
# Episode 13669, loss: 0.6000, total reward: 10.2600
# Episode 13670, loss: 5.9904, total reward: 10.3300
# Episode 13671, loss: 0.0119, total reward: 0.2200
# Episode 13672, loss: 1.3092, total reward: 10.0500
# Episode 13673, loss: 0.4670, total reward: 10.2000
# Episode 13674, loss: 1.5808, total reward: 10.1300
# Episode 13675, loss: 16.8066, total reward: 10.0600
# Episode 13676, loss: 0.4521, total reward: 10.3100
# Episode 13677, loss: 0.1245, total reward: 0.4200
# Episode 13678, loss: 0.2464, total reward: 10.1800
# Episode 13679, loss: -0.0047, total reward: 0.1100
# Episode 13680, loss: 0.0321, total reward: 0.5200
# Episode 13681, loss: 0.0172, total reward: 0.2200
# Episode 13682, loss: 0.0072, total reward: 0.6300
# Episode 13683, loss: -0.0486, total reward: 0.2200
# Episode 13684, loss: 0.6979, total reward: 10.3600
# Episode 13685, loss: 1.5228, total reward: 0.6300
# Episode 13686, loss: 0.1622, total reward: 0.5200
# Episode 13687, loss: 0.0028, total reward: 0.3200
# Episode 13688, loss: 12.2770, total reward: 9.9400
# Episode 13689, loss: 48.9689, total reward: 10.3000
# Episode 13690, loss: 7.9128, total reward: 10.0200
# Episode 13691, loss: 0.0178, total reward: 0.2200
# Episode 13692, loss: 0.1149, total reward: 0.8300
# Episode 13693, loss: 3.1590, total reward: 10.5700
# Episode 13694, loss: 5.0090, total reward: 10.0800
# Episode 13695, loss: 0.1708, total reward: 0.5200
# Episode 13696, loss: 0.1232, total reward: 0.5200
# Episode 13697, loss: 0.7748, total reward: 0.5200
# Episode 13698, loss: 7.6106, total reward: 10.4500
# Episode 13699, loss: 0.2522, total reward: 10.3800
# Episode 13700, loss: 0.0182, total reward: 0.2200
# Episode 13701, loss: 0.1813, total reward: 0.4200
# Episode 13702, loss: 2.1528, total reward: 10.4700
# Episode 13703, loss: 0.0746, total reward: 0.2200
# Episode 13704, loss: -0.0038, total reward: 0.5200
# Episode 13705, loss: 0.5039, total reward: 10.2400
# Episode 13706, loss: 0.0554, total reward: 0.5200
# Episode 13707, loss: 0.0272, total reward: 0.7300
# Episode 13708, loss: 0.3356, total reward: 0.6300
# Episode 13709, loss: 1.1201, total reward: 10.3200
# Episode 13710, loss: 0.0559, total reward: 0.4200
# Episode 13711, loss: -0.0035, total reward: 0.1100
# Episode 13712, loss: 0.1024, total reward: 10.1400
# Episode 13713, loss: 12.7091, total reward: 10.3000
# Episode 13714, loss: 1.3473, total reward: 10.1700
# Episode 13715, loss: 0.9047, total reward: 10.3700
# Episode 13716, loss: 1.3870, total reward: 10.2000
# Episode 13717, loss: 0.2556, total reward: 0.2200
# Episode 13718, loss: 1.4985, total reward: 10.4000
# Episode 13719, loss: 0.0365, total reward: 0.5200
# Episode 13720, loss: 1.9650, total reward: 10.6600
# Episode 13721, loss: 0.1005, total reward: 10.0300
# Episode 13722, loss: 2.5086, total reward: 9.9700
# Episode 13723, loss: 0.3124, total reward: 0.7300
# Episode 13724, loss: 3.7731, total reward: 9.9200
# Episode 13725, loss: 0.0801, total reward: 0.7300
# Episode 13726, loss: 0.2005, total reward: 9.8900
# Episode 13727, loss: 0.0522, total reward: 0.5200
# Episode 13728, loss: 38.7587, total reward: 10.6400
# Episode 13729, loss: 0.0291, total reward: 0.3200
# Episode 13730, loss: 2.3598, total reward: 10.2400
# Episode 13731, loss: 2.2822, total reward: 10.3600
# Episode 13732, loss: 11.3284, total reward: 10.4400
# Episode 13733, loss: 1.6982, total reward: 10.2600
# Episode 13734, loss: 0.7348, total reward: 10.2300
# Episode 13735, loss: -0.3666, total reward: 0.1100
# Episode 13736, loss: 0.0023, total reward: 0.3200
# Episode 13737, loss: 0.7442, total reward: 0.4200
# Episode 13738, loss: 1.6869, total reward: 0.5200
# Episode 13739, loss: 1.3063, total reward: 10.7800
# Episode 13740, loss: -0.0978, total reward: 0.5200
# Episode 13741, loss: 0.0026, total reward: 0.2200
# Episode 13742, loss: 3.8893, total reward: 10.4200
# Episode 13743, loss: 0.7530, total reward: 10.4400
# Episode 13744, loss: 0.0171, total reward: 0.2200
# Episode 13745, loss: 0.6002, total reward: 0.8300
# Episode 13746, loss: 14.5665, total reward: 10.4800
# Episode 13747, loss: 0.0081, total reward: 0.2500
# Episode 13748, loss: 0.0127, total reward: 10.2900
# Episode 13749, loss: 15.3252, total reward: 10.2000
# Episode 13750, loss: 1.6084, total reward: 10.6900
# Episode 13751, loss: -0.0064, total reward: 0.1100
# Episode 13752, loss: 0.5062, total reward: 10.1700
# Episode 13753, loss: 0.0025, total reward: 0.4200
# Episode 13754, loss: -0.0038, total reward: 0.4200
# Episode 13755, loss: 2.6134, total reward: 10.5100
# Episode 13756, loss: 0.0033, total reward: 0.6300
# Episode 13757, loss: 0.1100, total reward: 0.3700
# Episode 13758, loss: 0.0038, total reward: 10.0700
# Episode 13759, loss: 2.8773, total reward: 10.4500
# Episode 13760, loss: 0.3147, total reward: 10.1100
# Episode 13761, loss: 3.3064, total reward: 10.8500
# Episode 13762, loss: 2.7125, total reward: 10.1500
# Episode 13763, loss: 0.5970, total reward: 10.0700
# Episode 13764, loss: 1.1933, total reward: 10.4300
# Episode 13765, loss: 0.3523, total reward: 0.5200
# Episode 13766, loss: 0.6901, total reward: 10.7400
# Episode 13767, loss: 4.8361, total reward: 10.3600
# Episode 13768, loss: 1.0492, total reward: 0.4200
# Episode 13769, loss: -0.0046, total reward: 0.1600
# Episode 13770, loss: 0.8302, total reward: 10.4100
# Episode 13771, loss: 7.6907, total reward: 10.2100
# Episode 13772, loss: 6.4585, total reward: 9.9900
# Episode 13773, loss: 0.0123, total reward: 0.6300
# Episode 13774, loss: 0.0007, total reward: 10.1600
# Episode 13775, loss: 23.2090, total reward: 10.1700
# Episode 13776, loss: 0.1040, total reward: 0.7300
# Episode 13777, loss: 0.7118, total reward: 10.3500
# Episode 13778, loss: 0.6321, total reward: 0.4200
# Episode 13779, loss: 0.5445, total reward: 9.9700
# Episode 13780, loss: 0.0242, total reward: 0.2200
# Episode 13781, loss: 5.8922, total reward: 10.2500
# Episode 13782, loss: -0.0035, total reward: -0.0200
# Episode 13783, loss: 0.6322, total reward: 10.4500
# Episode 13784, loss: 9.1869, total reward: 10.2000
# Episode 13785, loss: 0.0503, total reward: 0.6300
# Episode 13786, loss: 2.9409, total reward: 10.3000
# Episode 13787, loss: 7.9612, total reward: 10.1600
# Episode 13788, loss: 0.0024, total reward: 10.1900
# Episode 13789, loss: 0.1187, total reward: 0.4200
# Episode 13790, loss: 3.1682, total reward: 10.5700
# Episode 13791, loss: 0.5483, total reward: 0.0600
# Episode 13792, loss: 0.8265, total reward: 10.4400
# Episode 13793, loss: 0.7471, total reward: 0.6300
# Episode 13794, loss: 1.4639, total reward: 10.1700
# Episode 13795, loss: 0.1179, total reward: 0.5900
# Episode 13796, loss: 0.0220, total reward: 0.6300
# Episode 13797, loss: 1.9682, total reward: 10.3700
# Episode 13798, loss: 9.6050, total reward: 10.1200
# Episode 13799, loss: 33.8299, total reward: 10.4600
# Episode 13800, loss: 2.9292, total reward: 10.1300
# Episode 13801, loss: 28.3039, total reward: 10.3500
# Episode 13802, loss: 0.8417, total reward: 10.3400
# Episode 13803, loss: 22.0223, total reward: 10.4500
# Episode 13804, loss: 0.7032, total reward: 10.2600
# Episode 13805, loss: 0.0224, total reward: 10.6700
# Episode 13806, loss: 0.4245, total reward: 10.4700
# Episode 13807, loss: 0.4029, total reward: 10.3300
# Episode 13808, loss: -0.0011, total reward: 0.4200
# Episode 13809, loss: 0.1105, total reward: 0.7300
# Episode 13810, loss: 1.8255, total reward: 10.2800
# Episode 13811, loss: 0.0296, total reward: 0.3200
# Episode 13812, loss: 28.4974, total reward: 10.0600
# Episode 13813, loss: 8.4743, total reward: 10.4500
# Episode 13814, loss: 0.3337, total reward: 10.2600
# Episode 13815, loss: -0.0409, total reward: 0.2500
# Episode 13816, loss: 24.3960, total reward: 10.4500
# Episode 13817, loss: 0.2280, total reward: 0.2200
# Episode 13818, loss: 6.8325, total reward: 10.5500
# Episode 13819, loss: 4.2427, total reward: 10.3700
# Episode 13820, loss: 0.0607, total reward: 10.1600
# Episode 13821, loss: 27.5306, total reward: 10.5000
# Episode 13822, loss: 0.6488, total reward: 10.3500
# Episode 13823, loss: 0.0072, total reward: 0.8100
# Episode 13824, loss: 6.1805, total reward: 10.3900
# Episode 13825, loss: 5.4981, total reward: 10.2400
# Episode 13826, loss: 3.6781, total reward: 10.4600
# Episode 13827, loss: 22.2217, total reward: 10.6400
# Episode 13828, loss: 27.1242, total reward: 10.5000
# Episode 13829, loss: 10.3378, total reward: 10.4500
# Episode 13830, loss: 1.2257, total reward: 10.4800
# Episode 13831, loss: 1.7323, total reward: 10.3800
# Episode 13832, loss: 0.0696, total reward: 0.6100
# Episode 13833, loss: 0.0011, total reward: 0.2200
# Episode 13834, loss: 0.0268, total reward: 0.1100
# Episode 13835, loss: -0.0086, total reward: 0.3200
# Episode 13836, loss: 0.4789, total reward: 10.5500
# Episode 13837, loss: 0.3339, total reward: 10.2700
# Episode 13838, loss: 2.3641, total reward: 10.2000
# Episode 13839, loss: 29.3748, total reward: 10.5400
# Episode 13840, loss: 29.3144, total reward: 10.3300
# Episode 13841, loss: 0.1714, total reward: 0.2200
# Episode 13842, loss: 24.4903, total reward: 10.4500
# Episode 13843, loss: 2.2272, total reward: 10.0400
# Episode 13844, loss: 0.2611, total reward: 0.9300
# Episode 13845, loss: 12.4877, total reward: 10.6500
# Episode 13846, loss: 0.7896, total reward: 10.5500
# Episode 13847, loss: 1.1038, total reward: 0.7300
# Episode 13848, loss: 11.3565, total reward: 10.4800
# Episode 13849, loss: 0.0007, total reward: 0.2200
# Episode 13850, loss: 0.1204, total reward: 0.2200
# Episode 13851, loss: 0.2265, total reward: 10.4800
# Episode 13852, loss: 2.7296, total reward: 10.6100
# Episode 13853, loss: -0.0125, total reward: 0.3200
# Episode 13854, loss: 0.8488, total reward: 10.6900
# Episode 13855, loss: -0.1035, total reward: -0.0100
# Episode 13856, loss: 1.3227, total reward: 10.1700
# Episode 13857, loss: 1.5695, total reward: 10.3800
# Episode 13858, loss: 0.2186, total reward: 10.5600
# Episode 13859, loss: 1.9812, total reward: 10.5500
# Episode 13860, loss: 3.4851, total reward: 10.5800
# Episode 13861, loss: 0.0066, total reward: 10.2600
# Episode 13862, loss: 0.7961, total reward: 10.5100
# Episode 13863, loss: 0.8726, total reward: 10.3800
# Episode 13864, loss: 5.3402, total reward: 10.2100
# Episode 13865, loss: 0.0230, total reward: 0.7300
# Episode 13866, loss: 1.8772, total reward: 10.2800
# Episode 13867, loss: 0.1561, total reward: 10.1600
# Episode 13868, loss: 31.7870, total reward: 10.5800
# Episode 13869, loss: 0.1004, total reward: 0.8300
# Episode 13870, loss: 0.0252, total reward: 10.0900
# Episode 13871, loss: 7.3213, total reward: 10.5400
# Episode 13872, loss: 0.0473, total reward: 0.5200
# Episode 13873, loss: 0.0483, total reward: 0.6300
# Episode 13874, loss: 25.4723, total reward: 10.2000
# Episode 13875, loss: 0.8898, total reward: 10.4100
# Episode 13876, loss: 16.5044, total reward: 10.2300
# Episode 13877, loss: 0.0338, total reward: 0.6100
# Episode 13878, loss: 1.4349, total reward: 10.0300
# Episode 13879, loss: 4.0165, total reward: 10.4500
# Episode 13880, loss: 1.8526, total reward: 10.3600
# Episode 13881, loss: 0.4566, total reward: 0.8300
# Episode 13882, loss: 0.5777, total reward: 0.6300
# Episode 13883, loss: 1.3589, total reward: 10.7500
# Episode 13884, loss: 6.5799, total reward: 10.5800
# Episode 13885, loss: 0.0362, total reward: 0.2200
# Episode 13886, loss: 0.3255, total reward: 10.2900
# Episode 13887, loss: 2.0025, total reward: 10.5500
# Episode 13888, loss: 0.1409, total reward: 10.0400
# Episode 13889, loss: 0.6622, total reward: 10.5900
# Episode 13890, loss: 20.2131, total reward: 10.7700
# Episode 13891, loss: 12.1166, total reward: 10.0600
# Episode 13892, loss: 2.4925, total reward: 10.4000
# Episode 13893, loss: 32.8842, total reward: 10.4400
# Episode 13894, loss: 1.1112, total reward: 10.0900
# Episode 13895, loss: 0.3022, total reward: 10.4600
# Episode 13896, loss: 0.4223, total reward: 10.0600
# Episode 13897, loss: 0.0884, total reward: 0.9300
# Episode 13898, loss: 0.7662, total reward: 10.3900
# Episode 13899, loss: 1.4339, total reward: 10.7300
# Episode 13900, loss: 0.0185, total reward: 0.2200
# Episode 13901, loss: 2.3523, total reward: 10.7000
# Episode 13902, loss: 0.0271, total reward: 10.1600
# Episode 13903, loss: 0.1106, total reward: 0.4200
# Episode 13904, loss: 0.1427, total reward: 0.3200
# Episode 13905, loss: 0.0141, total reward: 0.2200
# Episode 13906, loss: 1.1979, total reward: 10.0400
# Episode 13907, loss: 1.4731, total reward: 10.0400
# Episode 13908, loss: 3.7132, total reward: 10.5900
# Episode 13909, loss: 0.2597, total reward: 0.6300
# Episode 13910, loss: 4.6127, total reward: 10.6400
# Episode 13911, loss: 4.0877, total reward: 10.2800
# Episode 13912, loss: 0.7520, total reward: 10.3500
# Episode 13913, loss: 11.5034, total reward: 10.6500
# Episode 13914, loss: 0.3588, total reward: 10.4700
# Episode 13915, loss: 31.3506, total reward: 10.3800
# Episode 13916, loss: 0.4102, total reward: 10.5800
# Episode 13917, loss: 17.1886, total reward: 10.8400
# Episode 13918, loss: 0.0402, total reward: 0.0100
# Episode 13919, loss: 3.1823, total reward: 10.3000
# Episode 13920, loss: 0.0103, total reward: 0.1100
# Episode 13921, loss: 0.0530, total reward: 10.0600
# Episode 13922, loss: 0.0001, total reward: 0.0100
# Episode 13923, loss: 7.2255, total reward: 10.4700
# Episode 13924, loss: 6.2888, total reward: 10.5300
# Episode 13925, loss: 3.5938, total reward: 10.2400
# Episode 13926, loss: 0.0393, total reward: 0.6300
# Episode 13927, loss: 0.0065, total reward: 0.4400
# Episode 13928, loss: 0.0366, total reward: 0.6300
# Episode 13929, loss: 4.7444, total reward: 10.4400
# Episode 13930, loss: 1.8007, total reward: 10.3600
# Episode 13931, loss: 0.3185, total reward: 10.1700
# Episode 13932, loss: 0.0508, total reward: 0.1100
# Episode 13933, loss: 0.0017, total reward: 0.2200
# Episode 13934, loss: 0.4918, total reward: 10.5700
# Episode 13935, loss: 16.2012, total reward: 10.5800
# Episode 13936, loss: 0.0576, total reward: 0.7300
# Episode 13937, loss: 3.4105, total reward: 10.2900
# Episode 13938, loss: 0.1200, total reward: 0.2200
# Episode 13939, loss: 0.0484, total reward: 0.6300
# Episode 13940, loss: 0.5867, total reward: 10.3000
# Episode 13941, loss: 10.7409, total reward: 10.4500
# Episode 13942, loss: 4.4714, total reward: 10.0200
# Episode 13943, loss: 2.1618, total reward: 10.3300
# Episode 13944, loss: 3.0570, total reward: 10.1500
# Episode 13945, loss: 0.3621, total reward: 0.2700
# Episode 13946, loss: 0.1164, total reward: 0.3200
# Episode 13947, loss: -0.0031, total reward: 0.2200
# Episode 13948, loss: 0.5662, total reward: 0.4700
# Episode 13949, loss: 2.1136, total reward: 10.3200
# Episode 13950, loss: 10.9368, total reward: 10.8600
# Episode 13951, loss: 0.3781, total reward: 0.4200
# Episode 13952, loss: 1.2791, total reward: 10.1000
# Episode 13953, loss: 10.9375, total reward: 10.2000
# Episode 13954, loss: 0.9653, total reward: 10.0100
# Episode 13955, loss: -0.0784, total reward: 0.0100
# Episode 13956, loss: 1.1412, total reward: 10.4800
# Episode 13957, loss: 6.8283, total reward: 10.1000
# Episode 13958, loss: 0.8395, total reward: 10.4600
# Episode 13959, loss: 18.5732, total reward: 10.3700
# Episode 13960, loss: 38.4727, total reward: 10.6600
# Episode 13961, loss: 0.5623, total reward: 10.8800
# Episode 13962, loss: 0.0268, total reward: 0.3200
# Episode 13963, loss: 0.6945, total reward: 10.1300
# Episode 13964, loss: 0.0135, total reward: 0.6300
# Episode 13965, loss: 1.3203, total reward: 10.2200
# Episode 13966, loss: 43.1509, total reward: 10.1900
# Episode 13967, loss: 12.8724, total reward: 10.1500
# Episode 13968, loss: 0.0000, total reward: 9.9900
# Episode 13969, loss: 19.5241, total reward: 10.5300
